# %%
# %%
import tensorcircuit as tc
import pennylane as qml
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split,Subset
import random
import os
import time
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F
import numpy as np
import csv
import tensorflow as tf


data_path = 'E:\\Test\\VsCode_Test\\Jupyter notebook\\xLw\\data'

val_num = 200
data_num =  1200           # 需要划分的数据集大小
epochs = 20                 # 迭代轮次数
batch_size = 32

K = tc.set_backend("tensorflow")
# 归一化处理
def trans(x):
    x = np.array(x)
    x = x/255.0
    # print(x.shape)    
    return torch.from_numpy(x).float()  # 将 NumPy 数组 x 转换为 PyTorch 张量

transform = transforms.Compose([
    transforms.Resize((14, 14)),                # 将图片缩小为 14x14
    transforms.Lambda(lambda x:trans(x))
])

# 加载MNIST数据集 28X28X1   10类别   
trainset = torchvision.datasets.FashionMNIST(root=data_path, train=True,
                                        download=False, transform=transform)
testset = torchvision.datasets.FashionMNIST(root=data_path, train=False,
                                        download=False, transform=transform)

# 随机抽取训练集 data_num 张图片作为子集
subset_indices = random.sample(range(len(trainset)), k=data_num)
train_subset = Subset(trainset, subset_indices)

# 随机抽取测试集 data_num 张图片作为子集
subset_val = random.sample(range(len(testset)), k=val_num)
val_subset = Subset(testset, subset_val)

# 加载测试集
trainloader = torch.utils.data.DataLoader(train_subset, batch_size=batch_size,  # type: ignore
                                          shuffle=True)
testloader = torch.utils.data.DataLoader(val_subset, batch_size=batch_size,    # type: ignore
                                         shuffle=False)

# %%
n = 4
nlayers = 1


# 我们定义量子函数，
# 注意这个函数是在 tensorflow 上运行的
def qpred(x, weights):
    c = tc.Circuit(n)
    for i in range(n):
        c.h(i)
        c.ry(i, theta=x[i]*weights[i])
    for j in range(nlayers):
        for i in range(n - 1):
            c.cnot(i, i + 1)
    return [K.real(c.expectation([tc.gates.z(), [i]])) for i in range(n)]

# %%
qpred_vmap = K.vmap(qpred, vectorized_argnums=0)        # `qpred_vmap` 是一个具有向量化能力的 TensorFlow 函数
qpred_batch = tc.interfaces.torch_interface(qpred_vmap, jit=True) # 我们进一步将函数包装为 PyTorch 函数

# %%
class QuantumNetV2(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.q_weights = torch.nn.Parameter(torch.randn([n]))
        self.stride = 1

    def forward(self, inputs):
        kernel_size = 2
        
        # 使用转置卷积进行上采样
        padding_size = kernel_size - 1                  # 1 先进行填充
        padd_img = nn.functional.pad(inputs,(padding_size,padding_size,padding_size,padding_size),mode='constant',value=0)
        # padding_img.size()=16
        bs, ch , h , w = padd_img.size()                #    h=16

        h_out = self.stride*(h-1)+kernel_size           #   （17-1）+ 2 = 18
        w_out = self.stride*(w-1)+kernel_size           #   （17-1）+ 2 = 18
        out = torch.zeros((bs,4, h_out, w_out))
        for b in range(bs):
                for j in range(0, h_out-padding_size-1, self.stride):
                    for k in range(0, w_out-padding_size-1, self.stride):
                        # print(f'padd_img[b, 0, j, k]={padd_img[b, 0, j, k].shape}')
                        t1 = padd_img[b, 0, j, k]        
                        t2 = padd_img[b, 0, j, k + 1]
                        t3 = padd_img[b, 0, j + 1, k]    
                        t4 = padd_img[b, 0, j + 1, k + 1]

                        temp = torch.Tensor([t1,t2,t3,t4]) # 
                        temp = temp.view(1,4)

                        # temp = torch.unsqueeze(temp, 0)      
                        q_results = qpred_batch(temp, self.q_weights)     
                        for c in range(4):
                            out[b, c,j // kernel_size, k // kernel_size] = q_results[c]
        return out

# %%
# 经典CNNmodel 可进行修改
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
            
        # Quantum layer 1
        self.conv1 = QuantumNetV2()
        self.relu1 = nn.ReLU()
        self.batch1 = nn.BatchNorm2d(4)  # 4
                
        # Fully-Connected layer 2
        self.fc2 = nn.Linear(1156,10)
                
    def forward(self, x):

        # qconv layer 1
        out = self.conv1(x)                 
        out = self.relu1(out)   
        out = self.batch1(out)
        
        #Flatten拉平操作
        out = out.view(out.size(0),-1)      # print(f'-----拉平后的维度是--{out.shape}') #  torch.Size([64, 576])
        
        #FC 第二层
        out = self.fc2(out)
        return F.log_softmax(out,dim = 1)

# %%
model = CNNModel()
loss_fun = nn.CrossEntropyLoss()
opt = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
# 准确率计算
def accuracy(output,labels):
    prediction = torch.max(output.data,1)[1]
    rights = prediction.eq(labels.data.view_as(prediction)).sum()
    return rights,len(labels)

# 绘制训练结果
def draw_result(accs,losses,title):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14, 6))   # subplots创建1行 2列的子图
    
    ax1.plot(losses) 
    ax1.set_title(title+" Loss")
    ax1.set_xlabel("Steps")
    ax1.set_ylabel("Loss")
    
    ax2.plot(accs)
    ax2.set_title(title+" Accuracy")
    ax2.set_xlabel("Steps")
    ax2.set_ylabel("Accuracy")

# %%
def train(epochs,model,loss_fun,opt,train_loader,test_loader):
    train_accuracy = []             # 训练集准确率
    train_loss = []

    val_accuracy = []               # 验证集准确率
    val_loss = []
    for epoch in range(epochs):
                ### 训练模块
        train_total_accuracy = 0    # 训练集每epoch（18个batch的和）的准确率
        train_total_loss = 0
        for batch_idx,(data,labels) in enumerate(train_loader):
            t2 = time.time()
            data = data.view(data.shape[0],1, data.shape[1], data.shape[2])
            
            model.train()					    # 1 模型训练       
            output = model(data)			    # 2 模型输出
            # print(f'output.shape is {output.shape}')    # output.shape is torch.Size([64, 4, 17, 17])
            # print(f'labels.shape is {labels.shape}')    # labels.shape is torch.Size([64])
            loss = loss_fun(output,labels)	    # 3 计算损失

            opt.zero_grad()					    # 4 梯度清零
            loss.backward() 				    # 5 开始反向传播
            opt.step()                          # 6 梯度更新
            
            # 计算准确率
            accuracy_count, total_count = accuracy(output,labels)
            accuracy_rate = accuracy_count / total_count  # 计算准确率（预测正确的样本数除以总样本数）

            train_total_accuracy += accuracy_count
            train_total_loss +=loss.item()

            batch_time = time.time()-t2
            print(f'Epoch:{epoch}---batch({batch_idx})训练集---ACC:{accuracy_rate:.2%}---LOSS:{loss.item():.3f}---time:{batch_time:.2f}')        
        
        train_total_loss /= batch_idx+1
        train_accuracy.append(train_total_accuracy/len(train_subset))   # 保存1轮的数据 len(train_accuracy)
        train_loss.append(train_total_loss)
### 验证模块
        total_acc = 0
        total_test_loss = 0
        model.eval()
        with torch.no_grad():# 进行评测的时候网络不更新梯度
            for step,(data,target) in enumerate(test_loader):
                data = data.view(data.shape[0],1, data.shape[1], data.shape[2])            # 调整维度一致
                outputs = model(data)
                losses = loss_fun(outputs,target)                               # 计算损失

                accuracy_count, total_count = accuracy(outputs,target)          # 计算准确率
                accuracy_rate = accuracy_count / total_count                    # 计算准确率（预测正确的样本数除以总样本数）

                total_acc += accuracy_count
                total_test_loss+=losses.item()

        total_test_loss /= step + 1
        val_accuracy.append((total_acc/len(val_subset)))
        val_loss.append(total_test_loss)
        print(f'第{epoch}轮测试集准确率：{total_acc/len(val_subset):.2%}....测试集Loss:{total_test_loss}')
    
    ### 画出训练结果图 ##############
    draw_result(train_accuracy,train_loss,"Train")
    draw_result(val_accuracy,val_loss,"Val")
    
    ####  训练的结果写入文件   ##############
    with open(str(random.randint(100,999))+"_train.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Train_loss','Train_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, train_loss[i], train_accuracy[i].numpy()])
    
    #### 测试的结果写入文件  ##############
    with open(str(random.randint(1000,9999))+"_val.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Val_loss','Val_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, val_loss[i], val_accuracy[i].numpy()])

    ### 保存训练的结果
    # Loss0 = torch.tensor(save_train_loss)
    # torch.save(Loss0,'E:\\Test\\VsCode_Test\\Python\\xlw\\test1\\lw2\\epoch_{}'.format(epochs))
    return model, train_accuracy,train_loss


model, train_accuracy,train_loss = train(epochs,model,loss_fun,opt,trainloader,testloader)
# Out:
# Epoch:0---batch(0)训练集---ACC:6.25%---LOSS:2.375---time:18.08
# Epoch:0---batch(1)训练集---ACC:12.50%---LOSS:2.465---time:15.15
# Epoch:0---batch(2)训练集---ACC:25.00%---LOSS:2.157---time:13.42
# Epoch:0---batch(3)训练集---ACC:25.00%---LOSS:1.922---time:11.11
# Epoch:0---batch(4)训练集---ACC:34.38%---LOSS:1.823---time:12.14
# Epoch:0---batch(5)训练集---ACC:59.38%---LOSS:1.536---time:12.06
# Epoch:0---batch(6)训练集---ACC:31.25%---LOSS:1.698---time:11.58
# Epoch:0---batch(7)训练集---ACC:50.00%---LOSS:1.375---time:11.28
# Epoch:0---batch(8)训练集---ACC:71.88%---LOSS:1.127---time:13.86
# Epoch:0---batch(9)训练集---ACC:34.38%---LOSS:1.535---time:11.70
# Epoch:0---batch(10)训练集---ACC:65.62%---LOSS:1.237---time:12.75
# Epoch:0---batch(11)训练集---ACC:46.88%---LOSS:1.252---time:12.51
# Epoch:0---batch(12)训练集---ACC:53.12%---LOSS:1.167---time:13.77
# Epoch:0---batch(13)训练集---ACC:53.12%---LOSS:1.254---time:12.11
# Epoch:0---batch(14)训练集---ACC:71.88%---LOSS:1.029---time:13.30
# Epoch:0---batch(15)训练集---ACC:56.25%---LOSS:1.213---time:12.08
# Epoch:0---batch(16)训练集---ACC:62.50%---LOSS:1.216---time:11.51
# Epoch:0---batch(17)训练集---ACC:50.00%---LOSS:1.407---time:12.61
# Epoch:0---batch(18)训练集---ACC:62.50%---LOSS:1.136---time:11.31
# Epoch:0---batch(19)训练集---ACC:62.50%---LOSS:1.011---time:13.51
# Epoch:0---batch(20)训练集---ACC:78.12%---LOSS:0.692---time:13.56
# Epoch:0---batch(21)训练集---ACC:50.00%---LOSS:1.107---time:14.28
# Epoch:0---batch(22)训练集---ACC:71.88%---LOSS:0.598---time:16.26
# Epoch:0---batch(23)训练集---ACC:68.75%---LOSS:0.713---time:16.21
# Epoch:0---batch(24)训练集---ACC:68.75%---LOSS:0.909---time:12.45
# Epoch:0---batch(25)训练集---ACC:53.12%---LOSS:0.912---time:11.93
# Epoch:0---batch(26)训练集---ACC:68.75%---LOSS:0.748---time:11.92
# Epoch:0---batch(27)训练集---ACC:68.75%---LOSS:0.797---time:12.39
# Epoch:0---batch(28)训练集---ACC:71.88%---LOSS:0.870---time:14.37
# Epoch:0---batch(29)训练集---ACC:62.50%---LOSS:0.970---time:12.63
# Epoch:0---batch(30)训练集---ACC:56.25%---LOSS:1.253---time:17.04
# Epoch:0---batch(31)训练集---ACC:56.25%---LOSS:1.396---time:13.00
# Epoch:0---batch(32)训练集---ACC:65.62%---LOSS:1.068---time:12.94
# Epoch:0---batch(33)训练集---ACC:56.25%---LOSS:0.849---time:12.29
# Epoch:0---batch(34)训练集---ACC:65.62%---LOSS:0.928---time:12.01
# Epoch:0---batch(35)训练集---ACC:78.12%---LOSS:0.641---time:11.86
# Epoch:0---batch(36)训练集---ACC:75.00%---LOSS:0.769---time:12.33
# Epoch:0---batch(37)训练集---ACC:37.50%---LOSS:1.328---time:6.07
# 第0轮测试集准确率：62.50%....测试集Loss:1.2072044014930725
# Epoch:1---batch(0)训练集---ACC:78.12%---LOSS:0.636---time:11.99
# Epoch:1---batch(1)训练集---ACC:59.38%---LOSS:0.860---time:13.79
# Epoch:1---batch(2)训练集---ACC:59.38%---LOSS:0.871---time:12.76
# Epoch:1---batch(3)训练集---ACC:53.12%---LOSS:0.985---time:12.45
# Epoch:1---batch(4)训练集---ACC:84.38%---LOSS:0.439---time:11.90
# Epoch:1---batch(5)训练集---ACC:78.12%---LOSS:0.610---time:12.35
# Epoch:1---batch(6)训练集---ACC:59.38%---LOSS:0.970---time:11.21
# Epoch:1---batch(7)训练集---ACC:56.25%---LOSS:1.026---time:13.06
# Epoch:1---batch(8)训练集---ACC:75.00%---LOSS:0.720---time:11.73
# Epoch:1---batch(9)训练集---ACC:75.00%---LOSS:0.621---time:12.31
# Epoch:1---batch(10)训练集---ACC:71.88%---LOSS:0.803---time:12.31
# Epoch:1---batch(11)训练集---ACC:71.88%---LOSS:0.803---time:12.05
# Epoch:1---batch(12)训练集---ACC:71.88%---LOSS:0.799---time:14.51
# Epoch:1---batch(13)训练集---ACC:71.88%---LOSS:0.785---time:13.97
# Epoch:1---batch(14)训练集---ACC:81.25%---LOSS:0.553---time:18.28
# Epoch:1---batch(15)训练集---ACC:59.38%---LOSS:0.866---time:15.18
# Epoch:1---batch(16)训练集---ACC:84.38%---LOSS:0.462---time:14.41
# Epoch:1---batch(17)训练集---ACC:78.12%---LOSS:0.893---time:13.77
# Epoch:1---batch(18)训练集---ACC:87.50%---LOSS:0.806---time:13.19
# Epoch:1---batch(19)训练集---ACC:46.88%---LOSS:1.504---time:13.26
# Epoch:1---batch(20)训练集---ACC:75.00%---LOSS:0.851---time:21.56
# Epoch:1---batch(21)训练集---ACC:81.25%---LOSS:0.638---time:13.26
# Epoch:1---batch(22)训练集---ACC:71.88%---LOSS:0.727---time:15.54
# Epoch:1---batch(23)训练集---ACC:62.50%---LOSS:0.946---time:23.38
# Epoch:1---batch(24)训练集---ACC:84.38%---LOSS:0.476---time:24.15
# Epoch:1---batch(25)训练集---ACC:71.88%---LOSS:0.827---time:20.28
# Epoch:1---batch(26)训练集---ACC:59.38%---LOSS:0.838---time:14.85
# Epoch:1---batch(27)训练集---ACC:53.12%---LOSS:1.065---time:14.97
# Epoch:1---batch(28)训练集---ACC:62.50%---LOSS:0.796---time:18.49
# Epoch:1---batch(29)训练集---ACC:75.00%---LOSS:0.984---time:16.97
# Epoch:1---batch(30)训练集---ACC:71.88%---LOSS:0.951---time:17.40
# Epoch:1---batch(31)训练集---ACC:87.50%---LOSS:0.748---time:15.69
# Epoch:1---batch(32)训练集---ACC:65.62%---LOSS:0.844---time:14.35
# Epoch:1---batch(33)训练集---ACC:87.50%---LOSS:0.462---time:14.39
# Epoch:1---batch(34)训练集---ACC:75.00%---LOSS:0.721---time:14.19
# Epoch:1---batch(35)训练集---ACC:84.38%---LOSS:0.513---time:15.23
# Epoch:1---batch(36)训练集---ACC:65.62%---LOSS:0.807---time:15.16
# Epoch:1---batch(37)训练集---ACC:81.25%---LOSS:0.512---time:7.06
# 第1轮测试集准确率：76.00%....测试集Loss:0.8697771940912519
# Epoch:2---batch(0)训练集---ACC:78.12%---LOSS:0.764---time:14.67
# Epoch:2---batch(1)训练集---ACC:84.38%---LOSS:0.506---time:13.30
# Epoch:2---batch(2)训练集---ACC:90.62%---LOSS:0.484---time:13.81
# Epoch:2---batch(3)训练集---ACC:81.25%---LOSS:0.514---time:20.48
# Epoch:2---batch(4)训练集---ACC:78.12%---LOSS:0.764---time:15.37
# Epoch:2---batch(5)训练集---ACC:75.00%---LOSS:0.715---time:12.18
# Epoch:2---batch(6)训练集---ACC:62.50%---LOSS:1.053---time:10.98
# Epoch:2---batch(7)训练集---ACC:81.25%---LOSS:0.484---time:11.24
# Epoch:2---batch(8)训练集---ACC:68.75%---LOSS:0.638---time:12.41
# Epoch:2---batch(9)训练集---ACC:84.38%---LOSS:0.515---time:12.99
# Epoch:2---batch(10)训练集---ACC:68.75%---LOSS:0.766---time:15.13
# Epoch:2---batch(11)训练集---ACC:75.00%---LOSS:0.653---time:11.63
# Epoch:2---batch(12)训练集---ACC:81.25%---LOSS:0.497---time:12.34
# Epoch:2---batch(13)训练集---ACC:75.00%---LOSS:0.717---time:11.72
# Epoch:2---batch(14)训练集---ACC:71.88%---LOSS:0.692---time:11.27
# Epoch:2---batch(15)训练集---ACC:87.50%---LOSS:0.369---time:10.99
# Epoch:2---batch(16)训练集---ACC:75.00%---LOSS:0.526---time:11.26
# Epoch:2---batch(17)训练集---ACC:75.00%---LOSS:0.673---time:11.69
# Epoch:2---batch(18)训练集---ACC:68.75%---LOSS:0.775---time:10.91
# Epoch:2---batch(19)训练集---ACC:81.25%---LOSS:0.594---time:10.84
# Epoch:2---batch(20)训练集---ACC:62.50%---LOSS:0.849---time:11.26
# Epoch:2---batch(21)训练集---ACC:71.88%---LOSS:0.645---time:12.11
# Epoch:2---batch(22)训练集---ACC:71.88%---LOSS:0.664---time:11.75
# Epoch:2---batch(23)训练集---ACC:78.12%---LOSS:0.872---time:12.28
# Epoch:2---batch(24)训练集---ACC:62.50%---LOSS:0.953---time:11.56
# Epoch:2---batch(25)训练集---ACC:75.00%---LOSS:0.581---time:15.19
# Epoch:2---batch(26)训练集---ACC:78.12%---LOSS:0.509---time:14.15
# Epoch:2---batch(27)训练集---ACC:68.75%---LOSS:0.730---time:13.22
# Epoch:2---batch(28)训练集---ACC:84.38%---LOSS:0.553---time:13.25
# Epoch:2---batch(29)训练集---ACC:71.88%---LOSS:0.562---time:13.23
# Epoch:2---batch(30)训练集---ACC:78.12%---LOSS:0.650---time:12.97
# Epoch:2---batch(31)训练集---ACC:75.00%---LOSS:0.589---time:13.20
# Epoch:2---batch(32)训练集---ACC:78.12%---LOSS:0.785---time:13.02
# Epoch:2---batch(33)训练集---ACC:71.88%---LOSS:0.748---time:13.59
# Epoch:2---batch(34)训练集---ACC:71.88%---LOSS:0.615---time:13.26
# Epoch:2---batch(35)训练集---ACC:68.75%---LOSS:0.792---time:13.32
# Epoch:2---batch(36)训练集---ACC:75.00%---LOSS:0.723---time:13.17
# Epoch:2---batch(37)训练集---ACC:75.00%---LOSS:0.677---time:6.87
# 第2轮测试集准确率：76.00%....测试集Loss:0.7652603132384164
# Epoch:3---batch(0)训练集---ACC:78.12%---LOSS:0.413---time:13.68
# Epoch:3---batch(1)训练集---ACC:84.38%---LOSS:0.576---time:13.22
# Epoch:3---batch(2)训练集---ACC:65.62%---LOSS:0.720---time:13.60
# Epoch:3---batch(3)训练集---ACC:81.25%---LOSS:0.560---time:13.09
# Epoch:3---batch(4)训练集---ACC:62.50%---LOSS:0.716---time:13.48
# Epoch:3---batch(5)训练集---ACC:87.50%---LOSS:0.393---time:13.22
# Epoch:3---batch(6)训练集---ACC:65.62%---LOSS:0.722---time:13.35
# Epoch:3---batch(7)训练集---ACC:78.12%---LOSS:0.476---time:13.23
# Epoch:3---batch(8)训练集---ACC:78.12%---LOSS:0.548---time:13.18
# Epoch:3---batch(9)训练集---ACC:78.12%---LOSS:0.551---time:13.34
# Epoch:3---batch(10)训练集---ACC:81.25%---LOSS:0.526---time:13.07
# Epoch:3---batch(11)训练集---ACC:81.25%---LOSS:0.536---time:13.64
# Epoch:3---batch(12)训练集---ACC:68.75%---LOSS:0.762---time:12.95
# Epoch:3---batch(13)训练集---ACC:87.50%---LOSS:0.499---time:13.23
# Epoch:3---batch(14)训练集---ACC:90.62%---LOSS:0.350---time:13.11
# Epoch:3---batch(15)训练集---ACC:75.00%---LOSS:0.738---time:13.52
# Epoch:3---batch(16)训练集---ACC:81.25%---LOSS:0.562---time:13.13
# Epoch:3---batch(17)训练集---ACC:68.75%---LOSS:0.715---time:13.59
# Epoch:3---batch(18)训练集---ACC:81.25%---LOSS:0.409---time:13.44
# Epoch:3---batch(19)训练集---ACC:87.50%---LOSS:0.649---time:13.36
# Epoch:3---batch(20)训练集---ACC:78.12%---LOSS:0.672---time:13.18
# Epoch:3---batch(21)训练集---ACC:90.62%---LOSS:0.516---time:13.60
# Epoch:3---batch(22)训练集---ACC:68.75%---LOSS:0.828---time:15.35
# Epoch:3---batch(23)训练集---ACC:71.88%---LOSS:0.906---time:15.68
# Epoch:3---batch(24)训练集---ACC:78.12%---LOSS:0.609---time:15.29
# Epoch:3---batch(25)训练集---ACC:87.50%---LOSS:0.489---time:15.98
# Epoch:3---batch(26)训练集---ACC:71.88%---LOSS:0.568---time:13.60
# Epoch:3---batch(27)训练集---ACC:75.00%---LOSS:0.677---time:16.68
# Epoch:3---batch(28)训练集---ACC:75.00%---LOSS:0.627---time:15.06
# Epoch:3---batch(29)训练集---ACC:81.25%---LOSS:0.589---time:16.89
# Epoch:3---batch(30)训练集---ACC:59.38%---LOSS:1.155---time:15.01
# Epoch:3---batch(31)训练集---ACC:62.50%---LOSS:1.039---time:13.69
# Epoch:3---batch(32)训练集---ACC:71.88%---LOSS:0.686---time:13.02
# Epoch:3---batch(33)训练集---ACC:90.62%---LOSS:0.346---time:16.17
# Epoch:3---batch(34)训练集---ACC:87.50%---LOSS:0.269---time:17.54
# Epoch:3---batch(35)训练集---ACC:87.50%---LOSS:0.592---time:14.37
# Epoch:3---batch(36)训练集---ACC:78.12%---LOSS:0.589---time:14.22
# Epoch:3---batch(37)训练集---ACC:87.50%---LOSS:0.399---time:6.25
# 第3轮测试集准确率：74.50%....测试集Loss:0.9506538765771049
# Epoch:4---batch(0)训练集---ACC:87.50%---LOSS:0.592---time:10.80
# Epoch:4---batch(1)训练集---ACC:87.50%---LOSS:0.416---time:11.94
# Epoch:4---batch(2)训练集---ACC:78.12%---LOSS:0.798---time:10.54
# Epoch:4---batch(3)训练集---ACC:78.12%---LOSS:0.668---time:10.66
# Epoch:4---batch(4)训练集---ACC:78.12%---LOSS:0.756---time:10.39
# Epoch:4---batch(5)训练集---ACC:68.75%---LOSS:0.751---time:10.02
# Epoch:4---batch(6)训练集---ACC:71.88%---LOSS:0.669---time:10.72
# Epoch:4---batch(7)训练集---ACC:78.12%---LOSS:0.576---time:11.33
# Epoch:4---batch(8)训练集---ACC:71.88%---LOSS:0.635---time:10.92
# Epoch:4---batch(9)训练集---ACC:71.88%---LOSS:0.711---time:11.43
# Epoch:4---batch(10)训练集---ACC:81.25%---LOSS:0.492---time:10.36
# Epoch:4---batch(11)训练集---ACC:68.75%---LOSS:0.758---time:10.77
# Epoch:4---batch(12)训练集---ACC:75.00%---LOSS:0.775---time:10.05
# Epoch:4---batch(13)训练集---ACC:71.88%---LOSS:0.637---time:10.32
# Epoch:4---batch(14)训练集---ACC:71.88%---LOSS:0.592---time:10.38
# Epoch:4---batch(15)训练集---ACC:71.88%---LOSS:0.714---time:10.89
# Epoch:4---batch(16)训练集---ACC:81.25%---LOSS:0.502---time:10.35
# Epoch:4---batch(17)训练集---ACC:87.50%---LOSS:0.548---time:12.19
# Epoch:4---batch(18)训练集---ACC:84.38%---LOSS:0.419---time:12.06
# Epoch:4---batch(19)训练集---ACC:71.88%---LOSS:0.612---time:11.72
# Epoch:4---batch(20)训练集---ACC:87.50%---LOSS:0.451---time:11.76
# Epoch:4---batch(21)训练集---ACC:71.88%---LOSS:0.912---time:11.91
# Epoch:4---batch(22)训练集---ACC:65.62%---LOSS:1.188---time:11.35
# Epoch:4---batch(23)训练集---ACC:90.62%---LOSS:0.329---time:10.95
# Epoch:4---batch(24)训练集---ACC:68.75%---LOSS:0.650---time:11.43
# Epoch:4---batch(25)训练集---ACC:87.50%---LOSS:0.579---time:15.78
# Epoch:4---batch(26)训练集---ACC:68.75%---LOSS:0.702---time:12.59
# Epoch:4---batch(27)训练集---ACC:78.12%---LOSS:0.501---time:10.95
# Epoch:4---batch(28)训练集---ACC:68.75%---LOSS:0.624---time:12.74
# Epoch:4---batch(29)训练集---ACC:75.00%---LOSS:0.629---time:13.77
# Epoch:4---batch(30)训练集---ACC:75.00%---LOSS:0.521---time:13.14
# Epoch:4---batch(31)训练集---ACC:75.00%---LOSS:0.789---time:12.58
# Epoch:4---batch(32)训练集---ACC:75.00%---LOSS:0.683---time:13.97
# Epoch:4---batch(33)训练集---ACC:78.12%---LOSS:0.678---time:12.24
# Epoch:4---batch(34)训练集---ACC:84.38%---LOSS:0.484---time:12.20
# Epoch:4---batch(35)训练集---ACC:71.88%---LOSS:0.634---time:12.66
# Epoch:4---batch(36)训练集---ACC:71.88%---LOSS:0.704---time:12.10
# Epoch:4---batch(37)训练集---ACC:81.25%---LOSS:0.603---time:5.82
# 第4轮测试集准确率：72.00%....测试集Loss:0.8831675137792315
# Epoch:5---batch(0)训练集---ACC:75.00%---LOSS:0.550---time:10.57
# Epoch:5---batch(1)训练集---ACC:87.50%---LOSS:0.354---time:11.87
# Epoch:5---batch(2)训练集---ACC:87.50%---LOSS:0.437---time:11.43
# Epoch:5---batch(3)训练集---ACC:78.12%---LOSS:0.541---time:10.94
# Epoch:5---batch(4)训练集---ACC:84.38%---LOSS:0.456---time:10.40
# Epoch:5---batch(5)训练集---ACC:75.00%---LOSS:0.616---time:10.36
# Epoch:5---batch(6)训练集---ACC:78.12%---LOSS:0.573---time:10.93
# Epoch:5---batch(7)训练集---ACC:87.50%---LOSS:0.404---time:10.64
# Epoch:5---batch(8)训练集---ACC:78.12%---LOSS:0.671---time:10.81
# Epoch:5---batch(9)训练集---ACC:78.12%---LOSS:0.585---time:10.51
# Epoch:5---batch(10)训练集---ACC:81.25%---LOSS:0.628---time:11.04
# Epoch:5---batch(11)训练集---ACC:81.25%---LOSS:0.506---time:10.65
# Epoch:5---batch(12)训练集---ACC:68.75%---LOSS:0.674---time:10.93
# Epoch:5---batch(13)训练集---ACC:81.25%---LOSS:0.557---time:10.68
# Epoch:5---batch(14)训练集---ACC:90.62%---LOSS:0.317---time:11.22
# Epoch:5---batch(15)训练集---ACC:81.25%---LOSS:0.613---time:11.02
# Epoch:5---batch(16)训练集---ACC:84.38%---LOSS:0.399---time:11.22
# Epoch:5---batch(17)训练集---ACC:87.50%---LOSS:0.514---time:11.53
# Epoch:5---batch(18)训练集---ACC:75.00%---LOSS:0.723---time:11.37
# Epoch:5---batch(19)训练集---ACC:81.25%---LOSS:0.616---time:10.24
# Epoch:5---batch(20)训练集---ACC:62.50%---LOSS:0.960---time:10.93
# Epoch:5---batch(21)训练集---ACC:90.62%---LOSS:0.536---time:10.79
# Epoch:5---batch(22)训练集---ACC:84.38%---LOSS:0.536---time:12.13
# Epoch:5---batch(23)训练集---ACC:62.50%---LOSS:0.875---time:11.52
# Epoch:5---batch(24)训练集---ACC:81.25%---LOSS:0.656---time:11.09
# Epoch:5---batch(25)训练集---ACC:78.12%---LOSS:0.612---time:10.74
# Epoch:5---batch(26)训练集---ACC:62.50%---LOSS:0.872---time:11.11
# Epoch:5---batch(27)训练集---ACC:81.25%---LOSS:0.528---time:11.30
# Epoch:5---batch(28)训练集---ACC:71.88%---LOSS:0.723---time:11.23
# Epoch:5---batch(29)训练集---ACC:56.25%---LOSS:0.938---time:11.31
# Epoch:5---batch(30)训练集---ACC:81.25%---LOSS:0.469---time:11.18
# Epoch:5---batch(31)训练集---ACC:81.25%---LOSS:0.540---time:11.27
# Epoch:5---batch(32)训练集---ACC:71.88%---LOSS:0.614---time:10.77
# Epoch:5---batch(33)训练集---ACC:84.38%---LOSS:0.679---time:11.16
# Epoch:5---batch(34)训练集---ACC:87.50%---LOSS:0.449---time:11.32
# Epoch:5---batch(35)训练集---ACC:65.62%---LOSS:0.804---time:10.87
# Epoch:5---batch(36)训练集---ACC:65.62%---LOSS:0.650---time:11.44
# Epoch:5---batch(37)训练集---ACC:75.00%---LOSS:0.555---time:5.41
# 第5轮测试集准确率：77.50%....测试集Loss:0.7444882094860077
# Epoch:6---batch(0)训练集---ACC:81.25%---LOSS:0.388---time:11.21
# Epoch:6---batch(1)训练集---ACC:81.25%---LOSS:0.530---time:11.59
# Epoch:6---batch(2)训练集---ACC:75.00%---LOSS:0.511---time:12.09
# Epoch:6---batch(3)训练集---ACC:84.38%---LOSS:0.516---time:11.65
# Epoch:6---batch(4)训练集---ACC:71.88%---LOSS:0.604---time:11.07
# Epoch:6---batch(5)训练集---ACC:68.75%---LOSS:0.731---time:10.43
# Epoch:6---batch(6)训练集---ACC:78.12%---LOSS:0.452---time:10.49
# Epoch:6---batch(7)训练集---ACC:84.38%---LOSS:0.697---time:10.57
# Epoch:6---batch(8)训练集---ACC:81.25%---LOSS:0.414---time:11.31
# Epoch:6---batch(9)训练集---ACC:84.38%---LOSS:0.416---time:11.09
# Epoch:6---batch(10)训练集---ACC:84.38%---LOSS:0.469---time:11.37
# Epoch:6---batch(11)训练集---ACC:78.12%---LOSS:0.837---time:11.53
# Epoch:6---batch(12)训练集---ACC:93.75%---LOSS:0.242---time:11.22
# Epoch:6---batch(13)训练集---ACC:84.38%---LOSS:0.389---time:10.58
# Epoch:6---batch(14)训练集---ACC:78.12%---LOSS:0.562---time:10.42
# Epoch:6---batch(15)训练集---ACC:68.75%---LOSS:0.880---time:10.83
# Epoch:6---batch(16)训练集---ACC:75.00%---LOSS:0.718---time:10.89
# Epoch:6---batch(17)训练集---ACC:71.88%---LOSS:0.894---time:10.75
# Epoch:6---batch(18)训练集---ACC:71.88%---LOSS:0.670---time:11.01
# Epoch:6---batch(19)训练集---ACC:75.00%---LOSS:0.508---time:10.94
# Epoch:6---batch(20)训练集---ACC:75.00%---LOSS:0.493---time:10.56
# Epoch:6---batch(21)训练集---ACC:81.25%---LOSS:0.404---time:12.06
# Epoch:6---batch(22)训练集---ACC:81.25%---LOSS:0.657---time:11.15
# Epoch:6---batch(23)训练集---ACC:71.88%---LOSS:0.544---time:10.62
# Epoch:6---batch(24)训练集---ACC:78.12%---LOSS:0.452---time:10.76
# Epoch:6---batch(25)训练集---ACC:78.12%---LOSS:0.595---time:11.13
# Epoch:6---batch(26)训练集---ACC:78.12%---LOSS:0.564---time:11.16
# Epoch:6---batch(27)训练集---ACC:78.12%---LOSS:0.658---time:11.05
# Epoch:6---batch(28)训练集---ACC:81.25%---LOSS:0.586---time:11.09
# Epoch:6---batch(29)训练集---ACC:81.25%---LOSS:0.658---time:10.97
# Epoch:6---batch(30)训练集---ACC:75.00%---LOSS:0.565---time:10.58
# Epoch:6---batch(31)训练集---ACC:71.88%---LOSS:0.862---time:10.55
# Epoch:6---batch(32)训练集---ACC:87.50%---LOSS:0.509---time:10.98
# Epoch:6---batch(33)训练集---ACC:71.88%---LOSS:0.761---time:11.15
# Epoch:6---batch(34)训练集---ACC:84.38%---LOSS:0.512---time:11.76
# Epoch:6---batch(35)训练集---ACC:81.25%---LOSS:0.442---time:10.66
# Epoch:6---batch(36)训练集---ACC:68.75%---LOSS:0.745---time:10.71
# Epoch:6---batch(37)训练集---ACC:75.00%---LOSS:0.588---time:5.34
# 第6轮测试集准确率：72.00%....测试集Loss:0.8744477459362575
# Epoch:7---batch(0)训练集---ACC:78.12%---LOSS:0.893---time:10.50
# Epoch:7---batch(1)训练集---ACC:75.00%---LOSS:0.683---time:10.51
# Epoch:7---batch(2)训练集---ACC:75.00%---LOSS:0.621---time:11.24
# Epoch:7---batch(3)训练集---ACC:65.62%---LOSS:0.920---time:10.90
# Epoch:7---batch(4)训练集---ACC:78.12%---LOSS:0.612---time:10.85
# Epoch:7---batch(5)训练集---ACC:81.25%---LOSS:0.430---time:11.64
# Epoch:7---batch(6)训练集---ACC:87.50%---LOSS:0.557---time:10.80
# Epoch:7---batch(7)训练集---ACC:84.38%---LOSS:0.453---time:10.33
# Epoch:7---batch(8)训练集---ACC:90.62%---LOSS:0.406---time:10.29
# Epoch:7---batch(9)训练集---ACC:81.25%---LOSS:0.459---time:10.43
# Epoch:7---batch(10)训练集---ACC:71.88%---LOSS:0.852---time:10.39
# Epoch:7---batch(11)训练集---ACC:81.25%---LOSS:0.382---time:10.46
# Epoch:7---batch(12)训练集---ACC:87.50%---LOSS:0.425---time:10.42
# Epoch:7---batch(13)训练集---ACC:81.25%---LOSS:0.432---time:10.30
# Epoch:7---batch(14)训练集---ACC:81.25%---LOSS:0.451---time:10.21
# Epoch:7---batch(15)训练集---ACC:68.75%---LOSS:0.900---time:10.19
# Epoch:7---batch(16)训练集---ACC:84.38%---LOSS:0.596---time:10.28
# Epoch:7---batch(17)训练集---ACC:78.12%---LOSS:0.715---time:10.38
# Epoch:7---batch(18)训练集---ACC:84.38%---LOSS:0.543---time:10.12
# Epoch:7---batch(19)训练集---ACC:84.38%---LOSS:0.465---time:10.29
# Epoch:7---batch(20)训练集---ACC:84.38%---LOSS:0.308---time:10.36
# Epoch:7---batch(21)训练集---ACC:87.50%---LOSS:0.372---time:10.36
# Epoch:7---batch(22)训练集---ACC:71.88%---LOSS:0.580---time:10.48
# Epoch:7---batch(23)训练集---ACC:84.38%---LOSS:0.552---time:10.34
# Epoch:7---batch(24)训练集---ACC:87.50%---LOSS:0.384---time:10.32
# Epoch:7---batch(25)训练集---ACC:96.88%---LOSS:0.249---time:10.37
# Epoch:7---batch(26)训练集---ACC:78.12%---LOSS:0.483---time:10.21
# Epoch:7---batch(27)训练集---ACC:68.75%---LOSS:0.677---time:10.39
# Epoch:7---batch(28)训练集---ACC:71.88%---LOSS:0.653---time:10.39
# Epoch:7---batch(29)训练集---ACC:87.50%---LOSS:0.435---time:10.55
# Epoch:7---batch(30)训练集---ACC:81.25%---LOSS:0.629---time:10.26
# Epoch:7---batch(31)训练集---ACC:84.38%---LOSS:0.457---time:10.45
# Epoch:7---batch(32)训练集---ACC:68.75%---LOSS:0.763---time:10.45
# Epoch:7---batch(33)训练集---ACC:71.88%---LOSS:0.664---time:10.44
# Epoch:7---batch(34)训练集---ACC:87.50%---LOSS:0.583---time:10.35
# Epoch:7---batch(35)训练集---ACC:71.88%---LOSS:0.682---time:10.36
# Epoch:7---batch(36)训练集---ACC:81.25%---LOSS:0.449---time:10.36
# Epoch:7---batch(37)训练集---ACC:75.00%---LOSS:0.514---time:5.17
# 第7轮测试集准确率：76.00%....测试集Loss:0.7531627288886479
# Epoch:8---batch(0)训练集---ACC:90.62%---LOSS:0.308---time:10.30
# Epoch:8---batch(1)训练集---ACC:84.38%---LOSS:0.594---time:10.70
# Epoch:8---batch(2)训练集---ACC:75.00%---LOSS:0.524---time:11.88
# Epoch:8---batch(3)训练集---ACC:78.12%---LOSS:0.694---time:11.41
# Epoch:8---batch(4)训练集---ACC:71.88%---LOSS:0.720---time:12.12
# Epoch:8---batch(5)训练集---ACC:93.75%---LOSS:0.304---time:14.47
# Epoch:8---batch(6)训练集---ACC:68.75%---LOSS:0.626---time:10.77
# Epoch:8---batch(7)训练集---ACC:84.38%---LOSS:0.541---time:12.53
# Epoch:8---batch(8)训练集---ACC:81.25%---LOSS:0.406---time:11.68
# Epoch:8---batch(9)训练集---ACC:84.38%---LOSS:0.330---time:11.76
# Epoch:8---batch(10)训练集---ACC:87.50%---LOSS:0.356---time:12.09
# Epoch:8---batch(11)训练集---ACC:81.25%---LOSS:0.389---time:13.38
# Epoch:8---batch(12)训练集---ACC:71.88%---LOSS:0.679---time:11.77
# Epoch:8---batch(13)训练集---ACC:87.50%---LOSS:0.475---time:11.55
# Epoch:8---batch(14)训练集---ACC:68.75%---LOSS:0.705---time:11.90
# Epoch:8---batch(15)训练集---ACC:65.62%---LOSS:1.084---time:12.65
# Epoch:8---batch(16)训练集---ACC:84.38%---LOSS:0.317---time:13.08
# Epoch:8---batch(17)训练集---ACC:87.50%---LOSS:0.467---time:11.33
# Epoch:8---batch(18)训练集---ACC:75.00%---LOSS:0.482---time:11.17
# Epoch:8---batch(19)训练集---ACC:87.50%---LOSS:0.545---time:10.68
# Epoch:8---batch(20)训练集---ACC:81.25%---LOSS:0.496---time:10.56
# Epoch:8---batch(21)训练集---ACC:78.12%---LOSS:0.728---time:13.11
# Epoch:8---batch(22)训练集---ACC:87.50%---LOSS:0.409---time:14.94
# Epoch:8---batch(23)训练集---ACC:84.38%---LOSS:0.396---time:14.62
# Epoch:8---batch(24)训练集---ACC:75.00%---LOSS:0.648---time:11.43
# Epoch:8---batch(25)训练集---ACC:75.00%---LOSS:0.664---time:12.11
# Epoch:8---batch(26)训练集---ACC:78.12%---LOSS:0.444---time:14.69
# Epoch:8---batch(27)训练集---ACC:65.62%---LOSS:0.589---time:16.40
# Epoch:8---batch(28)训练集---ACC:68.75%---LOSS:0.750---time:12.74
# Epoch:8---batch(29)训练集---ACC:84.38%---LOSS:0.581---time:16.29
# Epoch:8---batch(30)训练集---ACC:90.62%---LOSS:0.352---time:13.41
# Epoch:8---batch(31)训练集---ACC:81.25%---LOSS:0.574---time:13.09
# Epoch:8---batch(32)训练集---ACC:81.25%---LOSS:0.576---time:14.45
# Epoch:8---batch(33)训练集---ACC:100.00%---LOSS:0.180---time:13.88
# Epoch:8---batch(34)训练集---ACC:87.50%---LOSS:0.416---time:12.33
# Epoch:8---batch(35)训练集---ACC:71.88%---LOSS:0.678---time:15.10
# Epoch:8---batch(36)训练集---ACC:87.50%---LOSS:0.468---time:13.19
# Epoch:8---batch(37)训练集---ACC:68.75%---LOSS:0.649---time:6.79
# 第8轮测试集准确率：80.00%....测试集Loss:0.7582152570996966
# Epoch:9---batch(0)训练集---ACC:90.62%---LOSS:0.301---time:13.29
# Epoch:9---batch(1)训练集---ACC:84.38%---LOSS:0.415---time:13.34
# Epoch:9---batch(2)训练集---ACC:71.88%---LOSS:0.608---time:13.40
# Epoch:9---batch(3)训练集---ACC:71.88%---LOSS:0.740---time:13.57
# Epoch:9---batch(4)训练集---ACC:81.25%---LOSS:0.739---time:13.27
# Epoch:9---batch(5)训练集---ACC:90.62%---LOSS:0.343---time:13.53
# Epoch:9---batch(6)训练集---ACC:87.50%---LOSS:0.357---time:13.30
# Epoch:9---batch(7)训练集---ACC:84.38%---LOSS:0.457---time:13.69
# Epoch:9---batch(8)训练集---ACC:93.75%---LOSS:0.308---time:13.23
# Epoch:9---batch(9)训练集---ACC:81.25%---LOSS:0.542---time:11.16
# Epoch:9---batch(10)训练集---ACC:87.50%---LOSS:0.392---time:13.07
# Epoch:9---batch(11)训练集---ACC:81.25%---LOSS:0.547---time:15.56
# Epoch:9---batch(12)训练集---ACC:68.75%---LOSS:0.715---time:13.29
# Epoch:9---batch(13)训练集---ACC:84.38%---LOSS:0.468---time:12.93
# Epoch:9---batch(14)训练集---ACC:78.12%---LOSS:0.430---time:12.83
# Epoch:9---batch(15)训练集---ACC:68.75%---LOSS:0.901---time:12.70
# Epoch:9---batch(16)训练集---ACC:81.25%---LOSS:0.782---time:12.76
# Epoch:9---batch(17)训练集---ACC:84.38%---LOSS:0.524---time:12.56
# Epoch:9---batch(18)训练集---ACC:90.62%---LOSS:0.305---time:12.77
# Epoch:9---batch(19)训练集---ACC:84.38%---LOSS:0.403---time:12.81
# Epoch:9---batch(20)训练集---ACC:81.25%---LOSS:0.566---time:12.68
# Epoch:9---batch(21)训练集---ACC:84.38%---LOSS:0.413---time:12.74
# Epoch:9---batch(22)训练集---ACC:71.88%---LOSS:0.621---time:12.58
# Epoch:9---batch(23)训练集---ACC:81.25%---LOSS:0.421---time:12.74
# Epoch:9---batch(24)训练集---ACC:68.75%---LOSS:0.653---time:12.74
# Epoch:9---batch(25)训练集---ACC:84.38%---LOSS:0.451---time:12.79
# Epoch:9---batch(26)训练集---ACC:81.25%---LOSS:0.560---time:12.60
# Epoch:9---batch(27)训练集---ACC:81.25%---LOSS:0.580---time:12.58
# Epoch:9---batch(28)训练集---ACC:84.38%---LOSS:0.399---time:12.68
# Epoch:9---batch(29)训练集---ACC:84.38%---LOSS:0.479---time:12.87
# Epoch:9---batch(30)训练集---ACC:75.00%---LOSS:0.521---time:12.66
# Epoch:9---batch(31)训练集---ACC:84.38%---LOSS:0.383---time:12.88
# Epoch:9---batch(32)训练集---ACC:62.50%---LOSS:0.880---time:13.83
# Epoch:9---batch(33)训练集---ACC:71.88%---LOSS:0.667---time:12.67
# Epoch:9---batch(34)训练集---ACC:75.00%---LOSS:0.533---time:14.25
# Epoch:9---batch(35)训练集---ACC:81.25%---LOSS:0.595---time:14.45
# Epoch:9---batch(36)训练集---ACC:68.75%---LOSS:0.792---time:14.85
# Epoch:9---batch(37)训练集---ACC:50.00%---LOSS:0.800---time:7.10
# 第9轮测试集准确率：80.50%....测试集Loss:0.7564208848135812
# Epoch:10---batch(0)训练集---ACC:90.62%---LOSS:0.267---time:11.73
# Epoch:10---batch(1)训练集---ACC:84.38%---LOSS:0.521---time:14.09
# Epoch:10---batch(2)训练集---ACC:81.25%---LOSS:0.625---time:14.72
# Epoch:10---batch(3)训练集---ACC:84.38%---LOSS:0.544---time:15.12
# Epoch:10---batch(4)训练集---ACC:68.75%---LOSS:0.814---time:14.24
# Epoch:10---batch(5)训练集---ACC:71.88%---LOSS:0.863---time:14.49
# Epoch:10---batch(6)训练集---ACC:71.88%---LOSS:0.748---time:14.68
# Epoch:10---batch(7)训练集---ACC:81.25%---LOSS:0.714---time:14.53
# Epoch:10---batch(8)训练集---ACC:84.38%---LOSS:0.466---time:14.61
# Epoch:10---batch(9)训练集---ACC:87.50%---LOSS:0.518---time:14.10
# Epoch:10---batch(10)训练集---ACC:81.25%---LOSS:0.600---time:14.20
# Epoch:10---batch(11)训练集---ACC:75.00%---LOSS:0.755---time:14.26
# Epoch:10---batch(12)训练集---ACC:78.12%---LOSS:0.513---time:14.48
# Epoch:10---batch(13)训练集---ACC:90.62%---LOSS:0.305---time:14.67
# Epoch:10---batch(14)训练集---ACC:75.00%---LOSS:0.581---time:15.04
# Epoch:10---batch(15)训练集---ACC:81.25%---LOSS:0.474---time:14.58
# Epoch:10---batch(16)训练集---ACC:81.25%---LOSS:0.468---time:13.59
# Epoch:10---batch(17)训练集---ACC:65.62%---LOSS:0.782---time:13.77
# Epoch:10---batch(18)训练集---ACC:78.12%---LOSS:0.748---time:16.44
# Epoch:10---batch(19)训练集---ACC:84.38%---LOSS:0.494---time:14.29
# Epoch:10---batch(20)训练集---ACC:81.25%---LOSS:0.679---time:14.13
# Epoch:10---batch(21)训练集---ACC:87.50%---LOSS:0.476---time:13.57
# Epoch:10---batch(22)训练集---ACC:87.50%---LOSS:0.393---time:13.50
# Epoch:10---batch(23)训练集---ACC:75.00%---LOSS:0.410---time:13.49
# Epoch:10---batch(24)训练集---ACC:84.38%---LOSS:0.400---time:13.40
# Epoch:10---batch(25)训练集---ACC:93.75%---LOSS:0.320---time:12.99
# Epoch:10---batch(26)训练集---ACC:81.25%---LOSS:0.464---time:13.47
# Epoch:10---batch(27)训练集---ACC:87.50%---LOSS:0.471---time:13.40
# Epoch:10---batch(28)训练集---ACC:81.25%---LOSS:0.370---time:13.07
# Epoch:10---batch(29)训练集---ACC:78.12%---LOSS:0.505---time:13.24
# Epoch:10---batch(30)训练集---ACC:90.62%---LOSS:0.340---time:13.17
# Epoch:10---batch(31)训练集---ACC:78.12%---LOSS:0.660---time:11.25
# Epoch:10---batch(32)训练集---ACC:78.12%---LOSS:0.552---time:11.10
# Epoch:10---batch(33)训练集---ACC:84.38%---LOSS:0.625---time:11.83
# Epoch:10---batch(34)训练集---ACC:84.38%---LOSS:0.363---time:11.77
# Epoch:10---batch(35)训练集---ACC:81.25%---LOSS:0.763---time:12.53
# Epoch:10---batch(36)训练集---ACC:75.00%---LOSS:0.669---time:13.48
# Epoch:10---batch(37)训练集---ACC:81.25%---LOSS:0.314---time:6.66
# 第10轮测试集准确率：78.50%....测试集Loss:0.7602162744317736
# Epoch:11---batch(0)训练集---ACC:84.38%---LOSS:0.420---time:13.76
# Epoch:11---batch(1)训练集---ACC:84.38%---LOSS:0.425---time:12.99
# Epoch:11---batch(2)训练集---ACC:84.38%---LOSS:0.633---time:11.91
# Epoch:11---batch(3)训练集---ACC:87.50%---LOSS:0.296---time:11.15
# Epoch:11---batch(4)训练集---ACC:71.88%---LOSS:0.473---time:11.29
# Epoch:11---batch(5)训练集---ACC:90.62%---LOSS:0.338---time:11.29
# Epoch:11---batch(6)训练集---ACC:87.50%---LOSS:0.391---time:11.50
# Epoch:11---batch(7)训练集---ACC:71.88%---LOSS:0.575---time:11.49
# Epoch:11---batch(8)训练集---ACC:75.00%---LOSS:0.483---time:11.64
# Epoch:11---batch(9)训练集---ACC:78.12%---LOSS:0.569---time:11.31
# Epoch:11---batch(10)训练集---ACC:84.38%---LOSS:0.597---time:11.49
# Epoch:11---batch(11)训练集---ACC:71.88%---LOSS:0.661---time:11.88
# Epoch:11---batch(12)训练集---ACC:75.00%---LOSS:0.654---time:11.82
# Epoch:11---batch(13)训练集---ACC:87.50%---LOSS:0.366---time:12.82
# Epoch:11---batch(14)训练集---ACC:75.00%---LOSS:0.634---time:11.60
# Epoch:11---batch(15)训练集---ACC:81.25%---LOSS:0.501---time:11.70
# Epoch:11---batch(16)训练集---ACC:75.00%---LOSS:0.564---time:12.08
# Epoch:11---batch(17)训练集---ACC:84.38%---LOSS:0.608---time:12.08
# Epoch:11---batch(18)训练集---ACC:84.38%---LOSS:0.337---time:12.04
# Epoch:11---batch(19)训练集---ACC:62.50%---LOSS:1.110---time:11.72
# Epoch:11---batch(20)训练集---ACC:68.75%---LOSS:0.795---time:12.06
# Epoch:11---batch(21)训练集---ACC:84.38%---LOSS:0.407---time:11.91
# Epoch:11---batch(22)训练集---ACC:81.25%---LOSS:0.620---time:11.76
# Epoch:11---batch(23)训练集---ACC:84.38%---LOSS:0.355---time:11.94
# Epoch:11---batch(24)训练集---ACC:62.50%---LOSS:0.907---time:12.52
# Epoch:11---batch(25)训练集---ACC:90.62%---LOSS:0.334---time:12.41
# Epoch:11---batch(26)训练集---ACC:78.12%---LOSS:0.758---time:11.69
# Epoch:11---batch(27)训练集---ACC:78.12%---LOSS:0.463---time:11.72
# Epoch:11---batch(28)训练集---ACC:78.12%---LOSS:0.751---time:14.58
# Epoch:11---batch(29)训练集---ACC:93.75%---LOSS:0.281---time:14.77
# Epoch:11---batch(30)训练集---ACC:93.75%---LOSS:0.418---time:18.00
# Epoch:11---batch(31)训练集---ACC:81.25%---LOSS:0.527---time:14.87
# Epoch:11---batch(32)训练集---ACC:68.75%---LOSS:0.781---time:13.89
# Epoch:11---batch(33)训练集---ACC:75.00%---LOSS:0.885---time:17.11
# Epoch:11---batch(34)训练集---ACC:84.38%---LOSS:0.481---time:20.79
# Epoch:11---batch(35)训练集---ACC:78.12%---LOSS:0.634---time:20.75
# Epoch:11---batch(36)训练集---ACC:78.12%---LOSS:0.378---time:20.67
# Epoch:11---batch(37)训练集---ACC:93.75%---LOSS:0.367---time:10.34
# 第11轮测试集准确率：77.00%....测试集Loss:0.8136934510299138
# Epoch:12---batch(0)训练集---ACC:78.12%---LOSS:0.548---time:20.59
# Epoch:12---batch(1)训练集---ACC:81.25%---LOSS:0.615---time:20.62
# Epoch:12---batch(2)训练集---ACC:87.50%---LOSS:0.374---time:20.58
# Epoch:12---batch(3)训练集---ACC:87.50%---LOSS:0.323---time:20.54
# Epoch:12---batch(4)训练集---ACC:81.25%---LOSS:0.499---time:20.61
# Epoch:12---batch(5)训练集---ACC:84.38%---LOSS:0.578---time:20.74
# Epoch:12---batch(6)训练集---ACC:81.25%---LOSS:0.677---time:20.72
# Epoch:12---batch(7)训练集---ACC:71.88%---LOSS:0.627---time:20.52
# Epoch:12---batch(8)训练集---ACC:90.62%---LOSS:0.371---time:20.76
# Epoch:12---batch(9)训练集---ACC:78.12%---LOSS:0.573---time:22.64
# Epoch:12---batch(10)训练集---ACC:78.12%---LOSS:0.500---time:26.89
# Epoch:12---batch(11)训练集---ACC:75.00%---LOSS:0.564---time:13.71
# Epoch:12---batch(12)训练集---ACC:78.12%---LOSS:0.567---time:13.85
# Epoch:12---batch(13)训练集---ACC:62.50%---LOSS:0.812---time:13.64
# Epoch:12---batch(14)训练集---ACC:81.25%---LOSS:0.541---time:13.42
# Epoch:12---batch(15)训练集---ACC:71.88%---LOSS:0.804---time:13.38
# Epoch:12---batch(16)训练集---ACC:75.00%---LOSS:0.602---time:13.13
# Epoch:12---batch(17)训练集---ACC:93.75%---LOSS:0.319---time:13.10
# Epoch:12---batch(18)训练集---ACC:71.88%---LOSS:0.640---time:14.79
# Epoch:12---batch(19)训练集---ACC:87.50%---LOSS:0.614---time:14.63
# Epoch:12---batch(20)训练集---ACC:87.50%---LOSS:0.719---time:13.30
# Epoch:12---batch(21)训练集---ACC:84.38%---LOSS:0.344---time:13.06
# Epoch:12---batch(22)训练集---ACC:81.25%---LOSS:0.513---time:12.88
# Epoch:12---batch(23)训练集---ACC:81.25%---LOSS:0.500---time:13.13
# Epoch:12---batch(24)训练集---ACC:84.38%---LOSS:0.492---time:13.03
# Epoch:12---batch(25)训练集---ACC:84.38%---LOSS:0.652---time:14.16
# Epoch:12---batch(26)训练集---ACC:81.25%---LOSS:0.606---time:12.91
# Epoch:12---batch(27)训练集---ACC:71.88%---LOSS:0.673---time:13.58
# Epoch:12---batch(28)训练集---ACC:87.50%---LOSS:0.395---time:14.08
# Epoch:12---batch(29)训练集---ACC:84.38%---LOSS:0.385---time:14.40
# Epoch:12---batch(30)训练集---ACC:81.25%---LOSS:0.507---time:16.00
# Epoch:12---batch(31)训练集---ACC:71.88%---LOSS:0.877---time:14.33
# Epoch:12---batch(32)训练集---ACC:81.25%---LOSS:0.533---time:16.48
# Epoch:12---batch(33)训练集---ACC:84.38%---LOSS:0.771---time:14.27
# Epoch:12---batch(34)训练集---ACC:84.38%---LOSS:0.453---time:13.47
# Epoch:12---batch(35)训练集---ACC:87.50%---LOSS:0.371---time:13.47
# Epoch:12---batch(36)训练集---ACC:75.00%---LOSS:0.750---time:13.64
# Epoch:12---batch(37)训练集---ACC:68.75%---LOSS:0.805---time:6.99
# 第12轮测试集准确率：72.50%....测试集Loss:0.8464252735887255
# Epoch:13---batch(0)训练集---ACC:84.38%---LOSS:0.335---time:13.34
# Epoch:13---batch(1)训练集---ACC:78.12%---LOSS:0.734---time:13.51
# Epoch:13---batch(2)训练集---ACC:81.25%---LOSS:0.410---time:13.56
# Epoch:13---batch(3)训练集---ACC:78.12%---LOSS:0.853---time:15.39
# Epoch:13---batch(4)训练集---ACC:87.50%---LOSS:0.434---time:17.75
# Epoch:13---batch(5)训练集---ACC:90.62%---LOSS:0.355---time:14.49
# Epoch:13---batch(6)训练集---ACC:81.25%---LOSS:0.543---time:14.75
# Epoch:13---batch(7)训练集---ACC:81.25%---LOSS:0.528---time:17.40
# Epoch:13---batch(8)训练集---ACC:78.12%---LOSS:0.497---time:15.15
# Epoch:13---batch(9)训练集---ACC:62.50%---LOSS:0.749---time:14.87
# Epoch:13---batch(10)训练集---ACC:87.50%---LOSS:0.744---time:14.42
# Epoch:13---batch(11)训练集---ACC:78.12%---LOSS:0.641---time:14.15
# Epoch:13---batch(12)训练集---ACC:81.25%---LOSS:0.512---time:14.32
# Epoch:13---batch(13)训练集---ACC:75.00%---LOSS:0.540---time:14.53
# Epoch:13---batch(14)训练集---ACC:87.50%---LOSS:0.369---time:14.41
# Epoch:13---batch(15)训练集---ACC:84.38%---LOSS:0.501---time:14.30
# Epoch:13---batch(16)训练集---ACC:81.25%---LOSS:0.459---time:13.64
# Epoch:13---batch(17)训练集---ACC:78.12%---LOSS:0.522---time:12.32
# Epoch:13---batch(18)训练集---ACC:65.62%---LOSS:0.859---time:11.97
# Epoch:13---batch(19)训练集---ACC:75.00%---LOSS:0.635---time:15.71
# Epoch:13---batch(20)训练集---ACC:93.75%---LOSS:0.270---time:12.08
# Epoch:13---batch(21)训练集---ACC:75.00%---LOSS:0.538---time:12.64
# Epoch:13---batch(22)训练集---ACC:84.38%---LOSS:0.463---time:14.46
# Epoch:13---batch(23)训练集---ACC:78.12%---LOSS:0.542---time:12.29
# Epoch:13---batch(24)训练集---ACC:75.00%---LOSS:0.677---time:14.45
# Epoch:13---batch(25)训练集---ACC:68.75%---LOSS:0.865---time:14.46
# Epoch:13---batch(26)训练集---ACC:87.50%---LOSS:0.251---time:15.62
# Epoch:13---batch(27)训练集---ACC:81.25%---LOSS:0.401---time:17.30
# Epoch:13---batch(28)训练集---ACC:81.25%---LOSS:0.613---time:16.19
# Epoch:13---batch(29)训练集---ACC:87.50%---LOSS:0.464---time:15.99
# Epoch:13---batch(30)训练集---ACC:78.12%---LOSS:0.679---time:12.19
# Epoch:13---batch(31)训练集---ACC:71.88%---LOSS:0.765---time:12.25
# Epoch:13---batch(32)训练集---ACC:71.88%---LOSS:0.652---time:13.35
# Epoch:13---batch(33)训练集---ACC:81.25%---LOSS:0.545---time:14.87
# Epoch:13---batch(34)训练集---ACC:90.62%---LOSS:0.347---time:16.04
# Epoch:13---batch(35)训练集---ACC:90.62%---LOSS:0.233---time:19.27
# Epoch:13---batch(36)训练集---ACC:75.00%---LOSS:0.533---time:13.39
# Epoch:13---batch(37)训练集---ACC:68.75%---LOSS:0.943---time:7.30
# 第13轮测试集准确率：78.00%....测试集Loss:0.7783062841211047
# Epoch:14---batch(0)训练集---ACC:90.62%---LOSS:0.473---time:13.09
# Epoch:14---batch(1)训练集---ACC:81.25%---LOSS:0.521---time:13.01
# Epoch:14---batch(2)训练集---ACC:75.00%---LOSS:0.435---time:12.79
# Epoch:14---batch(3)训练集---ACC:96.88%---LOSS:0.206---time:12.83
# Epoch:14---batch(4)训练集---ACC:87.50%---LOSS:0.406---time:13.04
# Epoch:14---batch(5)训练集---ACC:90.62%---LOSS:0.342---time:14.54
# Epoch:14---batch(6)训练集---ACC:68.75%---LOSS:0.904---time:13.31
# Epoch:14---batch(7)训练集---ACC:87.50%---LOSS:0.288---time:13.21
# Epoch:14---batch(8)训练集---ACC:84.38%---LOSS:0.510---time:12.92
# Epoch:14---batch(9)训练集---ACC:81.25%---LOSS:0.396---time:12.88
# Epoch:14---batch(10)训练集---ACC:81.25%---LOSS:0.453---time:13.31
# Epoch:14---batch(11)训练集---ACC:81.25%---LOSS:0.491---time:13.23
# Epoch:14---batch(12)训练集---ACC:78.12%---LOSS:0.486---time:13.51
# Epoch:14---batch(13)训练集---ACC:96.88%---LOSS:0.259---time:14.78
# Epoch:14---batch(14)训练集---ACC:90.62%---LOSS:0.290---time:13.07
# Epoch:14---batch(15)训练集---ACC:84.38%---LOSS:0.444---time:12.68
# Epoch:14---batch(16)训练集---ACC:81.25%---LOSS:0.450---time:12.96
# Epoch:14---batch(17)训练集---ACC:81.25%---LOSS:0.474---time:14.71
# Epoch:14---batch(18)训练集---ACC:84.38%---LOSS:0.582---time:12.92
# Epoch:14---batch(19)训练集---ACC:81.25%---LOSS:0.457---time:15.61
# Epoch:14---batch(20)训练集---ACC:84.38%---LOSS:0.252---time:13.34
# Epoch:14---batch(21)训练集---ACC:84.38%---LOSS:0.442---time:13.48
# Epoch:14---batch(22)训练集---ACC:84.38%---LOSS:0.520---time:13.28
# Epoch:14---batch(23)训练集---ACC:84.38%---LOSS:0.405---time:14.05
# Epoch:14---batch(24)训练集---ACC:87.50%---LOSS:0.368---time:14.71
# Epoch:14---batch(25)训练集---ACC:81.25%---LOSS:0.489---time:17.60
# Epoch:14---batch(26)训练集---ACC:75.00%---LOSS:0.629---time:17.07
# Epoch:14---batch(27)训练集---ACC:68.75%---LOSS:0.865---time:14.03
# Epoch:14---batch(28)训练集---ACC:65.62%---LOSS:0.669---time:15.97
# Epoch:14---batch(29)训练集---ACC:68.75%---LOSS:0.909---time:18.53
# Epoch:14---batch(30)训练集---ACC:84.38%---LOSS:0.474---time:14.62
# Epoch:14---batch(31)训练集---ACC:75.00%---LOSS:0.810---time:19.45
# Epoch:14---batch(32)训练集---ACC:81.25%---LOSS:0.466---time:14.61
# Epoch:14---batch(33)训练集---ACC:68.75%---LOSS:0.936---time:14.47
# Epoch:14---batch(34)训练集---ACC:90.62%---LOSS:0.391---time:14.33
# Epoch:14---batch(35)训练集---ACC:68.75%---LOSS:0.705---time:14.28
# Epoch:14---batch(36)训练集---ACC:87.50%---LOSS:0.614---time:14.62
# Epoch:14---batch(37)训练集---ACC:68.75%---LOSS:0.677---time:7.21
# 第14轮测试集准确率：74.50%....测试集Loss:0.9248718449047634
# Epoch:15---batch(0)训练集---ACC:93.75%---LOSS:0.172---time:14.05
# Epoch:15---batch(1)训练集---ACC:81.25%---LOSS:0.462---time:14.06
# Epoch:15---batch(2)训练集---ACC:81.25%---LOSS:0.473---time:14.59
# Epoch:15---batch(3)训练集---ACC:65.62%---LOSS:0.624---time:14.35
# Epoch:15---batch(4)训练集---ACC:75.00%---LOSS:0.523---time:14.21
# Epoch:15---batch(5)训练集---ACC:75.00%---LOSS:0.729---time:14.30
# Epoch:15---batch(6)训练集---ACC:81.25%---LOSS:0.640---time:14.48
# Epoch:15---batch(7)训练集---ACC:75.00%---LOSS:0.602---time:14.11
# Epoch:15---batch(8)训练集---ACC:75.00%---LOSS:0.604---time:14.15
# Epoch:15---batch(9)训练集---ACC:81.25%---LOSS:0.562---time:14.75
# Epoch:15---batch(10)训练集---ACC:81.25%---LOSS:0.434---time:14.39
# Epoch:15---batch(11)训练集---ACC:78.12%---LOSS:0.606---time:14.11
# Epoch:15---batch(12)训练集---ACC:78.12%---LOSS:0.435---time:14.67
# Epoch:15---batch(13)训练集---ACC:84.38%---LOSS:0.615---time:14.44
# Epoch:15---batch(14)训练集---ACC:87.50%---LOSS:0.403---time:14.32
# Epoch:15---batch(15)训练集---ACC:87.50%---LOSS:0.468---time:14.28
# Epoch:15---batch(16)训练集---ACC:87.50%---LOSS:0.376---time:14.62
# Epoch:15---batch(17)训练集---ACC:81.25%---LOSS:0.559---time:14.09
# Epoch:15---batch(18)训练集---ACC:87.50%---LOSS:0.398---time:14.25
# Epoch:15---batch(19)训练集---ACC:87.50%---LOSS:0.378---time:14.59
# Epoch:15---batch(20)训练集---ACC:81.25%---LOSS:0.656---time:14.40
# Epoch:15---batch(21)训练集---ACC:87.50%---LOSS:0.339---time:14.09
# Epoch:15---batch(22)训练集---ACC:90.62%---LOSS:0.322---time:14.49
# Epoch:15---batch(23)训练集---ACC:68.75%---LOSS:0.648---time:14.55
# Epoch:15---batch(24)训练集---ACC:78.12%---LOSS:0.702---time:14.29
# Epoch:15---batch(25)训练集---ACC:87.50%---LOSS:0.407---time:14.17
# Epoch:15---batch(26)训练集---ACC:87.50%---LOSS:0.327---time:14.79
# Epoch:15---batch(27)训练集---ACC:93.75%---LOSS:0.307---time:14.17
# Epoch:15---batch(28)训练集---ACC:81.25%---LOSS:0.512---time:14.10
# Epoch:15---batch(29)训练集---ACC:68.75%---LOSS:0.668---time:14.55
# Epoch:15---batch(30)训练集---ACC:90.62%---LOSS:0.366---time:14.37
# Epoch:15---batch(31)训练集---ACC:84.38%---LOSS:0.529---time:14.10
# Epoch:15---batch(32)训练集---ACC:90.62%---LOSS:0.404---time:14.25
# Epoch:15---batch(33)训练集---ACC:84.38%---LOSS:0.399---time:14.62
# Epoch:15---batch(34)训练集---ACC:84.38%---LOSS:0.453---time:14.05
# Epoch:15---batch(35)训练集---ACC:90.62%---LOSS:0.337---time:14.31
# Epoch:15---batch(36)训练集---ACC:90.62%---LOSS:0.367---time:14.87
# Epoch:15---batch(37)训练集---ACC:56.25%---LOSS:1.188---time:7.25
# 第15轮测试集准确率：79.00%....测试集Loss:0.8239835841315133
# Epoch:16---batch(0)训练集---ACC:78.12%---LOSS:0.641---time:14.48
# Epoch:16---batch(1)训练集---ACC:87.50%---LOSS:0.309---time:14.08
# Epoch:16---batch(2)训练集---ACC:81.25%---LOSS:0.539---time:14.53
# Epoch:16---batch(3)训练集---ACC:93.75%---LOSS:0.169---time:14.45
# Epoch:16---batch(4)训练集---ACC:81.25%---LOSS:0.486---time:14.33
# Epoch:16---batch(5)训练集---ACC:78.12%---LOSS:0.813---time:14.24
# Epoch:16---batch(6)训练集---ACC:87.50%---LOSS:0.414---time:14.30
# Epoch:16---batch(7)训练集---ACC:87.50%---LOSS:0.297---time:12.85
# Epoch:16---batch(8)训练集---ACC:75.00%---LOSS:0.529---time:13.04
# Epoch:16---batch(9)训练集---ACC:81.25%---LOSS:0.615---time:12.87
# Epoch:16---batch(10)训练集---ACC:78.12%---LOSS:0.392---time:12.80
# Epoch:16---batch(11)训练集---ACC:59.38%---LOSS:0.830---time:12.97
# Epoch:16---batch(12)训练集---ACC:71.88%---LOSS:0.875---time:12.99
# Epoch:16---batch(13)训练集---ACC:78.12%---LOSS:0.676---time:12.92
# Epoch:16---batch(14)训练集---ACC:90.62%---LOSS:0.431---time:12.85
# Epoch:16---batch(15)训练集---ACC:78.12%---LOSS:0.550---time:13.00
# Epoch:16---batch(16)训练集---ACC:81.25%---LOSS:0.404---time:12.96
# Epoch:16---batch(17)训练集---ACC:84.38%---LOSS:0.420---time:12.94
# Epoch:16---batch(18)训练集---ACC:81.25%---LOSS:0.666---time:12.95
# Epoch:16---batch(19)训练集---ACC:87.50%---LOSS:0.318---time:12.98
# Epoch:16---batch(20)训练集---ACC:62.50%---LOSS:1.140---time:13.07
# Epoch:16---batch(21)训练集---ACC:93.75%---LOSS:0.317---time:12.79
# Epoch:16---batch(22)训练集---ACC:81.25%---LOSS:0.477---time:13.19
# Epoch:16---batch(23)训练集---ACC:71.88%---LOSS:0.912---time:12.86
# Epoch:16---batch(24)训练集---ACC:84.38%---LOSS:0.542---time:12.81
# Epoch:16---batch(25)训练集---ACC:87.50%---LOSS:0.350---time:13.01
# Epoch:16---batch(26)训练集---ACC:81.25%---LOSS:0.562---time:12.92
# Epoch:16---batch(27)训练集---ACC:78.12%---LOSS:0.463---time:12.82
# Epoch:16---batch(28)训练集---ACC:81.25%---LOSS:0.405---time:12.93
# Epoch:16---batch(29)训练集---ACC:78.12%---LOSS:0.543---time:12.85
# Epoch:16---batch(30)训练集---ACC:71.88%---LOSS:0.644---time:12.89
# Epoch:16---batch(31)训练集---ACC:68.75%---LOSS:0.947---time:13.15
# Epoch:16---batch(32)训练集---ACC:93.75%---LOSS:0.255---time:13.02
# Epoch:16---batch(33)训练集---ACC:87.50%---LOSS:0.313---time:13.00
# Epoch:16---batch(34)训练集---ACC:84.38%---LOSS:0.451---time:12.96
# Epoch:16---batch(35)训练集---ACC:84.38%---LOSS:0.419---time:12.82
# Epoch:16---batch(36)训练集---ACC:84.38%---LOSS:0.640---time:12.99
# Epoch:16---batch(37)训练集---ACC:87.50%---LOSS:0.447---time:6.52
# 第16轮测试集准确率：75.50%....测试集Loss:0.918988402400698
# Epoch:17---batch(0)训练集---ACC:75.00%---LOSS:0.532---time:12.92
# Epoch:17---batch(1)训练集---ACC:75.00%---LOSS:0.588---time:13.09
# Epoch:17---batch(2)训练集---ACC:81.25%---LOSS:0.396---time:13.03
# Epoch:17---batch(3)训练集---ACC:75.00%---LOSS:0.639---time:12.94
# Epoch:17---batch(4)训练集---ACC:81.25%---LOSS:0.454---time:12.97
# Epoch:17---batch(5)训练集---ACC:62.50%---LOSS:0.771---time:12.91
# Epoch:17---batch(6)训练集---ACC:75.00%---LOSS:0.574---time:12.93
# Epoch:17---batch(7)训练集---ACC:87.50%---LOSS:0.538---time:12.81
# Epoch:17---batch(8)训练集---ACC:78.12%---LOSS:0.503---time:12.94
# Epoch:17---batch(9)训练集---ACC:75.00%---LOSS:0.632---time:13.05
# Epoch:17---batch(10)训练集---ACC:84.38%---LOSS:0.579---time:12.88
# Epoch:17---batch(11)训练集---ACC:78.12%---LOSS:0.703---time:13.05
# Epoch:17---batch(12)训练集---ACC:75.00%---LOSS:0.612---time:12.96
# Epoch:17---batch(13)训练集---ACC:87.50%---LOSS:0.486---time:12.86
# Epoch:17---batch(14)训练集---ACC:81.25%---LOSS:0.377---time:13.06
# Epoch:17---batch(15)训练集---ACC:90.62%---LOSS:0.417---time:13.16
# Epoch:17---batch(16)训练集---ACC:87.50%---LOSS:0.353---time:13.01
# Epoch:17---batch(17)训练集---ACC:84.38%---LOSS:0.508---time:12.95
# Epoch:17---batch(18)训练集---ACC:84.38%---LOSS:0.373---time:13.14
# Epoch:17---batch(19)训练集---ACC:84.38%---LOSS:0.372---time:12.89
# Epoch:17---batch(20)训练集---ACC:87.50%---LOSS:0.458---time:13.06
# Epoch:17---batch(21)训练集---ACC:71.88%---LOSS:0.634---time:13.03
# Epoch:17---batch(22)训练集---ACC:84.38%---LOSS:0.383---time:12.99
# Epoch:17---batch(23)训练集---ACC:81.25%---LOSS:0.413---time:13.04
# Epoch:17---batch(24)训练集---ACC:87.50%---LOSS:0.616---time:12.93
# Epoch:17---batch(25)训练集---ACC:71.88%---LOSS:0.669---time:12.90
# Epoch:17---batch(26)训练集---ACC:71.88%---LOSS:0.909---time:12.86
# Epoch:17---batch(27)训练集---ACC:84.38%---LOSS:0.492---time:12.99
# Epoch:17---batch(28)训练集---ACC:68.75%---LOSS:0.684---time:13.07
# Epoch:17---batch(29)训练集---ACC:93.75%---LOSS:0.251---time:13.06
# Epoch:17---batch(30)训练集---ACC:87.50%---LOSS:0.449---time:12.93
# Epoch:17---batch(31)训练集---ACC:75.00%---LOSS:0.569---time:12.86
# Epoch:17---batch(32)训练集---ACC:87.50%---LOSS:0.284---time:12.97
# Epoch:17---batch(33)训练集---ACC:84.38%---LOSS:0.412---time:12.67
# Epoch:17---batch(34)训练集---ACC:93.75%---LOSS:0.250---time:13.04
# Epoch:17---batch(35)训练集---ACC:75.00%---LOSS:0.776---time:13.04
# Epoch:17---batch(36)训练集---ACC:93.75%---LOSS:0.325---time:12.90
# Epoch:17---batch(37)训练集---ACC:75.00%---LOSS:0.454---time:6.46
# 第17轮测试集准确率：74.50%....测试集Loss:0.8536223939486912
# Epoch:18---batch(0)训练集---ACC:78.12%---LOSS:0.465---time:13.78
# Epoch:18---batch(1)训练集---ACC:90.62%---LOSS:0.247---time:13.71
# Epoch:18---batch(2)训练集---ACC:93.75%---LOSS:0.197---time:13.92
# Epoch:18---batch(3)训练集---ACC:78.12%---LOSS:0.521---time:13.70
# Epoch:18---batch(4)训练集---ACC:87.50%---LOSS:0.387---time:13.59
# Epoch:18---batch(5)训练集---ACC:78.12%---LOSS:0.643---time:14.23
# Epoch:18---batch(6)训练集---ACC:84.38%---LOSS:0.496---time:13.64
# Epoch:18---batch(7)训练集---ACC:81.25%---LOSS:0.561---time:13.79
# Epoch:18---batch(8)训练集---ACC:90.62%---LOSS:0.210---time:14.03
# Epoch:18---batch(9)训练集---ACC:84.38%---LOSS:0.386---time:13.87
# Epoch:18---batch(10)训练集---ACC:87.50%---LOSS:0.324---time:13.78
# Epoch:18---batch(11)训练集---ACC:71.88%---LOSS:0.536---time:13.61
# Epoch:18---batch(12)训练集---ACC:75.00%---LOSS:0.759---time:14.25
# Epoch:18---batch(13)训练集---ACC:75.00%---LOSS:0.775---time:13.69
# Epoch:18---batch(14)训练集---ACC:71.88%---LOSS:0.847---time:13.81
# Epoch:18---batch(15)训练集---ACC:81.25%---LOSS:0.499---time:14.02
# Epoch:18---batch(16)训练集---ACC:68.75%---LOSS:0.602---time:13.79
# Epoch:18---batch(17)训练集---ACC:87.50%---LOSS:0.467---time:13.88
# Epoch:18---batch(18)训练集---ACC:81.25%---LOSS:1.039---time:13.45
# Epoch:18---batch(19)训练集---ACC:78.12%---LOSS:0.555---time:14.24
# Epoch:18---batch(20)训练集---ACC:78.12%---LOSS:0.441---time:13.63
# Epoch:18---batch(21)训练集---ACC:75.00%---LOSS:0.590---time:13.79
# Epoch:18---batch(22)训练集---ACC:78.12%---LOSS:0.411---time:13.64
# Epoch:18---batch(23)训练集---ACC:81.25%---LOSS:0.604---time:14.00
# Epoch:18---batch(24)训练集---ACC:87.50%---LOSS:0.335---time:13.71
# Epoch:18---batch(25)训练集---ACC:78.12%---LOSS:0.512---time:13.47
# Epoch:18---batch(26)训练集---ACC:87.50%---LOSS:0.437---time:14.17
# Epoch:18---batch(27)训练集---ACC:84.38%---LOSS:0.450---time:13.58
# Epoch:18---batch(28)训练集---ACC:90.62%---LOSS:0.321---time:13.84
# Epoch:18---batch(29)训练集---ACC:84.38%---LOSS:0.485---time:13.64
# Epoch:18---batch(30)训练集---ACC:81.25%---LOSS:0.488---time:14.02
# Epoch:18---batch(31)训练集---ACC:71.88%---LOSS:0.547---time:15.61
# Epoch:18---batch(32)训练集---ACC:84.38%---LOSS:0.239---time:13.54
# Epoch:18---batch(33)训练集---ACC:71.88%---LOSS:0.747---time:14.29
# Epoch:18---batch(34)训练集---ACC:81.25%---LOSS:0.555---time:13.53
# Epoch:18---batch(35)训练集---ACC:90.62%---LOSS:0.220---time:13.76
# Epoch:18---batch(36)训练集---ACC:93.75%---LOSS:0.316---time:14.09
# Epoch:18---batch(37)训练集---ACC:68.75%---LOSS:0.664---time:7.08
# 第18轮测试集准确率：79.00%....测试集Loss:0.818909513098853
# Epoch:19---batch(0)训练集---ACC:87.50%---LOSS:0.390---time:14.14
# Epoch:19---batch(1)训练集---ACC:84.38%---LOSS:0.340---time:13.45
# Epoch:19---batch(2)训练集---ACC:78.12%---LOSS:0.591---time:13.73
# Epoch:19---batch(3)训练集---ACC:75.00%---LOSS:0.510---time:13.71
# Epoch:19---batch(4)训练集---ACC:90.62%---LOSS:0.403---time:13.69
# Epoch:19---batch(5)训练集---ACC:81.25%---LOSS:0.509---time:13.57
# Epoch:19---batch(6)训练集---ACC:90.62%---LOSS:0.448---time:16.00
# Epoch:19---batch(7)训练集---ACC:90.62%---LOSS:0.285---time:15.50
# Epoch:19---batch(8)训练集---ACC:81.25%---LOSS:0.770---time:15.08
# Epoch:19---batch(9)训练集---ACC:90.62%---LOSS:0.257---time:15.32
# Epoch:19---batch(10)训练集---ACC:75.00%---LOSS:0.976---time:15.26
# Epoch:19---batch(11)训练集---ACC:78.12%---LOSS:0.447---time:14.81
# Epoch:19---batch(12)训练集---ACC:81.25%---LOSS:0.294---time:13.58
# Epoch:19---batch(13)训练集---ACC:87.50%---LOSS:0.355---time:14.93
# Epoch:19---batch(14)训练集---ACC:75.00%---LOSS:0.659---time:16.78
# Epoch:19---batch(15)训练集---ACC:84.38%---LOSS:0.432---time:13.34
# Epoch:19---batch(16)训练集---ACC:81.25%---LOSS:0.571---time:12.47
# Epoch:19---batch(17)训练集---ACC:93.75%---LOSS:0.224---time:12.87
# Epoch:19---batch(18)训练集---ACC:87.50%---LOSS:0.414---time:13.81
# Epoch:19---batch(19)训练集---ACC:78.12%---LOSS:0.402---time:13.68
# Epoch:19---batch(20)训练集---ACC:71.88%---LOSS:0.812---time:13.20
# Epoch:19---batch(21)训练集---ACC:78.12%---LOSS:0.584---time:12.97
# Epoch:19---batch(22)训练集---ACC:75.00%---LOSS:0.626---time:15.21
# Epoch:19---batch(23)训练集---ACC:75.00%---LOSS:0.567---time:13.94
# Epoch:19---batch(24)训练集---ACC:81.25%---LOSS:0.577---time:14.06
# Epoch:19---batch(25)训练集---ACC:84.38%---LOSS:0.502---time:14.19
# Epoch:19---batch(26)训练集---ACC:90.62%---LOSS:0.264---time:13.71
# Epoch:19---batch(27)训练集---ACC:81.25%---LOSS:0.480---time:14.28
# Epoch:19---batch(28)训练集---ACC:90.62%---LOSS:0.289---time:14.22
# Epoch:19---batch(29)训练集---ACC:81.25%---LOSS:0.528---time:14.02
# Epoch:19---batch(30)训练集---ACC:81.25%---LOSS:0.375---time:14.01
# Epoch:19---batch(31)训练集---ACC:87.50%---LOSS:0.312---time:13.82
# Epoch:19---batch(32)训练集---ACC:81.25%---LOSS:0.501---time:14.77
# Epoch:19---batch(33)训练集---ACC:68.75%---LOSS:0.699---time:13.87
# Epoch:19---batch(34)训练集---ACC:87.50%---LOSS:0.419---time:14.16
# Epoch:19---batch(35)训练集---ACC:81.25%---LOSS:0.656---time:14.17
# Epoch:19---batch(36)训练集---ACC:87.50%---LOSS:0.288---time:14.20
# Epoch:19---batch(37)训练集---ACC:81.25%---LOSS:0.453---time:6.90
# 第19轮测试集准确率：77.00%....测试集Loss:0.9283678574221474

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 经典与传统的对比
# 加载经典
# Classical_Train_data = pd.read_csv('/home/WUYING_986418966_1288354473/Desktop/QCNN/src/QCNN-FC/QTCNN-MNIST/640_train.csv')
# Classical_Val_data = pd.read_csv('/home/WUYING_986418966_1288354473/Desktop/QCNN/src/QCNN-FC/QTCNN-MNIST/2091_val.csv')

# Classical_Train_data_acc = Classical_Train_data[['Train_acc']]
# Classical_Train_data_loss = Classical_Train_data[['Train_loss']]

# Classical_Val_data_acc = Classical_Val_data[['Val_acc']]
# Classical_Val_data_loss = Classical_Val_data[['Val_loss']]
def result(acc,loss,plt1_title,plt2_title,title):     # 合并结果
    #绘图
    plt.xticks(np.arange(0,20,1))
    plt.plot(acc,label=plt1_title)
    plt.plot(loss,label=plt2_title)
    plt.title(title) 
    plt.xlabel('epoch')
    plt.ylabel('probability')
    plt.legend()   #显示标签
    plt.show()

# 加载qcnn
Qcnn_Train_data = pd.read_csv('E:\\Test\VsCode_Test\\Jupyter notebook\\Tensorcircuit\\result\\Fashion\\s=1\\943_train.csv')
Qcnn_Val_data = pd.read_csv('E:\\Test\\VsCode_Test\\Jupyter notebook\\Tensorcircuit\\result\\Fashion\\s=1\\2549_val.csv')

Qcnn_Train_data_acc = Qcnn_Train_data[['Train_acc']]
Qcnn_Train_data_loss = Qcnn_Train_data[['Train_loss']]

Qcnn_Val_data_acc = Qcnn_Val_data[['Val_acc']]
Qcnn_Val_data_loss = Qcnn_Val_data[['Val_loss']]

# 损失值比较
result(Qcnn_Train_data_loss,Qcnn_Val_data_loss,'Train_set','Val_set','Loss')
# 准确率比较
result(Qcnn_Train_data_acc,Qcnn_Val_data_acc,'Train_set','Val_set','ACC')
