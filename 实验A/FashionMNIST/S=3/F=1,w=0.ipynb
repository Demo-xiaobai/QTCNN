# %%
# %%
import tensorcircuit as tc
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split,Subset
import random
import os
import time
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F
import numpy as np
import csv
import tensorflow as tf


data_path = 'C:\\Users\\17861160902_16355000\\vscode\\data'

val_num = 200
data_num =  1200           # 需要划分的数据集大小
epochs = 20                 # 迭代轮次数
batch_size = 32

K = tc.set_backend("tensorflow")
# 归一化处理
def trans(x):
    x = np.array(x)
    x = x/255.0
    # print(x.shape)    
    return torch.from_numpy(x).float()  # 将 NumPy 数组 x 转换为 PyTorch 张量

transform = transforms.Compose([
    transforms.Resize((14, 14)),                # 将图片缩小为 14x14
    transforms.Lambda(lambda x:trans(x))
])

# 加载MNIST数据集 28X28X1   10类别   
trainset = torchvision.datasets.FashionMNIST(root=data_path, train=True,
                                        download=True, transform=transform)
testset = torchvision.datasets.FashionMNIST(root=data_path, train=False,
                                        download=True, transform=transform)

# 随机抽取训练集 data_num 张图片作为子集
subset_indices = random.sample(range(len(trainset)), k=data_num)
train_subset = Subset(trainset, subset_indices)

# 随机抽取测试集 data_num 张图片作为子集
subset_val = random.sample(range(len(testset)), k=val_num)
val_subset = Subset(testset, subset_val)

# 加载测试集
trainloader = torch.utils.data.DataLoader(train_subset, batch_size=batch_size,shuffle=True)  # type: ignore
                                          
testloader = torch.utils.data.DataLoader(val_subset, batch_size=batch_size,shuffle=False)   # type: ignore

# %%
n = 4
nlayers = 1

# 我们定义量子函数，
# 注意这个函数是在 tensorflow 上运行的
def qpred(x, weights):

    c = tc.Circuit(n)
    for i in range(n):
        c.h(i)
        c.ry(i, theta=x[i]*weights[i])
    for j in range(nlayers):
        for i in range(n - 1):
            c.cnot(i, i + 1)
    return [K.real(c.expectation([tc.gates.z(), [i]])) for i in range(n)]

# %%
qpred_vmap = K.vmap(qpred, vectorized_argnums=0)        # `qpred_vmap` 是一个具有向量化能力的 TensorFlow 函数
qpred_batch = tc.interfaces.torch_interface(qpred_vmap, jit=True) # 我们进一步将函数包装为 PyTorch 函数

# %%
class QuantumNetV2(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.q_weights = torch.nn.Parameter(torch.randn([n]))
        self.stride = 1
        self.padding_s = 3  # 设定转置卷积的采样率

    def forward(self, inputs):

        in_bs,in_ch,in_w,in_h = inputs.shape

        kernel_size = 2

        padding_size = kernel_size - 1                  # 边界填充数
        
        # num = (in_w-1)*3+1                              # 得到插入空洞的个数 
        # 1 对输入元素间进行填充
        padding_temp = nn.functional.pad(inputs,(25,1,25,1),mode='constant',value=0)
        # print(padding_temp.shape)           # torch.Size([32, 1, 40, 40])
        
        
        # 开始元素间填充
        for bs in range(in_bs):
            for ch in range(in_ch):
                for i in range(in_w):     # 14是输入图片大小
                    for j in range(in_h):
                        padding_temp[bs,ch,i*2,j*2] = inputs[bs,ch,i,j]   # 对原图像（14X14）进行内部空洞
        # print(padding_temp)
        # print(padding_temp.shape)       # torch.Size([32, 1, 40, 40])                                                                                                                                                                                                                            

        # 2 输入特征图的周围进行边界填充， 使用转置卷积进行上采样，作为转置卷积的输入
        padd_img = nn.functional.pad(padding_temp,(padding_size,padding_size,padding_size,padding_size),mode='constant',value=0)
        # print(padd_img.shape)   # torch.Size([32, 1, 42, 42])

        bs, ch , h , w = padd_img.size()                     #    h = 42
        
        # 转置卷积后输出特征图的大小
        h_out = self.padding_s*(in_h-1)+kernel_size           #   3*（14-1）+ 2 = 41
        w_out = self.padding_s*(in_w-1)+kernel_size           #   3*（17-1）+ 2 = 41

        out = torch.zeros((bs,4, h_out, w_out))
        for b in range(bs):
                for j in range(0, h_out, self.stride):
                    for k in range(0, w_out, self.stride):

                        t1 = padd_img[b, 0, j, k]        
                        t2 = padd_img[b, 0, j, k + 1]
                        t3 = padd_img[b, 0, j + 1, k]    
                        t4 = padd_img[b, 0, j + 1, k + 1]

                        temp = torch.Tensor([t1,t2,t3,t4]) # 
                        temp = temp.view(1,4)

                        # temp = torch.unsqueeze(temp, 0)      
                        q_results = qpred_batch(temp, self.q_weights)     
                        for c in range(4):
                            out[b, c,j // kernel_size, k // kernel_size] = q_results[c]
        return out

# %%
# 经典CNNmodel 可进行修改
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
            
        # Quantum layer 1
        self.conv1 = QuantumNetV2()
        self.relu1 = nn.ReLU()
        self.batch1 = nn.BatchNorm2d(4)  # 4
                
        # Fully-Connected layer 2
        self.fc2 = nn.Linear(6724,10)
                
    def forward(self, x):

        # qconv layer 1
        out = self.conv1(x)                 
        out = self.relu1(out)   
        out = self.batch1(out)
        
        #Flatten拉平操作
        out = out.view(out.size(0),-1)      # print(f'-----拉平后的维度是--{out.shape}') #  torch.Size([64, 576])
        
        #FC 第二层
        out = self.fc2(out)
        return F.log_softmax(out,dim = 1)

# %%
model = CNNModel()
loss_fun = nn.CrossEntropyLoss()
opt = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
# 准确率计算
def accuracy(output,labels):
    prediction = torch.max(output.data,1)[1]
    rights = prediction.eq(labels.data.view_as(prediction)).sum()
    return rights,len(labels)

# 绘制训练结果
def draw_result(accs,losses,title):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14, 6))   # subplots创建1行 2列的子图
    
    ax1.plot(losses) 
    ax1.set_title(title+" Loss")
    ax1.set_xlabel("Steps")
    ax1.set_ylabel("Loss")
    
    ax2.plot(accs)
    ax2.set_title(title+" Accuracy")
    ax2.set_xlabel("Steps")
    ax2.set_ylabel("Accuracy")

# %%
def train(epochs,model,loss_fun,opt,train_loader,test_loader):
    train_accuracy = []             # 训练集准确率
    train_loss = []

    val_accuracy = []               # 验证集准确率
    val_loss = []
    for epoch in range(epochs):
                ### 训练模块
        train_total_accuracy = 0    # 训练集每epoch（18个batch的和）的准确率
        train_total_loss = 0
        for batch_idx,(data,labels) in enumerate(train_loader):
            t2 = time.time()
            data = data.view(data.shape[0],1, data.shape[1], data.shape[2])
            # print(data)
            model.train()					    # 1 模型训练       
            output = model(data)			    # 2 模型输出
            # print(f'output.shape is {output.shape}')    # output.shape is torch.Size([64, 4, 17, 17])
            # print(f'labels.shape is {labels.shape}')    # labels.shape is torch.Size([64])
            loss = loss_fun(output,labels)	    # 3 计算损失

            opt.zero_grad()					    # 4 梯度清零
            loss.backward() 				    # 5 开始反向传播
            opt.step()                          # 6 梯度更新
            
            # 计算准确率
            accuracy_count, total_count = accuracy(output,labels)
            accuracy_rate = accuracy_count / total_count  # 计算准确率（预测正确的样本数除以总样本数）

            train_total_accuracy += accuracy_count
            train_total_loss +=loss.item()

            batch_time = time.time()-t2
            print(f'Epoch:{epoch}---batch({batch_idx})训练集---ACC:{accuracy_rate:.2%}---LOSS:{loss.item():.3f}---time:{batch_time:.2f}')        
        
        train_total_loss /= batch_idx+1
        train_accuracy.append(train_total_accuracy/len(train_subset))   # 保存1轮的数据 len(train_accuracy)
        train_loss.append(train_total_loss)
### 验证模块
        total_acc = 0
        total_test_loss = 0
        model.eval()
        with torch.no_grad():# 进行评测的时候网络不更新梯度
            for step,(data,target) in enumerate(test_loader):
                data = data.view(data.shape[0],1, data.shape[1], data.shape[2])            # 调整维度一致
                outputs = model(data)
                losses = loss_fun(outputs,target)                               # 计算损失

                accuracy_count, total_count = accuracy(outputs,target)          # 计算准确率
                accuracy_rate = accuracy_count / total_count                    # 计算准确率（预测正确的样本数除以总样本数）

                total_acc += accuracy_count
                total_test_loss+=losses.item()

        total_test_loss /= step + 1
        val_accuracy.append((total_acc/len(val_subset)))
        val_loss.append(total_test_loss)
        print(f'第{epoch}轮测试集准确率：{total_acc/len(val_subset):.2%}....测试集Loss:{total_test_loss}')
    
    ### 画出训练结果图 ##############
    draw_result(train_accuracy,train_loss,"Train")
    draw_result(val_accuracy,val_loss,"Val")
    
    ####  训练的结果写入文件   ##############
    with open(str(random.randint(100,999))+"_train.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Train_loss','Train_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, train_loss[i], train_accuracy[i].numpy()])
    
    #### 测试的结果写入文件  ##############
    with open(str(random.randint(1000,9999))+"_val.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Val_loss','Val_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, val_loss[i], val_accuracy[i].numpy()])

    ### 保存训练的结果
    # Loss0 = torch.tensor(save_train_loss)
    # torch.save(Loss0,'E:\\Test\\VsCode_Test\\Python\\xlw\\test1\\lw2\\epoch_{}'.format(epochs))
    return model, train_accuracy,train_loss

model, train_accuracy,train_loss = train(epochs,model,loss_fun,opt,trainloader,testloader)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to C:\Users\17861160902_16355000\vscode\data\FashionMNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:46<00:00, 573808.94it/s]
# Extracting C:\Users\17861160902_16355000\vscode\data\FashionMNIST\raw\train-images-idx3-ubyte.gz to C:\Users\17861160902_16355000\vscode\data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to C:\Users\17861160902_16355000\vscode\data\FashionMNIST\raw\train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 142331.91it/s]
# Extracting C:\Users\17861160902_16355000\vscode\data\FashionMNIST\raw\train-labels-idx1-ubyte.gz to C:\Users\17861160902_16355000\vscode\data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to C:\Users\17861160902_16355000\vscode\data\FashionMNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:07<00:00, 556293.65it/s]
# Extracting C:\Users\17861160902_16355000\vscode\data\FashionMNIST\raw\t10k-images-idx3-ubyte.gz to C:\Users\17861160902_16355000\vscode\data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to C:\Users\17861160902_16355000\vscode\data\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 2504613.96it/s]
# Extracting C:\Users\17861160902_16355000\vscode\data\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz to C:\Users\17861160902_16355000\vscode\data\FashionMNIST\raw
#
# Epoch:0---batch(0)训练集---ACC:6.25%---LOSS:2.394---time:123.81
# Epoch:0---batch(1)训练集---ACC:21.88%---LOSS:11.205---time:104.93
# Epoch:0---batch(2)训练集---ACC:31.25%---LOSS:7.508---time:105.19
# Epoch:0---batch(3)训练集---ACC:18.75%---LOSS:9.149---time:110.57
# Epoch:0---batch(4)训练集---ACC:31.25%---LOSS:5.740---time:113.10
# Epoch:0---batch(5)训练集---ACC:46.88%---LOSS:4.291---time:107.17
# Epoch:0---batch(6)训练集---ACC:62.50%---LOSS:1.851---time:108.50
# Epoch:0---batch(7)训练集---ACC:43.75%---LOSS:2.118---time:109.68
# Epoch:0---batch(8)训练集---ACC:40.62%---LOSS:3.083---time:111.46
# Epoch:0---batch(9)训练集---ACC:56.25%---LOSS:2.023---time:108.50
# Epoch:0---batch(10)训练集---ACC:53.12%---LOSS:1.858---time:108.42
# Epoch:0---batch(11)训练集---ACC:56.25%---LOSS:1.611---time:107.31
# Epoch:0---batch(12)训练集---ACC:43.75%---LOSS:2.102---time:107.70
# Epoch:0---batch(13)训练集---ACC:43.75%---LOSS:2.818---time:108.35
# Epoch:0---batch(14)训练集---ACC:56.25%---LOSS:1.711---time:106.33
# Epoch:0---batch(15)训练集---ACC:68.75%---LOSS:1.284---time:107.64
# Epoch:0---batch(16)训练集---ACC:62.50%---LOSS:2.065---time:108.08
# Epoch:0---batch(17)训练集---ACC:71.88%---LOSS:1.549---time:107.95
# Epoch:0---batch(18)训练集---ACC:65.62%---LOSS:1.189---time:108.55
# Epoch:0---batch(19)训练集---ACC:65.62%---LOSS:2.723---time:107.35
# Epoch:0---batch(20)训练集---ACC:68.75%---LOSS:1.786---time:107.26
# Epoch:0---batch(21)训练集---ACC:78.12%---LOSS:0.924---time:107.47
# Epoch:0---batch(22)训练集---ACC:75.00%---LOSS:1.335---time:108.27
# Epoch:0---batch(23)训练集---ACC:75.00%---LOSS:1.383---time:106.36
# Epoch:0---batch(24)训练集---ACC:81.25%---LOSS:0.587---time:107.44
# Epoch:0---batch(25)训练集---ACC:65.62%---LOSS:1.667---time:107.48
# Epoch:0---batch(26)训练集---ACC:65.62%---LOSS:1.558---time:108.24
# Epoch:0---batch(27)训练集---ACC:65.62%---LOSS:1.594---time:106.31
# Epoch:0---batch(28)训练集---ACC:56.25%---LOSS:2.425---time:107.01
# Epoch:0---batch(29)训练集---ACC:59.38%---LOSS:1.466---time:107.36
# Epoch:0---batch(30)训练集---ACC:46.88%---LOSS:1.612---time:106.52
# Epoch:0---batch(31)训练集---ACC:50.00%---LOSS:1.384---time:107.18
# Epoch:0---batch(32)训练集---ACC:62.50%---LOSS:0.809---time:108.18
# Epoch:0---batch(33)训练集---ACC:87.50%---LOSS:1.278---time:107.25
# Epoch:0---batch(34)训练集---ACC:68.75%---LOSS:2.127---time:106.06
# Epoch:0---batch(35)训练集---ACC:81.25%---LOSS:0.913---time:107.67
# Epoch:0---batch(36)训练集---ACC:59.38%---LOSS:2.115---time:107.10
# Epoch:0---batch(37)训练集---ACC:62.50%---LOSS:2.063---time:53.45
# 第0轮测试集准确率：36.50%....测试集Loss:3.919805015836443
# Epoch:1---batch(0)训练集---ACC:65.62%---LOSS:1.509---time:107.76
# Epoch:1---batch(1)训练集---ACC:71.88%---LOSS:0.934---time:107.45
# Epoch:1---batch(2)训练集---ACC:81.25%---LOSS:0.771---time:106.68
# Epoch:1---batch(3)训练集---ACC:65.62%---LOSS:1.345---time:105.67
# Epoch:1---batch(4)训练集---ACC:53.12%---LOSS:1.712---time:106.67
# Epoch:1---batch(5)训练集---ACC:78.12%---LOSS:0.593---time:107.12
# Epoch:1---batch(6)训练集---ACC:71.88%---LOSS:0.880---time:107.41
# Epoch:1---batch(7)训练集---ACC:59.38%---LOSS:1.434---time:106.64
# Epoch:1---batch(8)训练集---ACC:71.88%---LOSS:0.929---time:106.21
# Epoch:1---batch(9)训练集---ACC:71.88%---LOSS:1.161---time:106.02
# Epoch:1---batch(10)训练集---ACC:78.12%---LOSS:0.719---time:106.19
# Epoch:1---batch(11)训练集---ACC:81.25%---LOSS:0.682---time:107.57
# Epoch:1---batch(12)训练集---ACC:75.00%---LOSS:0.799---time:108.52
# Epoch:1---batch(13)训练集---ACC:65.62%---LOSS:1.299---time:106.81
# Epoch:1---batch(14)训练集---ACC:65.62%---LOSS:0.920---time:106.34
# Epoch:1---batch(15)训练集---ACC:65.62%---LOSS:0.721---time:106.44
# Epoch:1---batch(16)训练集---ACC:81.25%---LOSS:0.593---time:106.75
# Epoch:1---batch(17)训练集---ACC:71.88%---LOSS:0.779---time:106.93
# Epoch:1---batch(18)训练集---ACC:78.12%---LOSS:0.945---time:106.27
# Epoch:1---batch(19)训练集---ACC:84.38%---LOSS:0.476---time:106.13
# Epoch:1---batch(20)训练集---ACC:87.50%---LOSS:0.360---time:106.34
# Epoch:1---batch(21)训练集---ACC:71.88%---LOSS:1.071---time:106.66
# Epoch:1---batch(22)训练集---ACC:71.88%---LOSS:1.041---time:106.98
# Epoch:1---batch(23)训练集---ACC:75.00%---LOSS:0.752---time:107.10
# Epoch:1---batch(24)训练集---ACC:78.12%---LOSS:0.919---time:106.17
# Epoch:1---batch(25)训练集---ACC:71.88%---LOSS:0.806---time:106.43
# Epoch:1---batch(26)训练集---ACC:68.75%---LOSS:0.969---time:106.18
# Epoch:1---batch(27)训练集---ACC:62.50%---LOSS:1.554---time:106.23
# Epoch:1---batch(28)训练集---ACC:75.00%---LOSS:0.776---time:106.25
# Epoch:1---batch(29)训练集---ACC:87.50%---LOSS:0.565---time:107.10
# Epoch:1---batch(30)训练集---ACC:59.38%---LOSS:1.194---time:107.25
# Epoch:1---batch(31)训练集---ACC:65.62%---LOSS:1.245---time:106.55
# Epoch:1---batch(32)训练集---ACC:71.88%---LOSS:0.826---time:106.04
# Epoch:1---batch(33)训练集---ACC:75.00%---LOSS:0.812---time:107.55
# Epoch:1---batch(34)训练集---ACC:65.62%---LOSS:1.097---time:108.12
# Epoch:1---batch(35)训练集---ACC:68.75%---LOSS:1.405---time:106.81
# Epoch:1---batch(36)训练集---ACC:78.12%---LOSS:0.436---time:105.43
# Epoch:1---batch(37)训练集---ACC:75.00%---LOSS:0.727---time:52.82
# 第1轮测试集准确率：73.50%....测试集Loss:0.7497844185147967
# Epoch:2---batch(0)训练集---ACC:93.75%---LOSS:0.306---time:107.67
# Epoch:2---batch(1)训练集---ACC:65.62%---LOSS:1.142---time:106.69
# Epoch:2---batch(2)训练集---ACC:65.62%---LOSS:1.192---time:106.41
# Epoch:2---batch(3)训练集---ACC:65.62%---LOSS:0.967---time:105.92
# Epoch:2---batch(4)训练集---ACC:75.00%---LOSS:0.747---time:106.22
# Epoch:2---batch(5)训练集---ACC:75.00%---LOSS:1.246---time:106.48
# Epoch:2---batch(6)训练集---ACC:81.25%---LOSS:0.523---time:106.02
# Epoch:2---batch(7)训练集---ACC:75.00%---LOSS:0.859---time:107.11
# Epoch:2---batch(8)训练集---ACC:71.88%---LOSS:0.746---time:105.82
# Epoch:2---batch(9)训练集---ACC:68.75%---LOSS:1.102---time:106.68
# Epoch:2---batch(10)训练集---ACC:68.75%---LOSS:0.997---time:106.59
# Epoch:2---batch(11)训练集---ACC:81.25%---LOSS:0.484---time:106.85
# Epoch:2---batch(12)训练集---ACC:56.25%---LOSS:1.277---time:106.31
# Epoch:2---batch(13)训练集---ACC:71.88%---LOSS:1.183---time:105.91
# Epoch:2---batch(14)训练集---ACC:84.38%---LOSS:0.470---time:105.15
# Epoch:2---batch(15)训练集---ACC:71.88%---LOSS:1.169---time:106.37
# Epoch:2---batch(16)训练集---ACC:65.62%---LOSS:0.970---time:106.28
# Epoch:2---batch(17)训练集---ACC:78.12%---LOSS:0.821---time:105.81
# Epoch:2---batch(18)训练集---ACC:75.00%---LOSS:0.780---time:106.60
# Epoch:2---batch(19)训练集---ACC:75.00%---LOSS:0.824---time:109.19
# Epoch:2---batch(20)训练集---ACC:65.62%---LOSS:0.745---time:109.41
# Epoch:2---batch(21)训练集---ACC:90.62%---LOSS:0.251---time:107.45
# Epoch:2---batch(22)训练集---ACC:84.38%---LOSS:0.495---time:107.98
# Epoch:2---batch(23)训练集---ACC:78.12%---LOSS:0.608---time:107.48
# Epoch:2---batch(24)训练集---ACC:75.00%---LOSS:1.407---time:109.62
# Epoch:2---batch(25)训练集---ACC:71.88%---LOSS:0.510---time:106.82
# Epoch:2---batch(26)训练集---ACC:75.00%---LOSS:0.954---time:107.75
# Epoch:2---batch(27)训练集---ACC:78.12%---LOSS:0.827---time:107.24
# Epoch:2---batch(28)训练集---ACC:78.12%---LOSS:0.728---time:105.51
# Epoch:2---batch(29)训练集---ACC:75.00%---LOSS:0.887---time:107.13
# Epoch:2---batch(30)训练集---ACC:71.88%---LOSS:0.859---time:108.43
# Epoch:2---batch(31)训练集---ACC:81.25%---LOSS:0.686---time:106.28
# Epoch:2---batch(32)训练集---ACC:65.62%---LOSS:0.912---time:106.65
# Epoch:2---batch(33)训练集---ACC:56.25%---LOSS:0.866---time:107.01
# Epoch:2---batch(34)训练集---ACC:71.88%---LOSS:0.542---time:108.13
# Epoch:2---batch(35)训练集---ACC:78.12%---LOSS:0.648---time:106.57
# Epoch:2---batch(36)训练集---ACC:75.00%---LOSS:0.820---time:105.96
# Epoch:2---batch(37)训练集---ACC:75.00%---LOSS:0.900---time:53.63
# 第2轮测试集准确率：69.00%....测试集Loss:1.0792834162712097
# Epoch:3---batch(0)训练集---ACC:93.75%---LOSS:0.296---time:106.56
# Epoch:3---batch(1)训练集---ACC:75.00%---LOSS:0.947---time:106.60
# Epoch:3---batch(2)训练集---ACC:65.62%---LOSS:0.893---time:107.65
# Epoch:3---batch(3)训练集---ACC:81.25%---LOSS:0.826---time:107.42
# Epoch:3---batch(4)训练集---ACC:78.12%---LOSS:0.687---time:105.96
# Epoch:3---batch(5)训练集---ACC:78.12%---LOSS:0.614---time:106.52
# Epoch:3---batch(6)训练集---ACC:84.38%---LOSS:0.472---time:106.33
# Epoch:3---batch(7)训练集---ACC:78.12%---LOSS:0.871---time:105.45
# Epoch:3---batch(8)训练集---ACC:81.25%---LOSS:0.604---time:106.30
# Epoch:3---batch(9)训练集---ACC:59.38%---LOSS:1.560---time:106.31
# Epoch:3---batch(10)训练集---ACC:87.50%---LOSS:0.409---time:107.64
# Epoch:3---batch(11)训练集---ACC:81.25%---LOSS:0.750---time:106.67
# Epoch:3---batch(12)训练集---ACC:87.50%---LOSS:0.493---time:107.55
# Epoch:3---batch(13)训练集---ACC:62.50%---LOSS:1.264---time:107.93
# Epoch:3---batch(14)训练集---ACC:87.50%---LOSS:0.256---time:106.01
# Epoch:3---batch(15)训练集---ACC:78.12%---LOSS:0.680---time:107.74
# Epoch:3---batch(16)训练集---ACC:71.88%---LOSS:0.881---time:106.79
# Epoch:3---batch(17)训练集---ACC:81.25%---LOSS:0.524---time:106.85
# Epoch:3---batch(18)训练集---ACC:81.25%---LOSS:0.915---time:106.57
# Epoch:3---batch(19)训练集---ACC:78.12%---LOSS:0.611---time:105.99
# Epoch:3---batch(20)训练集---ACC:81.25%---LOSS:0.502---time:106.53
# Epoch:3---batch(21)训练集---ACC:81.25%---LOSS:0.410---time:107.25
# Epoch:3---batch(22)训练集---ACC:78.12%---LOSS:0.676---time:105.69
# Epoch:3---batch(23)训练集---ACC:78.12%---LOSS:0.396---time:107.18
# Epoch:3---batch(24)训练集---ACC:65.62%---LOSS:0.728---time:106.46
# Epoch:3---batch(25)训练集---ACC:68.75%---LOSS:1.144---time:106.56
# Epoch:3---batch(26)训练集---ACC:81.25%---LOSS:0.456---time:106.36
# Epoch:3---batch(27)训练集---ACC:75.00%---LOSS:0.695---time:106.22
# Epoch:3---batch(28)训练集---ACC:84.38%---LOSS:0.485---time:108.99
# Epoch:3---batch(29)训练集---ACC:93.75%---LOSS:0.244---time:107.25
# Epoch:3---batch(30)训练集---ACC:68.75%---LOSS:1.181---time:107.82
# Epoch:3---batch(31)训练集---ACC:68.75%---LOSS:0.929---time:106.45
# Epoch:3---batch(32)训练集---ACC:68.75%---LOSS:0.872---time:107.22
# Epoch:3---batch(33)训练集---ACC:71.88%---LOSS:0.557---time:108.48
# Epoch:3---batch(34)训练集---ACC:65.62%---LOSS:0.726---time:105.73
# Epoch:3---batch(35)训练集---ACC:71.88%---LOSS:0.812---time:105.68
# Epoch:3---batch(36)训练集---ACC:84.38%---LOSS:0.828---time:105.96
# Epoch:3---batch(37)训练集---ACC:50.00%---LOSS:1.133---time:54.08
# 第3轮测试集准确率：73.00%....测试集Loss:0.7741365092141288
# Epoch:4---batch(0)训练集---ACC:78.12%---LOSS:0.763---time:108.04
# Epoch:4---batch(1)训练集---ACC:81.25%---LOSS:0.510---time:107.67
# Epoch:4---batch(2)训练集---ACC:81.25%---LOSS:0.745---time:107.56
# Epoch:4---batch(3)训练集---ACC:78.12%---LOSS:0.655---time:107.25
# Epoch:4---batch(4)训练集---ACC:75.00%---LOSS:0.742---time:107.14
# Epoch:4---batch(5)训练集---ACC:84.38%---LOSS:0.580---time:107.12
# Epoch:4---batch(6)训练集---ACC:81.25%---LOSS:0.504---time:107.62
# Epoch:4---batch(7)训练集---ACC:81.25%---LOSS:0.519---time:107.53
# Epoch:4---batch(8)训练集---ACC:84.38%---LOSS:0.531---time:106.04
# Epoch:4---batch(9)训练集---ACC:78.12%---LOSS:0.612---time:106.45
# Epoch:4---batch(10)训练集---ACC:84.38%---LOSS:0.401---time:107.64
# Epoch:4---batch(11)训练集---ACC:71.88%---LOSS:0.686---time:106.68
# Epoch:4---batch(12)训练集---ACC:68.75%---LOSS:0.761---time:106.01
# Epoch:4---batch(13)训练集---ACC:87.50%---LOSS:0.522---time:107.22
# Epoch:4---batch(14)训练集---ACC:78.12%---LOSS:0.528---time:107.14
# Epoch:4---batch(15)训练集---ACC:87.50%---LOSS:0.528---time:106.21
# Epoch:4---batch(16)训练集---ACC:81.25%---LOSS:0.980---time:106.65
# Epoch:4---batch(17)训练集---ACC:90.62%---LOSS:0.289---time:105.86
# Epoch:4---batch(18)训练集---ACC:78.12%---LOSS:0.661---time:105.62
# Epoch:4---batch(19)训练集---ACC:81.25%---LOSS:0.601---time:105.88
# Epoch:4---batch(20)训练集---ACC:90.62%---LOSS:0.234---time:106.61
# Epoch:4---batch(21)训练集---ACC:71.88%---LOSS:0.855---time:106.09
# Epoch:4---batch(22)训练集---ACC:65.62%---LOSS:0.790---time:106.51
# Epoch:4---batch(23)训练集---ACC:81.25%---LOSS:0.641---time:106.04
# Epoch:4---batch(24)训练集---ACC:78.12%---LOSS:0.596---time:105.84
# Epoch:4---batch(25)训练集---ACC:78.12%---LOSS:0.465---time:105.45
# Epoch:4---batch(26)训练集---ACC:84.38%---LOSS:0.419---time:106.14
# Epoch:4---batch(27)训练集---ACC:75.00%---LOSS:0.775---time:105.65
# Epoch:4---batch(28)训练集---ACC:84.38%---LOSS:0.555---time:107.52
# Epoch:4---batch(29)训练集---ACC:81.25%---LOSS:0.518---time:105.54
# Epoch:4---batch(30)训练集---ACC:71.88%---LOSS:0.624---time:106.56
# Epoch:4---batch(31)训练集---ACC:75.00%---LOSS:0.685---time:106.96
# Epoch:4---batch(32)训练集---ACC:78.12%---LOSS:0.496---time:108.70
# Epoch:4---batch(33)训练集---ACC:68.75%---LOSS:0.978---time:107.90
# Epoch:4---batch(34)训练集---ACC:90.62%---LOSS:0.480---time:107.97
# Epoch:4---batch(35)训练集---ACC:75.00%---LOSS:0.778---time:107.16
# Epoch:4---batch(36)训练集---ACC:90.62%---LOSS:0.417---time:107.21
# Epoch:4---batch(37)训练集---ACC:81.25%---LOSS:0.514---time:53.51
# 第4轮测试集准确率：74.50%....测试集Loss:0.7579919823578426
# Epoch:5---batch(0)训练集---ACC:96.88%---LOSS:0.239---time:106.56
# Epoch:5---batch(1)训练集---ACC:90.62%---LOSS:0.331---time:106.76
# Epoch:5---batch(2)训练集---ACC:78.12%---LOSS:0.464---time:106.15
# Epoch:5---batch(3)训练集---ACC:87.50%---LOSS:0.506---time:107.38
# Epoch:5---batch(4)训练集---ACC:81.25%---LOSS:0.555---time:106.48
# Epoch:5---batch(5)训练集---ACC:75.00%---LOSS:0.555---time:105.99
# Epoch:5---batch(6)训练集---ACC:84.38%---LOSS:0.500---time:105.49
# Epoch:5---batch(7)训练集---ACC:90.62%---LOSS:0.325---time:106.76
# Epoch:5---batch(8)训练集---ACC:56.25%---LOSS:1.182---time:106.72
# Epoch:5---batch(9)训练集---ACC:78.12%---LOSS:0.823---time:106.77
# Epoch:5---batch(10)训练集---ACC:68.75%---LOSS:0.741---time:105.30
# Epoch:5---batch(11)训练集---ACC:87.50%---LOSS:0.443---time:107.41
# Epoch:5---batch(12)训练集---ACC:81.25%---LOSS:0.711---time:107.19
# Epoch:5---batch(13)训练集---ACC:93.75%---LOSS:0.264---time:109.69
# Epoch:5---batch(14)训练集---ACC:84.38%---LOSS:0.802---time:107.37
# Epoch:5---batch(15)训练集---ACC:71.88%---LOSS:0.722---time:107.64
# Epoch:5---batch(16)训练集---ACC:78.12%---LOSS:0.547---time:108.98
# Epoch:5---batch(17)训练集---ACC:84.38%---LOSS:0.549---time:107.76
# Epoch:5---batch(18)训练集---ACC:84.38%---LOSS:0.540---time:107.92
# Epoch:5---batch(19)训练集---ACC:65.62%---LOSS:1.234---time:107.26
# Epoch:5---batch(20)训练集---ACC:84.38%---LOSS:0.480---time:107.71
# Epoch:5---batch(21)训练集---ACC:81.25%---LOSS:0.641---time:106.81
# Epoch:5---batch(22)训练集---ACC:78.12%---LOSS:0.648---time:109.15
# Epoch:5---batch(23)训练集---ACC:81.25%---LOSS:0.513---time:109.93
# Epoch:5---batch(24)训练集---ACC:71.88%---LOSS:0.694---time:108.40
# Epoch:5---batch(25)训练集---ACC:78.12%---LOSS:0.599---time:108.37
# Epoch:5---batch(26)训练集---ACC:71.88%---LOSS:0.715---time:108.40
# Epoch:5---batch(27)训练集---ACC:78.12%---LOSS:0.575---time:109.13
# Epoch:5---batch(28)训练集---ACC:78.12%---LOSS:0.509---time:106.89
# Epoch:5---batch(29)训练集---ACC:75.00%---LOSS:0.526---time:108.19
# Epoch:5---batch(30)训练集---ACC:71.88%---LOSS:1.024---time:108.00
# Epoch:5---batch(31)训练集---ACC:56.25%---LOSS:1.631---time:108.81
# Epoch:5---batch(32)训练集---ACC:78.12%---LOSS:0.891---time:107.64
# Epoch:5---batch(33)训练集---ACC:84.38%---LOSS:0.456---time:107.07
# Epoch:5---batch(34)训练集---ACC:81.25%---LOSS:0.453---time:107.62
# Epoch:5---batch(35)训练集---ACC:84.38%---LOSS:0.368---time:107.55
# Epoch:5---batch(36)训练集---ACC:84.38%---LOSS:0.470---time:107.21
# Epoch:5---batch(37)训练集---ACC:81.25%---LOSS:0.671---time:53.50
# 第5轮测试集准确率：70.00%....测试集Loss:0.8028347449643272
# Epoch:6---batch(0)训练集---ACC:90.62%---LOSS:0.320---time:108.09
# Epoch:6---batch(1)训练集---ACC:81.25%---LOSS:0.432---time:108.06
# Epoch:6---batch(2)训练集---ACC:78.12%---LOSS:0.446---time:109.19
# Epoch:6---batch(3)训练集---ACC:78.12%---LOSS:0.951---time:108.10
# Epoch:6---batch(4)训练集---ACC:90.62%---LOSS:0.338---time:108.17
# Epoch:6---batch(5)训练集---ACC:81.25%---LOSS:0.375---time:108.61
# Epoch:6---batch(6)训练集---ACC:71.88%---LOSS:0.627---time:108.27
# Epoch:6---batch(7)训练集---ACC:84.38%---LOSS:0.539---time:108.63
# Epoch:6---batch(8)训练集---ACC:84.38%---LOSS:0.529---time:107.67
# Epoch:6---batch(9)训练集---ACC:75.00%---LOSS:0.659---time:108.57
# Epoch:6---batch(10)训练集---ACC:62.50%---LOSS:0.820---time:107.62
# Epoch:6---batch(11)训练集---ACC:81.25%---LOSS:0.599---time:108.43
# Epoch:6---batch(12)训练集---ACC:84.38%---LOSS:0.477---time:109.13
# Epoch:6---batch(13)训练集---ACC:71.88%---LOSS:0.566---time:109.52
# Epoch:6---batch(14)训练集---ACC:81.25%---LOSS:0.699---time:108.02
# Epoch:6---batch(15)训练集---ACC:84.38%---LOSS:0.406---time:108.73
# Epoch:6---batch(16)训练集---ACC:81.25%---LOSS:0.686---time:108.58
# Epoch:6---batch(17)训练集---ACC:81.25%---LOSS:0.696---time:108.65
# Epoch:6---batch(18)训练集---ACC:78.12%---LOSS:0.600---time:109.16
# Epoch:6---batch(19)训练集---ACC:59.38%---LOSS:1.006---time:107.48
# Epoch:6---batch(20)训练集---ACC:81.25%---LOSS:0.392---time:107.69
# Epoch:6---batch(21)训练集---ACC:68.75%---LOSS:0.611---time:108.36
# Epoch:6---batch(22)训练集---ACC:81.25%---LOSS:0.673---time:107.73
# Epoch:6---batch(23)训练集---ACC:81.25%---LOSS:0.558---time:106.83
# Epoch:6---batch(24)训练集---ACC:65.62%---LOSS:0.872---time:107.03
# Epoch:6---batch(25)训练集---ACC:78.12%---LOSS:0.466---time:107.96
# Epoch:6---batch(26)训练集---ACC:84.38%---LOSS:0.494---time:106.69
# Epoch:6---batch(27)训练集---ACC:81.25%---LOSS:0.706---time:106.75
# Epoch:6---batch(28)训练集---ACC:81.25%---LOSS:0.366---time:107.25
# Epoch:6---batch(29)训练集---ACC:84.38%---LOSS:0.716---time:107.15
# Epoch:6---batch(30)训练集---ACC:87.50%---LOSS:0.518---time:107.02
# Epoch:6---batch(31)训练集---ACC:68.75%---LOSS:0.938---time:108.27
# Epoch:6---batch(32)训练集---ACC:68.75%---LOSS:1.020---time:106.11
# Epoch:6---batch(33)训练集---ACC:87.50%---LOSS:0.336---time:105.93
# Epoch:6---batch(34)训练集---ACC:84.38%---LOSS:0.542---time:106.10
# Epoch:6---batch(35)训练集---ACC:81.25%---LOSS:0.533---time:106.09
# Epoch:6---batch(36)训练集---ACC:78.12%---LOSS:0.522---time:107.16
# Epoch:6---batch(37)训练集---ACC:87.50%---LOSS:0.498---time:53.31
# 第6轮测试集准确率：72.00%....测试集Loss:0.764332360454968
# Epoch:7---batch(0)训练集---ACC:65.62%---LOSS:1.059---time:107.11
# Epoch:7---batch(1)训练集---ACC:81.25%---LOSS:0.457---time:107.84
# Epoch:7---batch(2)训练集---ACC:87.50%---LOSS:0.356---time:107.21
# Epoch:7---batch(3)训练集---ACC:81.25%---LOSS:0.512---time:110.70
# Epoch:7---batch(4)训练集---ACC:90.62%---LOSS:0.331---time:108.00
# Epoch:7---batch(5)训练集---ACC:78.12%---LOSS:0.581---time:106.16
# Epoch:7---batch(6)训练集---ACC:84.38%---LOSS:0.461---time:107.14
# Epoch:7---batch(7)训练集---ACC:87.50%---LOSS:0.518---time:105.80
# Epoch:7---batch(8)训练集---ACC:90.62%---LOSS:0.322---time:106.26
# Epoch:7---batch(9)训练集---ACC:81.25%---LOSS:0.417---time:106.30
# Epoch:7---batch(10)训练集---ACC:81.25%---LOSS:0.509---time:105.72
# Epoch:7---batch(11)训练集---ACC:84.38%---LOSS:0.386---time:106.62
# Epoch:7---batch(12)训练集---ACC:81.25%---LOSS:0.705---time:105.99
# Epoch:7---batch(13)训练集---ACC:81.25%---LOSS:0.424---time:105.78
# Epoch:7---batch(14)训练集---ACC:75.00%---LOSS:0.533---time:105.32
# Epoch:7---batch(15)训练集---ACC:84.38%---LOSS:0.498---time:105.97
# Epoch:7---batch(16)训练集---ACC:71.88%---LOSS:0.691---time:105.56
# Epoch:7---batch(17)训练集---ACC:87.50%---LOSS:0.366---time:106.03
# Epoch:7---batch(18)训练集---ACC:71.88%---LOSS:0.717---time:106.36
# Epoch:7---batch(19)训练集---ACC:81.25%---LOSS:0.542---time:106.18
# Epoch:7---batch(20)训练集---ACC:90.62%---LOSS:0.224---time:105.55
# Epoch:7---batch(21)训练集---ACC:81.25%---LOSS:0.374---time:106.18
# Epoch:7---batch(22)训练集---ACC:71.88%---LOSS:0.573---time:106.11
# Epoch:7---batch(23)训练集---ACC:93.75%---LOSS:0.252---time:105.55
# Epoch:7---batch(24)训练集---ACC:93.75%---LOSS:0.378---time:106.52
# Epoch:7---batch(25)训练集---ACC:81.25%---LOSS:0.480---time:106.05
# Epoch:7---batch(26)训练集---ACC:84.38%---LOSS:0.363---time:105.14
# Epoch:7---batch(27)训练集---ACC:71.88%---LOSS:0.623---time:106.69
# Epoch:7---batch(28)训练集---ACC:84.38%---LOSS:0.494---time:105.56
# Epoch:7---batch(29)训练集---ACC:78.12%---LOSS:0.611---time:106.68
# Epoch:7---batch(30)训练集---ACC:84.38%---LOSS:0.337---time:106.13
# Epoch:7---batch(31)训练集---ACC:81.25%---LOSS:0.634---time:106.67
# Epoch:7---batch(32)训练集---ACC:71.88%---LOSS:0.559---time:106.47
# Epoch:7---batch(33)训练集---ACC:75.00%---LOSS:0.568---time:106.01
# Epoch:7---batch(34)训练集---ACC:75.00%---LOSS:0.614---time:105.79
# Epoch:7---batch(35)训练集---ACC:84.38%---LOSS:0.498---time:105.46
# Epoch:7---batch(36)训练集---ACC:84.38%---LOSS:0.356---time:106.39
# Epoch:7---batch(37)训练集---ACC:75.00%---LOSS:1.015---time:53.93
# 第7轮测试集准确率：74.50%....测试集Loss:0.7620143336909158
# Epoch:8---batch(0)训练集---ACC:78.12%---LOSS:0.564---time:107.05
# Epoch:8---batch(1)训练集---ACC:84.38%---LOSS:0.668---time:105.95
# Epoch:8---batch(2)训练集---ACC:93.75%---LOSS:0.310---time:107.11
# Epoch:8---batch(3)训练集---ACC:84.38%---LOSS:0.521---time:106.80
# Epoch:8---batch(4)训练集---ACC:78.12%---LOSS:0.601---time:106.43
# Epoch:8---batch(5)训练集---ACC:71.88%---LOSS:0.884---time:107.65
# Epoch:8---batch(6)训练集---ACC:84.38%---LOSS:0.556---time:105.08
# Epoch:8---batch(7)训练集---ACC:75.00%---LOSS:0.623---time:106.54
# Epoch:8---batch(8)训练集---ACC:87.50%---LOSS:0.327---time:105.75
# Epoch:8---batch(9)训练集---ACC:78.12%---LOSS:0.475---time:105.90
# Epoch:8---batch(10)训练集---ACC:81.25%---LOSS:0.524---time:105.58
# Epoch:8---batch(11)训练集---ACC:84.38%---LOSS:0.346---time:106.05
# Epoch:8---batch(12)训练集---ACC:84.38%---LOSS:0.571---time:107.14
# Epoch:8---batch(13)训练集---ACC:81.25%---LOSS:0.497---time:105.95
# Epoch:8---batch(14)训练集---ACC:87.50%---LOSS:0.388---time:105.91
# Epoch:8---batch(15)训练集---ACC:93.75%---LOSS:0.340---time:105.92
# Epoch:8---batch(16)训练集---ACC:87.50%---LOSS:0.553---time:106.91
# Epoch:8---batch(17)训练集---ACC:84.38%---LOSS:0.385---time:106.14
# Epoch:8---batch(18)训练集---ACC:68.75%---LOSS:0.618---time:106.35
# Epoch:8---batch(19)训练集---ACC:90.62%---LOSS:0.315---time:105.99
# Epoch:8---batch(20)训练集---ACC:84.38%---LOSS:0.317---time:107.84
# Epoch:8---batch(21)训练集---ACC:81.25%---LOSS:0.558---time:106.79
# Epoch:8---batch(22)训练集---ACC:87.50%---LOSS:0.407---time:106.67
# Epoch:8---batch(23)训练集---ACC:84.38%---LOSS:0.511---time:107.14
# Epoch:8---batch(24)训练集---ACC:87.50%---LOSS:0.316---time:105.99
# Epoch:8---batch(25)训练集---ACC:84.38%---LOSS:0.363---time:107.58
# Epoch:8---batch(26)训练集---ACC:84.38%---LOSS:0.540---time:107.03
# Epoch:8---batch(27)训练集---ACC:81.25%---LOSS:0.465---time:107.54
# Epoch:8---batch(28)训练集---ACC:81.25%---LOSS:0.630---time:107.06
# Epoch:8---batch(29)训练集---ACC:84.38%---LOSS:0.501---time:106.49
# Epoch:8---batch(30)训练集---ACC:87.50%---LOSS:0.290---time:107.72
# Epoch:8---batch(31)训练集---ACC:84.38%---LOSS:0.349---time:107.45
# Epoch:8---batch(32)训练集---ACC:84.38%---LOSS:0.886---time:107.56
# Epoch:8---batch(33)训练集---ACC:84.38%---LOSS:0.581---time:106.30
# Epoch:8---batch(34)训练集---ACC:81.25%---LOSS:0.579---time:106.88
# Epoch:8---batch(35)训练集---ACC:84.38%---LOSS:0.484---time:107.01
# Epoch:8---batch(36)训练集---ACC:84.38%---LOSS:0.461---time:106.69
# Epoch:8---batch(37)训练集---ACC:75.00%---LOSS:0.975---time:52.53
# 第8轮测试集准确率：76.50%....测试集Loss:0.735032707452774
# Epoch:9---batch(0)训练集---ACC:84.38%---LOSS:0.505---time:106.89
# Epoch:9---batch(1)训练集---ACC:84.38%---LOSS:0.555---time:105.80
# Epoch:9---batch(2)训练集---ACC:81.25%---LOSS:0.464---time:106.08
# Epoch:9---batch(3)训练集---ACC:90.62%---LOSS:0.419---time:106.95
# Epoch:9---batch(4)训练集---ACC:81.25%---LOSS:0.696---time:105.98
# Epoch:9---batch(5)训练集---ACC:81.25%---LOSS:0.589---time:105.46
# Epoch:9---batch(6)训练集---ACC:87.50%---LOSS:0.635---time:107.77
# Epoch:9---batch(7)训练集---ACC:84.38%---LOSS:0.466---time:107.02
# Epoch:9---batch(8)训练集---ACC:90.62%---LOSS:0.314---time:105.83
# Epoch:9---batch(9)训练集---ACC:78.12%---LOSS:0.410---time:106.64
# Epoch:9---batch(10)训练集---ACC:68.75%---LOSS:0.869---time:106.60
# Epoch:9---batch(11)训练集---ACC:81.25%---LOSS:0.783---time:106.60
# Epoch:9---batch(12)训练集---ACC:71.88%---LOSS:0.876---time:106.37
# Epoch:9---batch(13)训练集---ACC:78.12%---LOSS:0.535---time:106.69
# Epoch:9---batch(14)训练集---ACC:84.38%---LOSS:0.551---time:106.97
# Epoch:9---batch(15)训练集---ACC:81.25%---LOSS:0.513---time:107.03
# Epoch:9---batch(16)训练集---ACC:87.50%---LOSS:0.638---time:107.10
# Epoch:9---batch(17)训练集---ACC:84.38%---LOSS:0.606---time:108.43
# Epoch:9---batch(18)训练集---ACC:81.25%---LOSS:0.864---time:107.02
# Epoch:9---batch(19)训练集---ACC:81.25%---LOSS:0.625---time:107.10
# Epoch:9---batch(20)训练集---ACC:87.50%---LOSS:0.407---time:106.17
# Epoch:9---batch(21)训练集---ACC:84.38%---LOSS:0.679---time:107.50
# Epoch:9---batch(22)训练集---ACC:78.12%---LOSS:0.630---time:107.08
# Epoch:9---batch(23)训练集---ACC:71.88%---LOSS:1.137---time:106.24
# Epoch:9---batch(24)训练集---ACC:71.88%---LOSS:0.869---time:106.26
# Epoch:9---batch(25)训练集---ACC:75.00%---LOSS:0.504---time:106.23
# Epoch:9---batch(26)训练集---ACC:78.12%---LOSS:0.827---time:106.48
# Epoch:9---batch(27)训练集---ACC:84.38%---LOSS:0.555---time:106.50
# Epoch:9---batch(28)训练集---ACC:78.12%---LOSS:0.823---time:106.41
# Epoch:9---batch(29)训练集---ACC:71.88%---LOSS:1.220---time:106.26
# Epoch:9---batch(30)训练集---ACC:75.00%---LOSS:1.486---time:105.39
# Epoch:9---batch(31)训练集---ACC:78.12%---LOSS:0.753---time:107.60
# Epoch:9---batch(32)训练集---ACC:71.88%---LOSS:1.182---time:106.55
# Epoch:9---batch(33)训练集---ACC:65.62%---LOSS:0.817---time:107.36
# Epoch:9---batch(34)训练集---ACC:84.38%---LOSS:0.530---time:106.23
# Epoch:9---batch(35)训练集---ACC:87.50%---LOSS:0.300---time:106.25
# Epoch:9---batch(36)训练集---ACC:65.62%---LOSS:1.367---time:106.23
# Epoch:9---batch(37)训练集---ACC:68.75%---LOSS:1.423---time:53.37
# 第9轮测试集准确率：65.50%....测试集Loss:1.1401718514306205
# Epoch:10---batch(0)训练集---ACC:78.12%---LOSS:1.036---time:106.02
# Epoch:10---batch(1)训练集---ACC:71.88%---LOSS:0.594---time:106.42
# Epoch:10---batch(2)训练集---ACC:84.38%---LOSS:0.554---time:106.38
# Epoch:10---batch(3)训练集---ACC:81.25%---LOSS:0.388---time:108.06
# Epoch:10---batch(4)训练集---ACC:71.88%---LOSS:0.719---time:107.11
# Epoch:10---batch(5)训练集---ACC:87.50%---LOSS:0.400---time:107.80
# Epoch:10---batch(6)训练集---ACC:62.50%---LOSS:1.170---time:107.88
# Epoch:10---batch(7)训练集---ACC:71.88%---LOSS:0.880---time:108.13
# Epoch:10---batch(8)训练集---ACC:84.38%---LOSS:0.621---time:106.86
# Epoch:10---batch(9)训练集---ACC:84.38%---LOSS:0.378---time:107.77
# Epoch:10---batch(10)训练集---ACC:65.62%---LOSS:0.831---time:108.01
# Epoch:10---batch(11)训练集---ACC:84.38%---LOSS:0.429---time:108.40
# Epoch:10---batch(12)训练集---ACC:84.38%---LOSS:0.552---time:107.68
# Epoch:10---batch(13)训练集---ACC:87.50%---LOSS:0.391---time:106.81
# Epoch:10---batch(14)训练集---ACC:62.50%---LOSS:1.120---time:106.57
# Epoch:10---batch(15)训练集---ACC:78.12%---LOSS:0.746---time:107.31
# Epoch:10---batch(16)训练集---ACC:84.38%---LOSS:0.441---time:107.10
# Epoch:10---batch(17)训练集---ACC:84.38%---LOSS:0.412---time:107.78
# Epoch:10---batch(18)训练集---ACC:87.50%---LOSS:0.715---time:106.46
# Epoch:10---batch(19)训练集---ACC:75.00%---LOSS:0.632---time:107.29
# Epoch:10---batch(20)训练集---ACC:71.88%---LOSS:0.953---time:107.23
# Epoch:10---batch(21)训练集---ACC:81.25%---LOSS:0.914---time:106.96
# Epoch:10---batch(22)训练集---ACC:81.25%---LOSS:0.704---time:106.76
# Epoch:10---batch(23)训练集---ACC:75.00%---LOSS:1.077---time:108.42
# Epoch:10---batch(24)训练集---ACC:84.38%---LOSS:0.312---time:106.42
# Epoch:10---batch(25)训练集---ACC:81.25%---LOSS:0.435---time:106.53
# Epoch:10---batch(26)训练集---ACC:62.50%---LOSS:1.253---time:105.46
# Epoch:10---batch(27)训练集---ACC:71.88%---LOSS:1.018---time:106.17
# Epoch:10---batch(28)训练集---ACC:81.25%---LOSS:0.816---time:106.92
# Epoch:10---batch(29)训练集---ACC:87.50%---LOSS:0.386---time:106.75
# Epoch:10---batch(30)训练集---ACC:87.50%---LOSS:0.638---time:106.36
# Epoch:10---batch(31)训练集---ACC:90.62%---LOSS:0.274---time:106.07
# Epoch:10---batch(32)训练集---ACC:81.25%---LOSS:0.581---time:105.40
# Epoch:10---batch(33)训练集---ACC:87.50%---LOSS:0.480---time:106.23
# Epoch:10---batch(34)训练集---ACC:90.62%---LOSS:0.351---time:106.51
# Epoch:10---batch(35)训练集---ACC:90.62%---LOSS:0.266---time:105.87
# Epoch:10---batch(36)训练集---ACC:84.38%---LOSS:0.557---time:106.45
# Epoch:10---batch(37)训练集---ACC:75.00%---LOSS:0.913---time:53.23
# 第10轮测试集准确率：73.00%....测试集Loss:0.7559549680777958
# Epoch:11---batch(0)训练集---ACC:87.50%---LOSS:0.409---time:107.02
# Epoch:11---batch(1)训练集---ACC:84.38%---LOSS:0.323---time:107.19
# Epoch:11---batch(2)训练集---ACC:84.38%---LOSS:0.413---time:107.84
# Epoch:11---batch(3)训练集---ACC:81.25%---LOSS:0.440---time:106.35
# Epoch:11---batch(4)训练集---ACC:87.50%---LOSS:0.364---time:107.51
# Epoch:11---batch(5)训练集---ACC:81.25%---LOSS:0.544---time:107.26
# Epoch:11---batch(6)训练集---ACC:78.12%---LOSS:0.618---time:106.57
# Epoch:11---batch(7)训练集---ACC:84.38%---LOSS:0.558---time:106.48
# Epoch:11---batch(8)训练集---ACC:78.12%---LOSS:0.455---time:105.93
# Epoch:11---batch(9)训练集---ACC:90.62%---LOSS:0.484---time:106.48
# Epoch:11---batch(10)训练集---ACC:78.12%---LOSS:0.539---time:105.57
# Epoch:11---batch(11)训练集---ACC:90.62%---LOSS:0.254---time:105.70
# Epoch:11---batch(12)训练集---ACC:84.38%---LOSS:0.362---time:106.09
# Epoch:11---batch(13)训练集---ACC:90.62%---LOSS:0.295---time:105.21
# Epoch:11---batch(14)训练集---ACC:81.25%---LOSS:0.570---time:106.74
# Epoch:11---batch(15)训练集---ACC:81.25%---LOSS:0.401---time:106.40
# Epoch:11---batch(16)训练集---ACC:84.38%---LOSS:0.431---time:106.04
# Epoch:11---batch(17)训练集---ACC:90.62%---LOSS:0.235---time:106.66
# Epoch:11---batch(18)训练集---ACC:96.88%---LOSS:0.208---time:107.10
# Epoch:11---batch(19)训练集---ACC:84.38%---LOSS:0.332---time:105.52
# Epoch:11---batch(20)训练集---ACC:87.50%---LOSS:0.369---time:107.13
# Epoch:11---batch(21)训练集---ACC:84.38%---LOSS:0.483---time:106.64
# Epoch:11---batch(22)训练集---ACC:87.50%---LOSS:0.277---time:106.20
# Epoch:11---batch(23)训练集---ACC:81.25%---LOSS:0.597---time:106.52
# Epoch:11---batch(24)训练集---ACC:84.38%---LOSS:0.360---time:106.41
# Epoch:11---batch(25)训练集---ACC:65.62%---LOSS:0.671---time:106.42
# Epoch:11---batch(26)训练集---ACC:75.00%---LOSS:0.701---time:105.92
# Epoch:11---batch(27)训练集---ACC:81.25%---LOSS:0.508---time:107.01
# Epoch:11---batch(28)训练集---ACC:75.00%---LOSS:0.621---time:107.09
# Epoch:11---batch(29)训练集---ACC:84.38%---LOSS:0.434---time:108.38
# Epoch:11---batch(30)训练集---ACC:81.25%---LOSS:0.419---time:109.72
# Epoch:11---batch(31)训练集---ACC:78.12%---LOSS:0.496---time:108.70
# Epoch:11---batch(32)训练集---ACC:71.88%---LOSS:0.679---time:107.52
# Epoch:11---batch(33)训练集---ACC:81.25%---LOSS:0.539---time:106.32
# Epoch:11---batch(34)训练集---ACC:81.25%---LOSS:0.441---time:108.13
# Epoch:11---batch(35)训练集---ACC:62.50%---LOSS:0.672---time:106.80
# Epoch:11---batch(36)训练集---ACC:75.00%---LOSS:0.606---time:106.81
# Epoch:11---batch(37)训练集---ACC:68.75%---LOSS:1.058---time:53.08
# 第11轮测试集准确率：79.00%....测试集Loss:0.6487402703080859
# Epoch:12---batch(0)训练集---ACC:87.50%---LOSS:0.454---time:108.21
# Epoch:12---batch(1)训练集---ACC:81.25%---LOSS:0.491---time:108.92
# Epoch:12---batch(2)训练集---ACC:87.50%---LOSS:0.338---time:107.39
# Epoch:12---batch(3)训练集---ACC:75.00%---LOSS:0.561---time:106.60
# Epoch:12---batch(4)训练集---ACC:71.88%---LOSS:0.687---time:106.98
# Epoch:12---batch(5)训练集---ACC:71.88%---LOSS:0.493---time:105.88
# Epoch:12---batch(6)训练集---ACC:90.62%---LOSS:0.236---time:107.21
# Epoch:12---batch(7)训练集---ACC:87.50%---LOSS:0.437---time:106.89
# Epoch:12---batch(8)训练集---ACC:87.50%---LOSS:0.387---time:106.98
# Epoch:12---batch(9)训练集---ACC:81.25%---LOSS:0.356---time:107.62
# Epoch:12---batch(10)训练集---ACC:87.50%---LOSS:0.305---time:107.71
# Epoch:12---batch(11)训练集---ACC:87.50%---LOSS:0.339---time:108.11
# Epoch:12---batch(12)训练集---ACC:87.50%---LOSS:0.399---time:107.96
# Epoch:12---batch(13)训练集---ACC:87.50%---LOSS:0.511---time:108.16
# Epoch:12---batch(14)训练集---ACC:75.00%---LOSS:0.482---time:108.97
# Epoch:12---batch(15)训练集---ACC:84.38%---LOSS:0.519---time:107.43
# Epoch:12---batch(16)训练集---ACC:90.62%---LOSS:0.286---time:107.53
# Epoch:12---batch(17)训练集---ACC:81.25%---LOSS:0.588---time:108.23
# Epoch:12---batch(18)训练集---ACC:84.38%---LOSS:0.429---time:106.50
# Epoch:12---batch(19)训练集---ACC:90.62%---LOSS:0.362---time:108.61
# Epoch:12---batch(20)训练集---ACC:81.25%---LOSS:0.701---time:106.99
# Epoch:12---batch(21)训练集---ACC:71.88%---LOSS:0.673---time:107.24
# Epoch:12---batch(22)训练集---ACC:84.38%---LOSS:0.446---time:107.85
# Epoch:12---batch(23)训练集---ACC:90.62%---LOSS:0.373---time:108.95
# Epoch:12---batch(24)训练集---ACC:81.25%---LOSS:0.372---time:108.49
# Epoch:12---batch(25)训练集---ACC:84.38%---LOSS:0.553---time:107.17
# Epoch:12---batch(26)训练集---ACC:84.38%---LOSS:0.497---time:106.53
# Epoch:12---batch(27)训练集---ACC:87.50%---LOSS:0.427---time:105.90
# Epoch:12---batch(28)训练集---ACC:81.25%---LOSS:0.361---time:106.81
# Epoch:12---batch(29)训练集---ACC:90.62%---LOSS:0.756---time:107.42
# Epoch:12---batch(30)训练集---ACC:84.38%---LOSS:0.626---time:107.72
# Epoch:12---batch(31)训练集---ACC:87.50%---LOSS:0.562---time:106.38
# Epoch:12---batch(32)训练集---ACC:93.75%---LOSS:0.288---time:106.73
# Epoch:12---batch(33)训练集---ACC:93.75%---LOSS:0.283---time:105.43
# Epoch:12---batch(34)训练集---ACC:90.62%---LOSS:0.261---time:105.55
# Epoch:12---batch(35)训练集---ACC:87.50%---LOSS:0.277---time:107.57
# Epoch:12---batch(36)训练集---ACC:84.38%---LOSS:0.460---time:104.80
# Epoch:12---batch(37)训练集---ACC:56.25%---LOSS:0.819---time:53.05
# 第12轮测试集准确率：82.50%....测试集Loss:0.5704380146094731
# Epoch:13---batch(0)训练集---ACC:90.62%---LOSS:0.213---time:107.22
# Epoch:13---batch(1)训练集---ACC:71.88%---LOSS:0.617---time:106.93
# Epoch:13---batch(2)训练集---ACC:87.50%---LOSS:0.282---time:107.63
# Epoch:13---batch(3)训练集---ACC:90.62%---LOSS:0.400---time:106.28
# Epoch:13---batch(4)训练集---ACC:84.38%---LOSS:0.489---time:106.74
# Epoch:13---batch(5)训练集---ACC:75.00%---LOSS:0.498---time:107.24
# Epoch:13---batch(6)训练集---ACC:81.25%---LOSS:0.497---time:108.12
# Epoch:13---batch(7)训练集---ACC:84.38%---LOSS:0.465---time:106.55
# Epoch:13---batch(8)训练集---ACC:75.00%---LOSS:0.532---time:106.70
# Epoch:13---batch(9)训练集---ACC:84.38%---LOSS:0.396---time:107.93
# Epoch:13---batch(10)训练集---ACC:84.38%---LOSS:0.375---time:108.05
# Epoch:13---batch(11)训练集---ACC:75.00%---LOSS:0.759---time:106.83
# Epoch:13---batch(12)训练集---ACC:87.50%---LOSS:0.366---time:107.25
# Epoch:13---batch(13)训练集---ACC:90.62%---LOSS:0.315---time:107.94
# Epoch:13---batch(14)训练集---ACC:90.62%---LOSS:0.315---time:107.69
# Epoch:13---batch(15)训练集---ACC:75.00%---LOSS:0.532---time:106.50
# Epoch:13---batch(16)训练集---ACC:87.50%---LOSS:0.408---time:106.99
# Epoch:13---batch(17)训练集---ACC:93.75%---LOSS:0.299---time:107.18
# Epoch:13---batch(18)训练集---ACC:87.50%---LOSS:0.308---time:107.21
# Epoch:13---batch(19)训练集---ACC:87.50%---LOSS:0.308---time:106.65
# Epoch:13---batch(20)训练集---ACC:87.50%---LOSS:0.285---time:107.10
# Epoch:13---batch(21)训练集---ACC:78.12%---LOSS:0.781---time:106.63
# Epoch:13---batch(22)训练集---ACC:75.00%---LOSS:0.607---time:106.17
# Epoch:13---batch(23)训练集---ACC:78.12%---LOSS:0.510---time:107.06
# Epoch:13---batch(24)训练集---ACC:81.25%---LOSS:0.432---time:107.12
# Epoch:13---batch(25)训练集---ACC:87.50%---LOSS:0.498---time:107.60
# Epoch:13---batch(26)训练集---ACC:78.12%---LOSS:0.512---time:106.93
# Epoch:13---batch(27)训练集---ACC:87.50%---LOSS:0.358---time:107.28
# Epoch:13---batch(28)训练集---ACC:81.25%---LOSS:0.629---time:106.80
# Epoch:13---batch(29)训练集---ACC:84.38%---LOSS:0.384---time:106.19
# Epoch:13---batch(30)训练集---ACC:75.00%---LOSS:0.656---time:106.77
# Epoch:13---batch(31)训练集---ACC:81.25%---LOSS:0.619---time:107.88
# Epoch:13---batch(32)训练集---ACC:81.25%---LOSS:0.724---time:106.33
# Epoch:13---batch(33)训练集---ACC:84.38%---LOSS:0.431---time:106.98
# Epoch:13---batch(34)训练集---ACC:90.62%---LOSS:0.302---time:107.57
# Epoch:13---batch(35)训练集---ACC:93.75%---LOSS:0.205---time:107.00
# Epoch:13---batch(36)训练集---ACC:87.50%---LOSS:0.330---time:106.55
# Epoch:13---batch(37)训练集---ACC:93.75%---LOSS:0.409---time:54.05
# 第13轮测试集准确率：73.00%....测试集Loss:0.7484489338738578
# Epoch:14---batch(0)训练集---ACC:75.00%---LOSS:0.901---time:106.59
# Epoch:14---batch(1)训练集---ACC:78.12%---LOSS:0.514---time:107.63
# Epoch:14---batch(2)训练集---ACC:84.38%---LOSS:0.407---time:107.33
# Epoch:14---batch(3)训练集---ACC:90.62%---LOSS:0.315---time:107.35
# Epoch:14---batch(4)训练集---ACC:90.62%---LOSS:0.288---time:107.14
# Epoch:14---batch(5)训练集---ACC:78.12%---LOSS:0.443---time:106.69
# Epoch:14---batch(6)训练集---ACC:90.62%---LOSS:0.283---time:107.52
# Epoch:14---batch(7)训练集---ACC:87.50%---LOSS:0.313---time:108.02
# Epoch:14---batch(8)训练集---ACC:84.38%---LOSS:0.459---time:107.09
# Epoch:14---batch(9)训练集---ACC:87.50%---LOSS:0.393---time:108.44
# Epoch:14---batch(10)训练集---ACC:87.50%---LOSS:0.455---time:107.38
# Epoch:14---batch(11)训练集---ACC:93.75%---LOSS:0.165---time:106.66
# Epoch:14---batch(12)训练集---ACC:81.25%---LOSS:0.467---time:106.36
# Epoch:14---batch(13)训练集---ACC:90.62%---LOSS:0.239---time:106.99
# Epoch:14---batch(14)训练集---ACC:81.25%---LOSS:0.589---time:106.27
# Epoch:14---batch(15)训练集---ACC:78.12%---LOSS:0.851---time:106.59
# Epoch:14---batch(16)训练集---ACC:84.38%---LOSS:0.282---time:108.02
# Epoch:14---batch(17)训练集---ACC:87.50%---LOSS:0.382---time:105.96
# Epoch:14---batch(18)训练集---ACC:87.50%---LOSS:0.386---time:106.05
# Epoch:14---batch(19)训练集---ACC:90.62%---LOSS:0.260---time:105.75
# Epoch:14---batch(20)训练集---ACC:93.75%---LOSS:0.240---time:106.42
# Epoch:14---batch(21)训练集---ACC:90.62%---LOSS:0.323---time:106.14
# Epoch:14---batch(22)训练集---ACC:87.50%---LOSS:0.338---time:106.60
# Epoch:14---batch(23)训练集---ACC:84.38%---LOSS:0.488---time:106.67
# Epoch:14---batch(24)训练集---ACC:84.38%---LOSS:0.489---time:106.82
# Epoch:14---batch(25)训练集---ACC:75.00%---LOSS:0.709---time:107.02
# Epoch:14---batch(26)训练集---ACC:87.50%---LOSS:0.438---time:106.20
# Epoch:14---batch(27)训练集---ACC:81.25%---LOSS:0.517---time:108.06
# Epoch:14---batch(28)训练集---ACC:81.25%---LOSS:0.402---time:107.04
# Epoch:14---batch(29)训练集---ACC:90.62%---LOSS:0.342---time:106.25
# Epoch:14---batch(30)训练集---ACC:81.25%---LOSS:0.701---time:105.94
# Epoch:14---batch(31)训练集---ACC:81.25%---LOSS:0.531---time:107.86
# Epoch:14---batch(32)训练集---ACC:93.75%---LOSS:0.328---time:107.01
# Epoch:14---batch(33)训练集---ACC:84.38%---LOSS:0.443---time:106.50
# Epoch:14---batch(34)训练集---ACC:78.12%---LOSS:0.620---time:107.21
# Epoch:14---batch(35)训练集---ACC:84.38%---LOSS:0.666---time:106.61
# Epoch:14---batch(36)训练集---ACC:78.12%---LOSS:0.680---time:106.91
# Epoch:14---batch(37)训练集---ACC:68.75%---LOSS:0.770---time:53.43
# 第14轮测试集准确率：76.50%....测试集Loss:0.6890787354537419
# Epoch:15---batch(0)训练集---ACC:90.62%---LOSS:0.278---time:105.94
# Epoch:15---batch(1)训练集---ACC:68.75%---LOSS:0.674---time:105.50
# Epoch:15---batch(2)训练集---ACC:87.50%---LOSS:0.520---time:106.37
# Epoch:15---batch(3)训练集---ACC:96.88%---LOSS:0.144---time:106.50
# Epoch:15---batch(4)训练集---ACC:93.75%---LOSS:0.228---time:107.53
# Epoch:15---batch(5)训练集---ACC:93.75%---LOSS:0.321---time:106.28
# Epoch:15---batch(6)训练集---ACC:81.25%---LOSS:0.378---time:106.46
# Epoch:15---batch(7)训练集---ACC:75.00%---LOSS:0.536---time:106.92
# Epoch:15---batch(8)训练集---ACC:84.38%---LOSS:0.417---time:106.37
# Epoch:15---batch(9)训练集---ACC:93.75%---LOSS:0.255---time:107.07
# Epoch:15---batch(10)训练集---ACC:75.00%---LOSS:0.823---time:106.99
# Epoch:15---batch(11)训练集---ACC:81.25%---LOSS:0.541---time:106.73
# Epoch:15---batch(12)训练集---ACC:87.50%---LOSS:0.347---time:106.58
# Epoch:15---batch(13)训练集---ACC:65.62%---LOSS:0.923---time:107.10
# Epoch:15---batch(14)训练集---ACC:90.62%---LOSS:0.252---time:107.02
# Epoch:15---batch(15)训练集---ACC:78.12%---LOSS:0.434---time:107.07
# Epoch:15---batch(16)训练集---ACC:81.25%---LOSS:0.419---time:106.80
# Epoch:15---batch(17)训练集---ACC:87.50%---LOSS:0.440---time:107.56
# Epoch:15---batch(18)训练集---ACC:78.12%---LOSS:0.673---time:107.22
# Epoch:15---batch(19)训练集---ACC:87.50%---LOSS:0.464---time:109.23
# Epoch:15---batch(20)训练集---ACC:90.62%---LOSS:0.262---time:108.17
# Epoch:15---batch(21)训练集---ACC:81.25%---LOSS:0.469---time:107.64
# Epoch:15---batch(22)训练集---ACC:90.62%---LOSS:0.412---time:109.00
# Epoch:15---batch(23)训练集---ACC:87.50%---LOSS:0.410---time:107.48
# Epoch:15---batch(24)训练集---ACC:81.25%---LOSS:0.424---time:108.10
# Epoch:15---batch(25)训练集---ACC:90.62%---LOSS:0.304---time:108.56
# Epoch:15---batch(26)训练集---ACC:75.00%---LOSS:0.601---time:108.32
# Epoch:15---batch(27)训练集---ACC:78.12%---LOSS:0.430---time:107.46
# Epoch:15---batch(28)训练集---ACC:81.25%---LOSS:0.635---time:107.65
# Epoch:15---batch(29)训练集---ACC:90.62%---LOSS:0.222---time:107.30
# Epoch:15---batch(30)训练集---ACC:90.62%---LOSS:0.337---time:107.56
# Epoch:15---batch(31)训练集---ACC:84.38%---LOSS:0.383---time:105.69
# Epoch:15---batch(32)训练集---ACC:81.25%---LOSS:0.661---time:107.64
# Epoch:15---batch(33)训练集---ACC:90.62%---LOSS:0.231---time:107.63
# Epoch:15---batch(34)训练集---ACC:81.25%---LOSS:0.409---time:108.47
# Epoch:15---batch(35)训练集---ACC:84.38%---LOSS:0.446---time:107.30
# Epoch:15---batch(36)训练集---ACC:78.12%---LOSS:0.467---time:107.61
# Epoch:15---batch(37)训练集---ACC:93.75%---LOSS:0.160---time:53.98
# 第15轮测试集准确率：77.50%....测试集Loss:0.6443179292338235
# Epoch:16---batch(0)训练集---ACC:84.38%---LOSS:0.379---time:105.94
# Epoch:16---batch(1)训练集---ACC:87.50%---LOSS:0.257---time:107.02
# Epoch:16---batch(2)训练集---ACC:93.75%---LOSS:0.268---time:107.05
# Epoch:16---batch(3)训练集---ACC:90.62%---LOSS:0.335---time:107.35
# Epoch:16---batch(4)训练集---ACC:87.50%---LOSS:0.300---time:107.58
# Epoch:16---batch(5)训练集---ACC:87.50%---LOSS:0.441---time:107.89
# Epoch:16---batch(6)训练集---ACC:93.75%---LOSS:0.179---time:107.36
# Epoch:16---batch(7)训练集---ACC:78.12%---LOSS:0.388---time:106.82
# Epoch:16---batch(8)训练集---ACC:93.75%---LOSS:0.315---time:106.41
# Epoch:16---batch(9)训练集---ACC:81.25%---LOSS:0.579---time:107.26
# Epoch:16---batch(10)训练集---ACC:81.25%---LOSS:0.478---time:106.92
# Epoch:16---batch(11)训练集---ACC:84.38%---LOSS:0.526---time:106.78
# Epoch:16---batch(12)训练集---ACC:87.50%---LOSS:0.321---time:108.01
# Epoch:16---batch(13)训练集---ACC:81.25%---LOSS:0.665---time:107.42
# Epoch:16---batch(14)训练集---ACC:87.50%---LOSS:0.218---time:108.19
# Epoch:16---batch(15)训练集---ACC:81.25%---LOSS:0.463---time:107.04
# Epoch:16---batch(16)训练集---ACC:78.12%---LOSS:0.616---time:108.39
# Epoch:16---batch(17)训练集---ACC:84.38%---LOSS:0.555---time:107.68
# Epoch:16---batch(18)训练集---ACC:75.00%---LOSS:0.590---time:108.23
# Epoch:16---batch(19)训练集---ACC:84.38%---LOSS:0.454---time:108.61
# Epoch:16---batch(20)训练集---ACC:78.12%---LOSS:0.979---time:107.68
# Epoch:16---batch(21)训练集---ACC:81.25%---LOSS:0.352---time:107.34
# Epoch:16---batch(22)训练集---ACC:87.50%---LOSS:0.463---time:106.81
# Epoch:16---batch(23)训练集---ACC:90.62%---LOSS:0.451---time:104.95
# Epoch:16---batch(24)训练集---ACC:75.00%---LOSS:0.758---time:106.66
# Epoch:16---batch(25)训练集---ACC:90.62%---LOSS:0.298---time:107.57
# Epoch:16---batch(26)训练集---ACC:84.38%---LOSS:0.479---time:106.22
# Epoch:16---batch(27)训练集---ACC:84.38%---LOSS:0.355---time:106.48
# Epoch:16---batch(28)训练集---ACC:78.12%---LOSS:0.440---time:106.46
# Epoch:16---batch(29)训练集---ACC:93.75%---LOSS:0.213---time:107.25
# Epoch:16---batch(30)训练集---ACC:81.25%---LOSS:0.392---time:107.58
# Epoch:16---batch(31)训练集---ACC:81.25%---LOSS:0.691---time:106.28
# Epoch:16---batch(32)训练集---ACC:87.50%---LOSS:0.407---time:106.20
# Epoch:16---batch(33)训练集---ACC:90.62%---LOSS:0.219---time:107.44
# Epoch:16---batch(34)训练集---ACC:84.38%---LOSS:0.302---time:106.37
# Epoch:16---batch(35)训练集---ACC:87.50%---LOSS:0.372---time:106.99
# Epoch:16---batch(36)训练集---ACC:84.38%---LOSS:0.418---time:107.94
# Epoch:16---batch(37)训练集---ACC:75.00%---LOSS:0.574---time:53.24
# 第16轮测试集准确率：79.50%....测试集Loss:0.6174526576484952
# Epoch:17---batch(0)训练集---ACC:87.50%---LOSS:0.367---time:106.99
# Epoch:17---batch(1)训练集---ACC:87.50%---LOSS:0.352---time:106.82
# Epoch:17---batch(2)训练集---ACC:87.50%---LOSS:0.464---time:107.17
# Epoch:17---batch(3)训练集---ACC:75.00%---LOSS:0.512---time:107.31
# Epoch:17---batch(4)训练集---ACC:93.75%---LOSS:0.316---time:107.41
# Epoch:17---batch(5)训练集---ACC:90.62%---LOSS:0.315---time:107.22
# Epoch:17---batch(6)训练集---ACC:81.25%---LOSS:0.401---time:107.42
# Epoch:17---batch(7)训练集---ACC:81.25%---LOSS:0.400---time:108.78
# Epoch:17---batch(8)训练集---ACC:84.38%---LOSS:0.450---time:107.33
# Epoch:17---batch(9)训练集---ACC:84.38%---LOSS:0.350---time:107.68
# Epoch:17---batch(10)训练集---ACC:81.25%---LOSS:0.594---time:107.24
# Epoch:17---batch(11)训练集---ACC:78.12%---LOSS:0.494---time:106.75
# Epoch:17---batch(12)训练集---ACC:90.62%---LOSS:0.202---time:106.86
# Epoch:17---batch(13)训练集---ACC:87.50%---LOSS:0.454---time:106.07
# Epoch:17---batch(14)训练集---ACC:81.25%---LOSS:0.679---time:105.95
# Epoch:17---batch(15)训练集---ACC:87.50%---LOSS:0.556---time:106.28
# Epoch:17---batch(16)训练集---ACC:87.50%---LOSS:0.431---time:106.84
# Epoch:17---batch(17)训练集---ACC:78.12%---LOSS:0.664---time:106.54
# Epoch:17---batch(18)训练集---ACC:84.38%---LOSS:0.640---time:106.23
# Epoch:17---batch(19)训练集---ACC:93.75%---LOSS:0.286---time:106.13
# Epoch:17---batch(20)训练集---ACC:87.50%---LOSS:0.286---time:106.27
# Epoch:17---batch(21)训练集---ACC:93.75%---LOSS:0.267---time:105.94
# Epoch:17---batch(22)训练集---ACC:75.00%---LOSS:0.585---time:107.61
# Epoch:17---batch(23)训练集---ACC:87.50%---LOSS:0.539---time:106.88
# Epoch:17---batch(24)训练集---ACC:87.50%---LOSS:0.314---time:107.34
# Epoch:17---batch(25)训练集---ACC:81.25%---LOSS:0.262---time:107.38
# Epoch:17---batch(26)训练集---ACC:75.00%---LOSS:0.568---time:107.17
# Epoch:17---batch(27)训练集---ACC:81.25%---LOSS:0.436---time:106.80
# Epoch:17---batch(28)训练集---ACC:78.12%---LOSS:0.602---time:106.41
# Epoch:17---batch(29)训练集---ACC:87.50%---LOSS:0.303---time:106.42
# Epoch:17---batch(30)训练集---ACC:93.75%---LOSS:0.333---time:105.98
# Epoch:17---batch(31)训练集---ACC:78.12%---LOSS:0.486---time:106.92
# Epoch:17---batch(32)训练集---ACC:93.75%---LOSS:0.211---time:107.54
# Epoch:17---batch(33)训练集---ACC:87.50%---LOSS:0.411---time:106.99
# Epoch:17---batch(34)训练集---ACC:87.50%---LOSS:0.342---time:106.71
# Epoch:17---batch(35)训练集---ACC:81.25%---LOSS:0.679---time:105.77
# Epoch:17---batch(36)训练集---ACC:75.00%---LOSS:0.651---time:107.44
# Epoch:17---batch(37)训练集---ACC:93.75%---LOSS:0.250---time:53.42
# 第17轮测试集准确率：80.50%....测试集Loss:0.6798162077154432
# Epoch:18---batch(0)训练集---ACC:81.25%---LOSS:0.508---time:111.95
# Epoch:18---batch(1)训练集---ACC:87.50%---LOSS:0.269---time:110.25
# Epoch:18---batch(2)训练集---ACC:87.50%---LOSS:0.370---time:107.43
# Epoch:18---batch(3)训练集---ACC:81.25%---LOSS:0.452---time:107.59
# Epoch:18---batch(4)训练集---ACC:96.88%---LOSS:0.193---time:106.83
# Epoch:18---batch(5)训练集---ACC:87.50%---LOSS:0.368---time:107.39
# Epoch:18---batch(6)训练集---ACC:93.75%---LOSS:0.282---time:106.73
# Epoch:18---batch(7)训练集---ACC:90.62%---LOSS:0.314---time:106.79
# Epoch:18---batch(8)训练集---ACC:93.75%---LOSS:0.311---time:107.07
# Epoch:18---batch(9)训练集---ACC:93.75%---LOSS:0.208---time:106.49
# Epoch:18---batch(10)训练集---ACC:87.50%---LOSS:0.429---time:107.02
# Epoch:18---batch(11)训练集---ACC:93.75%---LOSS:0.262---time:108.61
# Epoch:18---batch(12)训练集---ACC:100.00%---LOSS:0.148---time:107.09
# Epoch:18---batch(13)训练集---ACC:84.38%---LOSS:0.306---time:106.88
# Epoch:18---batch(14)训练集---ACC:68.75%---LOSS:0.725---time:106.59
# Epoch:18---batch(15)训练集---ACC:81.25%---LOSS:0.553---time:105.76
# Epoch:18---batch(16)训练集---ACC:93.75%---LOSS:0.189---time:106.11
# Epoch:18---batch(17)训练集---ACC:81.25%---LOSS:0.397---time:105.74
# Epoch:18---batch(18)训练集---ACC:81.25%---LOSS:0.595---time:106.11
# Epoch:18---batch(19)训练集---ACC:84.38%---LOSS:0.411---time:105.93
# Epoch:18---batch(20)训练集---ACC:81.25%---LOSS:0.678---time:105.86
# Epoch:18---batch(21)训练集---ACC:84.38%---LOSS:0.708---time:105.83
# Epoch:18---batch(22)训练集---ACC:87.50%---LOSS:0.429---time:106.03
# Epoch:18---batch(23)训练集---ACC:71.88%---LOSS:0.773---time:105.89
# Epoch:18---batch(24)训练集---ACC:93.75%---LOSS:0.333---time:105.97
# Epoch:18---batch(25)训练集---ACC:87.50%---LOSS:0.457---time:105.80
# Epoch:18---batch(26)训练集---ACC:81.25%---LOSS:0.334---time:107.25
# Epoch:18---batch(27)训练集---ACC:81.25%---LOSS:0.411---time:107.33
# Epoch:18---batch(28)训练集---ACC:87.50%---LOSS:0.450---time:106.84
# Epoch:18---batch(29)训练集---ACC:90.62%---LOSS:0.368---time:106.90
# Epoch:18---batch(30)训练集---ACC:75.00%---LOSS:0.614---time:107.48
# Epoch:18---batch(31)训练集---ACC:90.62%---LOSS:0.428---time:106.23
# Epoch:18---batch(32)训练集---ACC:90.62%---LOSS:0.223---time:106.72
# Epoch:18---batch(33)训练集---ACC:84.38%---LOSS:0.366---time:106.92
# Epoch:18---batch(34)训练集---ACC:93.75%---LOSS:0.247---time:106.44
# Epoch:18---batch(35)训练集---ACC:81.25%---LOSS:0.623---time:108.18
# Epoch:18---batch(36)训练集---ACC:78.12%---LOSS:0.567---time:106.54
# Epoch:18---batch(37)训练集---ACC:81.25%---LOSS:0.319---time:53.26
# 第18轮测试集准确率：76.50%....测试集Loss:0.6645691650254386
# Epoch:19---batch(0)训练集---ACC:87.50%---LOSS:0.450---time:106.79
# Epoch:19---batch(1)训练集---ACC:90.62%---LOSS:0.327---time:105.34
# Epoch:19---batch(2)训练集---ACC:84.38%---LOSS:0.440---time:106.35
# Epoch:19---batch(3)训练集---ACC:81.25%---LOSS:0.392---time:106.11
# Epoch:19---batch(4)训练集---ACC:90.62%---LOSS:0.370---time:105.65
# Epoch:19---batch(5)训练集---ACC:87.50%---LOSS:0.341---time:106.10
# Epoch:19---batch(6)训练集---ACC:84.38%---LOSS:0.453---time:106.02
# Epoch:19---batch(7)训练集---ACC:87.50%---LOSS:0.496---time:106.55
# Epoch:19---batch(8)训练集---ACC:90.62%---LOSS:0.276---time:104.14
# Epoch:19---batch(9)训练集---ACC:90.62%---LOSS:0.462---time:106.06
# Epoch:19---batch(10)训练集---ACC:84.38%---LOSS:0.318---time:104.72
# Epoch:19---batch(11)训练集---ACC:90.62%---LOSS:0.311---time:105.68
# Epoch:19---batch(12)训练集---ACC:90.62%---LOSS:0.386---time:105.25
# Epoch:19---batch(13)训练集---ACC:90.62%---LOSS:0.239---time:105.09
# Epoch:19---batch(14)训练集---ACC:93.75%---LOSS:0.299---time:105.19
# Epoch:19---batch(15)训练集---ACC:90.62%---LOSS:0.249---time:106.66
# Epoch:19---batch(16)训练集---ACC:81.25%---LOSS:0.412---time:107.70
# Epoch:19---batch(17)训练集---ACC:87.50%---LOSS:0.263---time:106.39
# Epoch:19---batch(18)训练集---ACC:84.38%---LOSS:0.596---time:106.13
# Epoch:19---batch(19)训练集---ACC:93.75%---LOSS:0.223---time:105.94
# Epoch:19---batch(20)训练集---ACC:90.62%---LOSS:0.279---time:106.00
# Epoch:19---batch(21)训练集---ACC:93.75%---LOSS:0.328---time:105.76
# Epoch:19---batch(22)训练集---ACC:81.25%---LOSS:0.426---time:106.24
# Epoch:19---batch(23)训练集---ACC:93.75%---LOSS:0.174---time:105.03
# Epoch:19---batch(24)训练集---ACC:68.75%---LOSS:1.023---time:105.01
# Epoch:19---batch(25)训练集---ACC:81.25%---LOSS:0.355---time:106.16
# Epoch:19---batch(26)训练集---ACC:90.62%---LOSS:0.237---time:105.54
# Epoch:19---batch(27)训练集---ACC:78.12%---LOSS:0.703---time:106.39
# Epoch:19---batch(28)训练集---ACC:90.62%---LOSS:0.246---time:106.65
# Epoch:19---batch(29)训练集---ACC:81.25%---LOSS:0.602---time:106.07
# Epoch:19---batch(30)训练集---ACC:90.62%---LOSS:0.504---time:107.78
# Epoch:19---batch(31)训练集---ACC:90.62%---LOSS:0.260---time:106.88
# Epoch:19---batch(32)训练集---ACC:81.25%---LOSS:0.391---time:106.03
# Epoch:19---batch(33)训练集---ACC:84.38%---LOSS:0.417---time:106.15
# Epoch:19---batch(34)训练集---ACC:84.38%---LOSS:0.531---time:105.87
# Epoch:19---batch(35)训练集---ACC:90.62%---LOSS:0.180---time:105.31
# Epoch:19---batch(36)训练集---ACC:93.75%---LOSS:0.320---time:106.51
# Epoch:19---batch(37)训练集---ACC:50.00%---LOSS:0.877---time:52.68
# 第19轮测试集准确率：77.50%....测试集Loss:0.6946086500372205

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 经典与传统的对比
# 加载经典
# Classical_Train_data = pd.read_csv('/home/WUYING_986418966_1288354473/Desktop/QCNN/src/QCNN-FC/QTCNN-MNIST/640_train.csv')
# Classical_Val_data = pd.read_csv('/home/WUYING_986418966_1288354473/Desktop/QCNN/src/QCNN-FC/QTCNN-MNIST/2091_val.csv')

# Classical_Train_data_acc = Classical_Train_data[['Train_acc']]
# Classical_Train_data_loss = Classical_Train_data[['Train_loss']]

# Classical_Val_data_acc = Classical_Val_data[['Val_acc']]
# Classical_Val_data_loss = Classical_Val_data[['Val_loss']]
def result(acc,loss,plt1_title,plt2_title,title):     # 合并结果
    #绘图
    plt.xticks(np.arange(0,20,1))
    plt.plot(acc,label=plt1_title)
    plt.plot(loss,label=plt2_title)
    plt.title(title) 
    plt.xlabel('epoch')
    plt.ylabel('probability')
    plt.legend()   #显示标签
    plt.show()

# 加载qcnn
Qcnn_Train_data = pd.read_csv('C:\\Users\\17861160902_16355000\\vscode\\FashionMNIST\\s=3\\329_train.csv')
Qcnn_Val_data = pd.read_csv('C:\\Users\\17861160902_16355000\\vscode\\FashionMNIST\\s=3\\9921_val.csv')

Qcnn_Train_data_acc = Qcnn_Train_data[['Train_acc']]
Qcnn_Train_data_loss = Qcnn_Train_data[['Train_loss']]

Qcnn_Val_data_acc = Qcnn_Val_data[['Val_acc']]
Qcnn_Val_data_loss = Qcnn_Val_data[['Val_loss']]

# 损失值比较
result(Qcnn_Train_data_loss,Qcnn_Val_data_loss,'Train_set','Val_set','Loss')
# 准确率比较
result(Qcnn_Train_data_acc,Qcnn_Val_data_acc,'Train_set','Val_set','ACC')
