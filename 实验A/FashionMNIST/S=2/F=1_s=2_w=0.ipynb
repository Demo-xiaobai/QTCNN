# %%
# %%
import tensorcircuit as tc
# import pennylane as qml
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split,Subset
import random
import os
import time
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F
import numpy as np
import csv
import tensorflow as tf


data_path = 'E:\\Test\\VsCode_Test\\Jupyter notebook\\xLw\\data'

val_num = 200
data_num =  1200           # 需要划分的数据集大小
epochs = 20                 # 迭代轮次数
batch_size = 32

K = tc.set_backend("tensorflow")
# 归一化处理
def trans(x):
    x = np.array(x)
    x = x/255.0
    # print(x.shape)    
    return torch.from_numpy(x).float()  # 将 NumPy 数组 x 转换为 PyTorch 张量

transform = transforms.Compose([
    transforms.Resize((14, 14)),                # 将图片缩小为 14x14
    transforms.Lambda(lambda x:trans(x))
])

# 加载MNIST数据集 28X28X1   10类别   
trainset = torchvision.datasets.FashionMNIST(root=data_path, train=True,
                                        download=False, transform=transform)
testset = torchvision.datasets.FashionMNIST(root=data_path, train=False,
                                        download=False, transform=transform)

# 随机抽取训练集 data_num 张图片作为子集
subset_indices = random.sample(range(len(trainset)), k=data_num)
train_subset = Subset(trainset, subset_indices)

# 随机抽取测试集 data_num 张图片作为子集
subset_val = random.sample(range(len(testset)), k=val_num)
val_subset = Subset(testset, subset_val)

# 加载测试集
trainloader = torch.utils.data.DataLoader(train_subset, batch_size=batch_size,  # type: ignore
                                          shuffle=True)
testloader = torch.utils.data.DataLoader(val_subset, batch_size=batch_size,    # type: ignore
                                         shuffle=False)

# %%
n = 4
nlayers = 1

# 我们定义量子函数，
# 注意这个函数是在 tensorflow 上运行的
def qpred(x, weights):
    c = tc.Circuit(n)
    for i in range(n):
        c.h(i)
        c.ry(i, theta=x[i]*weights[i])
    for j in range(nlayers):
        for i in range(n - 1):
            c.cnot(i, i + 1)
    return [K.real(c.expectation([tc.gates.z(), [i]])) for i in range(n)]

# %%
qpred_vmap = K.vmap(qpred, vectorized_argnums=0)        # `qpred_vmap` 是一个具有向量化能力的 TensorFlow 函数
qpred_batch = tc.interfaces.torch_interface(qpred_vmap, jit=True) # 我们进一步将函数包装为 PyTorch 函数

# %%
class QuantumNetV2(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.q_weights = torch.nn.Parameter(torch.randn([n]))
        self.stride = 1
        self.padding_s = 2

    def forward(self, inputs):

        in_bs,in_ch,in_w,in_h = inputs.shape

        kernel_size = 2
        # 判断输入的步长S是多少再决定是否填充
        # padding_input_inside = self.padding_s - 1
        padding_size = kernel_size - 1                  # 边界填充数

        padding_temp = nn.functional.pad(inputs,(12,1,12,1),mode='constant',value=0)
        # print(padding_temp.shape) # 期望得到 27*27
        
        # 元素间填充
        for bs in range(in_bs):
            for ch in range(in_ch):
                for i in range(in_w):     # 14是输入图片大小
                    for j in range(in_h):
                        padding_temp[bs,ch,i*2,j*2] = inputs[bs,ch,i,j]   # 对原图像（14X14）进行内部空洞
        # print(padding_temp)
        # print(padding_temp.shape)       # torch.Size([32, 1, 27, 27])                                                                                                                                                                                                                            

        # 使用转置卷积进行上采样，作为转置卷积的输入
        padd_img = nn.functional.pad(padding_temp,(padding_size,padding_size,padding_size,padding_size),mode='constant',value=0)
        # print(padd_img.shape)   # torch.Size([32, 1, 29, 29])
        
        bs, ch , h , w = padd_img.size()                      #    h=29
        
        # 转置卷积后输出特征图的大小
        h_out = self.padding_s*(in_h-1)+kernel_size           #   2（14-1）+ 2 = 28
        w_out = self.padding_s*(in_w-1)+kernel_size           #   2（17-1）+ 2 = 28

        out = torch.zeros((bs,4, h_out, w_out))
        for b in range(bs):
                for j in range(0, h_out, self.stride):
                    for k in range(0, w_out, self.stride):
                        # print(f'padd_img[b, 0, j, k]={padd_img[b, 0, j, k].shape}')
                        t1 = padd_img[b, 0, j, k]        
                        t2 = padd_img[b, 0, j, k + 1]
                        t3 = padd_img[b, 0, j + 1, k]    
                        t4 = padd_img[b, 0, j + 1, k + 1]

                        temp = torch.Tensor([t1,t2,t3,t4]) # 
                        temp = temp.view(1,4)
    
                        q_results = qpred_batch(temp, self.q_weights)     
                        for c in range(4):
                            out[b, c,j // kernel_size, k // kernel_size] = q_results[c]
        return out

# %%
# 经典CNNmodel 可进行修改
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
            
        # Quantum layer 1
        self.conv1 = QuantumNetV2()
        self.relu1 = nn.ReLU()
        self.batch1 = nn.BatchNorm2d(4)  # 4
        
        # Fully-Connected layer 2
        self.fc2 = nn.Linear(3136,10)
                
    def forward(self, x):

        # qconv layer 1
        out = self.conv1(x)                 
        out = self.relu1(out)   
        out = self.batch1(out)
        
        #Flatten拉平操作
        out = out.view(out.size(0),-1)      # print(f'-----拉平后的维度是--{out.shape}') #  torch.Size([64, 576])
        
        #FC 第二层
        out = self.fc2(out)
        return F.log_softmax(out,dim = 1)

# %%
model = CNNModel()
loss_fun = nn.CrossEntropyLoss()
opt = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
# 准确率计算
def accuracy(output,labels):
    prediction = torch.max(output.data,1)[1]
    rights = prediction.eq(labels.data.view_as(prediction)).sum()
    return rights,len(labels)

# 绘制训练结果
def draw_result(accs,losses,title):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14, 6))   # subplots创建1行 2列的子图
    
    ax1.plot(losses) 
    ax1.set_title(title+" Loss")
    ax1.set_xlabel("Steps")
    ax1.set_ylabel("Loss")
    
    ax2.plot(accs)
    ax2.set_title(title+" Accuracy")
    ax2.set_xlabel("Steps")
    ax2.set_ylabel("Accuracy")

# %%
def train(epochs,model,loss_fun,opt,train_loader,test_loader):
    train_accuracy = []             # 训练集准确率
    train_loss = []

    val_accuracy = []               # 验证集准确率
    val_loss = []
    for epoch in range(epochs):
                ### 训练模块
        train_total_accuracy = 0    # 训练集每epoch（18个batch的和）的准确率
        train_total_loss = 0
        for batch_idx,(data,labels) in enumerate(train_loader):
            t2 = time.time()
            data = data.view(data.shape[0],1, data.shape[1], data.shape[2])
            # print(data)
            model.train()					    # 1 模型训练       
            output = model(data)			    # 2 模型输出
            # print(f'output.shape is {output.shape}')    # output.shape is torch.Size([64, 4, 17, 17])
            # print(f'labels.shape is {labels.shape}')    # labels.shape is torch.Size([64])
            loss = loss_fun(output,labels)	    # 3 计算损失

            opt.zero_grad()					    # 4 梯度清零
            loss.backward() 				    # 5 开始反向传播
            opt.step()                          # 6 梯度更新
            
            # 计算准确率
            accuracy_count, total_count = accuracy(output,labels)
            accuracy_rate = accuracy_count / total_count  # 计算准确率（预测正确的样本数除以总样本数）

            train_total_accuracy += accuracy_count
            train_total_loss +=loss.item()

            batch_time = time.time()-t2
            print(f'Epoch:{epoch}---batch({batch_idx})训练集---ACC:{accuracy_rate:.2%}---LOSS:{loss.item():.3f}---time:{batch_time:.2f}')        
        
        train_total_loss /= batch_idx+1
        train_accuracy.append(train_total_accuracy/len(train_subset))   # 保存1轮的数据 len(train_accuracy)
        train_loss.append(train_total_loss)
### 验证模块
        total_acc = 0
        total_test_loss = 0
        model.eval()
        with torch.no_grad():# 进行评测的时候网络不更新梯度
            for step,(data,target) in enumerate(test_loader):
                data = data.view(data.shape[0],1, data.shape[1], data.shape[2])            # 调整维度一致
                outputs = model(data)
                losses = loss_fun(outputs,target)                               # 计算损失

                accuracy_count, total_count = accuracy(outputs,target)          # 计算准确率
                accuracy_rate = accuracy_count / total_count                    # 计算准确率（预测正确的样本数除以总样本数）

                total_acc += accuracy_count
                total_test_loss+=losses.item()

        total_test_loss /= step + 1
        val_accuracy.append((total_acc/len(val_subset)))
        val_loss.append(total_test_loss)
        print(f'第{epoch}轮测试集准确率：{total_acc/len(val_subset):.2%}....测试集Loss:{total_test_loss}')
    
    ### 画出训练结果图 ##############
    draw_result(train_accuracy,train_loss,"Train")
    draw_result(val_accuracy,val_loss,"Val")
    
    ####  训练的结果写入文件   ##############
    with open(str(random.randint(100,999))+"_train.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Train_loss','Train_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, train_loss[i], train_accuracy[i].numpy()])
    
    #### 测试的结果写入文件  ##############
    with open(str(random.randint(1000,9999))+"_val.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Val_loss','Val_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, val_loss[i], val_accuracy[i].numpy()])

    ### 保存训练的结果
    # Loss0 = torch.tensor(save_train_loss)
    # torch.save(Loss0,'E:\\Test\\VsCode_Test\\Python\\xlw\\test1\\lw2\\epoch_{}'.format(epochs))
    return model, train_accuracy,train_loss


model, train_accuracy,train_loss = train(epochs,model,loss_fun,opt,trainloader,testloader)
# Out:
# Epoch:0---batch(0)训练集---ACC:18.75%---LOSS:2.242---time:64.18
# Epoch:0---batch(1)训练集---ACC:18.75%---LOSS:6.326---time:48.26
# Epoch:0---batch(2)训练集---ACC:21.88%---LOSS:5.372---time:52.44
# Epoch:0---batch(3)训练集---ACC:46.88%---LOSS:2.836---time:52.22
# Epoch:0---batch(4)训练集---ACC:50.00%---LOSS:1.790---time:47.86
# Epoch:0---batch(5)训练集---ACC:56.25%---LOSS:1.617---time:47.51
# Epoch:0---batch(6)训练集---ACC:40.62%---LOSS:1.988---time:48.31
# Epoch:0---batch(7)训练集---ACC:71.88%---LOSS:1.009---time:47.79
# Epoch:0---batch(8)训练集---ACC:68.75%---LOSS:1.012---time:47.35
# Epoch:0---batch(9)训练集---ACC:71.88%---LOSS:1.064---time:47.58
# Epoch:0---batch(10)训练集---ACC:62.50%---LOSS:1.046---time:47.62
# Epoch:0---batch(11)训练集---ACC:53.12%---LOSS:1.678---time:47.56
# Epoch:0---batch(12)训练集---ACC:75.00%---LOSS:0.995---time:47.67
# Epoch:0---batch(13)训练集---ACC:68.75%---LOSS:0.947---time:47.64
# Epoch:0---batch(14)训练集---ACC:59.38%---LOSS:1.430---time:47.44
# Epoch:0---batch(15)训练集---ACC:53.12%---LOSS:1.843---time:47.27
# Epoch:0---batch(16)训练集---ACC:59.38%---LOSS:1.504---time:47.25
# Epoch:0---batch(17)训练集---ACC:56.25%---LOSS:1.487---time:47.66
# Epoch:0---batch(18)训练集---ACC:68.75%---LOSS:1.363---time:46.85
# Epoch:0---batch(19)训练集---ACC:68.75%---LOSS:1.054---time:46.67
# Epoch:0---batch(20)训练集---ACC:53.12%---LOSS:1.728---time:46.36
# Epoch:0---batch(21)训练集---ACC:53.12%---LOSS:1.298---time:47.00
# Epoch:0---batch(22)训练集---ACC:71.88%---LOSS:0.821---time:46.79
# Epoch:0---batch(23)训练集---ACC:56.25%---LOSS:1.617---time:44.51
# Epoch:0---batch(24)训练集---ACC:46.88%---LOSS:1.366---time:45.13
# Epoch:0---batch(25)训练集---ACC:59.38%---LOSS:0.856---time:44.86
# Epoch:0---batch(26)训练集---ACC:68.75%---LOSS:0.880---time:44.84
# Epoch:0---batch(27)训练集---ACC:65.62%---LOSS:0.991---time:45.11
# Epoch:0---batch(28)训练集---ACC:78.12%---LOSS:0.584---time:44.95
# Epoch:0---batch(29)训练集---ACC:65.62%---LOSS:1.093---time:44.54
# Epoch:0---batch(30)训练集---ACC:68.75%---LOSS:1.048---time:45.07
# Epoch:0---batch(31)训练集---ACC:37.50%---LOSS:1.930---time:45.06
# Epoch:0---batch(32)训练集---ACC:71.88%---LOSS:0.767---time:44.77
# Epoch:0---batch(33)训练集---ACC:56.25%---LOSS:1.359---time:45.13
# Epoch:0---batch(34)训练集---ACC:81.25%---LOSS:0.766---time:44.71
# Epoch:0---batch(35)训练集---ACC:62.50%---LOSS:1.281---time:44.90
# Epoch:0---batch(36)训练集---ACC:65.62%---LOSS:0.742---time:45.47
# Epoch:0---batch(37)训练集---ACC:50.00%---LOSS:1.967---time:22.50
# 第0轮测试集准确率：60.00%....测试集Loss:1.1129651750837053
# Epoch:1---batch(0)训练集---ACC:65.62%---LOSS:0.812---time:58.28
# Epoch:1---batch(1)训练集---ACC:75.00%---LOSS:0.776---time:58.59
# Epoch:1---batch(2)训练集---ACC:84.38%---LOSS:0.774---time:58.11
# Epoch:1---batch(3)训练集---ACC:78.12%---LOSS:0.658---time:58.53
# Epoch:1---batch(4)训练集---ACC:68.75%---LOSS:0.995---time:58.71
# Epoch:1---batch(5)训练集---ACC:71.88%---LOSS:0.882---time:57.69
# Epoch:1---batch(6)训练集---ACC:75.00%---LOSS:0.557---time:58.10
# Epoch:1---batch(7)训练集---ACC:71.88%---LOSS:0.746---time:57.56
# Epoch:1---batch(8)训练集---ACC:71.88%---LOSS:1.029---time:58.31
# Epoch:1---batch(9)训练集---ACC:71.88%---LOSS:0.895---time:58.00
# Epoch:1---batch(10)训练集---ACC:68.75%---LOSS:0.646---time:57.25
# Epoch:1---batch(11)训练集---ACC:78.12%---LOSS:0.582---time:51.82
# Epoch:1---batch(12)训练集---ACC:65.62%---LOSS:0.894---time:47.46
# Epoch:1---batch(13)训练集---ACC:75.00%---LOSS:0.581---time:46.21
# Epoch:1---batch(14)训练集---ACC:78.12%---LOSS:0.729---time:49.66
# Epoch:1---batch(15)训练集---ACC:71.88%---LOSS:0.556---time:41.77
# Epoch:1---batch(16)训练集---ACC:84.38%---LOSS:0.826---time:43.07
# Epoch:1---batch(17)训练集---ACC:71.88%---LOSS:0.814---time:52.35
# Epoch:1---batch(18)训练集---ACC:75.00%---LOSS:0.789---time:46.13
# Epoch:1---batch(19)训练集---ACC:75.00%---LOSS:0.727---time:48.61
# Epoch:1---batch(20)训练集---ACC:78.12%---LOSS:0.711---time:48.46
# Epoch:1---batch(21)训练集---ACC:90.62%---LOSS:0.333---time:47.12
# Epoch:1---batch(22)训练集---ACC:78.12%---LOSS:0.551---time:48.98
# Epoch:1---batch(23)训练集---ACC:75.00%---LOSS:0.591---time:49.31
# Epoch:1---batch(24)训练集---ACC:68.75%---LOSS:0.863---time:50.18
# Epoch:1---batch(25)训练集---ACC:84.38%---LOSS:0.469---time:56.51
# Epoch:1---batch(26)训练集---ACC:75.00%---LOSS:0.651---time:62.00
# Epoch:1---batch(27)训练集---ACC:81.25%---LOSS:0.552---time:60.09
# Epoch:1---batch(28)训练集---ACC:78.12%---LOSS:0.769---time:58.37
# Epoch:1---batch(29)训练集---ACC:78.12%---LOSS:0.708---time:57.14
# Epoch:1---batch(30)训练集---ACC:90.62%---LOSS:0.303---time:61.58
# Epoch:1---batch(31)训练集---ACC:62.50%---LOSS:0.904---time:66.51
# Epoch:1---batch(32)训练集---ACC:78.12%---LOSS:0.592---time:60.35
# Epoch:1---batch(33)训练集---ACC:65.62%---LOSS:0.807---time:58.04
# Epoch:1---batch(34)训练集---ACC:71.88%---LOSS:0.773---time:51.64
# Epoch:1---batch(35)训练集---ACC:65.62%---LOSS:0.909---time:45.08
# Epoch:1---batch(36)训练集---ACC:78.12%---LOSS:0.638---time:43.55
# Epoch:1---batch(37)训练集---ACC:75.00%---LOSS:1.212---time:20.74
# 第1轮测试集准确率：72.50%....测试集Loss:0.8498342377798898
# Epoch:2---batch(0)训练集---ACC:62.50%---LOSS:1.185---time:58.15
# Epoch:2---batch(1)训练集---ACC:75.00%---LOSS:0.556---time:51.41
# Epoch:2---batch(2)训练集---ACC:65.62%---LOSS:0.839---time:47.51
# Epoch:2---batch(3)训练集---ACC:68.75%---LOSS:0.858---time:48.06
# Epoch:2---batch(4)训练集---ACC:68.75%---LOSS:0.799---time:50.41
# Epoch:2---batch(5)训练集---ACC:78.12%---LOSS:0.537---time:55.30
# Epoch:2---batch(6)训练集---ACC:71.88%---LOSS:0.871---time:52.81
# Epoch:2---batch(7)训练集---ACC:75.00%---LOSS:0.788---time:50.44
# Epoch:2---batch(8)训练集---ACC:87.50%---LOSS:0.327---time:45.33
# Epoch:2---batch(9)训练集---ACC:78.12%---LOSS:0.882---time:49.88
# Epoch:2---batch(10)训练集---ACC:78.12%---LOSS:0.663---time:46.03
# Epoch:2---batch(11)训练集---ACC:78.12%---LOSS:0.496---time:50.64
# Epoch:2---batch(12)训练集---ACC:81.25%---LOSS:0.536---time:48.09
# Epoch:2---batch(13)训练集---ACC:84.38%---LOSS:0.357---time:46.42
# Epoch:2---batch(14)训练集---ACC:71.88%---LOSS:0.764---time:42.16
# Epoch:2---batch(15)训练集---ACC:65.62%---LOSS:0.940---time:49.25
# Epoch:2---batch(16)训练集---ACC:71.88%---LOSS:1.372---time:47.54
# Epoch:2---batch(17)训练集---ACC:84.38%---LOSS:0.522---time:47.24
# Epoch:2---batch(18)训练集---ACC:75.00%---LOSS:0.628---time:42.86
# Epoch:2---batch(19)训练集---ACC:78.12%---LOSS:0.489---time:40.89
# Epoch:2---batch(20)训练集---ACC:81.25%---LOSS:0.515---time:38.66
# Epoch:2---batch(21)训练集---ACC:56.25%---LOSS:1.015---time:55.27
# Epoch:2---batch(22)训练集---ACC:75.00%---LOSS:0.722---time:58.36
# Epoch:2---batch(23)训练集---ACC:68.75%---LOSS:0.892---time:59.79
# Epoch:2---batch(24)训练集---ACC:71.88%---LOSS:0.929---time:56.65
# Epoch:2---batch(25)训练集---ACC:81.25%---LOSS:0.500---time:40.57
# Epoch:2---batch(26)训练集---ACC:68.75%---LOSS:0.788---time:40.03
# Epoch:2---batch(27)训练集---ACC:84.38%---LOSS:0.341---time:40.52
# Epoch:2---batch(28)训练集---ACC:75.00%---LOSS:0.879---time:41.68
# Epoch:2---batch(29)训练集---ACC:75.00%---LOSS:0.756---time:40.12
# Epoch:2---batch(30)训练集---ACC:62.50%---LOSS:0.919---time:37.92
# Epoch:2---batch(31)训练集---ACC:75.00%---LOSS:0.856---time:42.18
# Epoch:2---batch(32)训练集---ACC:84.38%---LOSS:0.431---time:39.98
# Epoch:2---batch(33)训练集---ACC:65.62%---LOSS:0.731---time:41.14
# Epoch:2---batch(34)训练集---ACC:84.38%---LOSS:0.592---time:41.17
# Epoch:2---batch(35)训练集---ACC:71.88%---LOSS:0.978---time:46.70
# Epoch:2---batch(36)训练集---ACC:65.62%---LOSS:1.162---time:42.17
# Epoch:2---batch(37)训练集---ACC:62.50%---LOSS:0.778---time:21.22
# 第2轮测试集准确率：78.00%....测试集Loss:0.639835136277335
# Epoch:3---batch(0)训练集---ACC:96.88%---LOSS:0.216---time:39.80
# Epoch:3---batch(1)训练集---ACC:56.25%---LOSS:0.841---time:39.76
# Epoch:3---batch(2)训练集---ACC:65.62%---LOSS:0.791---time:45.04
# Epoch:3---batch(3)训练集---ACC:78.12%---LOSS:0.666---time:41.03
# Epoch:3---batch(4)训练集---ACC:78.12%---LOSS:0.612---time:41.86
# Epoch:3---batch(5)训练集---ACC:68.75%---LOSS:0.732---time:43.38
# Epoch:3---batch(6)训练集---ACC:75.00%---LOSS:0.706---time:44.60
# Epoch:3---batch(7)训练集---ACC:81.25%---LOSS:0.617---time:45.36
# Epoch:3---batch(8)训练集---ACC:84.38%---LOSS:0.638---time:42.47
# Epoch:3---batch(9)训练集---ACC:90.62%---LOSS:0.331---time:42.44
# Epoch:3---batch(10)训练集---ACC:78.12%---LOSS:0.600---time:44.70
# Epoch:3---batch(11)训练集---ACC:59.38%---LOSS:1.036---time:42.71
# Epoch:3---batch(12)训练集---ACC:71.88%---LOSS:0.590---time:44.08
# Epoch:3---batch(13)训练集---ACC:93.75%---LOSS:0.298---time:47.55
# Epoch:3---batch(14)训练集---ACC:71.88%---LOSS:0.599---time:45.51
# Epoch:3---batch(15)训练集---ACC:68.75%---LOSS:0.918---time:44.79
# Epoch:3---batch(16)训练集---ACC:71.88%---LOSS:0.674---time:41.22
# Epoch:3---batch(17)训练集---ACC:84.38%---LOSS:0.437---time:41.68
# Epoch:3---batch(18)训练集---ACC:78.12%---LOSS:0.659---time:38.91
# Epoch:3---batch(19)训练集---ACC:75.00%---LOSS:0.588---time:37.86
# Epoch:3---batch(20)训练集---ACC:75.00%---LOSS:0.511---time:37.85
# Epoch:3---batch(21)训练集---ACC:75.00%---LOSS:0.474---time:39.63
# Epoch:3---batch(22)训练集---ACC:81.25%---LOSS:0.544---time:37.63
# Epoch:3---batch(23)训练集---ACC:78.12%---LOSS:0.655---time:41.07
# Epoch:3---batch(24)训练集---ACC:87.50%---LOSS:0.451---time:37.30
# Epoch:3---batch(25)训练集---ACC:84.38%---LOSS:0.415---time:39.21
# Epoch:3---batch(26)训练集---ACC:90.62%---LOSS:0.437---time:39.54
# Epoch:3---batch(27)训练集---ACC:81.25%---LOSS:0.695---time:38.46
# Epoch:3---batch(28)训练集---ACC:84.38%---LOSS:0.407---time:38.39
# Epoch:3---batch(29)训练集---ACC:75.00%---LOSS:0.833---time:37.77
# Epoch:3---batch(30)训练集---ACC:78.12%---LOSS:0.573---time:38.22
# Epoch:3---batch(31)训练集---ACC:81.25%---LOSS:0.410---time:39.31
# Epoch:3---batch(32)训练集---ACC:81.25%---LOSS:0.583---time:36.39
# Epoch:3---batch(33)训练集---ACC:71.88%---LOSS:0.721---time:36.75
# Epoch:3---batch(34)训练集---ACC:59.38%---LOSS:1.085---time:37.73
# Epoch:3---batch(35)训练集---ACC:68.75%---LOSS:1.169---time:38.79
# Epoch:3---batch(36)训练集---ACC:65.62%---LOSS:0.836---time:38.30
# Epoch:3---batch(37)训练集---ACC:68.75%---LOSS:0.545---time:19.73
# 第3轮测试集准确率：76.50%....测试集Loss:0.6781382475580487
# Epoch:4---batch(0)训练集---ACC:68.75%---LOSS:0.667---time:37.67
# Epoch:4---batch(1)训练集---ACC:81.25%---LOSS:0.464---time:37.05
# Epoch:4---batch(2)训练集---ACC:68.75%---LOSS:0.810---time:39.23
# Epoch:4---batch(3)训练集---ACC:81.25%---LOSS:0.576---time:36.50
# Epoch:4---batch(4)训练集---ACC:78.12%---LOSS:0.629---time:39.43
# Epoch:4---batch(5)训练集---ACC:68.75%---LOSS:1.138---time:38.89
# Epoch:4---batch(6)训练集---ACC:75.00%---LOSS:0.653---time:43.71
# Epoch:4---batch(7)训练集---ACC:75.00%---LOSS:0.651---time:47.46
# Epoch:4---batch(8)训练集---ACC:75.00%---LOSS:0.493---time:50.17
# Epoch:4---batch(9)训练集---ACC:68.75%---LOSS:0.792---time:54.11
# Epoch:4---batch(10)训练集---ACC:81.25%---LOSS:0.685---time:57.67
# Epoch:4---batch(11)训练集---ACC:71.88%---LOSS:0.796---time:47.55
# Epoch:4---batch(12)训练集---ACC:84.38%---LOSS:0.635---time:45.12
# Epoch:4---batch(13)训练集---ACC:78.12%---LOSS:0.670---time:44.72
# Epoch:4---batch(14)训练集---ACC:71.88%---LOSS:0.871---time:45.50
# Epoch:4---batch(15)训练集---ACC:68.75%---LOSS:1.310---time:44.86
# Epoch:4---batch(16)训练集---ACC:71.88%---LOSS:0.702---time:45.41
# Epoch:4---batch(17)训练集---ACC:87.50%---LOSS:0.510---time:45.33
# Epoch:4---batch(18)训练集---ACC:71.88%---LOSS:0.920---time:45.87
# Epoch:4---batch(19)训练集---ACC:68.75%---LOSS:0.932---time:45.82
# Epoch:4---batch(20)训练集---ACC:65.62%---LOSS:0.896---time:44.83
# Epoch:4---batch(21)训练集---ACC:71.88%---LOSS:0.551---time:44.72
# Epoch:4---batch(22)训练集---ACC:81.25%---LOSS:0.450---time:44.15
# Epoch:4---batch(23)训练集---ACC:81.25%---LOSS:0.465---time:50.92
# Epoch:4---batch(24)训练集---ACC:68.75%---LOSS:0.909---time:50.33
# Epoch:4---batch(25)训练集---ACC:87.50%---LOSS:0.299---time:52.85
# Epoch:4---batch(26)训练集---ACC:78.12%---LOSS:0.559---time:50.35
# Epoch:4---batch(27)训练集---ACC:81.25%---LOSS:0.538---time:48.10
# Epoch:4---batch(28)训练集---ACC:87.50%---LOSS:0.361---time:57.75
# Epoch:4---batch(29)训练集---ACC:87.50%---LOSS:0.338---time:49.40
# Epoch:4---batch(30)训练集---ACC:87.50%---LOSS:0.389---time:47.44
# Epoch:4---batch(31)训练集---ACC:84.38%---LOSS:0.480---time:42.84
# Epoch:4---batch(32)训练集---ACC:87.50%---LOSS:0.419---time:40.99
# Epoch:4---batch(33)训练集---ACC:71.88%---LOSS:0.664---time:39.85
# Epoch:4---batch(34)训练集---ACC:90.62%---LOSS:0.321---time:42.24
# Epoch:4---batch(35)训练集---ACC:78.12%---LOSS:0.506---time:38.33
# Epoch:4---batch(36)训练集---ACC:68.75%---LOSS:0.618---time:36.70
# Epoch:4---batch(37)训练集---ACC:75.00%---LOSS:0.483---time:18.40
# 第4轮测试集准确率：83.50%....测试集Loss:0.519778060061591
# Epoch:5---batch(0)训练集---ACC:84.38%---LOSS:0.410---time:36.84
# Epoch:5---batch(1)训练集---ACC:81.25%---LOSS:0.377---time:42.54
# Epoch:5---batch(2)训练集---ACC:87.50%---LOSS:0.435---time:46.21
# Epoch:5---batch(3)训练集---ACC:84.38%---LOSS:0.379---time:48.16
# Epoch:5---batch(4)训练集---ACC:75.00%---LOSS:0.608---time:47.41
# Epoch:5---batch(5)训练集---ACC:87.50%---LOSS:0.414---time:47.28
# Epoch:5---batch(6)训练集---ACC:75.00%---LOSS:0.607---time:47.04
# Epoch:5---batch(7)训练集---ACC:71.88%---LOSS:0.635---time:48.30
# Epoch:5---batch(8)训练集---ACC:84.38%---LOSS:0.439---time:48.30
# Epoch:5---batch(9)训练集---ACC:84.38%---LOSS:0.440---time:51.88
# Epoch:5---batch(10)训练集---ACC:84.38%---LOSS:0.358---time:46.39
# Epoch:5---batch(11)训练集---ACC:84.38%---LOSS:0.380---time:47.12
# Epoch:5---batch(12)训练集---ACC:75.00%---LOSS:0.604---time:47.16
# Epoch:5---batch(13)训练集---ACC:68.75%---LOSS:0.743---time:44.60
# Epoch:5---batch(14)训练集---ACC:81.25%---LOSS:0.508---time:45.01
# Epoch:5---batch(15)训练集---ACC:81.25%---LOSS:0.555---time:45.19
# Epoch:5---batch(16)训练集---ACC:68.75%---LOSS:0.690---time:44.41
# Epoch:5---batch(17)训练集---ACC:84.38%---LOSS:0.449---time:49.85
# Epoch:5---batch(18)训练集---ACC:71.88%---LOSS:0.753---time:47.53
# Epoch:5---batch(19)训练集---ACC:81.25%---LOSS:0.455---time:49.42
# Epoch:5---batch(20)训练集---ACC:81.25%---LOSS:0.446---time:48.60
# Epoch:5---batch(21)训练集---ACC:90.62%---LOSS:0.456---time:46.68
# Epoch:5---batch(22)训练集---ACC:93.75%---LOSS:0.450---time:47.63
# Epoch:5---batch(23)训练集---ACC:87.50%---LOSS:0.271---time:47.18
# Epoch:5---batch(24)训练集---ACC:84.38%---LOSS:0.327---time:47.62
# Epoch:5---batch(25)训练集---ACC:71.88%---LOSS:0.548---time:47.44
# Epoch:5---batch(26)训练集---ACC:71.88%---LOSS:0.735---time:48.44
# Epoch:5---batch(27)训练集---ACC:68.75%---LOSS:0.921---time:45.70
# Epoch:5---batch(28)训练集---ACC:75.00%---LOSS:0.776---time:48.58
# Epoch:5---batch(29)训练集---ACC:78.12%---LOSS:0.607---time:47.75
# Epoch:5---batch(30)训练集---ACC:78.12%---LOSS:0.539---time:47.71
# Epoch:5---batch(31)训练集---ACC:78.12%---LOSS:0.562---time:46.58
# Epoch:5---batch(32)训练集---ACC:84.38%---LOSS:0.442---time:54.75
# Epoch:5---batch(33)训练集---ACC:71.88%---LOSS:0.787---time:47.72
# Epoch:5---batch(34)训练集---ACC:75.00%---LOSS:0.651---time:48.39
# Epoch:5---batch(35)训练集---ACC:84.38%---LOSS:0.450---time:48.14
# Epoch:5---batch(36)训练集---ACC:84.38%---LOSS:0.442---time:46.63
# Epoch:5---batch(37)训练集---ACC:87.50%---LOSS:0.534---time:23.03
# 第5轮测试集准确率：79.00%....测试集Loss:0.6905645898410252
# Epoch:6---batch(0)训练集---ACC:68.75%---LOSS:0.812---time:45.79
# Epoch:6---batch(1)训练集---ACC:84.38%---LOSS:0.319---time:47.87
# Epoch:6---batch(2)训练集---ACC:71.88%---LOSS:0.592---time:46.67
# Epoch:6---batch(3)训练集---ACC:87.50%---LOSS:0.316---time:47.04
# Epoch:6---batch(4)训练集---ACC:68.75%---LOSS:0.598---time:47.80
# Epoch:6---batch(5)训练集---ACC:71.88%---LOSS:0.789---time:47.53
# Epoch:6---batch(6)训练集---ACC:84.38%---LOSS:0.348---time:49.40
# Epoch:6---batch(7)训练集---ACC:90.62%---LOSS:0.380---time:48.35
# Epoch:6---batch(8)训练集---ACC:93.75%---LOSS:0.349---time:50.08
# Epoch:6---batch(9)训练集---ACC:81.25%---LOSS:0.536---time:47.29
# Epoch:6---batch(10)训练集---ACC:75.00%---LOSS:0.737---time:47.73
# Epoch:6---batch(11)训练集---ACC:75.00%---LOSS:0.613---time:52.40
# Epoch:6---batch(12)训练集---ACC:87.50%---LOSS:0.502---time:45.99
# Epoch:6---batch(13)训练集---ACC:90.62%---LOSS:0.282---time:50.74
# Epoch:6---batch(14)训练集---ACC:84.38%---LOSS:0.436---time:43.45
# Epoch:6---batch(15)训练集---ACC:81.25%---LOSS:0.474---time:38.46
# Epoch:6---batch(16)训练集---ACC:81.25%---LOSS:0.443---time:38.74
# Epoch:6---batch(17)训练集---ACC:84.38%---LOSS:0.566---time:38.61
# Epoch:6---batch(18)训练集---ACC:81.25%---LOSS:0.639---time:38.11
# Epoch:6---batch(19)训练集---ACC:81.25%---LOSS:0.633---time:39.59
# Epoch:6---batch(20)训练集---ACC:78.12%---LOSS:0.612---time:40.54
# Epoch:6---batch(21)训练集---ACC:84.38%---LOSS:0.455---time:38.76
# Epoch:6---batch(22)训练集---ACC:78.12%---LOSS:0.778---time:39.71
# Epoch:6---batch(23)训练集---ACC:84.38%---LOSS:0.397---time:39.75
# Epoch:6---batch(24)训练集---ACC:75.00%---LOSS:0.718---time:39.48
# Epoch:6---batch(25)训练集---ACC:65.62%---LOSS:0.716---time:39.81
# Epoch:6---batch(26)训练集---ACC:84.38%---LOSS:0.326---time:41.48
# Epoch:6---batch(27)训练集---ACC:71.88%---LOSS:0.512---time:39.08
# Epoch:6---batch(28)训练集---ACC:87.50%---LOSS:0.504---time:39.94
# Epoch:6---batch(29)训练集---ACC:93.75%---LOSS:0.305---time:39.26
# Epoch:6---batch(30)训练集---ACC:81.25%---LOSS:0.551---time:38.52
# Epoch:6---batch(31)训练集---ACC:75.00%---LOSS:0.699---time:47.23
# Epoch:6---batch(32)训练集---ACC:84.38%---LOSS:0.515---time:51.56
# Epoch:6---batch(33)训练集---ACC:75.00%---LOSS:0.612---time:48.03
# Epoch:6---batch(34)训练集---ACC:84.38%---LOSS:0.521---time:47.18
# Epoch:6---batch(35)训练集---ACC:93.75%---LOSS:0.288---time:47.18
# Epoch:6---batch(36)训练集---ACC:78.12%---LOSS:0.604---time:47.20
# Epoch:6---batch(37)训练集---ACC:87.50%---LOSS:0.370---time:23.35
# 第6轮测试集准确率：81.00%....测试集Loss:0.5081327557563782
# Epoch:7---batch(0)训练集---ACC:93.75%---LOSS:0.235---time:47.06
# Epoch:7---batch(1)训练集---ACC:84.38%---LOSS:0.411---time:47.15
# Epoch:7---batch(2)训练集---ACC:81.25%---LOSS:0.469---time:47.25
# Epoch:7---batch(3)训练集---ACC:84.38%---LOSS:0.537---time:46.72
# Epoch:7---batch(4)训练集---ACC:78.12%---LOSS:0.423---time:47.20
# Epoch:7---batch(5)训练集---ACC:78.12%---LOSS:0.618---time:46.86
# Epoch:7---batch(6)训练集---ACC:90.62%---LOSS:0.267---time:46.94
# Epoch:7---batch(7)训练集---ACC:81.25%---LOSS:0.337---time:46.10
# Epoch:7---batch(8)训练集---ACC:81.25%---LOSS:0.530---time:49.60
# Epoch:7---batch(9)训练集---ACC:81.25%---LOSS:0.447---time:49.99
# Epoch:7---batch(10)训练集---ACC:90.62%---LOSS:0.345---time:54.13
# Epoch:7---batch(11)训练集---ACC:81.25%---LOSS:0.584---time:55.67
# Epoch:7---batch(12)训练集---ACC:84.38%---LOSS:0.326---time:46.13
# Epoch:7---batch(13)训练集---ACC:81.25%---LOSS:0.379---time:46.48
# Epoch:7---batch(14)训练集---ACC:75.00%---LOSS:0.507---time:45.81
# Epoch:7---batch(15)训练集---ACC:81.25%---LOSS:0.431---time:45.72
# Epoch:7---batch(16)训练集---ACC:87.50%---LOSS:0.482---time:46.33
# Epoch:7---batch(17)训练集---ACC:87.50%---LOSS:0.436---time:46.08
# Epoch:7---batch(18)训练集---ACC:68.75%---LOSS:0.610---time:46.33
# Epoch:7---batch(19)训练集---ACC:87.50%---LOSS:0.343---time:46.37
# Epoch:7---batch(20)训练集---ACC:78.12%---LOSS:0.779---time:46.60
# Epoch:7---batch(21)训练集---ACC:71.88%---LOSS:0.706---time:46.97
# Epoch:7---batch(22)训练集---ACC:84.38%---LOSS:0.449---time:47.23
# Epoch:7---batch(23)训练集---ACC:87.50%---LOSS:0.340---time:47.12
# Epoch:7---batch(24)训练集---ACC:87.50%---LOSS:0.439---time:47.44
# Epoch:7---batch(25)训练集---ACC:87.50%---LOSS:0.357---time:46.34
# Epoch:7---batch(26)训练集---ACC:81.25%---LOSS:0.544---time:46.17
# Epoch:7---batch(27)训练集---ACC:84.38%---LOSS:0.397---time:46.11
# Epoch:7---batch(28)训练集---ACC:87.50%---LOSS:0.369---time:46.23
# Epoch:7---batch(29)训练集---ACC:81.25%---LOSS:0.462---time:45.45
# Epoch:7---batch(30)训练集---ACC:81.25%---LOSS:0.465---time:46.39
# Epoch:7---batch(31)训练集---ACC:90.62%---LOSS:0.335---time:45.69
# Epoch:7---batch(32)训练集---ACC:87.50%---LOSS:0.468---time:49.89
# Epoch:7---batch(33)训练集---ACC:84.38%---LOSS:0.390---time:53.05
# Epoch:7---batch(34)训练集---ACC:84.38%---LOSS:0.479---time:86.28
# Epoch:7---batch(35)训练集---ACC:81.25%---LOSS:0.517---time:68.32
# Epoch:7---batch(36)训练集---ACC:87.50%---LOSS:0.440---time:72.48
# Epoch:7---batch(37)训练集---ACC:81.25%---LOSS:0.589---time:35.59
# 第7轮测试集准确率：78.00%....测试集Loss:0.6694536762578147
# Epoch:8---batch(0)训练集---ACC:87.50%---LOSS:0.354---time:50.19
# Epoch:8---batch(1)训练集---ACC:78.12%---LOSS:0.641---time:50.44
# Epoch:8---batch(2)训练集---ACC:65.62%---LOSS:0.949---time:47.90
# Epoch:8---batch(3)训练集---ACC:84.38%---LOSS:0.624---time:48.55
# Epoch:8---batch(4)训练集---ACC:84.38%---LOSS:0.401---time:54.39
# Epoch:8---batch(5)训练集---ACC:81.25%---LOSS:0.463---time:55.09
# Epoch:8---batch(6)训练集---ACC:87.50%---LOSS:0.402---time:48.46
# Epoch:8---batch(7)训练集---ACC:78.12%---LOSS:0.394---time:45.48
# Epoch:8---batch(8)训练集---ACC:84.38%---LOSS:0.348---time:55.70
# Epoch:8---batch(9)训练集---ACC:75.00%---LOSS:0.641---time:52.25
# Epoch:8---batch(10)训练集---ACC:68.75%---LOSS:0.764---time:50.13
# Epoch:8---batch(11)训练集---ACC:90.62%---LOSS:0.396---time:49.57
# Epoch:8---batch(12)训练集---ACC:71.88%---LOSS:0.840---time:55.95
# Epoch:8---batch(13)训练集---ACC:75.00%---LOSS:0.520---time:47.00
# Epoch:8---batch(14)训练集---ACC:84.38%---LOSS:0.400---time:47.60
# Epoch:8---batch(15)训练集---ACC:87.50%---LOSS:0.424---time:47.14
# Epoch:8---batch(16)训练集---ACC:81.25%---LOSS:0.568---time:46.87
# Epoch:8---batch(17)训练集---ACC:71.88%---LOSS:0.515---time:47.88
# Epoch:8---batch(18)训练集---ACC:96.88%---LOSS:0.249---time:46.50
# Epoch:8---batch(19)训练集---ACC:84.38%---LOSS:0.323---time:54.36
# Epoch:8---batch(20)训练集---ACC:84.38%---LOSS:0.447---time:62.74
# Epoch:8---batch(21)训练集---ACC:78.12%---LOSS:0.440---time:55.26
# Epoch:8---batch(22)训练集---ACC:84.38%---LOSS:0.387---time:55.26
# Epoch:8---batch(23)训练集---ACC:84.38%---LOSS:0.449---time:55.75
# Epoch:8---batch(24)训练集---ACC:81.25%---LOSS:0.437---time:55.78
# Epoch:8---batch(25)训练集---ACC:90.62%---LOSS:0.338---time:55.74
# Epoch:8---batch(26)训练集---ACC:87.50%---LOSS:0.390---time:61.15
# Epoch:8---batch(27)训练集---ACC:90.62%---LOSS:0.362---time:51.21
# Epoch:8---batch(28)训练集---ACC:78.12%---LOSS:0.546---time:52.71
# Epoch:8---batch(29)训练集---ACC:93.75%---LOSS:0.277---time:51.23
# Epoch:8---batch(30)训练集---ACC:81.25%---LOSS:0.420---time:49.80
# Epoch:8---batch(31)训练集---ACC:93.75%---LOSS:0.425---time:51.63
# Epoch:8---batch(32)训练集---ACC:81.25%---LOSS:0.546---time:49.52
# Epoch:8---batch(33)训练集---ACC:68.75%---LOSS:0.818---time:49.46
# Epoch:8---batch(34)训练集---ACC:93.75%---LOSS:0.268---time:52.98
# Epoch:8---batch(35)训练集---ACC:87.50%---LOSS:0.278---time:51.22
# Epoch:8---batch(36)训练集---ACC:78.12%---LOSS:0.397---time:48.35
# Epoch:8---batch(37)训练集---ACC:87.50%---LOSS:0.347---time:23.41
# 第8轮测试集准确率：78.00%....测试集Loss:0.6879934796265194
# Epoch:9---batch(0)训练集---ACC:87.50%---LOSS:0.388---time:46.89
# Epoch:9---batch(1)训练集---ACC:68.75%---LOSS:0.672---time:46.97
# Epoch:9---batch(2)训练集---ACC:78.12%---LOSS:0.537---time:47.20
# Epoch:9---batch(3)训练集---ACC:84.38%---LOSS:0.262---time:46.97
# Epoch:9---batch(4)训练集---ACC:75.00%---LOSS:0.502---time:47.16
# Epoch:9---batch(5)训练集---ACC:75.00%---LOSS:0.664---time:47.07
# Epoch:9---batch(6)训练集---ACC:68.75%---LOSS:0.769---time:46.90
# Epoch:9---batch(7)训练集---ACC:81.25%---LOSS:0.390---time:47.33
# Epoch:9---batch(8)训练集---ACC:93.75%---LOSS:0.250---time:48.15
# Epoch:9---batch(9)训练集---ACC:84.38%---LOSS:0.533---time:47.72
# Epoch:9---batch(10)训练集---ACC:87.50%---LOSS:0.553---time:47.66
# Epoch:9---batch(11)训练集---ACC:87.50%---LOSS:0.324---time:43.39
# Epoch:9---batch(12)训练集---ACC:68.75%---LOSS:0.869---time:38.41
# Epoch:9---batch(13)训练集---ACC:84.38%---LOSS:0.437---time:38.44
# Epoch:9---batch(14)训练集---ACC:81.25%---LOSS:0.401---time:38.72
# Epoch:9---batch(15)训练集---ACC:90.62%---LOSS:0.317---time:38.62
# Epoch:9---batch(16)训练集---ACC:65.62%---LOSS:0.784---time:38.59
# Epoch:9---batch(17)训练集---ACC:84.38%---LOSS:0.363---time:38.58
# Epoch:9---batch(18)训练集---ACC:81.25%---LOSS:0.551---time:38.56
# Epoch:9---batch(19)训练集---ACC:87.50%---LOSS:0.600---time:38.28
# Epoch:9---batch(20)训练集---ACC:75.00%---LOSS:0.475---time:38.55
# Epoch:9---batch(21)训练集---ACC:87.50%---LOSS:0.349---time:38.36
# Epoch:9---batch(22)训练集---ACC:84.38%---LOSS:0.396---time:38.64
# Epoch:9---batch(23)训练集---ACC:81.25%---LOSS:0.561---time:38.74
# Epoch:9---batch(24)训练集---ACC:68.75%---LOSS:0.676---time:38.40
# Epoch:9---batch(25)训练集---ACC:75.00%---LOSS:0.609---time:38.70
# Epoch:9---batch(26)训练集---ACC:87.50%---LOSS:0.330---time:38.81
# Epoch:9---batch(27)训练集---ACC:87.50%---LOSS:0.402---time:43.61
# Epoch:9---batch(28)训练集---ACC:81.25%---LOSS:0.530---time:90.21
# Epoch:9---batch(29)训练集---ACC:81.25%---LOSS:0.434---time:53.37
# Epoch:9---batch(30)训练集---ACC:75.00%---LOSS:0.561---time:51.55
# Epoch:9---batch(31)训练集---ACC:78.12%---LOSS:0.693---time:60.10
# Epoch:9---batch(32)训练集---ACC:93.75%---LOSS:0.240---time:53.36
# Epoch:9---batch(33)训练集---ACC:84.38%---LOSS:0.440---time:46.13
# Epoch:9---batch(34)训练集---ACC:84.38%---LOSS:0.494---time:47.34
# Epoch:9---batch(35)训练集---ACC:81.25%---LOSS:0.410---time:49.07
# Epoch:9---batch(36)训练集---ACC:75.00%---LOSS:0.712---time:44.97
# Epoch:9---batch(37)训练集---ACC:81.25%---LOSS:0.314---time:21.94
# 第9轮测试集准确率：81.00%....测试集Loss:0.5796417466231755
# Epoch:10---batch(0)训练集---ACC:68.75%---LOSS:0.615---time:40.56
# Epoch:10---batch(1)训练集---ACC:93.75%---LOSS:0.271---time:40.74
# Epoch:10---batch(2)训练集---ACC:84.38%---LOSS:0.428---time:40.52
# Epoch:10---batch(3)训练集---ACC:84.38%---LOSS:0.382---time:40.93
# Epoch:10---batch(4)训练集---ACC:87.50%---LOSS:0.308---time:40.60
# Epoch:10---batch(5)训练集---ACC:65.62%---LOSS:1.251---time:44.75
# Epoch:10---batch(6)训练集---ACC:78.12%---LOSS:0.642---time:45.47
# Epoch:10---batch(7)训练集---ACC:93.75%---LOSS:0.295---time:45.65
# Epoch:10---batch(8)训练集---ACC:96.88%---LOSS:0.115---time:51.39
# Epoch:10---batch(9)训练集---ACC:84.38%---LOSS:0.430---time:54.32
# Epoch:10---batch(10)训练集---ACC:90.62%---LOSS:0.277---time:47.31
# Epoch:10---batch(11)训练集---ACC:71.88%---LOSS:0.574---time:60.39
# Epoch:10---batch(12)训练集---ACC:84.38%---LOSS:0.625---time:71.33
# Epoch:10---batch(13)训练集---ACC:81.25%---LOSS:0.471---time:69.11
# Epoch:10---batch(14)训练集---ACC:84.38%---LOSS:0.476---time:91.15
# Epoch:10---batch(15)训练集---ACC:75.00%---LOSS:0.474---time:89.44
# Epoch:10---batch(16)训练集---ACC:87.50%---LOSS:0.288---time:46.44
# Epoch:10---batch(17)训练集---ACC:90.62%---LOSS:0.441---time:45.77
# Epoch:10---batch(18)训练集---ACC:78.12%---LOSS:0.627---time:45.74
# Epoch:10---batch(19)训练集---ACC:75.00%---LOSS:0.590---time:45.54
# Epoch:10---batch(20)训练集---ACC:75.00%---LOSS:0.556---time:45.16
# Epoch:10---batch(21)训练集---ACC:87.50%---LOSS:0.503---time:46.07
# Epoch:10---batch(22)训练集---ACC:75.00%---LOSS:0.508---time:49.00
# Epoch:10---batch(23)训练集---ACC:65.62%---LOSS:0.971---time:45.79
# Epoch:10---batch(24)训练集---ACC:81.25%---LOSS:0.485---time:45.69
# Epoch:10---batch(25)训练集---ACC:84.38%---LOSS:0.600---time:45.59
# Epoch:10---batch(26)训练集---ACC:93.75%---LOSS:0.253---time:45.58
# Epoch:10---batch(27)训练集---ACC:90.62%---LOSS:0.246---time:45.00
# Epoch:10---batch(28)训练集---ACC:78.12%---LOSS:0.572---time:45.44
# Epoch:10---batch(29)训练集---ACC:65.62%---LOSS:0.823---time:45.08
# Epoch:10---batch(30)训练集---ACC:93.75%---LOSS:0.347---time:45.78
# Epoch:10---batch(31)训练集---ACC:87.50%---LOSS:0.442---time:45.27
# Epoch:10---batch(32)训练集---ACC:87.50%---LOSS:0.407---time:45.87
# Epoch:10---batch(33)训练集---ACC:81.25%---LOSS:0.395---time:45.45
# Epoch:10---batch(34)训练集---ACC:78.12%---LOSS:0.695---time:47.90
# Epoch:10---batch(35)训练集---ACC:71.88%---LOSS:0.676---time:52.78
# Epoch:10---batch(36)训练集---ACC:75.00%---LOSS:0.594---time:47.37
# Epoch:10---batch(37)训练集---ACC:75.00%---LOSS:0.490---time:23.08
# 第10轮测试集准确率：83.00%....测试集Loss:0.5576520178999219
# Epoch:11---batch(0)训练集---ACC:75.00%---LOSS:0.482---time:46.96
# Epoch:11---batch(1)训练集---ACC:81.25%---LOSS:0.464---time:52.87
# Epoch:11---batch(2)训练集---ACC:93.75%---LOSS:0.220---time:47.76
# Epoch:11---batch(3)训练集---ACC:90.62%---LOSS:0.291---time:58.43
# Epoch:11---batch(4)训练集---ACC:84.38%---LOSS:0.387---time:64.19
# Epoch:11---batch(5)训练集---ACC:78.12%---LOSS:0.388---time:61.08
# Epoch:11---batch(6)训练集---ACC:81.25%---LOSS:0.379---time:54.49
# Epoch:11---batch(7)训练集---ACC:87.50%---LOSS:0.523---time:51.65
# Epoch:11---batch(8)训练集---ACC:81.25%---LOSS:0.383---time:51.60
# Epoch:11---batch(9)训练集---ACC:84.38%---LOSS:0.335---time:44.58
# Epoch:11---batch(10)训练集---ACC:71.88%---LOSS:0.769---time:43.06
# Epoch:11---batch(11)训练集---ACC:90.62%---LOSS:0.194---time:45.02
# Epoch:11---batch(12)训练集---ACC:87.50%---LOSS:0.399---time:49.09
# Epoch:11---batch(13)训练集---ACC:87.50%---LOSS:0.337---time:43.96
# Epoch:11---batch(14)训练集---ACC:84.38%---LOSS:0.527---time:40.02
# Epoch:11---batch(15)训练集---ACC:84.38%---LOSS:0.342---time:41.13
# Epoch:11---batch(16)训练集---ACC:84.38%---LOSS:0.316---time:42.37
# Epoch:11---batch(17)训练集---ACC:87.50%---LOSS:0.457---time:42.94
# Epoch:11---batch(18)训练集---ACC:78.12%---LOSS:0.438---time:41.56
# Epoch:11---batch(19)训练集---ACC:78.12%---LOSS:0.667---time:43.42
# Epoch:11---batch(20)训练集---ACC:84.38%---LOSS:0.490---time:43.10
# Epoch:11---batch(21)训练集---ACC:81.25%---LOSS:0.541---time:41.39
# Epoch:11---batch(22)训练集---ACC:81.25%---LOSS:0.402---time:45.62
# Epoch:11---batch(23)训练集---ACC:81.25%---LOSS:0.618---time:43.82
# Epoch:11---batch(24)训练集---ACC:87.50%---LOSS:0.360---time:44.60
# Epoch:11---batch(25)训练集---ACC:81.25%---LOSS:0.491---time:42.90
# Epoch:11---batch(26)训练集---ACC:84.38%---LOSS:0.430---time:41.38
# Epoch:11---batch(27)训练集---ACC:87.50%---LOSS:0.278---time:41.84
# Epoch:11---batch(28)训练集---ACC:84.38%---LOSS:0.451---time:44.30
# Epoch:11---batch(29)训练集---ACC:81.25%---LOSS:0.676---time:41.82
# Epoch:11---batch(30)训练集---ACC:93.75%---LOSS:0.274---time:44.18
# Epoch:11---batch(31)训练集---ACC:84.38%---LOSS:0.428---time:40.66
# Epoch:11---batch(32)训练集---ACC:81.25%---LOSS:0.490---time:43.56
# Epoch:11---batch(33)训练集---ACC:84.38%---LOSS:0.465---time:42.29
# Epoch:11---batch(34)训练集---ACC:90.62%---LOSS:0.254---time:44.04
# Epoch:11---batch(35)训练集---ACC:87.50%---LOSS:0.410---time:44.19
# Epoch:11---batch(36)训练集---ACC:96.88%---LOSS:0.207---time:44.10
# Epoch:11---batch(37)训练集---ACC:81.25%---LOSS:0.472---time:21.07
# 第11轮测试集准确率：81.50%....测试集Loss:0.581781016928809
# Epoch:12---batch(0)训练集---ACC:78.12%---LOSS:0.427---time:44.66
# Epoch:12---batch(1)训练集---ACC:84.38%---LOSS:0.411---time:44.04
# Epoch:12---batch(2)训练集---ACC:81.25%---LOSS:0.443---time:44.54
# Epoch:12---batch(3)训练集---ACC:90.62%---LOSS:0.354---time:45.83
# Epoch:12---batch(4)训练集---ACC:87.50%---LOSS:0.320---time:45.93
# Epoch:12---batch(5)训练集---ACC:90.62%---LOSS:0.348---time:43.67
# Epoch:12---batch(6)训练集---ACC:90.62%---LOSS:0.268---time:41.45
# Epoch:12---batch(7)训练集---ACC:87.50%---LOSS:0.364---time:41.35
# Epoch:12---batch(8)训练集---ACC:78.12%---LOSS:0.534---time:41.73
# Epoch:12---batch(9)训练集---ACC:87.50%---LOSS:0.297---time:40.92
# Epoch:12---batch(10)训练集---ACC:84.38%---LOSS:0.513---time:40.60
# Epoch:12---batch(11)训练集---ACC:71.88%---LOSS:0.618---time:44.37
# Epoch:12---batch(12)训练集---ACC:75.00%---LOSS:0.576---time:44.57
# Epoch:12---batch(13)训练集---ACC:87.50%---LOSS:0.341---time:52.00
# Epoch:12---batch(14)训练集---ACC:84.38%---LOSS:0.418---time:52.33
# Epoch:12---batch(15)训练集---ACC:90.62%---LOSS:0.360---time:46.41
# Epoch:12---batch(16)训练集---ACC:84.38%---LOSS:0.346---time:44.09
# Epoch:12---batch(17)训练集---ACC:75.00%---LOSS:0.354---time:44.58
# Epoch:12---batch(18)训练集---ACC:84.38%---LOSS:0.373---time:44.26
# Epoch:12---batch(19)训练集---ACC:87.50%---LOSS:0.621---time:46.66
# Epoch:12---batch(20)训练集---ACC:84.38%---LOSS:0.389---time:45.86
# Epoch:12---batch(21)训练集---ACC:78.12%---LOSS:0.505---time:43.83
# Epoch:12---batch(22)训练集---ACC:84.38%---LOSS:0.335---time:44.43
# Epoch:12---batch(23)训练集---ACC:84.38%---LOSS:0.395---time:44.98
# Epoch:12---batch(24)训练集---ACC:84.38%---LOSS:0.401---time:45.88
# Epoch:12---batch(25)训练集---ACC:90.62%---LOSS:0.503---time:43.93
# Epoch:12---batch(26)训练集---ACC:68.75%---LOSS:0.624---time:44.89
# Epoch:12---batch(27)训练集---ACC:87.50%---LOSS:0.345---time:45.88
# Epoch:12---batch(28)训练集---ACC:87.50%---LOSS:0.251---time:44.83
# Epoch:12---batch(29)训练集---ACC:90.62%---LOSS:0.302---time:50.16
# Epoch:12---batch(30)训练集---ACC:84.38%---LOSS:0.416---time:47.70
# Epoch:12---batch(31)训练集---ACC:84.38%---LOSS:0.404---time:44.06
# Epoch:12---batch(32)训练集---ACC:81.25%---LOSS:0.333---time:49.93
# Epoch:12---batch(33)训练集---ACC:81.25%---LOSS:0.568---time:46.57
# Epoch:12---batch(34)训练集---ACC:84.38%---LOSS:0.504---time:45.10
# Epoch:12---batch(35)训练集---ACC:75.00%---LOSS:0.694---time:42.69
# Epoch:12---batch(36)训练集---ACC:75.00%---LOSS:0.505---time:46.52
# Epoch:12---batch(37)训练集---ACC:81.25%---LOSS:0.550---time:22.42
# 第12轮测试集准确率：77.50%....测试集Loss:0.6615674240248544
# Epoch:13---batch(0)训练集---ACC:100.00%---LOSS:0.107---time:45.58
# Epoch:13---batch(1)训练集---ACC:84.38%---LOSS:0.291---time:45.30
# Epoch:13---batch(2)训练集---ACC:87.50%---LOSS:0.395---time:43.24
# Epoch:13---batch(3)训练集---ACC:81.25%---LOSS:0.446---time:44.63
# Epoch:13---batch(4)训练集---ACC:87.50%---LOSS:0.388---time:46.34
# Epoch:13---batch(5)训练集---ACC:81.25%---LOSS:0.607---time:47.58
# Epoch:13---batch(6)训练集---ACC:87.50%---LOSS:0.452---time:44.37
# Epoch:13---batch(7)训练集---ACC:87.50%---LOSS:0.460---time:46.82
# Epoch:13---batch(8)训练集---ACC:87.50%---LOSS:0.479---time:44.18
# Epoch:13---batch(9)训练集---ACC:81.25%---LOSS:0.401---time:42.59
# Epoch:13---batch(10)训练集---ACC:78.12%---LOSS:0.469---time:42.11
# Epoch:13---batch(11)训练集---ACC:81.25%---LOSS:0.544---time:41.76
# Epoch:13---batch(12)训练集---ACC:84.38%---LOSS:0.379---time:42.35
# Epoch:13---batch(13)训练集---ACC:81.25%---LOSS:0.316---time:45.66
# Epoch:13---batch(14)训练集---ACC:75.00%---LOSS:0.440---time:43.61
# Epoch:13---batch(15)训练集---ACC:81.25%---LOSS:0.363---time:45.50
# Epoch:13---batch(16)训练集---ACC:84.38%---LOSS:0.375---time:42.00
# Epoch:13---batch(17)训练集---ACC:78.12%---LOSS:0.469---time:43.28
# Epoch:13---batch(18)训练集---ACC:68.75%---LOSS:0.681---time:45.52
# Epoch:13---batch(19)训练集---ACC:78.12%---LOSS:0.562---time:43.83
# Epoch:13---batch(20)训练集---ACC:84.38%---LOSS:0.544---time:42.30
# Epoch:13---batch(21)训练集---ACC:93.75%---LOSS:0.308---time:40.78
# Epoch:13---batch(22)训练集---ACC:93.75%---LOSS:0.205---time:41.82
# Epoch:13---batch(23)训练集---ACC:87.50%---LOSS:0.480---time:41.35
# Epoch:13---batch(24)训练集---ACC:84.38%---LOSS:0.649---time:42.65
# Epoch:13---batch(25)训练集---ACC:90.62%---LOSS:0.329---time:44.15
# Epoch:13---batch(26)训练集---ACC:75.00%---LOSS:0.658---time:47.79
# Epoch:13---batch(27)训练集---ACC:78.12%---LOSS:0.801---time:41.50
# Epoch:13---batch(28)训练集---ACC:84.38%---LOSS:0.412---time:45.23
# Epoch:13---batch(29)训练集---ACC:90.62%---LOSS:0.293---time:43.63
# Epoch:13---batch(30)训练集---ACC:75.00%---LOSS:0.673---time:43.71
# Epoch:13---batch(31)训练集---ACC:78.12%---LOSS:0.476---time:40.52
# Epoch:13---batch(32)训练集---ACC:65.62%---LOSS:0.738---time:50.25
# Epoch:13---batch(33)训练集---ACC:81.25%---LOSS:0.645---time:45.18
# Epoch:13---batch(34)训练集---ACC:78.12%---LOSS:0.379---time:52.45
# Epoch:13---batch(35)训练集---ACC:71.88%---LOSS:0.814---time:47.53
# Epoch:13---batch(36)训练集---ACC:81.25%---LOSS:0.509---time:43.23
# Epoch:13---batch(37)训练集---ACC:68.75%---LOSS:0.700---time:21.45
# 第13轮测试集准确率：79.00%....测试集Loss:0.6325142128126962
# Epoch:14---batch(0)训练集---ACC:84.38%---LOSS:0.537---time:42.15
# Epoch:14---batch(1)训练集---ACC:87.50%---LOSS:0.383---time:41.02
# Epoch:14---batch(2)训练集---ACC:90.62%---LOSS:0.183---time:49.43
# Epoch:14---batch(3)训练集---ACC:81.25%---LOSS:0.670---time:47.33
# Epoch:14---batch(4)训练集---ACC:75.00%---LOSS:1.088---time:53.38
# Epoch:14---batch(5)训练集---ACC:90.62%---LOSS:0.481---time:43.77
# Epoch:14---batch(6)训练集---ACC:78.12%---LOSS:0.662---time:45.09
# Epoch:14---batch(7)训练集---ACC:56.25%---LOSS:1.161---time:44.47
# Epoch:14---batch(8)训练集---ACC:90.62%---LOSS:0.292---time:40.07
# Epoch:14---batch(9)训练集---ACC:93.75%---LOSS:0.189---time:41.19
# Epoch:14---batch(10)训练集---ACC:78.12%---LOSS:0.493---time:39.27
# Epoch:14---batch(11)训练集---ACC:81.25%---LOSS:0.595---time:38.97
# Epoch:14---batch(12)训练集---ACC:68.75%---LOSS:0.656---time:38.84
# Epoch:14---batch(13)训练集---ACC:75.00%---LOSS:0.742---time:39.13
# Epoch:14---batch(14)训练集---ACC:81.25%---LOSS:0.410---time:39.38
# Epoch:14---batch(15)训练集---ACC:75.00%---LOSS:0.452---time:38.68
# Epoch:14---batch(16)训练集---ACC:90.62%---LOSS:0.275---time:46.71
# Epoch:14---batch(17)训练集---ACC:87.50%---LOSS:0.348---time:88.78
# Epoch:14---batch(18)训练集---ACC:90.62%---LOSS:0.403---time:76.51
# Epoch:14---batch(19)训练集---ACC:90.62%---LOSS:0.363---time:79.30
# Epoch:14---batch(20)训练集---ACC:84.38%---LOSS:0.423---time:38.38
# Epoch:14---batch(21)训练集---ACC:87.50%---LOSS:0.501---time:44.73
# Epoch:14---batch(22)训练集---ACC:93.75%---LOSS:0.231---time:46.06
# Epoch:14---batch(23)训练集---ACC:75.00%---LOSS:0.651---time:36.77
# Epoch:14---batch(24)训练集---ACC:90.62%---LOSS:0.313---time:34.65
# Epoch:14---batch(25)训练集---ACC:78.12%---LOSS:0.584---time:35.09
# Epoch:14---batch(26)训练集---ACC:71.88%---LOSS:0.625---time:34.16
# Epoch:14---batch(27)训练集---ACC:84.38%---LOSS:0.446---time:34.90
# Epoch:14---batch(28)训练集---ACC:90.62%---LOSS:0.338---time:34.66
# Epoch:14---batch(29)训练集---ACC:90.62%---LOSS:0.308---time:34.27
# Epoch:14---batch(30)训练集---ACC:68.75%---LOSS:0.702---time:35.36
# Epoch:14---batch(31)训练集---ACC:81.25%---LOSS:0.531---time:34.36
# Epoch:14---batch(32)训练集---ACC:84.38%---LOSS:0.407---time:34.68
# Epoch:14---batch(33)训练集---ACC:87.50%---LOSS:0.402---time:34.77
# Epoch:14---batch(34)训练集---ACC:84.38%---LOSS:0.319---time:34.50
# Epoch:14---batch(35)训练集---ACC:93.75%---LOSS:0.250---time:34.50
# Epoch:14---batch(36)训练集---ACC:81.25%---LOSS:0.473---time:35.15
# Epoch:14---batch(37)训练集---ACC:81.25%---LOSS:0.500---time:17.71
# 第14轮测试集准确率：80.00%....测试集Loss:0.5850540740149361
# Epoch:15---batch(0)训练集---ACC:84.38%---LOSS:0.347---time:34.35
# Epoch:15---batch(1)训练集---ACC:87.50%---LOSS:0.212---time:34.92
# Epoch:15---batch(2)训练集---ACC:81.25%---LOSS:0.534---time:34.88
# Epoch:15---batch(3)训练集---ACC:81.25%---LOSS:0.576---time:34.81
# Epoch:15---batch(4)训练集---ACC:81.25%---LOSS:0.775---time:35.11
# Epoch:15---batch(5)训练集---ACC:71.88%---LOSS:0.821---time:34.73
# Epoch:15---batch(6)训练集---ACC:78.12%---LOSS:0.427---time:34.12
# Epoch:15---batch(7)训练集---ACC:81.25%---LOSS:0.572---time:34.46
# Epoch:15---batch(8)训练集---ACC:75.00%---LOSS:0.504---time:34.17
# Epoch:15---batch(9)训练集---ACC:90.62%---LOSS:0.340---time:34.93
# Epoch:15---batch(10)训练集---ACC:87.50%---LOSS:0.223---time:35.41
# Epoch:15---batch(11)训练集---ACC:71.88%---LOSS:0.444---time:34.82
# Epoch:15---batch(12)训练集---ACC:84.38%---LOSS:0.436---time:34.89
# Epoch:15---batch(13)训练集---ACC:68.75%---LOSS:0.626---time:35.11
# Epoch:15---batch(14)训练集---ACC:81.25%---LOSS:0.526---time:34.93
# Epoch:15---batch(15)训练集---ACC:81.25%---LOSS:0.492---time:35.10
# Epoch:15---batch(16)训练集---ACC:84.38%---LOSS:0.329---time:35.08
# Epoch:15---batch(17)训练集---ACC:90.62%---LOSS:0.319---time:34.72
# Epoch:15---batch(18)训练集---ACC:93.75%---LOSS:0.249---time:34.75
# Epoch:15---batch(19)训练集---ACC:81.25%---LOSS:0.459---time:34.56
# Epoch:15---batch(20)训练集---ACC:87.50%---LOSS:0.342---time:34.82
# Epoch:15---batch(21)训练集---ACC:78.12%---LOSS:0.385---time:34.88
# Epoch:15---batch(22)训练集---ACC:87.50%---LOSS:0.281---time:34.74
# Epoch:15---batch(23)训练集---ACC:84.38%---LOSS:0.362---time:35.04
# Epoch:15---batch(24)训练集---ACC:84.38%---LOSS:0.306---time:34.53
# Epoch:15---batch(25)训练集---ACC:81.25%---LOSS:0.631---time:35.26
# Epoch:15---batch(26)训练集---ACC:93.75%---LOSS:0.253---time:35.63
# Epoch:15---batch(27)训练集---ACC:71.88%---LOSS:0.687---time:34.63
# Epoch:15---batch(28)训练集---ACC:75.00%---LOSS:0.738---time:35.27
# Epoch:15---batch(29)训练集---ACC:75.00%---LOSS:0.708---time:34.70
# Epoch:15---batch(30)训练集---ACC:87.50%---LOSS:0.300---time:34.60
# Epoch:15---batch(31)训练集---ACC:84.38%---LOSS:0.444---time:34.70
# Epoch:15---batch(32)训练集---ACC:87.50%---LOSS:0.239---time:34.99
# Epoch:15---batch(33)训练集---ACC:81.25%---LOSS:0.513---time:35.05
# Epoch:15---batch(34)训练集---ACC:71.88%---LOSS:0.657---time:34.54
# Epoch:15---batch(35)训练集---ACC:81.25%---LOSS:0.510---time:34.81
# Epoch:15---batch(36)训练集---ACC:90.62%---LOSS:0.282---time:34.61
# Epoch:15---batch(37)训练集---ACC:87.50%---LOSS:0.374---time:17.34
# 第15轮测试集准确率：78.00%....测试集Loss:0.6173519385712487
# Epoch:16---batch(0)训练集---ACC:87.50%---LOSS:0.301---time:35.03
# Epoch:16---batch(1)训练集---ACC:93.75%---LOSS:0.335---time:34.44
# Epoch:16---batch(2)训练集---ACC:90.62%---LOSS:0.293---time:34.72
# Epoch:16---batch(3)训练集---ACC:81.25%---LOSS:0.590---time:35.51
# Epoch:16---batch(4)训练集---ACC:87.50%---LOSS:0.422---time:34.99
# Epoch:16---batch(5)训练集---ACC:87.50%---LOSS:0.289---time:35.42
# Epoch:16---batch(6)训练集---ACC:87.50%---LOSS:0.399---time:35.75
# Epoch:16---batch(7)训练集---ACC:81.25%---LOSS:0.544---time:35.35
# Epoch:16---batch(8)训练集---ACC:75.00%---LOSS:0.614---time:34.79
# Epoch:16---batch(9)训练集---ACC:81.25%---LOSS:0.609---time:34.41
# Epoch:16---batch(10)训练集---ACC:81.25%---LOSS:0.369---time:34.96
# Epoch:16---batch(11)训练集---ACC:93.75%---LOSS:0.223---time:34.66
# Epoch:16---batch(12)训练集---ACC:87.50%---LOSS:0.300---time:34.68
# Epoch:16---batch(13)训练集---ACC:84.38%---LOSS:0.353---time:34.62
# Epoch:16---batch(14)训练集---ACC:87.50%---LOSS:0.284---time:35.15
# Epoch:16---batch(15)训练集---ACC:87.50%---LOSS:0.358---time:34.62
# Epoch:16---batch(16)训练集---ACC:78.12%---LOSS:0.502---time:34.89
# Epoch:16---batch(17)训练集---ACC:75.00%---LOSS:0.619---time:35.18
# Epoch:16---batch(18)训练集---ACC:84.38%---LOSS:0.550---time:34.90
# Epoch:16---batch(19)训练集---ACC:96.88%---LOSS:0.293---time:34.97
# Epoch:16---batch(20)训练集---ACC:93.75%---LOSS:0.225---time:34.87
# Epoch:16---batch(21)训练集---ACC:90.62%---LOSS:0.284---time:35.04
# Epoch:16---batch(22)训练集---ACC:62.50%---LOSS:0.733---time:34.96
# Epoch:16---batch(23)训练集---ACC:78.12%---LOSS:0.692---time:34.45
# Epoch:16---batch(24)训练集---ACC:81.25%---LOSS:0.297---time:35.02
# Epoch:16---batch(25)训练集---ACC:78.12%---LOSS:0.708---time:34.87
# Epoch:16---batch(26)训练集---ACC:87.50%---LOSS:0.373---time:34.72
# Epoch:16---batch(27)训练集---ACC:81.25%---LOSS:0.413---time:34.80
# Epoch:16---batch(28)训练集---ACC:84.38%---LOSS:0.310---time:34.75
# Epoch:16---batch(29)训练集---ACC:87.50%---LOSS:0.452---time:35.34
# Epoch:16---batch(30)训练集---ACC:84.38%---LOSS:0.461---time:34.84
# Epoch:16---batch(31)训练集---ACC:93.75%---LOSS:0.303---time:34.92
# Epoch:16---batch(32)训练集---ACC:90.62%---LOSS:0.263---time:34.51
# Epoch:16---batch(33)训练集---ACC:71.88%---LOSS:0.551---time:34.96
# Epoch:16---batch(34)训练集---ACC:87.50%---LOSS:0.306---time:35.35
# Epoch:16---batch(35)训练集---ACC:96.88%---LOSS:0.214---time:35.06
# Epoch:16---batch(36)训练集---ACC:90.62%---LOSS:0.300---time:34.66
# Epoch:16---batch(37)训练集---ACC:100.00%---LOSS:0.094---time:17.48
# 第16轮测试集准确率：78.50%....测试集Loss:0.758115930216653
# Epoch:17---batch(0)训练集---ACC:78.12%---LOSS:0.541---time:35.17
# Epoch:17---batch(1)训练集---ACC:81.25%---LOSS:0.542---time:35.10
# Epoch:17---batch(2)训练集---ACC:81.25%---LOSS:0.652---time:35.26
# Epoch:17---batch(3)训练集---ACC:87.50%---LOSS:0.350---time:34.38
# Epoch:17---batch(4)训练集---ACC:93.75%---LOSS:0.363---time:34.87
# Epoch:17---batch(5)训练集---ACC:78.12%---LOSS:0.434---time:35.18
# Epoch:17---batch(6)训练集---ACC:78.12%---LOSS:0.584---time:34.89
# Epoch:17---batch(7)训练集---ACC:78.12%---LOSS:0.554---time:35.68
# Epoch:17---batch(8)训练集---ACC:90.62%---LOSS:0.507---time:35.35
# Epoch:17---batch(9)训练集---ACC:81.25%---LOSS:0.348---time:34.88
# Epoch:17---batch(10)训练集---ACC:87.50%---LOSS:0.391---time:34.80
# Epoch:17---batch(11)训练集---ACC:78.12%---LOSS:0.699---time:34.93
# Epoch:17---batch(12)训练集---ACC:87.50%---LOSS:0.430---time:35.03
# Epoch:17---batch(13)训练集---ACC:81.25%---LOSS:0.379---time:34.69
# Epoch:17---batch(14)训练集---ACC:84.38%---LOSS:0.489---time:35.13
# Epoch:17---batch(15)训练集---ACC:81.25%---LOSS:0.662---time:35.30
# Epoch:17---batch(16)训练集---ACC:81.25%---LOSS:0.800---time:35.15
# Epoch:17---batch(17)训练集---ACC:84.38%---LOSS:0.521---time:35.05
# Epoch:17---batch(18)训练集---ACC:87.50%---LOSS:0.329---time:34.87
# Epoch:17---batch(19)训练集---ACC:78.12%---LOSS:0.352---time:34.93
# Epoch:17---batch(20)训练集---ACC:84.38%---LOSS:0.565---time:35.16
# Epoch:17---batch(21)训练集---ACC:84.38%---LOSS:0.340---time:34.99
# Epoch:17---batch(22)训练集---ACC:81.25%---LOSS:0.483---time:34.67
# Epoch:17---batch(23)训练集---ACC:81.25%---LOSS:0.459---time:34.53
# Epoch:17---batch(24)训练集---ACC:84.38%---LOSS:0.379---time:35.26
# Epoch:17---batch(25)训练集---ACC:81.25%---LOSS:0.557---time:35.47
# Epoch:17---batch(26)训练集---ACC:84.38%---LOSS:0.487---time:35.23
# Epoch:17---batch(27)训练集---ACC:75.00%---LOSS:0.832---time:35.38
# Epoch:17---batch(28)训练集---ACC:93.75%---LOSS:0.268---time:35.30
# Epoch:17---batch(29)训练集---ACC:87.50%---LOSS:0.214---time:35.27
# Epoch:17---batch(30)训练集---ACC:87.50%---LOSS:0.299---time:34.90
# Epoch:17---batch(31)训练集---ACC:78.12%---LOSS:0.933---time:34.94
# Epoch:17---batch(32)训练集---ACC:87.50%---LOSS:0.288---time:35.01
# Epoch:17---batch(33)训练集---ACC:84.38%---LOSS:0.296---time:34.70
# Epoch:17---batch(34)训练集---ACC:96.88%---LOSS:0.160---time:34.93
# Epoch:17---batch(35)训练集---ACC:78.12%---LOSS:0.500---time:34.69
# Epoch:17---batch(36)训练集---ACC:84.38%---LOSS:0.450---time:34.95
# Epoch:17---batch(37)训练集---ACC:81.25%---LOSS:0.519---time:17.08
# 第17轮测试集准确率：79.50%....测试集Loss:0.6854859675679889
# Epoch:18---batch(0)训练集---ACC:90.62%---LOSS:0.323---time:34.43
# Epoch:18---batch(1)训练集---ACC:90.62%---LOSS:0.408---time:35.37
# Epoch:18---batch(2)训练集---ACC:84.38%---LOSS:0.372---time:34.88
# Epoch:18---batch(3)训练集---ACC:81.25%---LOSS:0.458---time:34.86
# Epoch:18---batch(4)训练集---ACC:87.50%---LOSS:0.380---time:34.46
# Epoch:18---batch(5)训练集---ACC:81.25%---LOSS:0.582---time:34.46
# Epoch:18---batch(6)训练集---ACC:90.62%---LOSS:0.317---time:34.88
# Epoch:18---batch(7)训练集---ACC:84.38%---LOSS:0.229---time:34.65
# Epoch:18---batch(8)训练集---ACC:81.25%---LOSS:0.462---time:34.65
# Epoch:18---batch(9)训练集---ACC:90.62%---LOSS:0.287---time:34.99
# Epoch:18---batch(10)训练集---ACC:81.25%---LOSS:0.748---time:34.75
# Epoch:18---batch(11)训练集---ACC:84.38%---LOSS:0.479---time:34.56
# Epoch:18---batch(12)训练集---ACC:84.38%---LOSS:0.432---time:34.71
# Epoch:18---batch(13)训练集---ACC:84.38%---LOSS:0.303---time:35.05
# Epoch:18---batch(14)训练集---ACC:81.25%---LOSS:0.405---time:34.72
# Epoch:18---batch(15)训练集---ACC:81.25%---LOSS:0.627---time:34.96
# Epoch:18---batch(16)训练集---ACC:81.25%---LOSS:0.686---time:34.90
# Epoch:18---batch(17)训练集---ACC:71.88%---LOSS:0.639---time:34.92
# Epoch:18---batch(18)训练集---ACC:90.62%---LOSS:0.367---time:35.15
# Epoch:18---batch(19)训练集---ACC:81.25%---LOSS:0.807---time:34.83
# Epoch:18---batch(20)训练集---ACC:84.38%---LOSS:0.314---time:34.56
# Epoch:18---batch(21)训练集---ACC:75.00%---LOSS:0.620---time:35.03
# Epoch:18---batch(22)训练集---ACC:68.75%---LOSS:0.578---time:35.08
# Epoch:18---batch(23)训练集---ACC:81.25%---LOSS:0.473---time:35.00
# Epoch:18---batch(24)训练集---ACC:87.50%---LOSS:0.419---time:34.72
# Epoch:18---batch(25)训练集---ACC:81.25%---LOSS:0.409---time:35.00
# Epoch:18---batch(26)训练集---ACC:81.25%---LOSS:0.529---time:34.63
# Epoch:18---batch(27)训练集---ACC:90.62%---LOSS:0.324---time:34.94
# Epoch:18---batch(28)训练集---ACC:87.50%---LOSS:0.417---time:34.89
# Epoch:18---batch(29)训练集---ACC:65.62%---LOSS:0.733---time:34.62
# Epoch:18---batch(30)训练集---ACC:78.12%---LOSS:0.327---time:35.16
# Epoch:18---batch(31)训练集---ACC:93.75%---LOSS:0.258---time:34.63
# Epoch:18---batch(32)训练集---ACC:84.38%---LOSS:0.415---time:34.57
# Epoch:18---batch(33)训练集---ACC:87.50%---LOSS:0.269---time:34.85
# Epoch:18---batch(34)训练集---ACC:81.25%---LOSS:0.286---time:34.58
# Epoch:18---batch(35)训练集---ACC:96.88%---LOSS:0.102---time:34.65
# Epoch:18---batch(36)训练集---ACC:90.62%---LOSS:0.278---time:34.88
# Epoch:18---batch(37)训练集---ACC:87.50%---LOSS:0.299---time:17.24
# 第18轮测试集准确率：81.00%....测试集Loss:0.6829576960631779
# Epoch:19---batch(0)训练集---ACC:78.12%---LOSS:0.391---time:34.67
# Epoch:19---batch(1)训练集---ACC:84.38%---LOSS:0.257---time:34.98
# Epoch:19---batch(2)训练集---ACC:87.50%---LOSS:0.291---time:34.88
# Epoch:19---batch(3)训练集---ACC:84.38%---LOSS:0.507---time:34.31
# Epoch:19---batch(4)训练集---ACC:78.12%---LOSS:0.685---time:34.83
# Epoch:19---batch(5)训练集---ACC:93.75%---LOSS:0.244---time:35.40
# Epoch:19---batch(6)训练集---ACC:84.38%---LOSS:0.469---time:35.60
# Epoch:19---batch(7)训练集---ACC:81.25%---LOSS:0.452---time:34.84
# Epoch:19---batch(8)训练集---ACC:65.62%---LOSS:0.632---time:35.02
# Epoch:19---batch(9)训练集---ACC:87.50%---LOSS:0.382---time:34.96
# Epoch:19---batch(10)训练集---ACC:84.38%---LOSS:0.353---time:34.67
# Epoch:19---batch(11)训练集---ACC:90.62%---LOSS:0.189---time:35.56
# Epoch:19---batch(12)训练集---ACC:75.00%---LOSS:0.456---time:35.14
# Epoch:19---batch(13)训练集---ACC:100.00%---LOSS:0.082---time:35.12
# Epoch:19---batch(14)训练集---ACC:75.00%---LOSS:0.638---time:35.02
# Epoch:19---batch(15)训练集---ACC:96.88%---LOSS:0.142---time:35.01
# Epoch:19---batch(16)训练集---ACC:90.62%---LOSS:0.211---time:35.50
# Epoch:19---batch(17)训练集---ACC:71.88%---LOSS:0.709---time:34.86
# Epoch:19---batch(18)训练集---ACC:84.38%---LOSS:0.600---time:35.06
# Epoch:19---batch(19)训练集---ACC:90.62%---LOSS:0.344---time:35.05
# Epoch:19---batch(20)训练集---ACC:87.50%---LOSS:0.440---time:34.95
# Epoch:19---batch(21)训练集---ACC:84.38%---LOSS:0.358---time:34.87
# Epoch:19---batch(22)训练集---ACC:84.38%---LOSS:0.343---time:34.88
# Epoch:19---batch(23)训练集---ACC:81.25%---LOSS:0.407---time:35.17
# Epoch:19---batch(24)训练集---ACC:71.88%---LOSS:0.529---time:35.25
# Epoch:19---batch(25)训练集---ACC:84.38%---LOSS:0.424---time:34.92
# Epoch:19---batch(26)训练集---ACC:87.50%---LOSS:0.309---time:35.20
# Epoch:19---batch(27)训练集---ACC:84.38%---LOSS:0.463---time:35.13
# Epoch:19---batch(28)训练集---ACC:78.12%---LOSS:0.490---time:34.81
# Epoch:19---batch(29)训练集---ACC:84.38%---LOSS:0.324---time:34.84
# Epoch:19---batch(30)训练集---ACC:62.50%---LOSS:0.791---time:34.94
# Epoch:19---batch(31)训练集---ACC:84.38%---LOSS:0.608---time:34.93
# Epoch:19---batch(32)训练集---ACC:90.62%---LOSS:0.250---time:35.31
# Epoch:19---batch(33)训练集---ACC:84.38%---LOSS:0.453---time:35.34
# Epoch:19---batch(34)训练集---ACC:87.50%---LOSS:0.276---time:34.75
# Epoch:19---batch(35)训练集---ACC:93.75%---LOSS:0.352---time:35.19
# Epoch:19---batch(36)训练集---ACC:71.88%---LOSS:0.637---time:35.50
# Epoch:19---batch(37)训练集---ACC:68.75%---LOSS:0.868---time:17.99
# 第19轮测试集准确率：83.00%....测试集Loss:0.5980483378682818

# %%
# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 经典与传统的对比
# 加载经典
# Classical_Train_data = pd.read_csv('/home/WUYING_986418966_1288354473/Desktop/QCNN/src/QCNN-FC/QTCNN-MNIST/640_train.csv')
# Classical_Val_data = pd.read_csv('/home/WUYING_986418966_1288354473/Desktop/QCNN/src/QCNN-FC/QTCNN-MNIST/2091_val.csv')

# Classical_Train_data_acc = Classical_Train_data[['Train_acc']]
# Classical_Train_data_loss = Classical_Train_data[['Train_loss']]

# Classical_Val_data_acc = Classical_Val_data[['Val_acc']]
# Classical_Val_data_loss = Classical_Val_data[['Val_loss']]
def result(acc,loss,plt1_title,plt2_title,title):     # 合并结果
    #绘图
    plt.xticks(np.arange(0,20,1))
    plt.plot(acc,label=plt1_title)
    plt.plot(loss,label=plt2_title)
    plt.title(title) 
    plt.xlabel('epoch')
    plt.ylabel('probability')
    plt.legend()   #显示标签
    plt.show()

# 加载qcnn
Qcnn_Train_data = pd.read_csv('E:\\Test\VsCode_Test\\Jupyter notebook\\Tensorcircuit\\result\\Fashion\\s=2\\566_train.csv')
Qcnn_Val_data = pd.read_csv('E:\\Test\\VsCode_Test\\Jupyter notebook\\Tensorcircuit\\result\\Fashion\\s=2\\8913_val.csv')

Qcnn_Train_data_acc = Qcnn_Train_data[['Train_acc']]
Qcnn_Train_data_loss = Qcnn_Train_data[['Train_loss']]

Qcnn_Val_data_acc = Qcnn_Val_data[['Val_acc']]
Qcnn_Val_data_loss = Qcnn_Val_data[['Val_loss']]

# 损失值比较
result(Qcnn_Train_data_loss,Qcnn_Val_data_loss,'Train_set','Val_set','Loss')
# 准确率比较
result(Qcnn_Train_data_acc,Qcnn_Val_data_acc,'Train_set','Val_set','ACC')
