# %%
# %%
import tensorcircuit as tc
# import pennylane as qml
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split,Subset
import random
import os
import time
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F
import numpy as np
import csv
import tensorflow as tf


data_path = 'E:\\Test\\VsCode_Test\\Jupyter notebook\\xLw\\data'

val_num = 200
data_num =  1200           # 需要划分的数据集大小
epochs = 20                 # 迭代轮次数
batch_size = 32

K = tc.set_backend("tensorflow")
# 归一化处理
def trans(x):
    x = np.array(x)
    x = x/255.0
    # print(x.shape)    
    return torch.from_numpy(x).float()  # 将 NumPy 数组 x 转换为 PyTorch 张量

transform = transforms.Compose([
    transforms.Resize((14, 14)),                # 将图片缩小为 14x14
    transforms.Lambda(lambda x:trans(x))
])

# 加载MNIST数据集 28X28X1   10类别   
trainset = torchvision.datasets.MNIST(root=data_path, train=True,
                                        download=False, transform=transform)
testset = torchvision.datasets.MNIST(root=data_path, train=False,
                                        download=False, transform=transform)

# 随机抽取训练集 data_num 张图片作为子集
subset_indices = random.sample(range(len(trainset)), k=data_num)
train_subset = Subset(trainset, subset_indices)

# 随机抽取测试集 data_num 张图片作为子集
subset_val = random.sample(range(len(testset)), k=val_num)
val_subset = Subset(testset, subset_val)

# 加载测试集
trainloader = torch.utils.data.DataLoader(train_subset, batch_size=batch_size,  # type: ignore
                                          shuffle=True)
testloader = torch.utils.data.DataLoader(val_subset, batch_size=batch_size,    # type: ignore
                                         shuffle=False)

# %%
n = 4
nlayers = 1

# 我们定义量子函数，
# 注意这个函数是在 tensorflow 上运行的
def qpred(x, weights):

    c = tc.Circuit(n)
    for i in range(n):
        c.h(i)
        c.ry(i, theta=x[i]*weights[i])
    for j in range(nlayers):
        for i in range(n - 1):
            c.cnot(i, i + 1)
            
    return [K.real(c.expectation([tc.gates.z(), [i]])) for i in range(n)]

# %%
qpred_vmap = K.vmap(qpred, vectorized_argnums=0)        # `qpred_vmap` 是一个具有向量化能力的 TensorFlow 函数
qpred_batch = tc.interfaces.torch_interface(qpred_vmap, jit=True) # 我们进一步将函数包装为 PyTorch 函数

# %%
class QuantumNetV2(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.q_weights = torch.nn.Parameter(torch.randn([n]))
        self.stride = 1
        self.padding_s = 2

    def forward(self, inputs):

        in_bs,in_ch,in_w,in_h = inputs.shape

        kernel_size = 2
        # 判断输入的步长S是多少再决定是否填充
        # padding_input_inside = self.padding_s - 1
        padding_size = kernel_size - 1                  # 边界填充数

        padding_temp = nn.functional.pad(inputs,(12,1,12,1),mode='constant',value=0)
        # print(padding_temp.shape) # 期望得到 27*27
        
        
        # 元素间填充
        for bs in range(in_bs):
            for ch in range(in_ch):
                for i in range(in_w):     # 14是输入图片大小
                    for j in range(in_h):
                        padding_temp[bs,ch,i*2,j*2] = inputs[bs,ch,i,j]   # 对原图像（14X14）进行内部空洞
        # print(padding_temp)
        # print(padding_temp.shape)       # torch.Size([32, 1, 27, 27])                                                                                                                                                                                                                            

        # 使用转置卷积进行上采样，作为转置卷积的输入
        padd_img = nn.functional.pad(padding_temp,(padding_size,padding_size,padding_size,padding_size),mode='constant',value=0)
        # print(padd_img.shape)   # torch.Size([32, 1, 29, 29])

        
        
        bs, ch , h , w = padd_img.size()                      #    h=29
        
        # 转置卷积后输出特征图的大小
        h_out = self.padding_s*(in_h-1)+kernel_size           #   2（14-1）+ 2 = 28
        w_out = self.padding_s*(in_w-1)+kernel_size           #   2（14-1）+ 2 = 28

        out = torch.zeros((bs,4, h_out, w_out))
        # print(f'padd_img={padd_img.shape}')             # padd_img=torch.Size([3, 1, 16, 16])
        for b in range(bs):
                for j in range(0, h_out, self.stride):
                    for k in range(0, w_out, self.stride):
                        # print(f'padd_img[b, 0, j, k]={padd_img[b, 0, j, k].shape}')
                        t1 = padd_img[b, 0, j, k]        
                        t2 = padd_img[b, 0, j, k + 1]
                        t3 = padd_img[b, 0, j + 1, k]    
                        t4 = padd_img[b, 0, j + 1, k + 1]

                        temp = torch.Tensor([t1,t2,t3,t4]) # 
                        temp = temp.view(1,4)

                        # temp = torch.unsqueeze(temp, 0)      
                        q_results = qpred_batch(temp, self.q_weights)     
                        for c in range(4):
                            out[b, c,j // kernel_size, k // kernel_size] = q_results[c]
        return out

# %%
# 经典CNNmodel 可进行修改
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
            
        # Quantum layer 1
        self.conv1 = QuantumNetV2()
        self.relu1 = nn.ReLU()
        self.batch1 = nn.BatchNorm2d(4)  # 4
        
        # Fully-Connected layer 2
        self.fc2 = nn.Linear(3136,10)
                
    def forward(self, x):

        # qconv layer 1
        out = self.conv1(x)                 
        out = self.relu1(out)   
        out = self.batch1(out)
        
        #Flatten拉平操作
        out = out.view(out.size(0),-1)      # print(f'-----拉平后的维度是--{out.shape}') #  torch.Size([64, 576])
           
        #FC 第二层
        out = self.fc2(out)
        return F.log_softmax(out,dim = 1)

# %%
model = CNNModel()
loss_fun = nn.CrossEntropyLoss()
opt = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
# 准确率计算
def accuracy(output,labels):
    prediction = torch.max(output.data,1)[1]
    rights = prediction.eq(labels.data.view_as(prediction)).sum()
    return rights,len(labels)

# 绘制训练结果
def draw_result(accs,losses,title):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14, 6))   # subplots创建1行 2列的子图
    
    ax1.plot(losses) 
    ax1.set_title(title+" Loss")
    ax1.set_xlabel("Steps")
    ax1.set_ylabel("Loss")
    
    ax2.plot(accs)
    ax2.set_title(title+" Accuracy")
    ax2.set_xlabel("Steps")
    ax2.set_ylabel("Accuracy")

# %%
def train(epochs,model,loss_fun,opt,train_loader,test_loader):
    train_accuracy = []             # 训练集准确率
    train_loss = []

    val_accuracy = []               # 验证集准确率
    val_loss = []
    for epoch in range(epochs):
                ### 训练模块
        train_total_accuracy = 0    # 训练集每epoch（18个batch的和）的准确率
        train_total_loss = 0
        for batch_idx,(data,labels) in enumerate(train_loader):
            t2 = time.time()
            data = data.view(data.shape[0],1, data.shape[1], data.shape[2])
            # print(data)
            model.train()					    # 1 模型训练       
            output = model(data)			    # 2 模型输出
            # print(f'output.shape is {output.shape}')    # output.shape is torch.Size([64, 4, 17, 17])
            # print(f'labels.shape is {labels.shape}')    # labels.shape is torch.Size([64])
            loss = loss_fun(output,labels)	    # 3 计算损失

            opt.zero_grad()					    # 4 梯度清零
            loss.backward() 				    # 5 开始反向传播
            opt.step()                          # 6 梯度更新
            
            # 计算准确率
            accuracy_count, total_count = accuracy(output,labels)
            accuracy_rate = accuracy_count / total_count  # 计算准确率（预测正确的样本数除以总样本数）

            train_total_accuracy += accuracy_count
            train_total_loss +=loss.item()

            batch_time = time.time()-t2
            print(f'Epoch:{epoch}---batch({batch_idx})训练集---ACC:{accuracy_rate:.2%}---LOSS:{loss.item():.3f}---time:{batch_time:.2f}')        
        
        train_total_loss /= batch_idx+1
        train_accuracy.append(train_total_accuracy/len(train_subset))   # 保存1轮的数据 len(train_accuracy)
        train_loss.append(train_total_loss)
### 验证模块
        total_acc = 0
        total_test_loss = 0
        model.eval()
        with torch.no_grad():# 进行评测的时候网络不更新梯度
            for step,(data,target) in enumerate(test_loader):
                data = data.view(data.shape[0],1, data.shape[1], data.shape[2])            # 调整维度一致
                outputs = model(data)
                losses = loss_fun(outputs,target)                               # 计算损失

                accuracy_count, total_count = accuracy(outputs,target)          # 计算准确率
                accuracy_rate = accuracy_count / total_count                    # 计算准确率（预测正确的样本数除以总样本数）

                total_acc += accuracy_count
                total_test_loss+=losses.item()

        total_test_loss /= step + 1
        val_accuracy.append((total_acc/len(val_subset)))
        val_loss.append(total_test_loss)
        print(f'第{epoch}轮测试集准确率：{total_acc/len(val_subset):.2%}....测试集Loss:{total_test_loss}')
    
    ### 画出训练结果图 ##############
    draw_result(train_accuracy,train_loss,"Train")
    draw_result(val_accuracy,val_loss,"Val")
    
    ####  训练的结果写入文件   ##############
    with open(str(random.randint(100,999))+"_train.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Train_loss','Train_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, train_loss[i], train_accuracy[i].numpy()])
    
    #### 测试的结果写入文件  ##############
    with open(str(random.randint(1000,9999))+"_val.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Val_loss','Val_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, val_loss[i], val_accuracy[i].numpy()])

    ### 保存训练的结果
    # Loss0 = torch.tensor(save_train_loss)
    # torch.save(Loss0,'E:\\Test\\VsCode_Test\\Python\\xlw\\test1\\lw2\\epoch_{}'.format(epochs))
    return model, train_accuracy,train_loss


model, train_accuracy,train_loss = train(epochs,model,loss_fun,opt,trainloader,testloader)
# Out:
# Epoch:0---batch(0)训练集---ACC:12.50%---LOSS:2.370---time:52.10
# Epoch:0---batch(1)训练集---ACC:31.25%---LOSS:4.172---time:44.26
# Epoch:0---batch(2)训练集---ACC:21.88%---LOSS:3.520---time:39.31
# Epoch:0---batch(3)训练集---ACC:40.62%---LOSS:1.789---time:45.37
# Epoch:0---batch(4)训练集---ACC:50.00%---LOSS:1.519---time:42.45
# Epoch:0---batch(5)训练集---ACC:56.25%---LOSS:1.815---time:43.26
# Epoch:0---batch(6)训练集---ACC:62.50%---LOSS:1.225---time:43.80
# Epoch:0---batch(7)训练集---ACC:53.12%---LOSS:1.711---time:46.72
# Epoch:0---batch(8)训练集---ACC:53.12%---LOSS:1.492---time:50.79
# Epoch:0---batch(9)训练集---ACC:59.38%---LOSS:1.493---time:42.06
# Epoch:0---batch(10)训练集---ACC:75.00%---LOSS:1.112---time:43.90
# Epoch:0---batch(11)训练集---ACC:78.12%---LOSS:0.556---time:40.69
# Epoch:0---batch(12)训练集---ACC:81.25%---LOSS:0.717---time:38.84
# Epoch:0---batch(13)训练集---ACC:84.38%---LOSS:0.573---time:45.29
# Epoch:0---batch(14)训练集---ACC:75.00%---LOSS:0.747---time:39.76
# Epoch:0---batch(15)训练集---ACC:62.50%---LOSS:1.148---time:39.96
# Epoch:0---batch(16)训练集---ACC:78.12%---LOSS:1.251---time:44.16
# Epoch:0---batch(17)训练集---ACC:78.12%---LOSS:0.668---time:39.46
# Epoch:0---batch(18)训练集---ACC:78.12%---LOSS:0.583---time:42.76
# Epoch:0---batch(19)训练集---ACC:65.62%---LOSS:0.886---time:38.91
# Epoch:0---batch(20)训练集---ACC:75.00%---LOSS:0.734---time:38.06
# Epoch:0---batch(21)训练集---ACC:75.00%---LOSS:0.645---time:38.24
# Epoch:0---batch(22)训练集---ACC:65.62%---LOSS:0.685---time:37.78
# Epoch:0---batch(23)训练集---ACC:75.00%---LOSS:1.149---time:38.15
# Epoch:0---batch(24)训练集---ACC:65.62%---LOSS:0.889---time:38.15
# Epoch:0---batch(25)训练集---ACC:87.50%---LOSS:0.422---time:46.85
# Epoch:0---batch(26)训练集---ACC:78.12%---LOSS:0.568---time:54.62
# Epoch:0---batch(27)训练集---ACC:78.12%---LOSS:0.543---time:56.44
# Epoch:0---batch(28)训练集---ACC:81.25%---LOSS:0.637---time:52.62
# Epoch:0---batch(29)训练集---ACC:84.38%---LOSS:0.485---time:46.18
# Epoch:0---batch(30)训练集---ACC:78.12%---LOSS:0.622---time:44.58
# Epoch:0---batch(31)训练集---ACC:71.88%---LOSS:0.835---time:45.91
# Epoch:0---batch(32)训练集---ACC:90.62%---LOSS:0.319---time:46.90
# Epoch:0---batch(33)训练集---ACC:81.25%---LOSS:0.618---time:54.26
# Epoch:0---batch(34)训练集---ACC:84.38%---LOSS:0.731---time:48.44
# Epoch:0---batch(35)训练集---ACC:81.25%---LOSS:0.535---time:48.31
# Epoch:0---batch(36)训练集---ACC:78.12%---LOSS:0.634---time:48.09
# Epoch:0---batch(37)训练集---ACC:68.75%---LOSS:0.620---time:21.65
# 第0轮测试集准确率：10.00%....测试集Loss:2.8872552939823697
# Epoch:1---batch(0)训练集---ACC:96.88%---LOSS:0.201---time:41.76
# Epoch:1---batch(1)训练集---ACC:87.50%---LOSS:0.240---time:42.67
# Epoch:1---batch(2)训练集---ACC:93.75%---LOSS:0.192---time:42.24
# Epoch:1---batch(3)训练集---ACC:93.75%---LOSS:0.330---time:40.52
# Epoch:1---batch(4)训练集---ACC:87.50%---LOSS:0.323---time:41.36
# Epoch:1---batch(5)训练集---ACC:96.88%---LOSS:0.215---time:43.24
# Epoch:1---batch(6)训练集---ACC:78.12%---LOSS:0.548---time:44.40
# Epoch:1---batch(7)训练集---ACC:87.50%---LOSS:0.326---time:44.06
# Epoch:1---batch(8)训练集---ACC:84.38%---LOSS:0.459---time:47.76
# Epoch:1---batch(9)训练集---ACC:90.62%---LOSS:0.376---time:45.56
# Epoch:1---batch(10)训练集---ACC:90.62%---LOSS:0.352---time:43.73
# Epoch:1---batch(11)训练集---ACC:87.50%---LOSS:0.392---time:43.65
# Epoch:1---batch(12)训练集---ACC:90.62%---LOSS:0.291---time:43.84
# Epoch:1---batch(13)训练集---ACC:90.62%---LOSS:0.349---time:41.87
# Epoch:1---batch(14)训练集---ACC:75.00%---LOSS:0.797---time:41.70
# Epoch:1---batch(15)训练集---ACC:87.50%---LOSS:0.348---time:41.10
# Epoch:1---batch(16)训练集---ACC:90.62%---LOSS:0.577---time:44.05
# Epoch:1---batch(17)训练集---ACC:93.75%---LOSS:0.354---time:44.75
# Epoch:1---batch(18)训练集---ACC:90.62%---LOSS:0.260---time:44.03
# Epoch:1---batch(19)训练集---ACC:81.25%---LOSS:0.482---time:41.83
# Epoch:1---batch(20)训练集---ACC:87.50%---LOSS:0.370---time:42.09
# Epoch:1---batch(21)训练集---ACC:84.38%---LOSS:0.265---time:41.13
# Epoch:1---batch(22)训练集---ACC:93.75%---LOSS:0.222---time:42.36
# Epoch:1---batch(23)训练集---ACC:75.00%---LOSS:0.633---time:54.66
# Epoch:1---batch(24)训练集---ACC:90.62%---LOSS:0.266---time:46.93
# Epoch:1---batch(25)训练集---ACC:84.38%---LOSS:0.431---time:46.93
# Epoch:1---batch(26)训练集---ACC:87.50%---LOSS:0.538---time:46.57
# Epoch:1---batch(27)训练集---ACC:90.62%---LOSS:0.279---time:46.61
# Epoch:1---batch(28)训练集---ACC:84.38%---LOSS:0.465---time:46.74
# Epoch:1---batch(29)训练集---ACC:71.88%---LOSS:0.605---time:46.53
# Epoch:1---batch(30)训练集---ACC:87.50%---LOSS:0.291---time:46.62
# Epoch:1---batch(31)训练集---ACC:87.50%---LOSS:0.229---time:46.66
# Epoch:1---batch(32)训练集---ACC:96.88%---LOSS:0.325---time:46.52
# Epoch:1---batch(33)训练集---ACC:81.25%---LOSS:0.561---time:46.43
# Epoch:1---batch(34)训练集---ACC:87.50%---LOSS:0.477---time:46.49
# Epoch:1---batch(35)训练集---ACC:84.38%---LOSS:0.552---time:46.62
# Epoch:1---batch(36)训练集---ACC:84.38%---LOSS:0.586---time:46.64
# Epoch:1---batch(37)训练集---ACC:87.50%---LOSS:0.236---time:23.44
# 第1轮测试集准确率：85.50%....测试集Loss:0.5706177268709455
# Epoch:2---batch(0)训练集---ACC:93.75%---LOSS:0.133---time:42.99
# Epoch:2---batch(1)训练集---ACC:87.50%---LOSS:0.235---time:42.95
# Epoch:2---batch(2)训练集---ACC:84.38%---LOSS:0.342---time:43.35
# Epoch:2---batch(3)训练集---ACC:93.75%---LOSS:0.286---time:42.39
# Epoch:2---batch(4)训练集---ACC:96.88%---LOSS:0.195---time:42.37
# Epoch:2---batch(5)训练集---ACC:93.75%---LOSS:0.164---time:42.43
# Epoch:2---batch(6)训练集---ACC:93.75%---LOSS:0.181---time:42.68
# Epoch:2---batch(7)训练集---ACC:93.75%---LOSS:0.199---time:43.78
# Epoch:2---batch(8)训练集---ACC:93.75%---LOSS:0.277---time:42.41
# Epoch:2---batch(9)训练集---ACC:78.12%---LOSS:0.424---time:43.18
# Epoch:2---batch(10)训练集---ACC:93.75%---LOSS:0.167---time:42.61
# Epoch:2---batch(11)训练集---ACC:96.88%---LOSS:0.235---time:42.98
# Epoch:2---batch(12)训练集---ACC:93.75%---LOSS:0.270---time:43.41
# Epoch:2---batch(13)训练集---ACC:87.50%---LOSS:0.331---time:42.51
# Epoch:2---batch(14)训练集---ACC:84.38%---LOSS:0.287---time:43.37
# Epoch:2---batch(15)训练集---ACC:96.88%---LOSS:0.245---time:42.65
# Epoch:2---batch(16)训练集---ACC:81.25%---LOSS:0.418---time:43.06
# Epoch:2---batch(17)训练集---ACC:96.88%---LOSS:0.207---time:42.96
# Epoch:2---batch(18)训练集---ACC:96.88%---LOSS:0.124---time:43.28
# Epoch:2---batch(19)训练集---ACC:90.62%---LOSS:0.377---time:42.77
# Epoch:2---batch(20)训练集---ACC:90.62%---LOSS:0.267---time:43.24
# Epoch:2---batch(21)训练集---ACC:93.75%---LOSS:0.357---time:42.70
# Epoch:2---batch(22)训练集---ACC:96.88%---LOSS:0.211---time:43.06
# Epoch:2---batch(23)训练集---ACC:87.50%---LOSS:0.265---time:42.89
# Epoch:2---batch(24)训练集---ACC:96.88%---LOSS:0.195---time:43.40
# Epoch:2---batch(25)训练集---ACC:96.88%---LOSS:0.222---time:43.45
# Epoch:2---batch(26)训练集---ACC:100.00%---LOSS:0.084---time:42.97
# Epoch:2---batch(27)训练集---ACC:90.62%---LOSS:0.207---time:42.93
# Epoch:2---batch(28)训练集---ACC:87.50%---LOSS:0.431---time:42.88
# Epoch:2---batch(29)训练集---ACC:93.75%---LOSS:0.215---time:42.43
# Epoch:2---batch(30)训练集---ACC:87.50%---LOSS:0.400---time:42.82
# Epoch:2---batch(31)训练集---ACC:90.62%---LOSS:0.275---time:43.43
# Epoch:2---batch(32)训练集---ACC:84.38%---LOSS:0.322---time:42.62
# Epoch:2---batch(33)训练集---ACC:96.88%---LOSS:0.172---time:43.14
# Epoch:2---batch(34)训练集---ACC:96.88%---LOSS:0.166---time:43.19
# Epoch:2---batch(35)训练集---ACC:96.88%---LOSS:0.335---time:42.69
# Epoch:2---batch(36)训练集---ACC:96.88%---LOSS:0.360---time:43.28
# Epoch:2---batch(37)训练集---ACC:81.25%---LOSS:0.640---time:21.35
# 第2轮测试集准确率：88.00%....测试集Loss:0.35559877327510286
# Epoch:3---batch(0)训练集---ACC:96.88%---LOSS:0.151---time:43.57
# Epoch:3---batch(1)训练集---ACC:96.88%---LOSS:0.141---time:42.61
# Epoch:3---batch(2)训练集---ACC:90.62%---LOSS:0.404---time:43.23
# Epoch:3---batch(3)训练集---ACC:93.75%---LOSS:0.147---time:43.05
# Epoch:3---batch(4)训练集---ACC:100.00%---LOSS:0.111---time:42.67
# Epoch:3---batch(5)训练集---ACC:81.25%---LOSS:0.415---time:43.03
# Epoch:3---batch(6)训练集---ACC:87.50%---LOSS:0.318---time:43.24
# Epoch:3---batch(7)训练集---ACC:96.88%---LOSS:0.109---time:43.39
# Epoch:3---batch(8)训练集---ACC:90.62%---LOSS:0.165---time:42.52
# Epoch:3---batch(9)训练集---ACC:96.88%---LOSS:0.172---time:42.98
# Epoch:3---batch(10)训练集---ACC:84.38%---LOSS:0.316---time:43.02
# Epoch:3---batch(11)训练集---ACC:93.75%---LOSS:0.240---time:42.90
# Epoch:3---batch(12)训练集---ACC:90.62%---LOSS:0.277---time:42.50
# Epoch:3---batch(13)训练集---ACC:96.88%---LOSS:0.248---time:43.02
# Epoch:3---batch(14)训练集---ACC:96.88%---LOSS:0.134---time:42.72
# Epoch:3---batch(15)训练集---ACC:90.62%---LOSS:0.259---time:42.52
# Epoch:3---batch(16)训练集---ACC:90.62%---LOSS:0.419---time:42.72
# Epoch:3---batch(17)训练集---ACC:93.75%---LOSS:0.226---time:43.20
# Epoch:3---batch(18)训练集---ACC:87.50%---LOSS:0.456---time:42.66
# Epoch:3---batch(19)训练集---ACC:96.88%---LOSS:0.154---time:42.64
# Epoch:3---batch(20)训练集---ACC:87.50%---LOSS:0.309---time:42.17
# Epoch:3---batch(21)训练集---ACC:90.62%---LOSS:0.260---time:43.38
# Epoch:3---batch(22)训练集---ACC:90.62%---LOSS:0.442---time:42.85
# Epoch:3---batch(23)训练集---ACC:84.38%---LOSS:0.395---time:42.88
# Epoch:3---batch(24)训练集---ACC:100.00%---LOSS:0.087---time:42.58
# Epoch:3---batch(25)训练集---ACC:96.88%---LOSS:0.093---time:42.69
# Epoch:3---batch(26)训练集---ACC:87.50%---LOSS:0.291---time:42.75
# Epoch:3---batch(27)训练集---ACC:90.62%---LOSS:0.270---time:42.86
# Epoch:3---batch(28)训练集---ACC:100.00%---LOSS:0.111---time:43.38
# Epoch:3---batch(29)训练集---ACC:93.75%---LOSS:0.212---time:43.10
# Epoch:3---batch(30)训练集---ACC:93.75%---LOSS:0.167---time:42.75
# Epoch:3---batch(31)训练集---ACC:93.75%---LOSS:0.232---time:43.07
# Epoch:3---batch(32)训练集---ACC:93.75%---LOSS:0.292---time:43.38
# Epoch:3---batch(33)训练集---ACC:93.75%---LOSS:0.252---time:42.62
# Epoch:3---batch(34)训练集---ACC:84.38%---LOSS:0.412---time:42.55
# Epoch:3---batch(35)训练集---ACC:96.88%---LOSS:0.095---time:42.67
# Epoch:3---batch(36)训练集---ACC:90.62%---LOSS:0.564---time:42.97
# Epoch:3---batch(37)训练集---ACC:100.00%---LOSS:0.163---time:21.33
# 第3轮测试集准确率：91.00%....测试集Loss:0.31192248527492794
# Epoch:4---batch(0)训练集---ACC:93.75%---LOSS:0.309---time:42.79
# Epoch:4---batch(1)训练集---ACC:100.00%---LOSS:0.057---time:42.55
# Epoch:4---batch(2)训练集---ACC:96.88%---LOSS:0.217---time:42.92
# Epoch:4---batch(3)训练集---ACC:100.00%---LOSS:0.079---time:43.11
# Epoch:4---batch(4)训练集---ACC:96.88%---LOSS:0.130---time:42.77
# Epoch:4---batch(5)训练集---ACC:96.88%---LOSS:0.145---time:42.86
# Epoch:4---batch(6)训练集---ACC:96.88%---LOSS:0.121---time:43.04
# Epoch:4---batch(7)训练集---ACC:87.50%---LOSS:0.275---time:43.68
# Epoch:4---batch(8)训练集---ACC:100.00%---LOSS:0.074---time:42.74
# Epoch:4---batch(9)训练集---ACC:93.75%---LOSS:0.145---time:42.71
# Epoch:4---batch(10)训练集---ACC:93.75%---LOSS:0.358---time:43.63
# Epoch:4---batch(11)训练集---ACC:90.62%---LOSS:0.207---time:42.91
# Epoch:4---batch(12)训练集---ACC:93.75%---LOSS:0.207---time:42.49
# Epoch:4---batch(13)训练集---ACC:93.75%---LOSS:0.116---time:43.24
# Epoch:4---batch(14)训练集---ACC:100.00%---LOSS:0.058---time:43.12
# Epoch:4---batch(15)训练集---ACC:87.50%---LOSS:0.272---time:43.44
# Epoch:4---batch(16)训练集---ACC:100.00%---LOSS:0.083---time:43.10
# Epoch:4---batch(17)训练集---ACC:93.75%---LOSS:0.189---time:42.51
# Epoch:4---batch(18)训练集---ACC:93.75%---LOSS:0.141---time:43.15
# Epoch:4---batch(19)训练集---ACC:100.00%---LOSS:0.081---time:42.86
# Epoch:4---batch(20)训练集---ACC:87.50%---LOSS:0.253---time:43.18
# Epoch:4---batch(21)训练集---ACC:93.75%---LOSS:0.144---time:43.02
# Epoch:4---batch(22)训练集---ACC:100.00%---LOSS:0.049---time:43.17
# Epoch:4---batch(23)训练集---ACC:96.88%---LOSS:0.176---time:42.94
# Epoch:4---batch(24)训练集---ACC:100.00%---LOSS:0.030---time:42.65
# Epoch:4---batch(25)训练集---ACC:93.75%---LOSS:0.221---time:43.04
# Epoch:4---batch(26)训练集---ACC:93.75%---LOSS:0.128---time:42.69
# Epoch:4---batch(27)训练集---ACC:93.75%---LOSS:0.238---time:42.84
# Epoch:4---batch(28)训练集---ACC:90.62%---LOSS:0.171---time:43.24
# Epoch:4---batch(29)训练集---ACC:96.88%---LOSS:0.130---time:43.10
# Epoch:4---batch(30)训练集---ACC:96.88%---LOSS:0.145---time:42.64
# Epoch:4---batch(31)训练集---ACC:96.88%---LOSS:0.115---time:43.66
# Epoch:4---batch(32)训练集---ACC:96.88%---LOSS:0.186---time:43.22
# Epoch:4---batch(33)训练集---ACC:100.00%---LOSS:0.086---time:43.37
# Epoch:4---batch(34)训练集---ACC:96.88%---LOSS:0.095---time:42.87
# Epoch:4---batch(35)训练集---ACC:81.25%---LOSS:0.582---time:42.89
# Epoch:4---batch(36)训练集---ACC:96.88%---LOSS:0.126---time:42.78
# Epoch:4---batch(37)训练集---ACC:93.75%---LOSS:0.135---time:21.43
# 第4轮测试集准确率：91.00%....测试集Loss:0.3305192398173468
# Epoch:5---batch(0)训练集---ACC:93.75%---LOSS:0.181---time:42.77
# Epoch:5---batch(1)训练集---ACC:100.00%---LOSS:0.089---time:43.21
# Epoch:5---batch(2)训练集---ACC:100.00%---LOSS:0.097---time:43.23
# Epoch:5---batch(3)训练集---ACC:90.62%---LOSS:0.205---time:43.19
# Epoch:5---batch(4)训练集---ACC:96.88%---LOSS:0.099---time:43.11
# Epoch:5---batch(5)训练集---ACC:96.88%---LOSS:0.118---time:43.11
# Epoch:5---batch(6)训练集---ACC:96.88%---LOSS:0.067---time:44.03
# Epoch:5---batch(7)训练集---ACC:96.88%---LOSS:0.124---time:43.70
# Epoch:5---batch(8)训练集---ACC:100.00%---LOSS:0.037---time:43.16
# Epoch:5---batch(9)训练集---ACC:96.88%---LOSS:0.091---time:43.29
# Epoch:5---batch(10)训练集---ACC:100.00%---LOSS:0.091---time:43.33
# Epoch:5---batch(11)训练集---ACC:100.00%---LOSS:0.054---time:42.98
# Epoch:5---batch(12)训练集---ACC:100.00%---LOSS:0.045---time:43.67
# Epoch:5---batch(13)训练集---ACC:93.75%---LOSS:0.177---time:42.93
# Epoch:5---batch(14)训练集---ACC:96.88%---LOSS:0.152---time:42.83
# Epoch:5---batch(15)训练集---ACC:90.62%---LOSS:0.202---time:43.03
# Epoch:5---batch(16)训练集---ACC:96.88%---LOSS:0.080---time:43.24
# Epoch:5---batch(17)训练集---ACC:93.75%---LOSS:0.176---time:42.94
# Epoch:5---batch(18)训练集---ACC:93.75%---LOSS:0.221---time:43.08
# Epoch:5---batch(19)训练集---ACC:96.88%---LOSS:0.120---time:43.12
# Epoch:5---batch(20)训练集---ACC:96.88%---LOSS:0.079---time:42.80
# Epoch:5---batch(21)训练集---ACC:100.00%---LOSS:0.149---time:43.16
# Epoch:5---batch(22)训练集---ACC:100.00%---LOSS:0.046---time:42.97
# Epoch:5---batch(23)训练集---ACC:96.88%---LOSS:0.110---time:43.06
# Epoch:5---batch(24)训练集---ACC:93.75%---LOSS:0.154---time:42.29
# Epoch:5---batch(25)训练集---ACC:93.75%---LOSS:0.148---time:42.81
# Epoch:5---batch(26)训练集---ACC:93.75%---LOSS:0.181---time:43.02
# Epoch:5---batch(27)训练集---ACC:100.00%---LOSS:0.023---time:42.67
# Epoch:5---batch(28)训练集---ACC:93.75%---LOSS:0.218---time:42.95
# Epoch:5---batch(29)训练集---ACC:93.75%---LOSS:0.195---time:42.69
# Epoch:5---batch(30)训练集---ACC:90.62%---LOSS:0.276---time:43.30
# Epoch:5---batch(31)训练集---ACC:96.88%---LOSS:0.245---time:42.86
# Epoch:5---batch(32)训练集---ACC:100.00%---LOSS:0.025---time:42.92
# Epoch:5---batch(33)训练集---ACC:90.62%---LOSS:0.173---time:43.25
# Epoch:5---batch(34)训练集---ACC:93.75%---LOSS:0.158---time:42.52
# Epoch:5---batch(35)训练集---ACC:96.88%---LOSS:0.073---time:43.05
# Epoch:5---batch(36)训练集---ACC:90.62%---LOSS:0.185---time:42.54
# Epoch:5---batch(37)训练集---ACC:93.75%---LOSS:0.148---time:21.84
# 第5轮测试集准确率：87.00%....测试集Loss:0.4323424313749586
# Epoch:6---batch(0)训练集---ACC:100.00%---LOSS:0.128---time:42.83
# Epoch:6---batch(1)训练集---ACC:96.88%---LOSS:0.066---time:42.82
# Epoch:6---batch(2)训练集---ACC:100.00%---LOSS:0.071---time:42.47
# Epoch:6---batch(3)训练集---ACC:93.75%---LOSS:0.234---time:42.78
# Epoch:6---batch(4)训练集---ACC:93.75%---LOSS:0.157---time:42.97
# Epoch:6---batch(5)训练集---ACC:100.00%---LOSS:0.101---time:42.66
# Epoch:6---batch(6)训练集---ACC:96.88%---LOSS:0.091---time:43.02
# Epoch:6---batch(7)训练集---ACC:93.75%---LOSS:0.233---time:42.62
# Epoch:6---batch(8)训练集---ACC:100.00%---LOSS:0.027---time:42.50
# Epoch:6---batch(9)训练集---ACC:96.88%---LOSS:0.131---time:42.87
# Epoch:6---batch(10)训练集---ACC:96.88%---LOSS:0.056---time:43.29
# Epoch:6---batch(11)训练集---ACC:96.88%---LOSS:0.095---time:43.23
# Epoch:6---batch(12)训练集---ACC:84.38%---LOSS:0.548---time:43.20
# Epoch:6---batch(13)训练集---ACC:96.88%---LOSS:0.108---time:42.95
# Epoch:6---batch(14)训练集---ACC:90.62%---LOSS:0.258---time:42.85
# Epoch:6---batch(15)训练集---ACC:90.62%---LOSS:0.140---time:43.01
# Epoch:6---batch(16)训练集---ACC:100.00%---LOSS:0.088---time:43.21
# Epoch:6---batch(17)训练集---ACC:100.00%---LOSS:0.045---time:43.40
# Epoch:6---batch(18)训练集---ACC:93.75%---LOSS:0.240---time:43.18
# Epoch:6---batch(19)训练集---ACC:93.75%---LOSS:0.268---time:43.05
# Epoch:6---batch(20)训练集---ACC:100.00%---LOSS:0.032---time:43.03
# Epoch:6---batch(21)训练集---ACC:100.00%---LOSS:0.041---time:42.64
# Epoch:6---batch(22)训练集---ACC:93.75%---LOSS:0.141---time:42.51
# Epoch:6---batch(23)训练集---ACC:100.00%---LOSS:0.133---time:43.20
# Epoch:6---batch(24)训练集---ACC:93.75%---LOSS:0.246---time:42.74
# Epoch:6---batch(25)训练集---ACC:93.75%---LOSS:0.236---time:43.15
# Epoch:6---batch(26)训练集---ACC:90.62%---LOSS:0.212---time:42.93
# Epoch:6---batch(27)训练集---ACC:96.88%---LOSS:0.069---time:42.62
# Epoch:6---batch(28)训练集---ACC:100.00%---LOSS:0.118---time:43.14
# Epoch:6---batch(29)训练集---ACC:90.62%---LOSS:0.191---time:43.01
# Epoch:6---batch(30)训练集---ACC:100.00%---LOSS:0.125---time:42.61
# Epoch:6---batch(31)训练集---ACC:96.88%---LOSS:0.091---time:43.47
# Epoch:6---batch(32)训练集---ACC:96.88%---LOSS:0.154---time:42.96
# Epoch:6---batch(33)训练集---ACC:87.50%---LOSS:0.361---time:42.73
# Epoch:6---batch(34)训练集---ACC:93.75%---LOSS:0.194---time:43.24
# Epoch:6---batch(35)训练集---ACC:96.88%---LOSS:0.229---time:43.49
# Epoch:6---batch(36)训练集---ACC:93.75%---LOSS:0.428---time:43.01
# Epoch:6---batch(37)训练集---ACC:81.25%---LOSS:0.474---time:21.35
# 第6轮测试集准确率：89.00%....测试集Loss:0.4872079651270594
# Epoch:7---batch(0)训练集---ACC:84.38%---LOSS:0.531---time:43.60
# Epoch:7---batch(1)训练集---ACC:96.88%---LOSS:0.051---time:42.91
# Epoch:7---batch(2)训练集---ACC:78.12%---LOSS:0.578---time:43.26
# Epoch:7---batch(3)训练集---ACC:93.75%---LOSS:0.178---time:42.72
# Epoch:7---batch(4)训练集---ACC:84.38%---LOSS:0.438---time:42.86
# Epoch:7---batch(5)训练集---ACC:96.88%---LOSS:0.055---time:42.46
# Epoch:7---batch(6)训练集---ACC:87.50%---LOSS:0.244---time:43.42
# Epoch:7---batch(7)训练集---ACC:90.62%---LOSS:0.245---time:44.46
# Epoch:7---batch(8)训练集---ACC:93.75%---LOSS:0.213---time:49.32
# Epoch:7---batch(9)训练集---ACC:96.88%---LOSS:0.074---time:45.38
# Epoch:7---batch(10)训练集---ACC:90.62%---LOSS:0.214---time:45.29
# Epoch:7---batch(11)训练集---ACC:87.50%---LOSS:0.224---time:76.54
# Epoch:7---batch(12)训练集---ACC:96.88%---LOSS:0.176---time:66.48
# Epoch:7---batch(13)训练集---ACC:87.50%---LOSS:0.220---time:54.61
# Epoch:7---batch(14)训练集---ACC:93.75%---LOSS:0.256---time:51.90
# Epoch:7---batch(15)训练集---ACC:100.00%---LOSS:0.059---time:58.58
# Epoch:7---batch(16)训练集---ACC:96.88%---LOSS:0.197---time:53.89
# Epoch:7---batch(17)训练集---ACC:96.88%---LOSS:0.137---time:44.13
# Epoch:7---batch(18)训练集---ACC:84.38%---LOSS:0.392---time:45.39
# Epoch:7---batch(19)训练集---ACC:93.75%---LOSS:0.126---time:45.13
# Epoch:7---batch(20)训练集---ACC:93.75%---LOSS:0.167---time:48.32
# Epoch:7---batch(21)训练集---ACC:96.88%---LOSS:0.114---time:46.00
# Epoch:7---batch(22)训练集---ACC:90.62%---LOSS:0.294---time:48.39
# Epoch:7---batch(23)训练集---ACC:93.75%---LOSS:0.173---time:40.59
# Epoch:7---batch(24)训练集---ACC:93.75%---LOSS:0.147---time:40.57
# Epoch:7---batch(25)训练集---ACC:90.62%---LOSS:0.137---time:57.15
# Epoch:7---batch(26)训练集---ACC:90.62%---LOSS:0.167---time:49.56
# Epoch:7---batch(27)训练集---ACC:93.75%---LOSS:0.173---time:51.44
# Epoch:7---batch(28)训练集---ACC:93.75%---LOSS:0.174---time:53.45
# Epoch:7---batch(29)训练集---ACC:93.75%---LOSS:0.174---time:47.39
# Epoch:7---batch(30)训练集---ACC:93.75%---LOSS:0.134---time:47.47
# Epoch:7---batch(31)训练集---ACC:93.75%---LOSS:0.126---time:48.37
# Epoch:7---batch(32)训练集---ACC:100.00%---LOSS:0.029---time:41.82
# Epoch:7---batch(33)训练集---ACC:100.00%---LOSS:0.080---time:44.50
# Epoch:7---batch(34)训练集---ACC:96.88%---LOSS:0.051---time:42.14
# Epoch:7---batch(35)训练集---ACC:100.00%---LOSS:0.063---time:41.78
# Epoch:7---batch(36)训练集---ACC:93.75%---LOSS:0.133---time:47.27
# Epoch:7---batch(37)训练集---ACC:87.50%---LOSS:0.316---time:23.42
# 第7轮测试集准确率：88.00%....测试集Loss:0.3677479422518185
# Epoch:8---batch(0)训练集---ACC:96.88%---LOSS:0.072---time:49.33
# Epoch:8---batch(1)训练集---ACC:96.88%---LOSS:0.089---time:47.44
# Epoch:8---batch(2)训练集---ACC:90.62%---LOSS:0.176---time:51.29
# Epoch:8---batch(3)训练集---ACC:93.75%---LOSS:0.137---time:45.11
# Epoch:8---batch(4)训练集---ACC:87.50%---LOSS:0.276---time:40.27
# Epoch:8---batch(5)训练集---ACC:84.38%---LOSS:0.213---time:39.62
# Epoch:8---batch(6)训练集---ACC:100.00%---LOSS:0.065---time:40.77
# Epoch:8---batch(7)训练集---ACC:96.88%---LOSS:0.043---time:39.94
# Epoch:8---batch(8)训练集---ACC:96.88%---LOSS:0.105---time:37.25
# Epoch:8---batch(9)训练集---ACC:93.75%---LOSS:0.206---time:42.14
# Epoch:8---batch(10)训练集---ACC:100.00%---LOSS:0.069---time:44.60
# Epoch:8---batch(11)训练集---ACC:96.88%---LOSS:0.079---time:40.45
# Epoch:8---batch(12)训练集---ACC:93.75%---LOSS:0.122---time:37.96
# Epoch:8---batch(13)训练集---ACC:96.88%---LOSS:0.158---time:39.28
# Epoch:8---batch(14)训练集---ACC:90.62%---LOSS:0.373---time:39.54
# Epoch:8---batch(15)训练集---ACC:96.88%---LOSS:0.119---time:42.74
# Epoch:8---batch(16)训练集---ACC:93.75%---LOSS:0.143---time:40.74
# Epoch:8---batch(17)训练集---ACC:96.88%---LOSS:0.195---time:42.35
# Epoch:8---batch(18)训练集---ACC:90.62%---LOSS:0.262---time:42.77
# Epoch:8---batch(19)训练集---ACC:96.88%---LOSS:0.062---time:40.91
# Epoch:8---batch(20)训练集---ACC:100.00%---LOSS:0.075---time:39.44
# Epoch:8---batch(21)训练集---ACC:90.62%---LOSS:0.190---time:35.67
# Epoch:8---batch(22)训练集---ACC:90.62%---LOSS:0.413---time:36.04
# Epoch:8---batch(23)训练集---ACC:100.00%---LOSS:0.046---time:42.20
# Epoch:8---batch(24)训练集---ACC:87.50%---LOSS:0.217---time:42.00
# Epoch:8---batch(25)训练集---ACC:90.62%---LOSS:0.169---time:38.77
# Epoch:8---batch(26)训练集---ACC:96.88%---LOSS:0.093---time:38.36
# Epoch:8---batch(27)训练集---ACC:93.75%---LOSS:0.141---time:41.92
# Epoch:8---batch(28)训练集---ACC:96.88%---LOSS:0.213---time:39.55
# Epoch:8---batch(29)训练集---ACC:100.00%---LOSS:0.039---time:43.84
# Epoch:8---batch(30)训练集---ACC:93.75%---LOSS:0.340---time:45.66
# Epoch:8---batch(31)训练集---ACC:96.88%---LOSS:0.158---time:48.03
# Epoch:8---batch(32)训练集---ACC:93.75%---LOSS:0.132---time:45.64
# Epoch:8---batch(33)训练集---ACC:96.88%---LOSS:0.192---time:44.77
# Epoch:8---batch(34)训练集---ACC:90.62%---LOSS:0.341---time:46.13
# Epoch:8---batch(35)训练集---ACC:96.88%---LOSS:0.114---time:44.46
# Epoch:8---batch(36)训练集---ACC:96.88%---LOSS:0.185---time:43.40
# Epoch:8---batch(37)训练集---ACC:100.00%---LOSS:0.094---time:23.96
# 第8轮测试集准确率：88.00%....测试集Loss:0.39416903257369995
# Epoch:9---batch(0)训练集---ACC:96.88%---LOSS:0.132---time:48.09
# Epoch:9---batch(1)训练集---ACC:100.00%---LOSS:0.039---time:42.80
# Epoch:9---batch(2)训练集---ACC:100.00%---LOSS:0.051---time:42.59
# Epoch:9---batch(3)训练集---ACC:100.00%---LOSS:0.062---time:46.00
# Epoch:9---batch(4)训练集---ACC:96.88%---LOSS:0.095---time:44.41
# Epoch:9---batch(5)训练集---ACC:93.75%---LOSS:0.238---time:58.82
# Epoch:9---batch(6)训练集---ACC:100.00%---LOSS:0.042---time:51.35
# Epoch:9---batch(7)训练集---ACC:100.00%---LOSS:0.056---time:38.95
# Epoch:9---batch(8)训练集---ACC:96.88%---LOSS:0.048---time:39.65
# Epoch:9---batch(9)训练集---ACC:90.62%---LOSS:0.325---time:39.94
# Epoch:9---batch(10)训练集---ACC:100.00%---LOSS:0.030---time:45.85
# Epoch:9---batch(11)训练集---ACC:100.00%---LOSS:0.069---time:41.68
# Epoch:9---batch(12)训练集---ACC:100.00%---LOSS:0.021---time:41.00
# Epoch:9---batch(13)训练集---ACC:90.62%---LOSS:0.262---time:42.51
# Epoch:9---batch(14)训练集---ACC:93.75%---LOSS:0.165---time:46.12
# Epoch:9---batch(15)训练集---ACC:100.00%---LOSS:0.022---time:50.69
# Epoch:9---batch(16)训练集---ACC:93.75%---LOSS:0.190---time:47.10
# Epoch:9---batch(17)训练集---ACC:96.88%---LOSS:0.095---time:52.87
# Epoch:9---batch(18)训练集---ACC:100.00%---LOSS:0.052---time:49.44
# Epoch:9---batch(19)训练集---ACC:100.00%---LOSS:0.053---time:47.76
# Epoch:9---batch(20)训练集---ACC:96.88%---LOSS:0.063---time:48.31
# Epoch:9---batch(21)训练集---ACC:90.62%---LOSS:0.228---time:48.50
# Epoch:9---batch(22)训练集---ACC:93.75%---LOSS:0.129---time:44.38
# Epoch:9---batch(23)训练集---ACC:96.88%---LOSS:0.072---time:69.28
# Epoch:9---batch(24)训练集---ACC:93.75%---LOSS:0.123---time:74.53
# Epoch:9---batch(25)训练集---ACC:100.00%---LOSS:0.030---time:52.35
# Epoch:9---batch(26)训练集---ACC:96.88%---LOSS:0.070---time:59.39
# Epoch:9---batch(27)训练集---ACC:100.00%---LOSS:0.085---time:55.17
# Epoch:9---batch(28)训练集---ACC:100.00%---LOSS:0.045---time:46.16
# Epoch:9---batch(29)训练集---ACC:96.88%---LOSS:0.058---time:50.68
# Epoch:9---batch(30)训练集---ACC:100.00%---LOSS:0.044---time:47.77
# Epoch:9---batch(31)训练集---ACC:93.75%---LOSS:0.195---time:56.46
# Epoch:9---batch(32)训练集---ACC:96.88%---LOSS:0.104---time:54.95
# Epoch:9---batch(33)训练集---ACC:93.75%---LOSS:0.062---time:52.84
# Epoch:9---batch(34)训练集---ACC:96.88%---LOSS:0.103---time:51.56
# Epoch:9---batch(35)训练集---ACC:100.00%---LOSS:0.042---time:50.75
# Epoch:9---batch(36)训练集---ACC:93.75%---LOSS:0.164---time:52.71
# Epoch:9---batch(37)训练集---ACC:87.50%---LOSS:0.282---time:25.70
# 第9轮测试集准确率：89.50%....测试集Loss:0.39228840065853937
# Epoch:10---batch(0)训练集---ACC:100.00%---LOSS:0.029---time:55.85
# Epoch:10---batch(1)训练集---ACC:100.00%---LOSS:0.057---time:57.91
# Epoch:10---batch(2)训练集---ACC:96.88%---LOSS:0.146---time:53.67
# Epoch:10---batch(3)训练集---ACC:93.75%---LOSS:0.131---time:60.50
# Epoch:10---batch(4)训练集---ACC:100.00%---LOSS:0.073---time:58.38
# Epoch:10---batch(5)训练集---ACC:96.88%---LOSS:0.057---time:56.52
# Epoch:10---batch(6)训练集---ACC:93.75%---LOSS:0.217---time:59.39
# Epoch:10---batch(7)训练集---ACC:100.00%---LOSS:0.032---time:54.88
# Epoch:10---batch(8)训练集---ACC:100.00%---LOSS:0.051---time:60.95
# Epoch:10---batch(9)训练集---ACC:100.00%---LOSS:0.062---time:50.21
# Epoch:10---batch(10)训练集---ACC:100.00%---LOSS:0.062---time:47.61
# Epoch:10---batch(11)训练集---ACC:96.88%---LOSS:0.057---time:46.42
# Epoch:10---batch(12)训练集---ACC:96.88%---LOSS:0.084---time:45.06
# Epoch:10---batch(13)训练集---ACC:96.88%---LOSS:0.129---time:44.78
# Epoch:10---batch(14)训练集---ACC:100.00%---LOSS:0.031---time:46.56
# Epoch:10---batch(15)训练集---ACC:96.88%---LOSS:0.051---time:49.84
# Epoch:10---batch(16)训练集---ACC:96.88%---LOSS:0.056---time:46.99
# Epoch:10---batch(17)训练集---ACC:100.00%---LOSS:0.037---time:47.45
# Epoch:10---batch(18)训练集---ACC:100.00%---LOSS:0.034---time:48.66
# Epoch:10---batch(19)训练集---ACC:100.00%---LOSS:0.052---time:51.25
# Epoch:10---batch(20)训练集---ACC:93.75%---LOSS:0.125---time:47.35
# Epoch:10---batch(21)训练集---ACC:100.00%---LOSS:0.036---time:48.90
# Epoch:10---batch(22)训练集---ACC:100.00%---LOSS:0.009---time:51.29
# Epoch:10---batch(23)训练集---ACC:96.88%---LOSS:0.160---time:54.08
# Epoch:10---batch(24)训练集---ACC:93.75%---LOSS:0.125---time:50.84
# Epoch:10---batch(25)训练集---ACC:96.88%---LOSS:0.098---time:55.06
# Epoch:10---batch(26)训练集---ACC:96.88%---LOSS:0.121---time:51.74
# Epoch:10---batch(27)训练集---ACC:100.00%---LOSS:0.006---time:62.38
# Epoch:10---batch(28)训练集---ACC:100.00%---LOSS:0.024---time:49.28
# Epoch:10---batch(29)训练集---ACC:96.88%---LOSS:0.145---time:50.57
# Epoch:10---batch(30)训练集---ACC:100.00%---LOSS:0.054---time:48.58
# Epoch:10---batch(31)训练集---ACC:100.00%---LOSS:0.053---time:52.61
# Epoch:10---batch(32)训练集---ACC:100.00%---LOSS:0.024---time:73.11
# Epoch:10---batch(33)训练集---ACC:96.88%---LOSS:0.125---time:50.91
# Epoch:10---batch(34)训练集---ACC:100.00%---LOSS:0.041---time:45.89
# Epoch:10---batch(35)训练集---ACC:100.00%---LOSS:0.016---time:45.08
# Epoch:10---batch(36)训练集---ACC:100.00%---LOSS:0.051---time:44.44
# Epoch:10---batch(37)训练集---ACC:100.00%---LOSS:0.036---time:22.34
# 第10轮测试集准确率：90.00%....测试集Loss:0.3944118938275746
# Epoch:11---batch(0)训练集---ACC:100.00%---LOSS:0.038---time:45.33
# Epoch:11---batch(1)训练集---ACC:96.88%---LOSS:0.123---time:49.68
# Epoch:11---batch(2)训练集---ACC:100.00%---LOSS:0.018---time:52.71
# Epoch:11---batch(3)训练集---ACC:100.00%---LOSS:0.021---time:46.68
# Epoch:11---batch(4)训练集---ACC:90.62%---LOSS:0.172---time:51.35
# Epoch:11---batch(5)训练集---ACC:96.88%---LOSS:0.058---time:54.32
# Epoch:11---batch(6)训练集---ACC:100.00%---LOSS:0.045---time:47.21
# Epoch:11---batch(7)训练集---ACC:100.00%---LOSS:0.022---time:42.11
# Epoch:11---batch(8)训练集---ACC:100.00%---LOSS:0.035---time:43.63
# Epoch:11---batch(9)训练集---ACC:90.62%---LOSS:0.166---time:41.96
# Epoch:11---batch(10)训练集---ACC:100.00%---LOSS:0.061---time:48.78
# Epoch:11---batch(11)训练集---ACC:100.00%---LOSS:0.035---time:48.24
# Epoch:11---batch(12)训练集---ACC:100.00%---LOSS:0.038---time:43.91
# Epoch:11---batch(13)训练集---ACC:100.00%---LOSS:0.056---time:49.56
# Epoch:11---batch(14)训练集---ACC:96.88%---LOSS:0.089---time:61.95
# Epoch:11---batch(15)训练集---ACC:96.88%---LOSS:0.126---time:58.79
# Epoch:11---batch(16)训练集---ACC:100.00%---LOSS:0.041---time:51.71
# Epoch:11---batch(17)训练集---ACC:100.00%---LOSS:0.018---time:44.73
# Epoch:11---batch(18)训练集---ACC:100.00%---LOSS:0.026---time:47.00
# Epoch:11---batch(19)训练集---ACC:100.00%---LOSS:0.023---time:45.89
# Epoch:11---batch(20)训练集---ACC:96.88%---LOSS:0.057---time:50.44
# Epoch:11---batch(21)训练集---ACC:100.00%---LOSS:0.038---time:45.27
# Epoch:11---batch(22)训练集---ACC:93.75%---LOSS:0.123---time:39.79
# Epoch:11---batch(23)训练集---ACC:93.75%---LOSS:0.112---time:37.79
# Epoch:11---batch(24)训练集---ACC:96.88%---LOSS:0.123---time:38.86
# Epoch:11---batch(25)训练集---ACC:100.00%---LOSS:0.017---time:42.70
# Epoch:11---batch(26)训练集---ACC:100.00%---LOSS:0.019---time:49.73
# Epoch:11---batch(27)训练集---ACC:100.00%---LOSS:0.031---time:58.92
# Epoch:11---batch(28)训练集---ACC:100.00%---LOSS:0.028---time:91.90
# Epoch:11---batch(29)训练集---ACC:100.00%---LOSS:0.025---time:78.84
# Epoch:11---batch(30)训练集---ACC:96.88%---LOSS:0.071---time:66.33
# Epoch:11---batch(31)训练集---ACC:100.00%---LOSS:0.055---time:95.16
# Epoch:11---batch(32)训练集---ACC:100.00%---LOSS:0.008---time:62.18
# Epoch:11---batch(33)训练集---ACC:96.88%---LOSS:0.077---time:51.69
# Epoch:11---batch(34)训练集---ACC:96.88%---LOSS:0.077---time:54.52
# Epoch:11---batch(35)训练集---ACC:96.88%---LOSS:0.064---time:44.83
# Epoch:11---batch(36)训练集---ACC:100.00%---LOSS:0.011---time:47.84
# Epoch:11---batch(37)训练集---ACC:100.00%---LOSS:0.027---time:23.20
# 第11轮测试集准确率：88.00%....测试集Loss:0.6209215841123036
# Epoch:12---batch(0)训练集---ACC:96.88%---LOSS:0.075---time:42.55
# Epoch:12---batch(1)训练集---ACC:84.38%---LOSS:0.392---time:41.73
# Epoch:12---batch(2)训练集---ACC:100.00%---LOSS:0.052---time:40.98
# Epoch:12---batch(3)训练集---ACC:100.00%---LOSS:0.021---time:38.43
# Epoch:12---batch(4)训练集---ACC:93.75%---LOSS:0.078---time:38.36
# Epoch:12---batch(5)训练集---ACC:96.88%---LOSS:0.087---time:38.41
# Epoch:12---batch(6)训练集---ACC:96.88%---LOSS:0.081---time:39.62
# Epoch:12---batch(7)训练集---ACC:96.88%---LOSS:0.157---time:39.10
# Epoch:12---batch(8)训练集---ACC:100.00%---LOSS:0.017---time:38.81
# Epoch:12---batch(9)训练集---ACC:93.75%---LOSS:0.147---time:38.35
# Epoch:12---batch(10)训练集---ACC:96.88%---LOSS:0.209---time:38.50
# Epoch:12---batch(11)训练集---ACC:100.00%---LOSS:0.019---time:38.48
# Epoch:12---batch(12)训练集---ACC:96.88%---LOSS:0.100---time:38.41
# Epoch:12---batch(13)训练集---ACC:96.88%---LOSS:0.055---time:39.07
# Epoch:12---batch(14)训练集---ACC:96.88%---LOSS:0.047---time:38.21
# Epoch:12---batch(15)训练集---ACC:100.00%---LOSS:0.019---time:38.37
# Epoch:12---batch(16)训练集---ACC:100.00%---LOSS:0.014---time:38.45
# Epoch:12---batch(17)训练集---ACC:100.00%---LOSS:0.088---time:38.22
# Epoch:12---batch(18)训练集---ACC:100.00%---LOSS:0.034---time:38.48
# Epoch:12---batch(19)训练集---ACC:93.75%---LOSS:0.156---time:38.46
# Epoch:12---batch(20)训练集---ACC:100.00%---LOSS:0.021---time:38.37
# Epoch:12---batch(21)训练集---ACC:96.88%---LOSS:0.059---time:38.22
# Epoch:12---batch(22)训练集---ACC:100.00%---LOSS:0.027---time:38.39
# Epoch:12---batch(23)训练集---ACC:100.00%---LOSS:0.021---time:38.95
# Epoch:12---batch(24)训练集---ACC:96.88%---LOSS:0.044---time:38.45
# Epoch:12---batch(25)训练集---ACC:96.88%---LOSS:0.179---time:38.40
# Epoch:12---batch(26)训练集---ACC:93.75%---LOSS:0.076---time:38.34
# Epoch:12---batch(27)训练集---ACC:100.00%---LOSS:0.028---time:38.38
# Epoch:12---batch(28)训练集---ACC:100.00%---LOSS:0.015---time:38.12
# Epoch:12---batch(29)训练集---ACC:100.00%---LOSS:0.038---time:38.52
# Epoch:12---batch(30)训练集---ACC:100.00%---LOSS:0.022---time:38.14
# Epoch:12---batch(31)训练集---ACC:93.75%---LOSS:0.133---time:38.22
# Epoch:12---batch(32)训练集---ACC:96.88%---LOSS:0.094---time:38.46
# Epoch:12---batch(33)训练集---ACC:100.00%---LOSS:0.014---time:38.51
# Epoch:12---batch(34)训练集---ACC:96.88%---LOSS:0.191---time:38.27
# Epoch:12---batch(35)训练集---ACC:100.00%---LOSS:0.024---time:38.27
# Epoch:12---batch(36)训练集---ACC:96.88%---LOSS:0.064---time:38.33
# Epoch:12---batch(37)训练集---ACC:100.00%---LOSS:0.052---time:19.21
# 第12轮测试集准确率：88.00%....测试集Loss:0.543889794498682
# Epoch:13---batch(0)训练集---ACC:96.88%---LOSS:0.063---time:38.28
# Epoch:13---batch(1)训练集---ACC:100.00%---LOSS:0.049---time:38.27
# Epoch:13---batch(2)训练集---ACC:96.88%---LOSS:0.085---time:38.50
# Epoch:13---batch(3)训练集---ACC:100.00%---LOSS:0.021---time:38.05
# Epoch:13---batch(4)训练集---ACC:96.88%---LOSS:0.047---time:38.08
# Epoch:13---batch(5)训练集---ACC:100.00%---LOSS:0.012---time:37.82
# Epoch:13---batch(6)训练集---ACC:100.00%---LOSS:0.017---time:38.17
# Epoch:13---batch(7)训练集---ACC:96.88%---LOSS:0.147---time:38.28
# Epoch:13---batch(8)训练集---ACC:100.00%---LOSS:0.054---time:38.20
# Epoch:13---batch(9)训练集---ACC:100.00%---LOSS:0.035---time:38.22
# Epoch:13---batch(10)训练集---ACC:96.88%---LOSS:0.070---time:37.99
# Epoch:13---batch(11)训练集---ACC:100.00%---LOSS:0.014---time:37.92
# Epoch:13---batch(12)训练集---ACC:96.88%---LOSS:0.070---time:38.08
# Epoch:13---batch(13)训练集---ACC:100.00%---LOSS:0.030---time:37.95
# Epoch:13---batch(14)训练集---ACC:96.88%---LOSS:0.046---time:38.12
# Epoch:13---batch(15)训练集---ACC:96.88%---LOSS:0.067---time:38.14
# Epoch:13---batch(16)训练集---ACC:96.88%---LOSS:0.050---time:38.32
# Epoch:13---batch(17)训练集---ACC:100.00%---LOSS:0.045---time:38.14
# Epoch:13---batch(18)训练集---ACC:100.00%---LOSS:0.048---time:38.26
# Epoch:13---batch(19)训练集---ACC:93.75%---LOSS:0.123---time:38.00
# Epoch:13---batch(20)训练集---ACC:100.00%---LOSS:0.043---time:38.36
# Epoch:13---batch(21)训练集---ACC:100.00%---LOSS:0.054---time:38.13
# Epoch:13---batch(22)训练集---ACC:100.00%---LOSS:0.012---time:38.74
# Epoch:13---batch(23)训练集---ACC:96.88%---LOSS:0.058---time:38.11
# Epoch:13---batch(24)训练集---ACC:100.00%---LOSS:0.011---time:38.82
# Epoch:13---batch(25)训练集---ACC:100.00%---LOSS:0.020---time:42.25
# Epoch:13---batch(26)训练集---ACC:96.88%---LOSS:0.078---time:47.69
# Epoch:13---batch(27)训练集---ACC:100.00%---LOSS:0.117---time:46.03
# Epoch:13---batch(28)训练集---ACC:96.88%---LOSS:0.060---time:60.57
# Epoch:13---batch(29)训练集---ACC:100.00%---LOSS:0.013---time:80.97
# Epoch:13---batch(30)训练集---ACC:100.00%---LOSS:0.023---time:72.29
# Epoch:13---batch(31)训练集---ACC:100.00%---LOSS:0.049---time:60.66
# Epoch:13---batch(32)训练集---ACC:100.00%---LOSS:0.040---time:58.63
# Epoch:13---batch(33)训练集---ACC:96.88%---LOSS:0.174---time:53.92
# Epoch:13---batch(34)训练集---ACC:100.00%---LOSS:0.023---time:45.54
# Epoch:13---batch(35)训练集---ACC:100.00%---LOSS:0.045---time:54.39
# Epoch:13---batch(36)训练集---ACC:100.00%---LOSS:0.012---time:57.58
# Epoch:13---batch(37)训练集---ACC:100.00%---LOSS:0.005---time:26.38
# 第13轮测试集准确率：88.00%....测试集Loss:0.4580967937197004
# Epoch:14---batch(0)训练集---ACC:100.00%---LOSS:0.039---time:37.90
# Epoch:14---batch(1)训练集---ACC:96.88%---LOSS:0.051---time:37.87
# Epoch:14---batch(2)训练集---ACC:100.00%---LOSS:0.020---time:41.53
# Epoch:14---batch(3)训练集---ACC:96.88%---LOSS:0.038---time:40.76
# Epoch:14---batch(4)训练集---ACC:96.88%---LOSS:0.109---time:39.38
# Epoch:14---batch(5)训练集---ACC:96.88%---LOSS:0.047---time:37.35
# Epoch:14---batch(6)训练集---ACC:96.88%---LOSS:0.073---time:39.83
# Epoch:14---batch(7)训练集---ACC:100.00%---LOSS:0.071---time:37.79
# Epoch:14---batch(8)训练集---ACC:100.00%---LOSS:0.003---time:39.94
# Epoch:14---batch(9)训练集---ACC:100.00%---LOSS:0.043---time:39.81
# Epoch:14---batch(10)训练集---ACC:96.88%---LOSS:0.100---time:44.09
# Epoch:14---batch(11)训练集---ACC:100.00%---LOSS:0.008---time:49.23
# Epoch:14---batch(12)训练集---ACC:100.00%---LOSS:0.011---time:50.81
# Epoch:14---batch(13)训练集---ACC:100.00%---LOSS:0.035---time:50.86
# Epoch:14---batch(14)训练集---ACC:96.88%---LOSS:0.064---time:49.67
# Epoch:14---batch(15)训练集---ACC:100.00%---LOSS:0.039---time:52.60
# Epoch:14---batch(16)训练集---ACC:100.00%---LOSS:0.003---time:46.43
# Epoch:14---batch(17)训练集---ACC:96.88%---LOSS:0.089---time:45.86
# Epoch:14---batch(18)训练集---ACC:100.00%---LOSS:0.020---time:47.15
# Epoch:14---batch(19)训练集---ACC:100.00%---LOSS:0.027---time:47.15
# Epoch:14---batch(20)训练集---ACC:100.00%---LOSS:0.017---time:46.37
# Epoch:14---batch(21)训练集---ACC:100.00%---LOSS:0.014---time:47.10
# Epoch:14---batch(22)训练集---ACC:96.88%---LOSS:0.036---time:47.72
# Epoch:14---batch(23)训练集---ACC:93.75%---LOSS:0.147---time:45.99
# Epoch:14---batch(24)训练集---ACC:100.00%---LOSS:0.009---time:47.23
# Epoch:14---batch(25)训练集---ACC:96.88%---LOSS:0.059---time:46.85
# Epoch:14---batch(26)训练集---ACC:93.75%---LOSS:0.223---time:46.12
# Epoch:14---batch(27)训练集---ACC:100.00%---LOSS:0.011---time:47.94
# Epoch:14---batch(28)训练集---ACC:100.00%---LOSS:0.009---time:46.67
# Epoch:14---batch(29)训练集---ACC:100.00%---LOSS:0.014---time:46.29
# Epoch:14---batch(30)训练集---ACC:100.00%---LOSS:0.031---time:46.71
# Epoch:14---batch(31)训练集---ACC:96.88%---LOSS:0.075---time:48.30
# Epoch:14---batch(32)训练集---ACC:100.00%---LOSS:0.020---time:47.27
# Epoch:14---batch(33)训练集---ACC:100.00%---LOSS:0.006---time:49.14
# Epoch:14---batch(34)训练集---ACC:100.00%---LOSS:0.006---time:54.33
# Epoch:14---batch(35)训练集---ACC:93.75%---LOSS:0.084---time:51.10
# Epoch:14---batch(36)训练集---ACC:96.88%---LOSS:0.075---time:50.28
# Epoch:14---batch(37)训练集---ACC:93.75%---LOSS:0.101---time:24.45
# 第14轮测试集准确率：87.50%....测试集Loss:0.544136751975332
# Epoch:15---batch(0)训练集---ACC:96.88%---LOSS:0.065---time:46.71
# Epoch:15---batch(1)训练集---ACC:96.88%---LOSS:0.068---time:46.49
# Epoch:15---batch(2)训练集---ACC:100.00%---LOSS:0.009---time:47.30
# Epoch:15---batch(3)训练集---ACC:100.00%---LOSS:0.012---time:46.68
# Epoch:15---batch(4)训练集---ACC:100.00%---LOSS:0.015---time:46.98
# Epoch:15---batch(5)训练集---ACC:93.75%---LOSS:0.124---time:47.66
# Epoch:15---batch(6)训练集---ACC:93.75%---LOSS:0.135---time:48.15
# Epoch:15---batch(7)训练集---ACC:90.62%---LOSS:0.174---time:48.64
# Epoch:15---batch(8)训练集---ACC:100.00%---LOSS:0.021---time:53.54
# Epoch:15---batch(9)训练集---ACC:100.00%---LOSS:0.014---time:52.22
# Epoch:15---batch(10)训练集---ACC:96.88%---LOSS:0.095---time:57.37
# Epoch:15---batch(11)训练集---ACC:96.88%---LOSS:0.047---time:52.98
# Epoch:15---batch(12)训练集---ACC:100.00%---LOSS:0.043---time:51.02
# Epoch:15---batch(13)训练集---ACC:96.88%---LOSS:0.058---time:54.28
# Epoch:15---batch(14)训练集---ACC:96.88%---LOSS:0.081---time:53.83
# Epoch:15---batch(15)训练集---ACC:96.88%---LOSS:0.092---time:57.00
# Epoch:15---batch(16)训练集---ACC:96.88%---LOSS:0.095---time:51.75
# Epoch:15---batch(17)训练集---ACC:100.00%---LOSS:0.020---time:47.64
# Epoch:15---batch(18)训练集---ACC:100.00%---LOSS:0.032---time:47.39
# Epoch:15---batch(19)训练集---ACC:90.62%---LOSS:0.518---time:48.74
# Epoch:15---batch(20)训练集---ACC:93.75%---LOSS:0.227---time:48.02
# Epoch:15---batch(21)训练集---ACC:93.75%---LOSS:0.165---time:51.37
# Epoch:15---batch(22)训练集---ACC:96.88%---LOSS:0.067---time:49.87
# Epoch:15---batch(23)训练集---ACC:93.75%---LOSS:0.207---time:48.57
# Epoch:15---batch(24)训练集---ACC:100.00%---LOSS:0.023---time:46.67
# Epoch:15---batch(25)训练集---ACC:84.38%---LOSS:0.231---time:47.50
# Epoch:15---batch(26)训练集---ACC:100.00%---LOSS:0.053---time:47.40
# Epoch:15---batch(27)训练集---ACC:96.88%---LOSS:0.124---time:46.52
# Epoch:15---batch(28)训练集---ACC:96.88%---LOSS:0.086---time:46.03
# Epoch:15---batch(29)训练集---ACC:100.00%---LOSS:0.004---time:47.45
# Epoch:15---batch(30)训练集---ACC:96.88%---LOSS:0.171---time:46.33
# Epoch:15---batch(31)训练集---ACC:100.00%---LOSS:0.021---time:46.07
# Epoch:15---batch(32)训练集---ACC:96.88%---LOSS:0.049---time:45.46
# Epoch:15---batch(33)训练集---ACC:100.00%---LOSS:0.006---time:46.08
# Epoch:15---batch(34)训练集---ACC:93.75%---LOSS:0.128---time:48.41
# Epoch:15---batch(35)训练集---ACC:96.88%---LOSS:0.112---time:48.44
# Epoch:15---batch(36)训练集---ACC:93.75%---LOSS:0.100---time:49.47
# Epoch:15---batch(37)训练集---ACC:93.75%---LOSS:0.073---time:23.67
# 第15轮测试集准确率：87.00%....测试集Loss:0.5584624750273568
# Epoch:16---batch(0)训练集---ACC:100.00%---LOSS:0.075---time:50.23
# Epoch:16---batch(1)训练集---ACC:100.00%---LOSS:0.020---time:47.65
# Epoch:16---batch(2)训练集---ACC:96.88%---LOSS:0.104---time:48.38
# Epoch:16---batch(3)训练集---ACC:100.00%---LOSS:0.041---time:47.43
# Epoch:16---batch(4)训练集---ACC:96.88%---LOSS:0.137---time:48.78
# Epoch:16---batch(5)训练集---ACC:96.88%---LOSS:0.036---time:52.28
# Epoch:16---batch(6)训练集---ACC:93.75%---LOSS:0.204---time:49.10
# Epoch:16---batch(7)训练集---ACC:100.00%---LOSS:0.037---time:51.26
# Epoch:16---batch(8)训练集---ACC:100.00%---LOSS:0.036---time:49.70
# Epoch:16---batch(9)训练集---ACC:100.00%---LOSS:0.024---time:52.67
# Epoch:16---batch(10)训练集---ACC:100.00%---LOSS:0.014---time:50.79
# Epoch:16---batch(11)训练集---ACC:96.88%---LOSS:0.121---time:48.85
# Epoch:16---batch(12)训练集---ACC:87.50%---LOSS:0.457---time:51.79
# Epoch:16---batch(13)训练集---ACC:93.75%---LOSS:0.093---time:50.25
# Epoch:16---batch(14)训练集---ACC:100.00%---LOSS:0.015---time:48.90
# Epoch:16---batch(15)训练集---ACC:100.00%---LOSS:0.001---time:47.67
# Epoch:16---batch(16)训练集---ACC:96.88%---LOSS:0.109---time:48.61
# Epoch:16---batch(17)训练集---ACC:100.00%---LOSS:0.033---time:47.67
# Epoch:16---batch(18)训练集---ACC:93.75%---LOSS:0.269---time:47.90
# Epoch:16---batch(19)训练集---ACC:96.88%---LOSS:0.100---time:49.92
# Epoch:16---batch(20)训练集---ACC:96.88%---LOSS:0.091---time:47.98
# Epoch:16---batch(21)训练集---ACC:100.00%---LOSS:0.018---time:47.87
# Epoch:16---batch(22)训练集---ACC:96.88%---LOSS:0.075---time:47.32
# Epoch:16---batch(23)训练集---ACC:90.62%---LOSS:0.225---time:46.79
# Epoch:16---batch(24)训练集---ACC:100.00%---LOSS:0.035---time:47.38
# Epoch:16---batch(25)训练集---ACC:96.88%---LOSS:0.124---time:48.64
# Epoch:16---batch(26)训练集---ACC:96.88%---LOSS:0.061---time:48.68
# Epoch:16---batch(27)训练集---ACC:96.88%---LOSS:0.080---time:45.53
# Epoch:16---batch(28)训练集---ACC:93.75%---LOSS:0.104---time:44.98
# Epoch:16---batch(29)训练集---ACC:100.00%---LOSS:0.010---time:44.84
# Epoch:16---batch(30)训练集---ACC:93.75%---LOSS:0.145---time:44.84
# Epoch:16---batch(31)训练集---ACC:96.88%---LOSS:0.147---time:44.74
# Epoch:16---batch(32)训练集---ACC:96.88%---LOSS:0.077---time:44.75
# Epoch:16---batch(33)训练集---ACC:93.75%---LOSS:0.172---time:44.72
# Epoch:16---batch(34)训练集---ACC:96.88%---LOSS:0.055---time:44.95
# Epoch:16---batch(35)训练集---ACC:100.00%---LOSS:0.025---time:44.85
# Epoch:16---batch(36)训练集---ACC:100.00%---LOSS:0.040---time:44.76
# Epoch:16---batch(37)训练集---ACC:93.75%---LOSS:0.326---time:24.05
# 第16轮测试集准确率：89.50%....测试集Loss:0.4682920639004026
# Epoch:17---batch(0)训练集---ACC:96.88%---LOSS:0.103---time:45.26
# Epoch:17---batch(1)训练集---ACC:96.88%---LOSS:0.036---time:45.51
# Epoch:17---batch(2)训练集---ACC:90.62%---LOSS:0.201---time:53.27
# Epoch:17---batch(3)训练集---ACC:93.75%---LOSS:0.129---time:51.51
# Epoch:17---batch(4)训练集---ACC:100.00%---LOSS:0.020---time:58.48
# Epoch:17---batch(5)训练集---ACC:96.88%---LOSS:0.054---time:56.22
# Epoch:17---batch(6)训练集---ACC:90.62%---LOSS:0.128---time:54.97
# Epoch:17---batch(7)训练集---ACC:90.62%---LOSS:0.146---time:55.66
# Epoch:17---batch(8)训练集---ACC:96.88%---LOSS:0.058---time:58.15
# Epoch:17---batch(9)训练集---ACC:93.75%---LOSS:0.135---time:53.80
# Epoch:17---batch(10)训练集---ACC:96.88%---LOSS:0.057---time:53.90
# Epoch:17---batch(11)训练集---ACC:96.88%---LOSS:0.086---time:54.64
# Epoch:17---batch(12)训练集---ACC:100.00%---LOSS:0.056---time:60.33
# Epoch:17---batch(13)训练集---ACC:90.62%---LOSS:0.180---time:82.09
# Epoch:17---batch(14)训练集---ACC:93.75%---LOSS:0.151---time:59.88
# Epoch:17---batch(15)训练集---ACC:100.00%---LOSS:0.049---time:72.90
# Epoch:17---batch(16)训练集---ACC:100.00%---LOSS:0.032---time:66.92
# Epoch:17---batch(17)训练集---ACC:90.62%---LOSS:0.186---time:78.75
# Epoch:17---batch(18)训练集---ACC:100.00%---LOSS:0.003---time:64.40
# Epoch:17---batch(19)训练集---ACC:100.00%---LOSS:0.008---time:53.58
# Epoch:17---batch(20)训练集---ACC:96.88%---LOSS:0.105---time:56.98
# Epoch:17---batch(21)训练集---ACC:96.88%---LOSS:0.107---time:52.41
# Epoch:17---batch(22)训练集---ACC:100.00%---LOSS:0.053---time:66.03
# Epoch:17---batch(23)训练集---ACC:100.00%---LOSS:0.033---time:64.91
# Epoch:17---batch(24)训练集---ACC:100.00%---LOSS:0.053---time:85.42
# Epoch:17---batch(25)训练集---ACC:100.00%---LOSS:0.038---time:70.28
# Epoch:17---batch(26)训练集---ACC:100.00%---LOSS:0.007---time:78.55
# Epoch:17---batch(27)训练集---ACC:100.00%---LOSS:0.085---time:52.97
# Epoch:17---batch(28)训练集---ACC:100.00%---LOSS:0.042---time:48.15
# Epoch:17---batch(29)训练集---ACC:93.75%---LOSS:0.237---time:50.51
# Epoch:17---batch(30)训练集---ACC:96.88%---LOSS:0.040---time:49.75
# Epoch:17---batch(31)训练集---ACC:100.00%---LOSS:0.056---time:50.74
# Epoch:17---batch(32)训练集---ACC:96.88%---LOSS:0.035---time:51.89
# Epoch:17---batch(33)训练集---ACC:93.75%---LOSS:0.166---time:48.71
# Epoch:17---batch(34)训练集---ACC:100.00%---LOSS:0.030---time:49.64
# Epoch:17---batch(35)训练集---ACC:100.00%---LOSS:0.010---time:48.12
# Epoch:17---batch(36)训练集---ACC:100.00%---LOSS:0.029---time:54.60
# Epoch:17---batch(37)训练集---ACC:93.75%---LOSS:0.122---time:22.87
# 第17轮测试集准确率：89.00%....测试集Loss:0.5610383259398597
# Epoch:18---batch(0)训练集---ACC:100.00%---LOSS:0.012---time:48.71
# Epoch:18---batch(1)训练集---ACC:100.00%---LOSS:0.020---time:45.19
# Epoch:18---batch(2)训练集---ACC:100.00%---LOSS:0.009---time:46.09
# Epoch:18---batch(3)训练集---ACC:96.88%---LOSS:0.056---time:47.17
# Epoch:18---batch(4)训练集---ACC:100.00%---LOSS:0.011---time:37.54
# Epoch:18---batch(5)训练集---ACC:96.88%---LOSS:0.042---time:41.69
# Epoch:18---batch(6)训练集---ACC:90.62%---LOSS:0.173---time:49.45
# Epoch:18---batch(7)训练集---ACC:100.00%---LOSS:0.018---time:49.43
# Epoch:18---batch(8)训练集---ACC:100.00%---LOSS:0.023---time:58.75
# Epoch:18---batch(9)训练集---ACC:96.88%---LOSS:0.052---time:61.68
# Epoch:18---batch(10)训练集---ACC:100.00%---LOSS:0.032---time:46.42
# Epoch:18---batch(11)训练集---ACC:100.00%---LOSS:0.044---time:49.40
# Epoch:18---batch(12)训练集---ACC:100.00%---LOSS:0.043---time:48.86
# Epoch:18---batch(13)训练集---ACC:96.88%---LOSS:0.074---time:52.41
# Epoch:18---batch(14)训练集---ACC:100.00%---LOSS:0.015---time:52.13
# Epoch:18---batch(15)训练集---ACC:93.75%---LOSS:0.076---time:46.55
# Epoch:18---batch(16)训练集---ACC:100.00%---LOSS:0.015---time:44.64
# Epoch:18---batch(17)训练集---ACC:100.00%---LOSS:0.010---time:44.82
# Epoch:18---batch(18)训练集---ACC:96.88%---LOSS:0.125---time:44.66
# Epoch:18---batch(19)训练集---ACC:100.00%---LOSS:0.016---time:44.66
# Epoch:18---batch(20)训练集---ACC:100.00%---LOSS:0.011---time:44.84
# Epoch:18---batch(21)训练集---ACC:100.00%---LOSS:0.062---time:44.67
# Epoch:18---batch(22)训练集---ACC:96.88%---LOSS:0.060---time:44.51
# Epoch:18---batch(23)训练集---ACC:100.00%---LOSS:0.056---time:44.58
# Epoch:18---batch(24)训练集---ACC:100.00%---LOSS:0.011---time:44.61
# Epoch:18---batch(25)训练集---ACC:96.88%---LOSS:0.072---time:44.80
# Epoch:18---batch(26)训练集---ACC:96.88%---LOSS:0.064---time:44.47
# Epoch:18---batch(27)训练集---ACC:100.00%---LOSS:0.015---time:44.86
# Epoch:18---batch(28)训练集---ACC:100.00%---LOSS:0.051---time:44.82
# Epoch:18---batch(29)训练集---ACC:100.00%---LOSS:0.024---time:44.91
# Epoch:18---batch(30)训练集---ACC:96.88%---LOSS:0.081---time:44.70
# Epoch:18---batch(31)训练集---ACC:96.88%---LOSS:0.045---time:44.73
# Epoch:18---batch(32)训练集---ACC:100.00%---LOSS:0.027---time:45.22
# Epoch:18---batch(33)训练集---ACC:96.88%---LOSS:0.085---time:45.19
# Epoch:18---batch(34)训练集---ACC:100.00%---LOSS:0.023---time:45.52
# Epoch:18---batch(35)训练集---ACC:93.75%---LOSS:0.104---time:44.91
# Epoch:18---batch(36)训练集---ACC:93.75%---LOSS:0.113---time:44.94
# Epoch:18---batch(37)训练集---ACC:100.00%---LOSS:0.049---time:22.55
# 第18轮测试集准确率：90.00%....测试集Loss:0.5469782991068703
# Epoch:19---batch(0)训练集---ACC:100.00%---LOSS:0.017---time:45.10
# Epoch:19---batch(1)训练集---ACC:93.75%---LOSS:0.110---time:44.81
# Epoch:19---batch(2)训练集---ACC:93.75%---LOSS:0.118---time:45.09
# Epoch:19---batch(3)训练集---ACC:100.00%---LOSS:0.039---time:45.25
# Epoch:19---batch(4)训练集---ACC:96.88%---LOSS:0.078---time:47.10
# Epoch:19---batch(5)训练集---ACC:100.00%---LOSS:0.016---time:44.90
# Epoch:19---batch(6)训练集---ACC:93.75%---LOSS:0.114---time:45.15
# Epoch:19---batch(7)训练集---ACC:96.88%---LOSS:0.072---time:45.41
# Epoch:19---batch(8)训练集---ACC:100.00%---LOSS:0.013---time:44.52
# Epoch:19---batch(9)训练集---ACC:100.00%---LOSS:0.028---time:42.75
# Epoch:19---batch(10)训练集---ACC:100.00%---LOSS:0.023---time:42.58
# Epoch:19---batch(11)训练集---ACC:96.88%---LOSS:0.062---time:42.66
# Epoch:19---batch(12)训练集---ACC:100.00%---LOSS:0.035---time:42.37
# Epoch:19---batch(13)训练集---ACC:100.00%---LOSS:0.011---time:42.40
# Epoch:19---batch(14)训练集---ACC:100.00%---LOSS:0.025---time:42.85
# Epoch:19---batch(15)训练集---ACC:96.88%---LOSS:0.052---time:42.53
# Epoch:19---batch(16)训练集---ACC:100.00%---LOSS:0.020---time:42.52
# Epoch:19---batch(17)训练集---ACC:100.00%---LOSS:0.020---time:43.15
# Epoch:19---batch(18)训练集---ACC:100.00%---LOSS:0.024---time:42.79
# Epoch:19---batch(19)训练集---ACC:100.00%---LOSS:0.008---time:42.92
# Epoch:19---batch(20)训练集---ACC:100.00%---LOSS:0.011---time:43.15
# Epoch:19---batch(21)训练集---ACC:100.00%---LOSS:0.010---time:43.05
# Epoch:19---batch(22)训练集---ACC:96.88%---LOSS:0.108---time:42.37
# Epoch:19---batch(23)训练集---ACC:100.00%---LOSS:0.013---time:42.58
# Epoch:19---batch(24)训练集---ACC:100.00%---LOSS:0.004---time:42.67
# Epoch:19---batch(25)训练集---ACC:100.00%---LOSS:0.017---time:43.32
# Epoch:19---batch(26)训练集---ACC:96.88%---LOSS:0.041---time:42.24
# Epoch:19---batch(27)训练集---ACC:100.00%---LOSS:0.009---time:42.96
# Epoch:19---batch(28)训练集---ACC:96.88%---LOSS:0.062---time:42.24
# Epoch:19---batch(29)训练集---ACC:100.00%---LOSS:0.042---time:42.75
# Epoch:19---batch(30)训练集---ACC:96.88%---LOSS:0.106---time:42.67
# Epoch:19---batch(31)训练集---ACC:100.00%---LOSS:0.030---time:42.70
# Epoch:19---batch(32)训练集---ACC:100.00%---LOSS:0.022---time:42.72
# Epoch:19---batch(33)训练集---ACC:100.00%---LOSS:0.036---time:42.60
# Epoch:19---batch(34)训练集---ACC:100.00%---LOSS:0.012---time:42.73
# Epoch:19---batch(35)训练集---ACC:96.88%---LOSS:0.067---time:42.93
# Epoch:19---batch(36)训练集---ACC:100.00%---LOSS:0.002---time:43.03
# Epoch:19---batch(37)训练集---ACC:100.00%---LOSS:0.002---time:21.60
# 第19轮测试集准确率：88.00%....测试集Loss:0.6785965008395058

# %%
# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 经典与传统的对比
# 加载经典
# Classical_Train_data = pd.read_csv('/home/WUYING_986418966_1288354473/Desktop/QCNN/src/QCNN-FC/QTCNN-MNIST/640_train.csv')
# Classical_Val_data = pd.read_csv('/home/WUYING_986418966_1288354473/Desktop/QCNN/src/QCNN-FC/QTCNN-MNIST/2091_val.csv')

# Classical_Train_data_acc = Classical_Train_data[['Train_acc']]
# Classical_Train_data_loss = Classical_Train_data[['Train_loss']]

# Classical_Val_data_acc = Classical_Val_data[['Val_acc']]
# Classical_Val_data_loss = Classical_Val_data[['Val_loss']]
def result(acc,loss,plt1_title,plt2_title,title):     # 合并结果
    #绘图
    plt.xticks(np.arange(0,20,1))
    plt.plot(acc,label=plt1_title)
    plt.plot(loss,label=plt2_title)
    plt.title(title) 
    plt.xlabel('epoch')
    plt.ylabel('probability')
    plt.legend()   #显示标签
    plt.show()

# 加载qcnn
Qcnn_Train_data = pd.read_csv('E:\\Test\VsCode_Test\\Jupyter notebook\\Tensorcircuit\\result\\MNIST\\944_train.csv')
Qcnn_Val_data = pd.read_csv('E:\\Test\\VsCode_Test\\Jupyter notebook\\Tensorcircuit\\result\\MNIST\\7615_val.csv')

Qcnn_Train_data_acc = Qcnn_Train_data[['Train_acc']]
Qcnn_Train_data_loss = Qcnn_Train_data[['Train_loss']]

Qcnn_Val_data_acc = Qcnn_Val_data[['Val_acc']]
Qcnn_Val_data_loss = Qcnn_Val_data[['Val_loss']]

# 损失值比较
result(Qcnn_Train_data_loss,Qcnn_Val_data_loss,'Train_set','Val_set','Loss')
# 准确率比较
result(Qcnn_Train_data_acc,Qcnn_Val_data_acc,'Train_set','Val_set','ACC')
