# %%
import tensorcircuit as tc
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split,Subset
import random
import os
import time
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F
import numpy as np
import csv
import tensorflow as tf


data_path = 'E:\\Test\\VsCode_Test\\Jupyter notebook\\xLw\\data'

val_num = 200
data_num =  1200           # 需要划分的数据集大小
epochs = 20                 # 迭代轮次数
batch_size = 32

K = tc.set_backend("tensorflow")
# 归一化处理
def trans(x):
    x = np.array(x)
    x = x/255.0
    # print(x.shape)    
    return torch.from_numpy(x).float()          # 将 NumPy 数组 x 转换为 PyTorch 张量

transform = transforms.Compose([
    transforms.Resize((14, 14)),                # 将图片缩小为 14x14
    transforms.Lambda(lambda x:trans(x))
])

# 加载MNIST数据集 28X28X1   10类别   
trainset = torchvision.datasets.MNIST(root=data_path, train=True,
                                        download=False, transform=transform)
testset = torchvision.datasets.MNIST(root=data_path, train=False,
                                        download=False, transform=transform)

# 随机抽取训练集 data_num 张图片作为子集
subset_indices = random.sample(range(len(trainset)), k=data_num)
train_subset = Subset(trainset, subset_indices)

# 随机抽取测试集 data_num 张图片作为子集
subset_val = random.sample(range(len(testset)), k=val_num)
val_subset = Subset(testset, subset_val)

# 加载测试集
trainloader = torch.utils.data.DataLoader(train_subset, batch_size=batch_size,  # type: ignore
                                          shuffle=True)
testloader = torch.utils.data.DataLoader(val_subset, batch_size=batch_size,    # type: ignore
                                         shuffle=False)

# %%
n = 4
nlayers = 1

def qpred(x, weights):
    c = tc.Circuit(n)
    for i in range(n):
        c.h(i)
        c.ry(i, theta=x[i]*weights[i])
    for j in range(nlayers):
        for i in range(n - 1):
            c.cnot(i, i + 1)
    return [K.real(c.expectation([tc.gates.z(), [i]])) for i in range(n)]

# %%
qpred_vmap = K.vmap(qpred, vectorized_argnums=0)        # `qpred_vmap` 是一个具有向量化能力的 TensorFlow 函数
qpred_batch = tc.interfaces.torch_interface(qpred_vmap, jit=True) # 我们进一步将函数包装为 PyTorch 函数

# %%
class QuantumNetV2(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.q_weights = torch.nn.Parameter(torch.randn([n]))
        self.stride = 1

    def forward(self, inputs):
        kernel_size = 2
        
        # 使用转置卷积进行上采样
        padding_size = kernel_size - 1                  # 1 先进行填充
        padd_img = nn.functional.pad(inputs,(padding_size,padding_size,padding_size,padding_size),mode='constant',value=0)
        # padding_img.size()=16
        bs, ch , h , w = padd_img.size()                #    h=16

        h_out = self.stride*(h-1)+kernel_size           #   （17-1）+ 2 = 18
        w_out = self.stride*(w-1)+kernel_size           #   （17-1）+ 2 = 18
        out = torch.zeros((bs,4, h_out, w_out))
        # print(f'padd_img={padd_img.shape}')             # padd_img=torch.Size([3, 1, 16, 16])
        for b in range(bs):
                for j in range(0, h_out-padding_size-1, self.stride):
                    for k in range(0, w_out-padding_size-1, self.stride):
                        # print(f'padd_img[b, 0, j, k]={padd_img[b, 0, j, k].shape}')
                        t1 = padd_img[b, 0, j, k]        
                        t2 = padd_img[b, 0, j, k + 1]
                        t3 = padd_img[b, 0, j + 1, k]    
                        t4 = padd_img[b, 0, j + 1, k + 1]

                        temp = torch.Tensor([t1,t2,t3,t4]) # 
                        temp = temp.view(1,4)

                        # temp = torch.unsqueeze(temp, 0)      
                        q_results = qpred_batch(temp, self.q_weights)     
                        for c in range(4):
                            out[b, c,j // kernel_size, k // kernel_size] = q_results[c]
        return out

# %%
# 经典CNNmodel 可进行修改
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
            
        # Quantum layer 1
        self.conv1 = QuantumNetV2()
        self.relu1 = nn.ReLU()
        self.batch1 = nn.BatchNorm2d(4)  # 4
        
        # Fully-Connected layer 2
        self.fc2 = nn.Linear(1156,10)
                
    def forward(self, x):

        # qconv layer 1
        out = self.conv1(x)                 
        out = self.relu1(out)   
        out = self.batch1(out)
        
        #Flatten拉平操作
        out = out.view(out.size(0),-1)      # print(f'-----拉平后的维度是--{out.shape}') #  torch.Size([64, 576])
        
        #FC 第二层
        out = self.fc2(out)
        return F.log_softmax(out,dim = 1)

# %%
model = CNNModel()
loss_fun = nn.CrossEntropyLoss()
opt = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
# 准确率计算
def accuracy(output,labels):
    prediction = torch.max(output.data,1)[1]
    rights = prediction.eq(labels.data.view_as(prediction)).sum()
    return rights,len(labels)

# 绘制训练结果
def draw_result(accs,losses,title):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14, 6))   # subplots创建1行 2列的子图
    
    ax1.plot(losses) 
    ax1.set_title(title+" Loss")
    ax1.set_xlabel("Steps")
    ax1.set_ylabel("Loss")
    
    ax2.plot(accs)
    ax2.set_title(title+" Accuracy")
    ax2.set_xlabel("Steps")
    ax2.set_ylabel("Accuracy")

# %%
def train(epochs,model,loss_fun,opt,train_loader,test_loader):
    train_accuracy = []             # 训练集准确率
    train_loss = []

    val_accuracy = []               # 验证集准确率
    val_loss = []
    for epoch in range(epochs):
                ### 训练模块
        train_total_accuracy = 0    # 训练集每epoch（18个batch的和）的准确率
        train_total_loss = 0
        for batch_idx,(data,labels) in enumerate(train_loader):
            t2 = time.time()
            data = data.view(data.shape[0],1, data.shape[1], data.shape[2])
            
            model.train()					    # 1 模型训练       
            output = model(data)			    # 2 模型输出
            # print(f'output.shape is {output.shape}')    # output.shape is torch.Size([64, 4, 17, 17])
            # print(f'labels.shape is {labels.shape}')    # labels.shape is torch.Size([64])
            loss = loss_fun(output,labels)	    # 3 计算损失

            opt.zero_grad()					    # 4 梯度清零
            loss.backward() 				    # 5 开始反向传播
            opt.step()                          # 6 梯度更新
            
            # 计算准确率
            accuracy_count, total_count = accuracy(output,labels)
            accuracy_rate = accuracy_count / total_count  # 计算准确率（预测正确的样本数除以总样本数）

            train_total_accuracy += accuracy_count
            train_total_loss +=loss.item()

            batch_time = time.time()-t2
            print(f'Epoch:{epoch}---batch({batch_idx})训练集---ACC:{accuracy_rate:.2%}---LOSS:{loss.item():.3f}---time:{batch_time:.2f}')        
        
        train_total_loss /= batch_idx+1
        train_accuracy.append(train_total_accuracy/len(train_subset))   # 保存1轮的数据 len(train_accuracy)
        train_loss.append(train_total_loss)
### 验证模块
        total_acc = 0
        total_test_loss = 0
        model.eval()
        with torch.no_grad():# 进行评测的时候网络不更新梯度
            for step,(data,target) in enumerate(test_loader):
                data = data.view(data.shape[0],1, data.shape[1], data.shape[2])            # 调整维度一致
                outputs = model(data)
                losses = loss_fun(outputs,target)                               # 计算损失

                accuracy_count, total_count = accuracy(outputs,target)          # 计算准确率
                accuracy_rate = accuracy_count / total_count                    # 计算准确率（预测正确的样本数除以总样本数）

                total_acc += accuracy_count
                total_test_loss+=losses.item()

        total_test_loss /= step + 1
        val_accuracy.append((total_acc/len(val_subset)))
        val_loss.append(total_test_loss)
        print(f'第{epoch}轮测试集准确率：{total_acc/len(val_subset):.2%}....测试集Loss:{total_test_loss}')
    
    ### 画出训练结果图 ##############
    draw_result(train_accuracy,train_loss,"Train")
    draw_result(val_accuracy,val_loss,"Val")
    
    ####  训练的结果写入文件   ##############
    with open(str(random.randint(100,999))+"_train.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Train_loss','Train_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, train_loss[i], train_accuracy[i].numpy()])
    
    #### 测试的结果写入文件  ##############
    with open(str(random.randint(1000,9999))+"_val.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Val_loss','Val_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, val_loss[i], val_accuracy[i].numpy()])

    ### 保存训练的结果
    # Loss0 = torch.tensor(save_train_loss)
    # torch.save(Loss0,'E:\\Test\\VsCode_Test\\Python\\xlw\\test1\\lw2\\epoch_{}'.format(epochs))
    return model, train_accuracy,train_loss

# %%
model, train_accuracy,train_loss = train(epochs,model,loss_fun,opt,trainloader,testloader)
# Out:
# Epoch:0---batch(0)训练集---ACC:9.38%---LOSS:2.420---time:29.89
# Epoch:0---batch(1)训练集---ACC:31.25%---LOSS:2.207---time:13.55
# Epoch:0---batch(2)训练集---ACC:9.38%---LOSS:2.381---time:12.77
# Epoch:0---batch(3)训练集---ACC:9.38%---LOSS:2.500---time:13.15
# Epoch:0---batch(4)训练集---ACC:25.00%---LOSS:1.922---time:13.06
# Epoch:0---batch(5)训练集---ACC:40.62%---LOSS:2.092---time:13.01
# Epoch:0---batch(6)训练集---ACC:53.12%---LOSS:2.250---time:13.14
# Epoch:0---batch(7)训练集---ACC:31.25%---LOSS:1.699---time:12.77
# Epoch:0---batch(8)训练集---ACC:46.88%---LOSS:1.650---time:13.02
# Epoch:0---batch(9)训练集---ACC:40.62%---LOSS:1.721---time:12.76
# Epoch:0---batch(10)训练集---ACC:53.12%---LOSS:1.364---time:12.79
# Epoch:0---batch(11)训练集---ACC:40.62%---LOSS:1.735---time:12.87
# Epoch:0---batch(12)训练集---ACC:46.88%---LOSS:1.532---time:14.20
# Epoch:0---batch(13)训练集---ACC:59.38%---LOSS:1.148---time:25.01
# Epoch:0---batch(14)训练集---ACC:40.62%---LOSS:1.940---time:21.44
# Epoch:0---batch(15)训练集---ACC:59.38%---LOSS:1.672---time:19.98
# Epoch:0---batch(16)训练集---ACC:56.25%---LOSS:1.401---time:24.18
# Epoch:0---batch(17)训练集---ACC:56.25%---LOSS:1.634---time:19.07
# Epoch:0---batch(18)训练集---ACC:71.88%---LOSS:1.405---time:20.28
# Epoch:0---batch(19)训练集---ACC:46.88%---LOSS:1.537---time:18.60
# Epoch:0---batch(20)训练集---ACC:56.25%---LOSS:1.681---time:19.28
# Epoch:0---batch(21)训练集---ACC:53.12%---LOSS:1.456---time:19.33
# Epoch:0---batch(22)训练集---ACC:50.00%---LOSS:1.291---time:19.81
# Epoch:0---batch(23)训练集---ACC:71.88%---LOSS:0.865---time:28.32
# Epoch:0---batch(24)训练集---ACC:75.00%---LOSS:1.077---time:25.52
# Epoch:0---batch(25)训练集---ACC:75.00%---LOSS:0.813---time:19.38
# Epoch:0---batch(26)训练集---ACC:62.50%---LOSS:1.183---time:20.31
# Epoch:0---batch(27)训练集---ACC:59.38%---LOSS:1.251---time:21.01
# Epoch:0---batch(28)训练集---ACC:56.25%---LOSS:1.227---time:21.12
# Epoch:0---batch(29)训练集---ACC:56.25%---LOSS:1.320---time:20.28
# Epoch:0---batch(30)训练集---ACC:53.12%---LOSS:1.241---time:18.90
# Epoch:0---batch(31)训练集---ACC:68.75%---LOSS:1.077---time:23.51
# Epoch:0---batch(32)训练集---ACC:62.50%---LOSS:1.143---time:33.09
# Epoch:0---batch(33)训练集---ACC:87.50%---LOSS:0.598---time:19.71
# Epoch:0---batch(34)训练集---ACC:71.88%---LOSS:0.868---time:18.41
# Epoch:0---batch(35)训练集---ACC:65.62%---LOSS:1.317---time:18.15
# Epoch:0---batch(36)训练集---ACC:62.50%---LOSS:1.278---time:17.91
# Epoch:0---batch(37)训练集---ACC:75.00%---LOSS:0.803---time:10.81
# 第0轮测试集准确率：26.50%....测试集Loss:1.9426435913358415
# Epoch:1---batch(0)训练集---ACC:71.88%---LOSS:1.213---time:26.39
# Epoch:1---batch(1)训练集---ACC:78.12%---LOSS:0.816---time:18.90
# Epoch:1---batch(2)训练集---ACC:78.12%---LOSS:0.867---time:26.32
# Epoch:1---batch(3)训练集---ACC:78.12%---LOSS:0.644---time:20.54
# Epoch:1---batch(4)训练集---ACC:68.75%---LOSS:1.030---time:21.70
# Epoch:1---batch(5)训练集---ACC:81.25%---LOSS:0.657---time:23.72
# Epoch:1---batch(6)训练集---ACC:78.12%---LOSS:0.943---time:26.30
# Epoch:1---batch(7)训练集---ACC:65.62%---LOSS:0.974---time:18.56
# Epoch:1---batch(8)训练集---ACC:78.12%---LOSS:0.780---time:18.09
# Epoch:1---batch(9)训练集---ACC:68.75%---LOSS:0.819---time:20.56
# Epoch:1---batch(10)训练集---ACC:65.62%---LOSS:1.013---time:22.08
# Epoch:1---batch(11)训练集---ACC:71.88%---LOSS:1.090---time:16.85
# Epoch:1---batch(12)训练集---ACC:71.88%---LOSS:0.714---time:15.40
# Epoch:1---batch(13)训练集---ACC:71.88%---LOSS:0.972---time:14.88
# Epoch:1---batch(14)训练集---ACC:65.62%---LOSS:0.980---time:14.57
# Epoch:1---batch(15)训练集---ACC:68.75%---LOSS:0.894---time:15.54
# Epoch:1---batch(16)训练集---ACC:71.88%---LOSS:0.817---time:17.24
# Epoch:1---batch(17)训练集---ACC:68.75%---LOSS:1.028---time:20.23
# Epoch:1---batch(18)训练集---ACC:71.88%---LOSS:0.693---time:13.92
# Epoch:1---batch(19)训练集---ACC:81.25%---LOSS:0.728---time:11.54
# Epoch:1---batch(20)训练集---ACC:71.88%---LOSS:0.775---time:11.46
# Epoch:1---batch(21)训练集---ACC:71.88%---LOSS:0.945---time:11.19
# Epoch:1---batch(22)训练集---ACC:62.50%---LOSS:0.983---time:10.69
# Epoch:1---batch(23)训练集---ACC:78.12%---LOSS:0.883---time:10.80
# Epoch:1---batch(24)训练集---ACC:65.62%---LOSS:0.894---time:10.93
# Epoch:1---batch(25)训练集---ACC:68.75%---LOSS:1.155---time:10.41
# Epoch:1---batch(26)训练集---ACC:59.38%---LOSS:1.133---time:10.48
# Epoch:1---batch(27)训练集---ACC:71.88%---LOSS:0.824---time:10.82
# Epoch:1---batch(28)训练集---ACC:56.25%---LOSS:1.291---time:10.71
# Epoch:1---batch(29)训练集---ACC:53.12%---LOSS:0.944---time:10.86
# Epoch:1---batch(30)训练集---ACC:68.75%---LOSS:1.077---time:10.25
# Epoch:1---batch(31)训练集---ACC:56.25%---LOSS:1.293---time:10.40
# Epoch:1---batch(32)训练集---ACC:65.62%---LOSS:0.852---time:11.81
# Epoch:1---batch(33)训练集---ACC:78.12%---LOSS:0.560---time:12.05
# Epoch:1---batch(34)训练集---ACC:62.50%---LOSS:0.959---time:11.54
# Epoch:1---batch(35)训练集---ACC:87.50%---LOSS:0.568---time:11.84
# Epoch:1---batch(36)训练集---ACC:75.00%---LOSS:0.772---time:11.65
# Epoch:1---batch(37)训练集---ACC:68.75%---LOSS:1.186---time:5.61
# 第1轮测试集准确率：71.00%....测试集Loss:1.0224026441574097
# Epoch:2---batch(0)训练集---ACC:84.38%---LOSS:0.603---time:12.66
# Epoch:2---batch(1)训练集---ACC:84.38%---LOSS:0.623---time:11.15
# Epoch:2---batch(2)训练集---ACC:71.88%---LOSS:0.829---time:11.22
# Epoch:2---batch(3)训练集---ACC:62.50%---LOSS:0.997---time:10.70
# Epoch:2---batch(4)训练集---ACC:68.75%---LOSS:0.968---time:10.70
# Epoch:2---batch(5)训练集---ACC:75.00%---LOSS:0.706---time:11.48
# Epoch:2---batch(6)训练集---ACC:78.12%---LOSS:0.786---time:12.22
# Epoch:2---batch(7)训练集---ACC:84.38%---LOSS:0.671---time:11.03
# Epoch:2---batch(8)训练集---ACC:78.12%---LOSS:0.935---time:11.25
# Epoch:2---batch(9)训练集---ACC:68.75%---LOSS:0.713---time:12.68
# Epoch:2---batch(10)训练集---ACC:59.38%---LOSS:1.118---time:13.28
# Epoch:2---batch(11)训练集---ACC:68.75%---LOSS:0.912---time:11.80
# Epoch:2---batch(12)训练集---ACC:68.75%---LOSS:0.806---time:11.56
# Epoch:2---batch(13)训练集---ACC:62.50%---LOSS:1.133---time:11.40
# Epoch:2---batch(14)训练集---ACC:75.00%---LOSS:0.744---time:12.08
# Epoch:2---batch(15)训练集---ACC:81.25%---LOSS:0.765---time:11.29
# Epoch:2---batch(16)训练集---ACC:75.00%---LOSS:0.752---time:11.15
# Epoch:2---batch(17)训练集---ACC:90.62%---LOSS:0.591---time:10.60
# Epoch:2---batch(18)训练集---ACC:71.88%---LOSS:0.754---time:10.82
# Epoch:2---batch(19)训练集---ACC:65.62%---LOSS:0.624---time:10.61
# Epoch:2---batch(20)训练集---ACC:78.12%---LOSS:0.951---time:11.02
# Epoch:2---batch(21)训练集---ACC:68.75%---LOSS:1.036---time:10.70
# Epoch:2---batch(22)训练集---ACC:87.50%---LOSS:0.627---time:10.62
# Epoch:2---batch(23)训练集---ACC:90.62%---LOSS:0.477---time:10.83
# Epoch:2---batch(24)训练集---ACC:68.75%---LOSS:0.883---time:11.23
# Epoch:2---batch(25)训练集---ACC:68.75%---LOSS:0.823---time:11.67
# Epoch:2---batch(26)训练集---ACC:71.88%---LOSS:0.808---time:11.16
# Epoch:2---batch(27)训练集---ACC:75.00%---LOSS:0.747---time:10.95
# Epoch:2---batch(28)训练集---ACC:65.62%---LOSS:1.193---time:11.27
# Epoch:2---batch(29)训练集---ACC:62.50%---LOSS:0.855---time:11.83
# Epoch:2---batch(30)训练集---ACC:78.12%---LOSS:0.709---time:11.37
# Epoch:2---batch(31)训练集---ACC:68.75%---LOSS:0.770---time:11.17
# Epoch:2---batch(32)训练集---ACC:59.38%---LOSS:0.848---time:11.66
# Epoch:2---batch(33)训练集---ACC:62.50%---LOSS:0.937---time:11.36
# Epoch:2---batch(34)训练集---ACC:78.12%---LOSS:0.804---time:11.36
# Epoch:2---batch(35)训练集---ACC:62.50%---LOSS:1.090---time:11.21
# Epoch:2---batch(36)训练集---ACC:84.38%---LOSS:0.782---time:11.37
# Epoch:2---batch(37)训练集---ACC:62.50%---LOSS:1.016---time:5.77
# 第2轮测试集准确率：63.50%....测试集Loss:1.0380528654370988
# Epoch:3---batch(0)训练集---ACC:84.38%---LOSS:0.500---time:11.19
# Epoch:3---batch(1)训练集---ACC:71.88%---LOSS:0.816---time:11.12
# Epoch:3---batch(2)训练集---ACC:75.00%---LOSS:0.831---time:11.15
# Epoch:3---batch(3)训练集---ACC:68.75%---LOSS:0.883---time:11.39
# Epoch:3---batch(4)训练集---ACC:68.75%---LOSS:0.711---time:10.94
# Epoch:3---batch(5)训练集---ACC:75.00%---LOSS:0.588---time:11.14
# Epoch:3---batch(6)训练集---ACC:81.25%---LOSS:0.681---time:11.26
# Epoch:3---batch(7)训练集---ACC:84.38%---LOSS:0.563---time:11.92
# Epoch:3---batch(8)训练集---ACC:81.25%---LOSS:0.643---time:11.84
# Epoch:3---batch(9)训练集---ACC:78.12%---LOSS:0.678---time:11.59
# Epoch:3---batch(10)训练集---ACC:78.12%---LOSS:0.705---time:11.30
# Epoch:3---batch(11)训练集---ACC:75.00%---LOSS:0.778---time:11.16
# Epoch:3---batch(12)训练集---ACC:68.75%---LOSS:1.034---time:11.06
# Epoch:3---batch(13)训练集---ACC:71.88%---LOSS:0.860---time:11.31
# Epoch:3---batch(14)训练集---ACC:78.12%---LOSS:0.781---time:11.35
# Epoch:3---batch(15)训练集---ACC:78.12%---LOSS:0.680---time:11.66
# Epoch:3---batch(16)训练集---ACC:84.38%---LOSS:0.774---time:11.33
# Epoch:3---batch(17)训练集---ACC:75.00%---LOSS:0.703---time:11.05
# Epoch:3---batch(18)训练集---ACC:78.12%---LOSS:0.900---time:11.16
# Epoch:3---batch(19)训练集---ACC:90.62%---LOSS:0.519---time:11.58
# Epoch:3---batch(20)训练集---ACC:65.62%---LOSS:0.887---time:11.05
# Epoch:3---batch(21)训练集---ACC:71.88%---LOSS:0.713---time:11.51
# Epoch:3---batch(22)训练集---ACC:78.12%---LOSS:0.719---time:11.25
# Epoch:3---batch(23)训练集---ACC:68.75%---LOSS:0.759---time:10.85
# Epoch:3---batch(24)训练集---ACC:75.00%---LOSS:0.638---time:10.97
# Epoch:3---batch(25)训练集---ACC:65.62%---LOSS:1.063---time:11.11
# Epoch:3---batch(26)训练集---ACC:65.62%---LOSS:1.100---time:10.97
# Epoch:3---batch(27)训练集---ACC:78.12%---LOSS:0.489---time:11.23
# Epoch:3---batch(28)训练集---ACC:65.62%---LOSS:0.960---time:10.87
# Epoch:3---batch(29)训练集---ACC:75.00%---LOSS:0.838---time:11.31
# Epoch:3---batch(30)训练集---ACC:75.00%---LOSS:0.780---time:11.40
# Epoch:3---batch(31)训练集---ACC:62.50%---LOSS:1.151---time:11.46
# Epoch:3---batch(32)训练集---ACC:75.00%---LOSS:0.733---time:11.46
# Epoch:3---batch(33)训练集---ACC:68.75%---LOSS:0.946---time:11.23
# Epoch:3---batch(34)训练集---ACC:75.00%---LOSS:0.706---time:10.95
# Epoch:3---batch(35)训练集---ACC:65.62%---LOSS:1.425---time:11.09
# Epoch:3---batch(36)训练集---ACC:71.88%---LOSS:0.708---time:11.36
# Epoch:3---batch(37)训练集---ACC:75.00%---LOSS:0.847---time:5.52
# 第3轮测试集准确率：71.00%....测试集Loss:1.0013646738869804
# Epoch:4---batch(0)训练集---ACC:75.00%---LOSS:0.809---time:11.44
# Epoch:4---batch(1)训练集---ACC:81.25%---LOSS:0.793---time:11.32
# Epoch:4---batch(2)训练集---ACC:71.88%---LOSS:0.719---time:11.12
# Epoch:4---batch(3)训练集---ACC:84.38%---LOSS:0.515---time:11.10
# Epoch:4---batch(4)训练集---ACC:87.50%---LOSS:0.521---time:11.42
# Epoch:4---batch(5)训练集---ACC:78.12%---LOSS:0.727---time:11.36
# Epoch:4---batch(6)训练集---ACC:62.50%---LOSS:1.069---time:11.43
# Epoch:4---batch(7)训练集---ACC:59.38%---LOSS:0.878---time:11.20
# Epoch:4---batch(8)训练集---ACC:75.00%---LOSS:0.876---time:11.18
# Epoch:4---batch(9)训练集---ACC:90.62%---LOSS:0.505---time:11.09
# Epoch:4---batch(10)训练集---ACC:75.00%---LOSS:0.643---time:11.43
# Epoch:4---batch(11)训练集---ACC:75.00%---LOSS:0.799---time:11.05
# Epoch:4---batch(12)训练集---ACC:78.12%---LOSS:0.759---time:11.08
# Epoch:4---batch(13)训练集---ACC:71.88%---LOSS:0.974---time:11.31
# Epoch:4---batch(14)训练集---ACC:81.25%---LOSS:0.549---time:11.25
# Epoch:4---batch(15)训练集---ACC:56.25%---LOSS:0.957---time:11.15
# Epoch:4---batch(16)训练集---ACC:62.50%---LOSS:1.040---time:10.98
# Epoch:4---batch(17)训练集---ACC:81.25%---LOSS:0.815---time:11.34
# Epoch:4---batch(18)训练集---ACC:62.50%---LOSS:0.918---time:11.13
# Epoch:4---batch(19)训练集---ACC:81.25%---LOSS:0.390---time:11.26
# Epoch:4---batch(20)训练集---ACC:78.12%---LOSS:0.568---time:11.19
# Epoch:4---batch(21)训练集---ACC:87.50%---LOSS:0.496---time:11.02
# Epoch:4---batch(22)训练集---ACC:78.12%---LOSS:0.605---time:11.12
# Epoch:4---batch(23)训练集---ACC:68.75%---LOSS:0.923---time:10.75
# Epoch:4---batch(24)训练集---ACC:81.25%---LOSS:0.521---time:10.69
# Epoch:4---batch(25)训练集---ACC:62.50%---LOSS:0.860---time:11.00
# Epoch:4---batch(26)训练集---ACC:65.62%---LOSS:1.135---time:10.75
# Epoch:4---batch(27)训练集---ACC:75.00%---LOSS:0.663---time:10.82
# Epoch:4---batch(28)训练集---ACC:81.25%---LOSS:0.716---time:11.05
# Epoch:4---batch(29)训练集---ACC:84.38%---LOSS:0.761---time:11.37
# Epoch:4---batch(30)训练集---ACC:71.88%---LOSS:0.890---time:11.33
# Epoch:4---batch(31)训练集---ACC:90.62%---LOSS:0.442---time:11.22
# Epoch:4---batch(32)训练集---ACC:78.12%---LOSS:0.691---time:11.62
# Epoch:4---batch(33)训练集---ACC:75.00%---LOSS:0.653---time:11.18
# Epoch:4---batch(34)训练集---ACC:75.00%---LOSS:0.556---time:11.45
# Epoch:4---batch(35)训练集---ACC:75.00%---LOSS:0.984---time:10.69
# Epoch:4---batch(36)训练集---ACC:62.50%---LOSS:1.013---time:11.12
# Epoch:4---batch(37)训练集---ACC:81.25%---LOSS:0.738---time:5.66
# 第4轮测试集准确率：67.50%....测试集Loss:1.029801070690155
# Epoch:5---batch(0)训练集---ACC:78.12%---LOSS:0.571---time:10.94
# Epoch:5---batch(1)训练集---ACC:90.62%---LOSS:0.424---time:10.78
# Epoch:5---batch(2)训练集---ACC:78.12%---LOSS:0.814---time:11.65
# Epoch:5---batch(3)训练集---ACC:68.75%---LOSS:1.066---time:11.01
# Epoch:5---batch(4)训练集---ACC:81.25%---LOSS:0.522---time:11.39
# Epoch:5---batch(5)训练集---ACC:75.00%---LOSS:0.818---time:10.95
# Epoch:5---batch(6)训练集---ACC:84.38%---LOSS:0.377---time:10.86
# Epoch:5---batch(7)训练集---ACC:84.38%---LOSS:0.656---time:11.29
# Epoch:5---batch(8)训练集---ACC:78.12%---LOSS:0.634---time:11.36
# Epoch:5---batch(9)训练集---ACC:78.12%---LOSS:0.435---time:12.78
# Epoch:5---batch(10)训练集---ACC:68.75%---LOSS:0.741---time:11.15
# Epoch:5---batch(11)训练集---ACC:90.62%---LOSS:0.566---time:10.82
# Epoch:5---batch(12)训练集---ACC:78.12%---LOSS:0.556---time:11.90
# Epoch:5---batch(13)训练集---ACC:71.88%---LOSS:1.087---time:11.48
# Epoch:5---batch(14)训练集---ACC:78.12%---LOSS:0.703---time:11.07
# Epoch:5---batch(15)训练集---ACC:59.38%---LOSS:0.981---time:11.59
# Epoch:5---batch(16)训练集---ACC:75.00%---LOSS:0.679---time:10.89
# Epoch:5---batch(17)训练集---ACC:78.12%---LOSS:0.826---time:11.12
# Epoch:5---batch(18)训练集---ACC:75.00%---LOSS:0.653---time:12.25
# Epoch:5---batch(19)训练集---ACC:71.88%---LOSS:0.616---time:11.05
# Epoch:5---batch(20)训练集---ACC:87.50%---LOSS:0.497---time:11.45
# Epoch:5---batch(21)训练集---ACC:78.12%---LOSS:0.483---time:11.71
# Epoch:5---batch(22)训练集---ACC:71.88%---LOSS:0.904---time:11.50
# Epoch:5---batch(23)训练集---ACC:71.88%---LOSS:0.707---time:11.36
# Epoch:5---batch(24)训练集---ACC:62.50%---LOSS:0.737---time:11.15
# Epoch:5---batch(25)训练集---ACC:75.00%---LOSS:0.679---time:11.39
# Epoch:5---batch(26)训练集---ACC:71.88%---LOSS:0.877---time:11.30
# Epoch:5---batch(27)训练集---ACC:78.12%---LOSS:0.610---time:11.20
# Epoch:5---batch(28)训练集---ACC:65.62%---LOSS:1.004---time:11.26
# Epoch:5---batch(29)训练集---ACC:65.62%---LOSS:0.782---time:11.34
# Epoch:5---batch(30)训练集---ACC:71.88%---LOSS:0.823---time:11.35
# Epoch:5---batch(31)训练集---ACC:75.00%---LOSS:0.734---time:11.44
# Epoch:5---batch(32)训练集---ACC:78.12%---LOSS:0.905---time:11.10
# Epoch:5---batch(33)训练集---ACC:75.00%---LOSS:0.801---time:10.83
# Epoch:5---batch(34)训练集---ACC:71.88%---LOSS:0.690---time:10.94
# Epoch:5---batch(35)训练集---ACC:78.12%---LOSS:0.848---time:10.74
# Epoch:5---batch(36)训练集---ACC:75.00%---LOSS:0.851---time:10.79
# Epoch:5---batch(37)训练集---ACC:93.75%---LOSS:0.276---time:5.41
# 第5轮测试集准确率：67.50%....测试集Loss:1.135809804712023
# Epoch:6---batch(0)训练集---ACC:87.50%---LOSS:0.702---time:10.92
# Epoch:6---batch(1)训练集---ACC:84.38%---LOSS:0.609---time:10.79
# Epoch:6---batch(2)训练集---ACC:78.12%---LOSS:0.878---time:10.74
# Epoch:6---batch(3)训练集---ACC:68.75%---LOSS:0.808---time:10.78
# Epoch:6---batch(4)训练集---ACC:62.50%---LOSS:1.060---time:10.88
# Epoch:6---batch(5)训练集---ACC:90.62%---LOSS:0.356---time:10.75
# Epoch:6---batch(6)训练集---ACC:84.38%---LOSS:0.803---time:10.91
# Epoch:6---batch(7)训练集---ACC:75.00%---LOSS:0.480---time:10.98
# Epoch:6---batch(8)训练集---ACC:84.38%---LOSS:0.645---time:10.83
# Epoch:6---batch(9)训练集---ACC:71.88%---LOSS:0.688---time:10.88
# Epoch:6---batch(10)训练集---ACC:68.75%---LOSS:0.739---time:10.81
# Epoch:6---batch(11)训练集---ACC:78.12%---LOSS:0.553---time:11.12
# Epoch:6---batch(12)训练集---ACC:78.12%---LOSS:0.636---time:10.81
# Epoch:6---batch(13)训练集---ACC:68.75%---LOSS:0.695---time:10.78
# Epoch:6---batch(14)训练集---ACC:75.00%---LOSS:1.001---time:10.76
# Epoch:6---batch(15)训练集---ACC:71.88%---LOSS:0.702---time:10.75
# Epoch:6---batch(16)训练集---ACC:81.25%---LOSS:0.607---time:10.77
# Epoch:6---batch(17)训练集---ACC:71.88%---LOSS:0.792---time:10.71
# Epoch:6---batch(18)训练集---ACC:78.12%---LOSS:0.859---time:10.74
# Epoch:6---batch(19)训练集---ACC:84.38%---LOSS:0.579---time:10.80
# Epoch:6---batch(20)训练集---ACC:81.25%---LOSS:0.443---time:10.80
# Epoch:6---batch(21)训练集---ACC:71.88%---LOSS:0.606---time:10.78
# Epoch:6---batch(22)训练集---ACC:81.25%---LOSS:0.619---time:10.82
# Epoch:6---batch(23)训练集---ACC:78.12%---LOSS:0.747---time:10.90
# Epoch:6---batch(24)训练集---ACC:78.12%---LOSS:0.684---time:11.00
# Epoch:6---batch(25)训练集---ACC:75.00%---LOSS:0.537---time:10.85
# Epoch:6---batch(26)训练集---ACC:75.00%---LOSS:0.817---time:10.85
# Epoch:6---batch(27)训练集---ACC:87.50%---LOSS:0.428---time:11.03
# Epoch:6---batch(28)训练集---ACC:71.88%---LOSS:0.780---time:10.88
# Epoch:6---batch(29)训练集---ACC:78.12%---LOSS:0.538---time:10.83
# Epoch:6---batch(30)训练集---ACC:65.62%---LOSS:0.923---time:10.88
# Epoch:6---batch(31)训练集---ACC:75.00%---LOSS:0.608---time:10.76
# Epoch:6---batch(32)训练集---ACC:75.00%---LOSS:1.279---time:10.75
# Epoch:6---batch(33)训练集---ACC:78.12%---LOSS:0.770---time:10.85
# Epoch:6---batch(34)训练集---ACC:68.75%---LOSS:0.748---time:10.86
# Epoch:6---batch(35)训练集---ACC:75.00%---LOSS:0.840---time:10.76
# Epoch:6---batch(36)训练集---ACC:87.50%---LOSS:0.413---time:10.80
# Epoch:6---batch(37)训练集---ACC:75.00%---LOSS:0.607---time:5.32
# 第6轮测试集准确率：71.50%....测试集Loss:1.1035169618470329
# Epoch:7---batch(0)训练集---ACC:71.88%---LOSS:0.693---time:13.05
# Epoch:7---batch(1)训练集---ACC:87.50%---LOSS:0.580---time:13.47
# Epoch:7---batch(2)训练集---ACC:78.12%---LOSS:0.714---time:13.63
# Epoch:7---batch(3)训练集---ACC:78.12%---LOSS:0.495---time:13.98
# Epoch:7---batch(4)训练集---ACC:84.38%---LOSS:0.489---time:13.51
# Epoch:7---batch(5)训练集---ACC:71.88%---LOSS:0.827---time:12.88
# Epoch:7---batch(6)训练集---ACC:81.25%---LOSS:0.760---time:12.97
# Epoch:7---batch(7)训练集---ACC:81.25%---LOSS:0.617---time:11.97
# Epoch:7---batch(8)训练集---ACC:81.25%---LOSS:0.714---time:11.46
# Epoch:7---batch(9)训练集---ACC:87.50%---LOSS:0.388---time:14.36
# Epoch:7---batch(10)训练集---ACC:84.38%---LOSS:0.563---time:12.92
# Epoch:7---batch(11)训练集---ACC:84.38%---LOSS:0.488---time:13.24
# Epoch:7---batch(12)训练集---ACC:71.88%---LOSS:0.564---time:12.84
# Epoch:7---batch(13)训练集---ACC:71.88%---LOSS:0.690---time:13.25
# Epoch:7---batch(14)训练集---ACC:84.38%---LOSS:0.732---time:12.83
# Epoch:7---batch(15)训练集---ACC:84.38%---LOSS:0.514---time:13.11
# Epoch:7---batch(16)训练集---ACC:87.50%---LOSS:0.366---time:12.42
# Epoch:7---batch(17)训练集---ACC:71.88%---LOSS:0.931---time:13.27
# Epoch:7---batch(18)训练集---ACC:68.75%---LOSS:1.213---time:13.08
# Epoch:7---batch(19)训练集---ACC:68.75%---LOSS:1.055---time:13.42
# Epoch:7---batch(20)训练集---ACC:78.12%---LOSS:0.895---time:13.01
# Epoch:7---batch(21)训练集---ACC:90.62%---LOSS:0.481---time:12.74
# Epoch:7---batch(22)训练集---ACC:65.62%---LOSS:0.770---time:13.46
# Epoch:7---batch(23)训练集---ACC:68.75%---LOSS:0.919---time:13.63
# Epoch:7---batch(24)训练集---ACC:87.50%---LOSS:0.724---time:13.20
# Epoch:7---batch(25)训练集---ACC:87.50%---LOSS:0.439---time:13.58
# Epoch:7---batch(26)训练集---ACC:65.62%---LOSS:0.939---time:14.49
# Epoch:7---batch(27)训练集---ACC:65.62%---LOSS:1.100---time:13.65
# Epoch:7---batch(28)训练集---ACC:75.00%---LOSS:0.606---time:13.55
# Epoch:7---batch(29)训练集---ACC:62.50%---LOSS:0.844---time:12.71
# Epoch:7---batch(30)训练集---ACC:81.25%---LOSS:0.786---time:11.08
# Epoch:7---batch(31)训练集---ACC:84.38%---LOSS:0.649---time:11.26
# Epoch:7---batch(32)训练集---ACC:75.00%---LOSS:0.579---time:11.61
# Epoch:7---batch(33)训练集---ACC:71.88%---LOSS:0.711---time:11.20
# Epoch:7---batch(34)训练集---ACC:75.00%---LOSS:0.707---time:11.41
# Epoch:7---batch(35)训练集---ACC:62.50%---LOSS:1.047---time:11.54
# Epoch:7---batch(36)训练集---ACC:84.38%---LOSS:0.555---time:11.94
# Epoch:7---batch(37)训练集---ACC:68.75%---LOSS:0.810---time:5.57
# 第7轮测试集准确率：69.00%....测试集Loss:1.068588605948857
# Epoch:8---batch(0)训练集---ACC:84.38%---LOSS:0.466---time:11.12
# Epoch:8---batch(1)训练集---ACC:68.75%---LOSS:0.637---time:10.82
# Epoch:8---batch(2)训练集---ACC:71.88%---LOSS:1.030---time:10.93
# Epoch:8---batch(3)训练集---ACC:75.00%---LOSS:0.608---time:10.99
# Epoch:8---batch(4)训练集---ACC:78.12%---LOSS:0.577---time:11.32
# Epoch:8---batch(5)训练集---ACC:75.00%---LOSS:0.774---time:10.94
# Epoch:8---batch(6)训练集---ACC:84.38%---LOSS:0.439---time:10.92
# Epoch:8---batch(7)训练集---ACC:71.88%---LOSS:0.665---time:10.89
# Epoch:8---batch(8)训练集---ACC:78.12%---LOSS:0.802---time:11.23
# Epoch:8---batch(9)训练集---ACC:78.12%---LOSS:0.622---time:11.07
# Epoch:8---batch(10)训练集---ACC:87.50%---LOSS:0.480---time:10.96
# Epoch:8---batch(11)训练集---ACC:78.12%---LOSS:0.688---time:10.88
# Epoch:8---batch(12)训练集---ACC:90.62%---LOSS:0.412---time:11.01
# Epoch:8---batch(13)训练集---ACC:68.75%---LOSS:0.803---time:11.14
# Epoch:8---batch(14)训练集---ACC:65.62%---LOSS:0.804---time:11.62
# Epoch:8---batch(15)训练集---ACC:81.25%---LOSS:0.339---time:11.73
# Epoch:8---batch(16)训练集---ACC:81.25%---LOSS:0.710---time:11.44
# Epoch:8---batch(17)训练集---ACC:81.25%---LOSS:0.716---time:11.02
# Epoch:8---batch(18)训练集---ACC:78.12%---LOSS:0.617---time:11.32
# Epoch:8---batch(19)训练集---ACC:75.00%---LOSS:0.841---time:11.20
# Epoch:8---batch(20)训练集---ACC:75.00%---LOSS:0.706---time:10.89
# Epoch:8---batch(21)训练集---ACC:68.75%---LOSS:0.830---time:11.63
# Epoch:8---batch(22)训练集---ACC:65.62%---LOSS:0.893---time:11.48
# Epoch:8---batch(23)训练集---ACC:81.25%---LOSS:0.682---time:11.81
# Epoch:8---batch(24)训练集---ACC:75.00%---LOSS:0.725---time:11.08
# Epoch:8---batch(25)训练集---ACC:84.38%---LOSS:0.900---time:11.89
# Epoch:8---batch(26)训练集---ACC:84.38%---LOSS:0.705---time:10.96
# Epoch:8---batch(27)训练集---ACC:56.25%---LOSS:1.053---time:11.94
# Epoch:8---batch(28)训练集---ACC:84.38%---LOSS:0.471---time:11.14
# Epoch:8---batch(29)训练集---ACC:71.88%---LOSS:0.834---time:10.96
# Epoch:8---batch(30)训练集---ACC:71.88%---LOSS:0.581---time:11.44
# Epoch:8---batch(31)训练集---ACC:62.50%---LOSS:0.970---time:11.35
# Epoch:8---batch(32)训练集---ACC:87.50%---LOSS:0.442---time:11.59
# Epoch:8---batch(33)训练集---ACC:71.88%---LOSS:0.895---time:10.39
# Epoch:8---batch(34)训练集---ACC:75.00%---LOSS:0.538---time:10.94
# Epoch:8---batch(35)训练集---ACC:84.38%---LOSS:0.504---time:11.14
# Epoch:8---batch(36)训练集---ACC:68.75%---LOSS:0.987---time:11.20
# Epoch:8---batch(37)训练集---ACC:56.25%---LOSS:1.051---time:5.66
# 第8轮测试集准确率：68.50%....测试集Loss:1.0529287627765112
# Epoch:9---batch(0)训练集---ACC:81.25%---LOSS:0.570---time:12.26
# Epoch:9---batch(1)训练集---ACC:78.12%---LOSS:0.638---time:10.65
# Epoch:9---batch(2)训练集---ACC:65.62%---LOSS:0.735---time:10.68
# Epoch:9---batch(3)训练集---ACC:81.25%---LOSS:0.534---time:10.72
# Epoch:9---batch(4)训练集---ACC:84.38%---LOSS:0.666---time:10.67
# Epoch:9---batch(5)训练集---ACC:87.50%---LOSS:0.451---time:10.76
# Epoch:9---batch(6)训练集---ACC:96.88%---LOSS:0.299---time:10.69
# Epoch:9---batch(7)训练集---ACC:84.38%---LOSS:0.553---time:10.65
# Epoch:9---batch(8)训练集---ACC:71.88%---LOSS:1.032---time:10.68
# Epoch:9---batch(9)训练集---ACC:71.88%---LOSS:0.642---time:10.68
# Epoch:9---batch(10)训练集---ACC:68.75%---LOSS:0.589---time:10.79
# Epoch:9---batch(11)训练集---ACC:75.00%---LOSS:0.535---time:10.72
# Epoch:9---batch(12)训练集---ACC:84.38%---LOSS:0.712---time:10.60
# Epoch:9---batch(13)训练集---ACC:62.50%---LOSS:0.862---time:10.72
# Epoch:9---batch(14)训练集---ACC:65.62%---LOSS:0.910---time:10.70
# Epoch:9---batch(15)训练集---ACC:65.62%---LOSS:0.691---time:10.74
# Epoch:9---batch(16)训练集---ACC:65.62%---LOSS:0.968---time:10.73
# Epoch:9---batch(17)训练集---ACC:75.00%---LOSS:0.711---time:10.66
# Epoch:9---batch(18)训练集---ACC:71.88%---LOSS:0.819---time:10.67
# Epoch:9---batch(19)训练集---ACC:81.25%---LOSS:0.844---time:10.70
# Epoch:9---batch(20)训练集---ACC:90.62%---LOSS:0.459---time:10.65
# Epoch:9---batch(21)训练集---ACC:71.88%---LOSS:0.657---time:10.66
# Epoch:9---batch(22)训练集---ACC:84.38%---LOSS:0.568---time:10.69
# Epoch:9---batch(23)训练集---ACC:71.88%---LOSS:1.037---time:10.75
# Epoch:9---batch(24)训练集---ACC:87.50%---LOSS:0.365---time:10.76
# Epoch:9---batch(25)训练集---ACC:71.88%---LOSS:0.925---time:10.71
# Epoch:9---batch(26)训练集---ACC:65.62%---LOSS:0.883---time:10.64
# Epoch:9---batch(27)训练集---ACC:78.12%---LOSS:0.772---time:10.73
# Epoch:9---batch(28)训练集---ACC:68.75%---LOSS:0.830---time:10.62
# Epoch:9---batch(29)训练集---ACC:78.12%---LOSS:0.558---time:10.64
# Epoch:9---batch(30)训练集---ACC:75.00%---LOSS:0.742---time:10.71
# Epoch:9---batch(31)训练集---ACC:78.12%---LOSS:0.637---time:10.73
# Epoch:9---batch(32)训练集---ACC:68.75%---LOSS:1.091---time:10.66
# Epoch:9---batch(33)训练集---ACC:78.12%---LOSS:0.790---time:10.69
# Epoch:9---batch(34)训练集---ACC:81.25%---LOSS:0.704---time:10.79
# Epoch:9---batch(35)训练集---ACC:68.75%---LOSS:0.675---time:10.66
# Epoch:9---batch(36)训练集---ACC:75.00%---LOSS:0.544---time:10.68
# Epoch:9---batch(37)训练集---ACC:68.75%---LOSS:0.696---time:5.35
# 第9轮测试集准确率：66.50%....测试集Loss:1.0661446366991316
# Epoch:10---batch(0)训练集---ACC:75.00%---LOSS:0.627---time:13.21
# Epoch:10---batch(1)训练集---ACC:75.00%---LOSS:0.925---time:12.40
# Epoch:10---batch(2)训练集---ACC:84.38%---LOSS:0.481---time:12.76
# Epoch:10---batch(3)训练集---ACC:75.00%---LOSS:0.702---time:12.78
# Epoch:10---batch(4)训练集---ACC:90.62%---LOSS:0.350---time:12.99
# Epoch:10---batch(5)训练集---ACC:84.38%---LOSS:0.635---time:12.72
# Epoch:10---batch(6)训练集---ACC:62.50%---LOSS:0.805---time:13.04
# Epoch:10---batch(7)训练集---ACC:68.75%---LOSS:0.746---time:12.49
# Epoch:10---batch(8)训练集---ACC:87.50%---LOSS:0.465---time:12.79
# Epoch:10---batch(9)训练集---ACC:81.25%---LOSS:0.532---time:12.71
# Epoch:10---batch(10)训练集---ACC:84.38%---LOSS:0.452---time:12.90
# Epoch:10---batch(11)训练集---ACC:84.38%---LOSS:0.460---time:12.92
# Epoch:10---batch(12)训练集---ACC:81.25%---LOSS:0.459---time:12.92
# Epoch:10---batch(13)训练集---ACC:59.38%---LOSS:0.735---time:12.75
# Epoch:10---batch(14)训练集---ACC:75.00%---LOSS:0.695---time:12.74
# Epoch:10---batch(15)训练集---ACC:87.50%---LOSS:0.571---time:12.58
# Epoch:10---batch(16)训练集---ACC:65.62%---LOSS:0.659---time:12.70
# Epoch:10---batch(17)训练集---ACC:81.25%---LOSS:0.661---time:12.70
# Epoch:10---batch(18)训练集---ACC:75.00%---LOSS:0.598---time:12.97
# Epoch:10---batch(19)训练集---ACC:75.00%---LOSS:0.597---time:12.87
# Epoch:10---batch(20)训练集---ACC:75.00%---LOSS:0.650---time:12.72
# Epoch:10---batch(21)训练集---ACC:68.75%---LOSS:0.924---time:12.99
# Epoch:10---batch(22)训练集---ACC:84.38%---LOSS:0.547---time:12.40
# Epoch:10---batch(23)训练集---ACC:71.88%---LOSS:0.624---time:13.23
# Epoch:10---batch(24)训练集---ACC:87.50%---LOSS:0.422---time:12.57
# Epoch:10---batch(25)训练集---ACC:62.50%---LOSS:1.009---time:12.87
# Epoch:10---batch(26)训练集---ACC:84.38%---LOSS:0.405---time:12.87
# Epoch:10---batch(27)训练集---ACC:78.12%---LOSS:0.826---time:13.11
# Epoch:10---batch(28)训练集---ACC:71.88%---LOSS:0.926---time:12.69
# Epoch:10---batch(29)训练集---ACC:46.88%---LOSS:1.604---time:12.99
# Epoch:10---batch(30)训练集---ACC:75.00%---LOSS:0.825---time:12.87
# Epoch:10---batch(31)训练集---ACC:75.00%---LOSS:0.949---time:12.90
# Epoch:10---batch(32)训练集---ACC:84.38%---LOSS:0.532---time:12.78
# Epoch:10---batch(33)训练集---ACC:81.25%---LOSS:0.819---time:12.76
# Epoch:10---batch(34)训练集---ACC:59.38%---LOSS:1.051---time:12.82
# Epoch:10---batch(35)训练集---ACC:75.00%---LOSS:0.528---time:13.00
# Epoch:10---batch(36)训练集---ACC:68.75%---LOSS:0.712---time:12.68
# Epoch:10---batch(37)训练集---ACC:75.00%---LOSS:1.153---time:6.52
# 第10轮测试集准确率：71.00%....测试集Loss:1.0888090559414454
# Epoch:11---batch(0)训练集---ACC:71.88%---LOSS:0.949---time:12.93
# Epoch:11---batch(1)训练集---ACC:84.38%---LOSS:0.398---time:12.61
# Epoch:11---batch(2)训练集---ACC:90.62%---LOSS:0.407---time:13.17
# Epoch:11---batch(3)训练集---ACC:90.62%---LOSS:0.425---time:12.58
# Epoch:11---batch(4)训练集---ACC:81.25%---LOSS:0.607---time:12.66
# Epoch:11---batch(5)训练集---ACC:71.88%---LOSS:0.864---time:12.55
# Epoch:11---batch(6)训练集---ACC:81.25%---LOSS:0.450---time:13.39
# Epoch:11---batch(7)训练集---ACC:81.25%---LOSS:0.536---time:12.78
# Epoch:11---batch(8)训练集---ACC:81.25%---LOSS:0.528---time:13.05
# Epoch:11---batch(9)训练集---ACC:87.50%---LOSS:0.432---time:12.59
# Epoch:11---batch(10)训练集---ACC:68.75%---LOSS:0.886---time:13.03
# Epoch:11---batch(11)训练集---ACC:65.62%---LOSS:0.961---time:12.72
# Epoch:11---batch(12)训练集---ACC:81.25%---LOSS:0.517---time:12.94
# Epoch:11---batch(13)训练集---ACC:81.25%---LOSS:0.444---time:12.46
# Epoch:11---batch(14)训练集---ACC:78.12%---LOSS:0.736---time:12.95
# Epoch:11---batch(15)训练集---ACC:81.25%---LOSS:0.506---time:12.53
# Epoch:11---batch(16)训练集---ACC:84.38%---LOSS:0.406---time:12.73
# Epoch:11---batch(17)训练集---ACC:78.12%---LOSS:0.566---time:12.67
# Epoch:11---batch(18)训练集---ACC:53.12%---LOSS:1.277---time:12.81
# Epoch:11---batch(19)训练集---ACC:62.50%---LOSS:0.983---time:12.49
# Epoch:11---batch(20)训练集---ACC:81.25%---LOSS:0.494---time:12.89
# Epoch:11---batch(21)训练集---ACC:78.12%---LOSS:0.601---time:12.60
# Epoch:11---batch(22)训练集---ACC:75.00%---LOSS:0.689---time:12.99
# Epoch:11---batch(23)训练集---ACC:81.25%---LOSS:0.461---time:12.94
# Epoch:11---batch(24)训练集---ACC:75.00%---LOSS:0.564---time:12.77
# Epoch:11---batch(25)训练集---ACC:84.38%---LOSS:0.496---time:12.86
# Epoch:11---batch(26)训练集---ACC:65.62%---LOSS:0.856---time:12.62
# Epoch:11---batch(27)训练集---ACC:78.12%---LOSS:0.626---time:12.82
# Epoch:11---batch(28)训练集---ACC:84.38%---LOSS:0.669---time:12.49
# Epoch:11---batch(29)训练集---ACC:68.75%---LOSS:0.786---time:13.08
# Epoch:11---batch(30)训练集---ACC:78.12%---LOSS:0.951---time:12.87
# Epoch:11---batch(31)训练集---ACC:84.38%---LOSS:0.473---time:13.00
# Epoch:11---batch(32)训练集---ACC:65.62%---LOSS:1.027---time:12.47
# Epoch:11---batch(33)训练集---ACC:78.12%---LOSS:0.624---time:13.01
# Epoch:11---batch(34)训练集---ACC:78.12%---LOSS:0.878---time:12.71
# Epoch:11---batch(35)训练集---ACC:75.00%---LOSS:0.768---time:13.06
# Epoch:11---batch(36)训练集---ACC:81.25%---LOSS:0.546---time:12.63
# Epoch:11---batch(37)训练集---ACC:87.50%---LOSS:0.511---time:6.51
# 第11轮测试集准确率：73.00%....测试集Loss:1.086760904107775
# Epoch:12---batch(0)训练集---ACC:81.25%---LOSS:0.728---time:12.65
# Epoch:12---batch(1)训练集---ACC:78.12%---LOSS:0.720---time:12.89
# Epoch:12---batch(2)训练集---ACC:81.25%---LOSS:0.631---time:12.55
# Epoch:12---batch(3)训练集---ACC:81.25%---LOSS:0.545---time:13.02
# Epoch:12---batch(4)训练集---ACC:75.00%---LOSS:1.117---time:12.52
# Epoch:12---batch(5)训练集---ACC:68.75%---LOSS:0.914---time:12.94
# Epoch:12---batch(6)训练集---ACC:75.00%---LOSS:0.579---time:12.36
# Epoch:12---batch(7)训练集---ACC:71.88%---LOSS:0.731---time:12.85
# Epoch:12---batch(8)训练集---ACC:90.62%---LOSS:0.521---time:12.55
# Epoch:12---batch(9)训练集---ACC:78.12%---LOSS:0.602---time:12.96
# Epoch:12---batch(10)训练集---ACC:78.12%---LOSS:0.536---time:12.52
# Epoch:12---batch(11)训练集---ACC:87.50%---LOSS:0.572---time:12.58
# Epoch:12---batch(12)训练集---ACC:90.62%---LOSS:0.414---time:12.88
# Epoch:12---batch(13)训练集---ACC:87.50%---LOSS:0.523---time:12.52
# Epoch:12---batch(14)训练集---ACC:68.75%---LOSS:0.690---time:12.48
# Epoch:12---batch(15)训练集---ACC:87.50%---LOSS:0.480---time:12.73
# Epoch:12---batch(16)训练集---ACC:78.12%---LOSS:0.578---time:12.86
# Epoch:12---batch(17)训练集---ACC:84.38%---LOSS:0.446---time:12.61
# Epoch:12---batch(18)训练集---ACC:93.75%---LOSS:0.324---time:12.62
# Epoch:12---batch(19)训练集---ACC:81.25%---LOSS:0.661---time:12.42
# Epoch:12---batch(20)训练集---ACC:90.62%---LOSS:0.324---time:13.04
# Epoch:12---batch(21)训练集---ACC:84.38%---LOSS:0.384---time:12.48
# Epoch:12---batch(22)训练集---ACC:78.12%---LOSS:0.851---time:12.55
# Epoch:12---batch(23)训练集---ACC:71.88%---LOSS:0.830---time:12.45
# Epoch:12---batch(24)训练集---ACC:81.25%---LOSS:0.760---time:13.06
# Epoch:12---batch(25)训练集---ACC:78.12%---LOSS:0.573---time:12.43
# Epoch:12---batch(26)训练集---ACC:75.00%---LOSS:0.966---time:13.06
# Epoch:12---batch(27)训练集---ACC:78.12%---LOSS:0.473---time:12.36
# Epoch:12---batch(28)训练集---ACC:68.75%---LOSS:0.743---time:13.01
# Epoch:12---batch(29)训练集---ACC:75.00%---LOSS:0.624---time:12.44
# Epoch:12---batch(30)训练集---ACC:71.88%---LOSS:0.666---time:13.04
# Epoch:12---batch(31)训练集---ACC:78.12%---LOSS:0.651---time:12.88
# Epoch:12---batch(32)训练集---ACC:78.12%---LOSS:0.692---time:13.03
# Epoch:12---batch(33)训练集---ACC:84.38%---LOSS:0.417---time:12.20
# Epoch:12---batch(34)训练集---ACC:75.00%---LOSS:0.614---time:12.37
# Epoch:12---batch(35)训练集---ACC:65.62%---LOSS:0.844---time:12.41
# Epoch:12---batch(36)训练集---ACC:81.25%---LOSS:0.486---time:12.47
# Epoch:12---batch(37)训练集---ACC:68.75%---LOSS:0.789---time:6.35
# 第12轮测试集准确率：69.00%....测试集Loss:1.1032736812319075
# Epoch:13---batch(0)训练集---ACC:81.25%---LOSS:0.505---time:12.50
# Epoch:13---batch(1)训练集---ACC:71.88%---LOSS:0.745---time:12.58
# Epoch:13---batch(2)训练集---ACC:75.00%---LOSS:0.674---time:12.34
# Epoch:13---batch(3)训练集---ACC:71.88%---LOSS:0.696---time:12.53
# Epoch:13---batch(4)训练集---ACC:87.50%---LOSS:0.604---time:12.17
# Epoch:13---batch(5)训练集---ACC:84.38%---LOSS:0.428---time:12.56
# Epoch:13---batch(6)训练集---ACC:75.00%---LOSS:0.910---time:12.61
# Epoch:13---batch(7)训练集---ACC:75.00%---LOSS:0.759---time:12.43
# Epoch:13---batch(8)训练集---ACC:87.50%---LOSS:0.435---time:12.37
# Epoch:13---batch(9)训练集---ACC:78.12%---LOSS:0.538---time:12.63
# Epoch:13---batch(10)训练集---ACC:65.62%---LOSS:0.861---time:12.44
# Epoch:13---batch(11)训练集---ACC:81.25%---LOSS:0.483---time:12.57
# Epoch:13---batch(12)训练集---ACC:81.25%---LOSS:0.628---time:12.58
# Epoch:13---batch(13)训练集---ACC:87.50%---LOSS:0.404---time:12.28
# Epoch:13---batch(14)训练集---ACC:84.38%---LOSS:0.372---time:12.25
# Epoch:13---batch(15)训练集---ACC:78.12%---LOSS:0.552---time:12.33
# Epoch:13---batch(16)训练集---ACC:84.38%---LOSS:0.554---time:12.46
# Epoch:13---batch(17)训练集---ACC:56.25%---LOSS:0.985---time:12.21
# Epoch:13---batch(18)训练集---ACC:81.25%---LOSS:0.714---time:12.13
# Epoch:13---batch(19)训练集---ACC:84.38%---LOSS:0.566---time:12.42
# Epoch:13---batch(20)训练集---ACC:78.12%---LOSS:0.476---time:13.27
# Epoch:13---batch(21)训练集---ACC:59.38%---LOSS:1.110---time:12.44
# Epoch:13---batch(22)训练集---ACC:71.88%---LOSS:0.617---time:12.37
# Epoch:13---batch(23)训练集---ACC:93.75%---LOSS:0.299---time:12.51
# Epoch:13---batch(24)训练集---ACC:84.38%---LOSS:0.402---time:12.61
# Epoch:13---batch(25)训练集---ACC:87.50%---LOSS:0.434---time:12.34
# Epoch:13---batch(26)训练集---ACC:78.12%---LOSS:1.035---time:12.42
# Epoch:13---batch(27)训练集---ACC:71.88%---LOSS:1.066---time:12.42
# Epoch:13---batch(28)训练集---ACC:71.88%---LOSS:0.737---time:12.28
# Epoch:13---batch(29)训练集---ACC:81.25%---LOSS:0.464---time:12.98
# Epoch:13---batch(30)训练集---ACC:78.12%---LOSS:0.807---time:12.76
# Epoch:13---batch(31)训练集---ACC:87.50%---LOSS:0.367---time:12.47
# Epoch:13---batch(32)训练集---ACC:75.00%---LOSS:0.756---time:12.29
# Epoch:13---batch(33)训练集---ACC:81.25%---LOSS:0.678---time:12.33
# Epoch:13---batch(34)训练集---ACC:62.50%---LOSS:0.980---time:12.58
# Epoch:13---batch(35)训练集---ACC:87.50%---LOSS:0.445---time:12.88
# Epoch:13---batch(36)训练集---ACC:81.25%---LOSS:0.751---time:12.48
# Epoch:13---batch(37)训练集---ACC:81.25%---LOSS:0.584---time:6.45
# 第13轮测试集准确率：70.50%....测试集Loss:1.1573000465120589
# Epoch:14---batch(0)训练集---ACC:87.50%---LOSS:0.455---time:12.84
# Epoch:14---batch(1)训练集---ACC:78.12%---LOSS:0.637---time:12.47
# Epoch:14---batch(2)训练集---ACC:90.62%---LOSS:0.544---time:12.57
# Epoch:14---batch(3)训练集---ACC:78.12%---LOSS:0.491---time:12.60
# Epoch:14---batch(4)训练集---ACC:84.38%---LOSS:0.344---time:12.60
# Epoch:14---batch(5)训练集---ACC:78.12%---LOSS:0.737---time:12.32
# Epoch:14---batch(6)训练集---ACC:75.00%---LOSS:0.715---time:12.50
# Epoch:14---batch(7)训练集---ACC:75.00%---LOSS:1.147---time:12.40
# Epoch:14---batch(8)训练集---ACC:78.12%---LOSS:0.742---time:12.43
# Epoch:14---batch(9)训练集---ACC:71.88%---LOSS:0.723---time:12.46
# Epoch:14---batch(10)训练集---ACC:75.00%---LOSS:0.722---time:12.66
# Epoch:14---batch(11)训练集---ACC:75.00%---LOSS:0.606---time:12.47
# Epoch:14---batch(12)训练集---ACC:81.25%---LOSS:0.628---time:12.71
# Epoch:14---batch(13)训练集---ACC:81.25%---LOSS:0.622---time:12.59
# Epoch:14---batch(14)训练集---ACC:81.25%---LOSS:0.582---time:12.45
# Epoch:14---batch(15)训练集---ACC:71.88%---LOSS:0.785---time:12.61
# Epoch:14---batch(16)训练集---ACC:87.50%---LOSS:0.442---time:12.64
# Epoch:14---batch(17)训练集---ACC:81.25%---LOSS:0.588---time:12.58
# Epoch:14---batch(18)训练集---ACC:90.62%---LOSS:0.429---time:12.23
# Epoch:14---batch(19)训练集---ACC:81.25%---LOSS:0.563---time:12.22
# Epoch:14---batch(20)训练集---ACC:78.12%---LOSS:0.507---time:12.46
# Epoch:14---batch(21)训练集---ACC:71.88%---LOSS:0.703---time:12.65
# Epoch:14---batch(22)训练集---ACC:81.25%---LOSS:0.689---time:12.58
# Epoch:14---batch(23)训练集---ACC:78.12%---LOSS:0.604---time:12.42
# Epoch:14---batch(24)训练集---ACC:78.12%---LOSS:0.869---time:12.68
# Epoch:14---batch(25)训练集---ACC:81.25%---LOSS:0.614---time:12.60
# Epoch:14---batch(26)训练集---ACC:68.75%---LOSS:0.763---time:12.39
# Epoch:14---batch(27)训练集---ACC:81.25%---LOSS:0.564---time:12.79
# Epoch:14---batch(28)训练集---ACC:78.12%---LOSS:0.671---time:12.56
# Epoch:14---batch(29)训练集---ACC:81.25%---LOSS:0.517---time:12.53
# Epoch:14---batch(30)训练集---ACC:81.25%---LOSS:0.614---time:12.63
# Epoch:14---batch(31)训练集---ACC:87.50%---LOSS:0.320---time:12.49
# Epoch:14---batch(32)训练集---ACC:75.00%---LOSS:0.653---time:12.51
# Epoch:14---batch(33)训练集---ACC:84.38%---LOSS:0.455---time:12.44
# Epoch:14---batch(34)训练集---ACC:78.12%---LOSS:0.913---time:12.66
# Epoch:14---batch(35)训练集---ACC:90.62%---LOSS:0.414---time:12.59
# Epoch:14---batch(36)训练集---ACC:75.00%---LOSS:0.924---time:12.40
# Epoch:14---batch(37)训练集---ACC:81.25%---LOSS:0.488---time:6.30
# 第14轮测试集准确率：71.50%....测试集Loss:1.1687833496502467
# Epoch:15---batch(0)训练集---ACC:75.00%---LOSS:0.485---time:12.59
# Epoch:15---batch(1)训练集---ACC:93.75%---LOSS:0.266---time:12.26
# Epoch:15---batch(2)训练集---ACC:71.88%---LOSS:0.618---time:12.13
# Epoch:15---batch(3)训练集---ACC:84.38%---LOSS:0.723---time:12.46
# Epoch:15---batch(4)训练集---ACC:78.12%---LOSS:0.625---time:12.56
# Epoch:15---batch(5)训练集---ACC:90.62%---LOSS:0.411---time:12.43
# Epoch:15---batch(6)训练集---ACC:75.00%---LOSS:0.986---time:12.17
# Epoch:15---batch(7)训练集---ACC:75.00%---LOSS:0.552---time:12.32
# Epoch:15---batch(8)训练集---ACC:87.50%---LOSS:0.692---time:12.34
# Epoch:15---batch(9)训练集---ACC:78.12%---LOSS:0.457---time:12.33
# Epoch:15---batch(10)训练集---ACC:87.50%---LOSS:0.431---time:12.53
# Epoch:15---batch(11)训练集---ACC:75.00%---LOSS:0.888---time:12.30
# Epoch:15---batch(12)训练集---ACC:81.25%---LOSS:0.541---time:12.42
# Epoch:15---batch(13)训练集---ACC:78.12%---LOSS:0.485---time:12.63
# Epoch:15---batch(14)训练集---ACC:93.75%---LOSS:0.294---time:12.31
# Epoch:15---batch(15)训练集---ACC:81.25%---LOSS:0.567---time:12.26
# Epoch:15---batch(16)训练集---ACC:71.88%---LOSS:0.534---time:12.49
# Epoch:15---batch(17)训练集---ACC:78.12%---LOSS:0.609---time:12.47
# Epoch:15---batch(18)训练集---ACC:71.88%---LOSS:0.701---time:12.63
# Epoch:15---batch(19)训练集---ACC:71.88%---LOSS:0.650---time:12.45
# Epoch:15---batch(20)训练集---ACC:78.12%---LOSS:0.615---time:12.47
# Epoch:15---batch(21)训练集---ACC:65.62%---LOSS:1.037---time:12.53
# Epoch:15---batch(22)训练集---ACC:68.75%---LOSS:0.707---time:12.67
# Epoch:15---batch(23)训练集---ACC:81.25%---LOSS:0.607---time:12.43
# Epoch:15---batch(24)训练集---ACC:84.38%---LOSS:0.404---time:12.55
# Epoch:15---batch(25)训练集---ACC:78.12%---LOSS:0.910---time:12.68
# Epoch:15---batch(26)训练集---ACC:84.38%---LOSS:0.670---time:12.51
# Epoch:15---batch(27)训练集---ACC:84.38%---LOSS:0.692---time:12.57
# Epoch:15---batch(28)训练集---ACC:78.12%---LOSS:0.984---time:12.34
# Epoch:15---batch(29)训练集---ACC:81.25%---LOSS:0.419---time:12.51
# Epoch:15---batch(30)训练集---ACC:84.38%---LOSS:0.600---time:12.56
# Epoch:15---batch(31)训练集---ACC:84.38%---LOSS:0.540---time:12.45
# Epoch:15---batch(32)训练集---ACC:75.00%---LOSS:0.749---time:12.54
# Epoch:15---batch(33)训练集---ACC:71.88%---LOSS:0.700---time:12.35
# Epoch:15---batch(34)训练集---ACC:75.00%---LOSS:0.760---time:12.57
# Epoch:15---batch(35)训练集---ACC:84.38%---LOSS:0.579---time:12.47
# Epoch:15---batch(36)训练集---ACC:87.50%---LOSS:0.431---time:12.30
# Epoch:15---batch(37)训练集---ACC:62.50%---LOSS:0.792---time:6.12
# 第15轮测试集准确率：67.00%....测试集Loss:1.1500085592269897
# Epoch:16---batch(0)训练集---ACC:75.00%---LOSS:0.615---time:12.48
# Epoch:16---batch(1)训练集---ACC:84.38%---LOSS:0.475---time:12.39
# Epoch:16---batch(2)训练集---ACC:84.38%---LOSS:0.555---time:12.33
# Epoch:16---batch(3)训练集---ACC:81.25%---LOSS:0.645---time:12.48
# Epoch:16---batch(4)训练集---ACC:90.62%---LOSS:0.343---time:12.51
# Epoch:16---batch(5)训练集---ACC:90.62%---LOSS:0.414---time:12.54
# Epoch:16---batch(6)训练集---ACC:75.00%---LOSS:0.944---time:12.43
# Epoch:16---batch(7)训练集---ACC:93.75%---LOSS:0.228---time:12.34
# Epoch:16---batch(8)训练集---ACC:65.62%---LOSS:0.812---time:12.47
# Epoch:16---batch(9)训练集---ACC:87.50%---LOSS:0.546---time:12.41
# Epoch:16---batch(10)训练集---ACC:81.25%---LOSS:0.602---time:12.59
# Epoch:16---batch(11)训练集---ACC:62.50%---LOSS:0.960---time:12.63
# Epoch:16---batch(12)训练集---ACC:87.50%---LOSS:0.394---time:12.45
# Epoch:16---batch(13)训练集---ACC:87.50%---LOSS:0.597---time:12.68
# Epoch:16---batch(14)训练集---ACC:78.12%---LOSS:0.687---time:12.33
# Epoch:16---batch(15)训练集---ACC:78.12%---LOSS:0.700---time:12.40
# Epoch:16---batch(16)训练集---ACC:81.25%---LOSS:0.771---time:12.53
# Epoch:16---batch(17)训练集---ACC:81.25%---LOSS:0.567---time:12.34
# Epoch:16---batch(18)训练集---ACC:87.50%---LOSS:0.468---time:12.56
# Epoch:16---batch(19)训练集---ACC:71.88%---LOSS:0.744---time:12.23
# Epoch:16---batch(20)训练集---ACC:81.25%---LOSS:0.505---time:12.17
# Epoch:16---batch(21)训练集---ACC:75.00%---LOSS:0.643---time:12.66
# Epoch:16---batch(22)训练集---ACC:68.75%---LOSS:0.802---time:12.53
# Epoch:16---batch(23)训练集---ACC:84.38%---LOSS:0.384---time:12.27
# Epoch:16---batch(24)训练集---ACC:81.25%---LOSS:0.474---time:12.62
# Epoch:16---batch(25)训练集---ACC:81.25%---LOSS:0.550---time:12.57
# Epoch:16---batch(26)训练集---ACC:75.00%---LOSS:0.582---time:12.62
# Epoch:16---batch(27)训练集---ACC:84.38%---LOSS:0.471---time:12.58
# Epoch:16---batch(28)训练集---ACC:71.88%---LOSS:1.176---time:12.47
# Epoch:16---batch(29)训练集---ACC:84.38%---LOSS:0.729---time:12.34
# Epoch:16---batch(30)训练集---ACC:81.25%---LOSS:0.824---time:12.47
# Epoch:16---batch(31)训练集---ACC:62.50%---LOSS:0.931---time:12.35
# Epoch:16---batch(32)训练集---ACC:81.25%---LOSS:0.635---time:12.44
# Epoch:16---batch(33)训练集---ACC:68.75%---LOSS:0.870---time:12.13
# Epoch:16---batch(34)训练集---ACC:87.50%---LOSS:0.517---time:12.60
# Epoch:16---batch(35)训练集---ACC:78.12%---LOSS:0.934---time:12.40
# Epoch:16---batch(36)训练集---ACC:90.62%---LOSS:0.398---time:12.27
# Epoch:16---batch(37)训练集---ACC:56.25%---LOSS:1.047---time:6.26
# 第16轮测试集准确率：73.00%....测试集Loss:1.1624958940914698
# Epoch:17---batch(0)训练集---ACC:75.00%---LOSS:0.736---time:12.33
# Epoch:17---batch(1)训练集---ACC:81.25%---LOSS:0.564---time:12.53
# Epoch:17---batch(2)训练集---ACC:81.25%---LOSS:0.525---time:12.48
# Epoch:17---batch(3)训练集---ACC:78.12%---LOSS:0.606---time:12.58
# Epoch:17---batch(4)训练集---ACC:87.50%---LOSS:0.438---time:12.53
# Epoch:17---batch(5)训练集---ACC:84.38%---LOSS:0.775---time:12.71
# Epoch:17---batch(6)训练集---ACC:90.62%---LOSS:0.297---time:12.64
# Epoch:17---batch(7)训练集---ACC:84.38%---LOSS:0.413---time:12.33
# Epoch:17---batch(8)训练集---ACC:81.25%---LOSS:0.564---time:12.53
# Epoch:17---batch(9)训练集---ACC:87.50%---LOSS:0.374---time:12.44
# Epoch:17---batch(10)训练集---ACC:65.62%---LOSS:1.091---time:12.58
# Epoch:17---batch(11)训练集---ACC:68.75%---LOSS:0.901---time:12.54
# Epoch:17---batch(12)训练集---ACC:84.38%---LOSS:0.490---time:12.41
# Epoch:17---batch(13)训练集---ACC:84.38%---LOSS:0.482---time:12.67
# Epoch:17---batch(14)训练集---ACC:90.62%---LOSS:0.336---time:12.45
# Epoch:17---batch(15)训练集---ACC:75.00%---LOSS:0.838---time:12.54
# Epoch:17---batch(16)训练集---ACC:84.38%---LOSS:0.561---time:12.13
# Epoch:17---batch(17)训练集---ACC:53.12%---LOSS:1.175---time:12.34
# Epoch:17---batch(18)训练集---ACC:84.38%---LOSS:0.465---time:12.55
# Epoch:17---batch(19)训练集---ACC:87.50%---LOSS:0.360---time:12.54
# Epoch:17---batch(20)训练集---ACC:81.25%---LOSS:0.740---time:12.52
# Epoch:17---batch(21)训练集---ACC:84.38%---LOSS:0.513---time:12.16
# Epoch:17---batch(22)训练集---ACC:75.00%---LOSS:0.731---time:12.41
# Epoch:17---batch(23)训练集---ACC:84.38%---LOSS:0.728---time:12.49
# Epoch:17---batch(24)训练集---ACC:65.62%---LOSS:0.959---time:12.39
# Epoch:17---batch(25)训练集---ACC:87.50%---LOSS:0.411---time:12.48
# Epoch:17---batch(26)训练集---ACC:68.75%---LOSS:0.899---time:12.61
# Epoch:17---batch(27)训练集---ACC:87.50%---LOSS:0.574---time:12.66
# Epoch:17---batch(28)训练集---ACC:71.88%---LOSS:0.550---time:12.40
# Epoch:17---batch(29)训练集---ACC:84.38%---LOSS:0.603---time:12.61
# Epoch:17---batch(30)训练集---ACC:84.38%---LOSS:0.528---time:12.61
# Epoch:17---batch(31)训练集---ACC:78.12%---LOSS:1.137---time:12.53
# Epoch:17---batch(32)训练集---ACC:71.88%---LOSS:0.823---time:12.43
# Epoch:17---batch(33)训练集---ACC:81.25%---LOSS:0.705---time:12.22
# Epoch:17---batch(34)训练集---ACC:84.38%---LOSS:0.400---time:12.37
# Epoch:17---batch(35)训练集---ACC:87.50%---LOSS:0.390---time:12.42
# Epoch:17---batch(36)训练集---ACC:71.88%---LOSS:0.765---time:12.51
# Epoch:17---batch(37)训练集---ACC:87.50%---LOSS:0.461---time:6.25
# 第17轮测试集准确率：69.50%....测试集Loss:1.2311944620949882
# Epoch:18---batch(0)训练集---ACC:78.12%---LOSS:0.696---time:12.55
# Epoch:18---batch(1)训练集---ACC:78.12%---LOSS:0.726---time:12.46
# Epoch:18---batch(2)训练集---ACC:71.88%---LOSS:1.095---time:12.34
# Epoch:18---batch(3)训练集---ACC:87.50%---LOSS:0.396---time:12.27
# Epoch:18---batch(4)训练集---ACC:84.38%---LOSS:0.668---time:12.51
# Epoch:18---batch(5)训练集---ACC:84.38%---LOSS:0.639---time:12.51
# Epoch:18---batch(6)训练集---ACC:75.00%---LOSS:0.739---time:12.34
# Epoch:18---batch(7)训练集---ACC:84.38%---LOSS:0.440---time:12.51
# Epoch:18---batch(8)训练集---ACC:78.12%---LOSS:0.620---time:12.38
# Epoch:18---batch(9)训练集---ACC:81.25%---LOSS:0.632---time:12.54
# Epoch:18---batch(10)训练集---ACC:81.25%---LOSS:0.505---time:12.62
# Epoch:18---batch(11)训练集---ACC:81.25%---LOSS:0.520---time:12.37
# Epoch:18---batch(12)训练集---ACC:81.25%---LOSS:0.563---time:12.41
# Epoch:18---batch(13)训练集---ACC:87.50%---LOSS:0.597---time:12.55
# Epoch:18---batch(14)训练集---ACC:75.00%---LOSS:0.505---time:12.55
# Epoch:18---batch(15)训练集---ACC:75.00%---LOSS:0.737---time:12.24
# Epoch:18---batch(16)训练集---ACC:81.25%---LOSS:0.526---time:12.59
# Epoch:18---batch(17)训练集---ACC:56.25%---LOSS:1.009---time:12.34
# Epoch:18---batch(18)训练集---ACC:93.75%---LOSS:0.485---time:12.30
# Epoch:18---batch(19)训练集---ACC:75.00%---LOSS:0.606---time:12.49
# Epoch:18---batch(20)训练集---ACC:81.25%---LOSS:0.640---time:12.27
# Epoch:18---batch(21)训练集---ACC:78.12%---LOSS:0.498---time:12.49
# Epoch:18---batch(22)训练集---ACC:84.38%---LOSS:0.442---time:12.31
# Epoch:18---batch(23)训练集---ACC:84.38%---LOSS:0.725---time:12.50
# Epoch:18---batch(24)训练集---ACC:81.25%---LOSS:0.707---time:12.35
# Epoch:18---batch(25)训练集---ACC:84.38%---LOSS:0.757---time:12.22
# Epoch:18---batch(26)训练集---ACC:75.00%---LOSS:0.634---time:12.54
# Epoch:18---batch(27)训练集---ACC:87.50%---LOSS:0.457---time:12.63
# Epoch:18---batch(28)训练集---ACC:87.50%---LOSS:0.505---time:12.45
# Epoch:18---batch(29)训练集---ACC:71.88%---LOSS:0.636---time:12.33
# Epoch:18---batch(30)训练集---ACC:81.25%---LOSS:0.403---time:12.58
# Epoch:18---batch(31)训练集---ACC:78.12%---LOSS:0.414---time:12.43
# Epoch:18---batch(32)训练集---ACC:84.38%---LOSS:0.397---time:12.41
# Epoch:18---batch(33)训练集---ACC:71.88%---LOSS:0.656---time:12.48
# Epoch:18---batch(34)训练集---ACC:75.00%---LOSS:0.823---time:12.41
# Epoch:18---batch(35)训练集---ACC:84.38%---LOSS:0.549---time:12.47
# Epoch:18---batch(36)训练集---ACC:75.00%---LOSS:0.782---time:12.34
# Epoch:18---batch(37)训练集---ACC:87.50%---LOSS:0.916---time:6.13
# 第18轮测试集准确率：70.00%....测试集Loss:1.169199866907937
# Epoch:19---batch(0)训练集---ACC:81.25%---LOSS:1.068---time:12.54
# Epoch:19---batch(1)训练集---ACC:87.50%---LOSS:0.480---time:12.48
# Epoch:19---batch(2)训练集---ACC:78.12%---LOSS:0.600---time:12.38
# Epoch:19---batch(3)训练集---ACC:81.25%---LOSS:0.470---time:12.27
# Epoch:19---batch(4)训练集---ACC:65.62%---LOSS:0.794---time:12.55
# Epoch:19---batch(5)训练集---ACC:84.38%---LOSS:0.504---time:12.18
# Epoch:19---batch(6)训练集---ACC:87.50%---LOSS:0.473---time:12.35
# Epoch:19---batch(7)训练集---ACC:90.62%---LOSS:0.260---time:12.70
# Epoch:19---batch(8)训练集---ACC:84.38%---LOSS:0.536---time:12.17
# Epoch:19---batch(9)训练集---ACC:81.25%---LOSS:0.600---time:12.58
# Epoch:19---batch(10)训练集---ACC:75.00%---LOSS:0.893---time:12.55
# Epoch:19---batch(11)训练集---ACC:62.50%---LOSS:1.308---time:12.38
# Epoch:19---batch(12)训练集---ACC:84.38%---LOSS:0.419---time:12.56
# Epoch:19---batch(13)训练集---ACC:90.62%---LOSS:0.385---time:12.65
# Epoch:19---batch(14)训练集---ACC:81.25%---LOSS:0.551---time:12.57
# Epoch:19---batch(15)训练集---ACC:81.25%---LOSS:0.513---time:12.56
# Epoch:19---batch(16)训练集---ACC:78.12%---LOSS:0.711---time:12.35
# Epoch:19---batch(17)训练集---ACC:75.00%---LOSS:0.576---time:12.52
# Epoch:19---batch(18)训练集---ACC:84.38%---LOSS:0.724---time:12.52
# Epoch:19---batch(19)训练集---ACC:90.62%---LOSS:0.342---time:12.27
# Epoch:19---batch(20)训练集---ACC:84.38%---LOSS:0.473---time:12.28
# Epoch:19---batch(21)训练集---ACC:75.00%---LOSS:0.558---time:12.25
# Epoch:19---batch(22)训练集---ACC:75.00%---LOSS:0.455---time:12.52
# Epoch:19---batch(23)训练集---ACC:78.12%---LOSS:0.589---time:12.43
# Epoch:19---batch(24)训练集---ACC:71.88%---LOSS:0.614---time:12.17
# Epoch:19---batch(25)训练集---ACC:65.62%---LOSS:1.089---time:12.57
# Epoch:19---batch(26)训练集---ACC:81.25%---LOSS:0.765---time:12.50
# Epoch:19---batch(27)训练集---ACC:84.38%---LOSS:0.469---time:12.42
# Epoch:19---batch(28)训练集---ACC:84.38%---LOSS:0.503---time:12.52
# Epoch:19---batch(29)训练集---ACC:81.25%---LOSS:0.578---time:12.32
# Epoch:19---batch(30)训练集---ACC:81.25%---LOSS:0.549---time:12.52
# Epoch:19---batch(31)训练集---ACC:78.12%---LOSS:0.791---time:12.56
# Epoch:19---batch(32)训练集---ACC:81.25%---LOSS:0.641---time:12.57
# Epoch:19---batch(33)训练集---ACC:75.00%---LOSS:0.711---time:12.46
# Epoch:19---batch(34)训练集---ACC:81.25%---LOSS:0.615---time:12.54
# Epoch:19---batch(35)训练集---ACC:75.00%---LOSS:0.671---time:12.53
# Epoch:19---batch(36)训练集---ACC:87.50%---LOSS:0.388---time:12.60
# Epoch:19---batch(37)训练集---ACC:87.50%---LOSS:0.324---time:6.23
# 第19轮测试集准确率：69.50%....测试集Loss:1.2178289890289307

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 经典与传统的对比
# 加载经典
# Classical_Train_data = pd.read_csv('/home/WUYING_986418966_1288354473/Desktop/QCNN/src/QCNN-FC/QTCNN-MNIST/640_train.csv')
# Classical_Val_data = pd.read_csv('/home/WUYING_986418966_1288354473/Desktop/QCNN/src/QCNN-FC/QTCNN-MNIST/2091_val.csv')

# Classical_Train_data_acc = Classical_Train_data[['Train_acc']]
# Classical_Train_data_loss = Classical_Train_data[['Train_loss']]

# Classical_Val_data_acc = Classical_Val_data[['Val_acc']]
# Classical_Val_data_loss = Classical_Val_data[['Val_loss']]
def result(acc,loss,plt1_title,plt2_title,title):     # 合并结果
    #绘图
    plt.xticks(np.arange(0,20,1))
    plt.plot(acc,label=plt1_title)
    plt.plot(loss,label=plt2_title)
    plt.title(title) 
    plt.xlabel('epoch')
    plt.ylabel('probability')
    plt.legend()   #显示标签
    plt.show()
# E:\Test\VsCode_Test\Jupyter notebook\Tensorcircuit\result\MNIST\s=1\7049_val.csv
# 加载qcnn
Qcnn_Train_data = pd.read_csv('E:\\Test\\VsCode_Test\\Jupyter notebook\\Tensorcircuit\\result\MNIST\\s=1\\475_train.csv')
Qcnn_Val_data = pd.read_csv('E:\\Test\\VsCode_Test\\Jupyter notebook\\Tensorcircuit\\result\MNIST\\s=1\\7049_val.csv')

Qcnn_Train_data_acc = Qcnn_Train_data[['Train_acc']]
Qcnn_Train_data_loss = Qcnn_Train_data[['Train_loss']]

Qcnn_Val_data_acc = Qcnn_Val_data[['Val_acc']]
Qcnn_Val_data_loss = Qcnn_Val_data[['Val_loss']]

# 损失值比较
result(Qcnn_Train_data_loss,Qcnn_Val_data_loss,'Train_set','Val_set','Loss')
# 准确率比较
result(Qcnn_Train_data_acc,Qcnn_Val_data_acc,'Train_set','Val_set','ACC')
