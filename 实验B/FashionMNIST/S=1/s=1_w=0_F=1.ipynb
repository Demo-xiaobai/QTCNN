# %%
# %%
import tensorcircuit as tc
import pennylane as qml
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split,Subset
import random
import os
import time
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F
import numpy as np
import csv
import tensorflow as tf


data_path = 'E:\\Test\\VsCode_Test\\Jupyter notebook\\zemp\\xLw\\data'

val_num = 200
data_num =  1200           # 需要划分的数据集大小
epochs = 20                 # 迭代轮次数
batch_size = 32

K = tc.set_backend("tensorflow")
# 归一化处理
def trans(x):
    x = np.array(x)
    x = x/255.0
    # print(x.shape)    
    return torch.from_numpy(x).float()  # 将 NumPy 数组 x 转换为 PyTorch 张量

transform = transforms.Compose([
    transforms.Resize((14, 14)),                # 将图片缩小为 14x14
    transforms.Lambda(lambda x:trans(x))
])

# 加载MNIST数据集 28X28X1   10类别   
trainset = torchvision.datasets.FashionMNIST(root=data_path, train=True,
                                        download=False, transform=transform)
testset = torchvision.datasets.FashionMNIST(root=data_path, train=False,
                                        download=False, transform=transform)

# 随机抽取训练集 data_num 张图片作为子集
subset_indices = random.sample(range(len(trainset)), k=data_num)
train_subset = Subset(trainset, subset_indices)

# 随机抽取测试集 data_num 张图片作为子集
subset_val = random.sample(range(len(testset)), k=val_num)
val_subset = Subset(testset, subset_val)

# 加载测试集
trainloader = torch.utils.data.DataLoader(train_subset, batch_size=batch_size,  # type: ignore
                                          shuffle=True)
testloader = torch.utils.data.DataLoader(val_subset, batch_size=batch_size,    # type: ignore
                                         shuffle=False)

# %%
n = 4
nlayers = 1


# 我们定义量子函数，
# 注意这个函数是在 tensorflow 上运行的
def qpred(x, weights):
    c = tc.Circuit(n)
    for i in range(n):
        c.h(i)
        c.ry(i,theta=x[i]*weights[i])
    for i in range(n):
        c.crx(i,(i+1)%4,theta=weights[i+4])
    return [K.real(c.expectation([tc.gates.z(), [i]])) for i in range(n)]

# %%
qpred_vmap = K.vmap(qpred, vectorized_argnums=0)        # `qpred_vmap` 是一个具有向量化能力的 TensorFlow 函数
qpred_batch = tc.interfaces.torch_interface(qpred_vmap, jit=True) # 我们进一步将函数包装为 PyTorch 函数

# %%
class QuantumNetV2(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.q_weights = torch.nn.Parameter(torch.randn([n*2]))
        self.stride = 1

    def forward(self, inputs):
        kernel_size = 2
        
        # 使用转置卷积进行上采样
        padding_size = kernel_size - 1                  # 1 先进行填充
        padd_img = nn.functional.pad(inputs,(padding_size,padding_size,padding_size,padding_size),mode='constant',value=0)
        # padding_img.size()=16
        bs, ch , h , w = padd_img.size()                #    h=16

        h_out = self.stride*(h-1)+kernel_size           #   （14-1）+ 2 = 15
        w_out = self.stride*(w-1)+kernel_size           #   （14-1）+ 2 = 15
        out = torch.zeros((bs,4, h_out, w_out))
        for b in range(bs):
                for j in range(0, h_out-padding_size-1, self.stride):
                    for k in range(0, w_out-padding_size-1, self.stride):
                        # print(f'padd_img[b, 0, j, k]={padd_img[b, 0, j, k].shape}')
                        t1 = padd_img[b, 0, j, k]        
                        t2 = padd_img[b, 0, j, k + 1]
                        t3 = padd_img[b, 0, j + 1, k]    
                        t4 = padd_img[b, 0, j + 1, k + 1]

                        temp = torch.Tensor([t1,t2,t3,t4]) # 
                        temp = temp.view(1,4)

                        # temp = torch.unsqueeze(temp, 0)      
                        q_results = qpred_batch(temp, self.q_weights)     
                        for c in range(4):
                            out[b, c,j // kernel_size, k // kernel_size] = q_results[c]
        return out

# %%
# 经典CNNmodel 可进行修改
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
            
        # Quantum layer 1
        self.conv1 = QuantumNetV2()
        self.relu1 = nn.ReLU()
        self.batch1 = nn.BatchNorm2d(4)  # 4
                
        # Fully-Connected layer 2
        self.fc2 = nn.Linear(1156,10)
                
    def forward(self, x):

        # qconv layer 1
        out = self.conv1(x)                 
        out = self.relu1(out)   
        out = self.batch1(out)
        
        #Flatten拉平操作
        out = out.view(out.size(0),-1)      # print(f'-----拉平后的维度是--{out.shape}') #  torch.Size([64, 576])
        
        #FC 第二层
        out = self.fc2(out)
        return F.log_softmax(out,dim = 1)

# %%
model = CNNModel()
loss_fun = nn.CrossEntropyLoss()
opt = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
# 准确率计算
def accuracy(output,labels):
    prediction = torch.max(output.data,1)[1]
    rights = prediction.eq(labels.data.view_as(prediction)).sum()
    return rights,len(labels)

# 绘制训练结果
def draw_result(accs,losses,title):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14, 6))   # subplots创建1行 2列的子图
    
    ax1.plot(losses) 
    ax1.set_title(title+" Loss")
    ax1.set_xlabel("Steps")
    ax1.set_ylabel("Loss")
    
    ax2.plot(accs)
    ax2.set_title(title+" Accuracy")
    ax2.set_xlabel("Steps")
    ax2.set_ylabel("Accuracy")

# %%
def train(epochs,model,loss_fun,opt,train_loader,test_loader):
    train_accuracy = []             # 训练集准确率
    train_loss = []

    val_accuracy = []               # 验证集准确率
    val_loss = []
    for epoch in range(epochs):
                ### 训练模块
        train_total_accuracy = 0    # 训练集每epoch（18个batch的和）的准确率
        train_total_loss = 0
        for batch_idx,(data,labels) in enumerate(train_loader):
            t2 = time.time()
            data = data.view(data.shape[0],1, data.shape[1], data.shape[2])
            
            model.train()					    # 1 模型训练       
            output = model(data)			    # 2 模型输出
            # print(f'output.shape is {output.shape}')    # output.shape is torch.Size([64, 4, 17, 17])
            # print(f'labels.shape is {labels.shape}')    # labels.shape is torch.Size([64])
            loss = loss_fun(output,labels)	    # 3 计算损失

            opt.zero_grad()					    # 4 梯度清零
            loss.backward() 				    # 5 开始反向传播
            opt.step()                          # 6 梯度更新
            
            # 计算准确率
            accuracy_count, total_count = accuracy(output,labels)
            accuracy_rate = accuracy_count / total_count  # 计算准确率（预测正确的样本数除以总样本数）

            train_total_accuracy += accuracy_count
            train_total_loss +=loss.item()

            batch_time = time.time()-t2
            print(f'Epoch:{epoch}---batch({batch_idx})训练集---ACC:{accuracy_rate:.2%}---LOSS:{loss.item():.3f}---time:{batch_time:.2f}')        
        
        train_total_loss /= batch_idx+1
        train_accuracy.append(train_total_accuracy/len(train_subset))   # 保存1轮的数据 len(train_accuracy)
        train_loss.append(train_total_loss)
### 验证模块
        total_acc = 0
        total_test_loss = 0
        model.eval()
        with torch.no_grad():# 进行评测的时候网络不更新梯度
            for step,(data,target) in enumerate(test_loader):
                data = data.view(data.shape[0],1, data.shape[1], data.shape[2])            # 调整维度一致
                outputs = model(data)
                losses = loss_fun(outputs,target)                               # 计算损失

                accuracy_count, total_count = accuracy(outputs,target)          # 计算准确率
                accuracy_rate = accuracy_count / total_count                    # 计算准确率（预测正确的样本数除以总样本数）

                total_acc += accuracy_count
                total_test_loss+=losses.item()

        total_test_loss /= step + 1
        val_accuracy.append((total_acc/len(val_subset)))
        val_loss.append(total_test_loss)
        print(f'第{epoch}轮测试集准确率：{total_acc/len(val_subset):.2%}....测试集Loss:{total_test_loss}')
    
    ### 画出训练结果图 ##############
    draw_result(train_accuracy,train_loss,"Train")
    draw_result(val_accuracy,val_loss,"Val")
    
    ####  训练的结果写入文件   ##############
    with open(str(random.randint(100,999))+"_train.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Train_loss','Train_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, train_loss[i], train_accuracy[i].numpy()])
    
    #### 测试的结果写入文件  ##############
    with open(str(random.randint(1000,9999))+"_val.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Val_loss','Val_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, val_loss[i], val_accuracy[i].numpy()])

    ### 保存训练的结果
    # Loss0 = torch.tensor(save_train_loss)
    # torch.save(Loss0,'E:\\Test\\VsCode_Test\\Python\\xlw\\test1\\lw2\\epoch_{}'.format(epochs))
    return model, train_accuracy,train_loss


model, train_accuracy,train_loss = train(epochs,model,loss_fun,opt,trainloader,testloader)
# Out:
# Epoch:0---batch(0)训练集---ACC:15.62%---LOSS:2.527---time:27.31
# Epoch:0---batch(1)训练集---ACC:12.50%---LOSS:4.910---time:14.43
# Epoch:0---batch(2)训练集---ACC:18.75%---LOSS:4.331---time:13.65
# Epoch:0---batch(3)训练集---ACC:43.75%---LOSS:1.966---time:14.48
# Epoch:0---batch(4)训练集---ACC:53.12%---LOSS:1.366---time:13.61
# Epoch:0---batch(5)训练集---ACC:50.00%---LOSS:1.794---time:16.01
# Epoch:0---batch(6)训练集---ACC:40.62%---LOSS:1.831---time:14.70
# Epoch:0---batch(7)训练集---ACC:34.38%---LOSS:1.607---time:13.52
# Epoch:0---batch(8)训练集---ACC:50.00%---LOSS:1.412---time:12.91
# Epoch:0---batch(9)训练集---ACC:53.12%---LOSS:1.462---time:14.79
# Epoch:0---batch(10)训练集---ACC:50.00%---LOSS:2.090---time:12.46
# Epoch:0---batch(11)训练集---ACC:65.62%---LOSS:0.965---time:11.81
# Epoch:0---batch(12)训练集---ACC:56.25%---LOSS:1.228---time:11.94
# Epoch:0---batch(13)训练集---ACC:68.75%---LOSS:0.833---time:11.19
# Epoch:0---batch(14)训练集---ACC:65.62%---LOSS:1.067---time:11.33
# Epoch:0---batch(15)训练集---ACC:68.75%---LOSS:0.870---time:11.12
# Epoch:0---batch(16)训练集---ACC:59.38%---LOSS:1.918---time:11.33
# Epoch:0---batch(17)训练集---ACC:62.50%---LOSS:1.321---time:13.25
# Epoch:0---batch(18)训练集---ACC:65.62%---LOSS:1.244---time:12.69
# Epoch:0---batch(19)训练集---ACC:68.75%---LOSS:1.027---time:23.40
# Epoch:0---batch(20)训练集---ACC:71.88%---LOSS:0.730---time:18.40
# Epoch:0---batch(21)训练集---ACC:71.88%---LOSS:0.664---time:12.44
# Epoch:0---batch(22)训练集---ACC:62.50%---LOSS:0.838---time:11.84
# Epoch:0---batch(23)训练集---ACC:65.62%---LOSS:0.895---time:12.55
# Epoch:0---batch(24)训练集---ACC:59.38%---LOSS:0.912---time:11.58
# Epoch:0---batch(25)训练集---ACC:62.50%---LOSS:0.759---time:11.26
# Epoch:0---batch(26)训练集---ACC:65.62%---LOSS:0.647---time:11.40
# Epoch:0---batch(27)训练集---ACC:81.25%---LOSS:0.794---time:11.28
# Epoch:0---batch(28)训练集---ACC:59.38%---LOSS:1.190---time:12.13
# Epoch:0---batch(29)训练集---ACC:59.38%---LOSS:0.938---time:15.14
# Epoch:0---batch(30)训练集---ACC:65.62%---LOSS:0.986---time:17.04
# Epoch:0---batch(31)训练集---ACC:75.00%---LOSS:0.775---time:17.14
# Epoch:0---batch(32)训练集---ACC:68.75%---LOSS:1.316---time:16.83
# Epoch:0---batch(33)训练集---ACC:68.75%---LOSS:1.014---time:16.80
# Epoch:0---batch(34)训练集---ACC:62.50%---LOSS:0.899---time:16.95
# Epoch:0---batch(35)训练集---ACC:78.12%---LOSS:0.662---time:16.83
# Epoch:0---batch(36)训练集---ACC:71.88%---LOSS:1.363---time:16.86
# Epoch:0---batch(37)训练集---ACC:87.50%---LOSS:0.413---time:8.40
# 第0轮测试集准确率：66.50%....测试集Loss:0.9707074335643223
# Epoch:1---batch(0)训练集---ACC:75.00%---LOSS:0.627---time:12.54
# Epoch:1---batch(1)训练集---ACC:71.88%---LOSS:0.770---time:12.18
# Epoch:1---batch(2)训练集---ACC:81.25%---LOSS:0.619---time:11.88
# Epoch:1---batch(3)训练集---ACC:81.25%---LOSS:0.790---time:17.27
# Epoch:1---batch(4)训练集---ACC:81.25%---LOSS:0.595---time:17.06
# Epoch:1---batch(5)训练集---ACC:84.38%---LOSS:0.695---time:15.34
# Epoch:1---batch(6)训练集---ACC:53.12%---LOSS:1.126---time:14.43
# Epoch:1---batch(7)训练集---ACC:96.88%---LOSS:0.267---time:14.38
# Epoch:1---batch(8)训练集---ACC:81.25%---LOSS:0.882---time:14.37
# Epoch:1---batch(9)训练集---ACC:78.12%---LOSS:0.648---time:14.36
# Epoch:1---batch(10)训练集---ACC:78.12%---LOSS:0.587---time:15.42
# Epoch:1---batch(11)训练集---ACC:62.50%---LOSS:0.835---time:23.16
# Epoch:1---batch(12)训练集---ACC:71.88%---LOSS:1.161---time:27.79
# Epoch:1---batch(13)训练集---ACC:59.38%---LOSS:1.441---time:28.26
# Epoch:1---batch(14)训练集---ACC:75.00%---LOSS:0.721---time:25.36
# Epoch:1---batch(15)训练集---ACC:78.12%---LOSS:0.741---time:24.64
# Epoch:1---batch(16)训练集---ACC:62.50%---LOSS:1.056---time:25.45
# Epoch:1---batch(17)训练集---ACC:65.62%---LOSS:1.016---time:25.65
# Epoch:1---batch(18)训练集---ACC:62.50%---LOSS:0.803---time:17.81
# Epoch:1---batch(19)训练集---ACC:81.25%---LOSS:0.559---time:17.99
# Epoch:1---batch(20)训练集---ACC:71.88%---LOSS:0.854---time:18.61
# Epoch:1---batch(21)训练集---ACC:75.00%---LOSS:0.788---time:20.91
# Epoch:1---batch(22)训练集---ACC:81.25%---LOSS:0.448---time:17.21
# Epoch:1---batch(23)训练集---ACC:65.62%---LOSS:0.751---time:16.93
# Epoch:1---batch(24)训练集---ACC:81.25%---LOSS:0.693---time:14.06
# Epoch:1---batch(25)训练集---ACC:84.38%---LOSS:0.460---time:11.62
# Epoch:1---batch(26)训练集---ACC:65.62%---LOSS:1.041---time:15.28
# Epoch:1---batch(27)训练集---ACC:81.25%---LOSS:0.571---time:12.14
# Epoch:1---batch(28)训练集---ACC:71.88%---LOSS:0.712---time:11.54
# Epoch:1---batch(29)训练集---ACC:78.12%---LOSS:0.435---time:11.81
# Epoch:1---batch(30)训练集---ACC:68.75%---LOSS:1.254---time:12.63
# Epoch:1---batch(31)训练集---ACC:84.38%---LOSS:0.582---time:16.10
# Epoch:1---batch(32)训练集---ACC:84.38%---LOSS:0.431---time:16.46
# Epoch:1---batch(33)训练集---ACC:84.38%---LOSS:0.553---time:17.14
# Epoch:1---batch(34)训练集---ACC:75.00%---LOSS:0.585---time:16.91
# Epoch:1---batch(35)训练集---ACC:84.38%---LOSS:0.467---time:16.53
# Epoch:1---batch(36)训练集---ACC:87.50%---LOSS:0.455---time:16.61
# Epoch:1---batch(37)训练集---ACC:68.75%---LOSS:0.514---time:8.48
# 第1轮测试集准确率：71.50%....测试集Loss:0.9464784392288753
# Epoch:2---batch(0)训练集---ACC:81.25%---LOSS:0.510---time:12.48
# Epoch:2---batch(1)训练集---ACC:75.00%---LOSS:0.883---time:11.99
# Epoch:2---batch(2)训练集---ACC:84.38%---LOSS:0.756---time:13.10
# Epoch:2---batch(3)训练集---ACC:71.88%---LOSS:0.845---time:14.32
# Epoch:2---batch(4)训练集---ACC:84.38%---LOSS:0.620---time:12.66
# Epoch:2---batch(5)训练集---ACC:75.00%---LOSS:0.465---time:13.24
# Epoch:2---batch(6)训练集---ACC:81.25%---LOSS:0.502---time:11.99
# Epoch:2---batch(7)训练集---ACC:78.12%---LOSS:0.449---time:12.17
# Epoch:2---batch(8)训练集---ACC:59.38%---LOSS:1.020---time:12.15
# Epoch:2---batch(9)训练集---ACC:78.12%---LOSS:0.493---time:12.25
# Epoch:2---batch(10)训练集---ACC:87.50%---LOSS:0.361---time:14.12
# Epoch:2---batch(11)训练集---ACC:75.00%---LOSS:0.472---time:15.31
# Epoch:2---batch(12)训练集---ACC:87.50%---LOSS:0.485---time:12.14
# Epoch:2---batch(13)训练集---ACC:90.62%---LOSS:0.319---time:12.47
# Epoch:2---batch(14)训练集---ACC:75.00%---LOSS:0.867---time:13.00
# Epoch:2---batch(15)训练集---ACC:81.25%---LOSS:0.516---time:12.77
# Epoch:2---batch(16)训练集---ACC:62.50%---LOSS:0.689---time:13.50
# Epoch:2---batch(17)训练集---ACC:81.25%---LOSS:0.421---time:12.65
# Epoch:2---batch(18)训练集---ACC:81.25%---LOSS:0.423---time:12.62
# Epoch:2---batch(19)训练集---ACC:78.12%---LOSS:0.499---time:13.14
# Epoch:2---batch(20)训练集---ACC:78.12%---LOSS:0.390---time:13.13
# Epoch:2---batch(21)训练集---ACC:78.12%---LOSS:0.512---time:13.08
# Epoch:2---batch(22)训练集---ACC:71.88%---LOSS:0.831---time:12.75
# Epoch:2---batch(23)训练集---ACC:84.38%---LOSS:0.502---time:12.62
# Epoch:2---batch(24)训练集---ACC:87.50%---LOSS:0.540---time:12.75
# Epoch:2---batch(25)训练集---ACC:81.25%---LOSS:0.455---time:12.70
# Epoch:2---batch(26)训练集---ACC:81.25%---LOSS:0.555---time:14.34
# Epoch:2---batch(27)训练集---ACC:59.38%---LOSS:0.866---time:12.80
# Epoch:2---batch(28)训练集---ACC:84.38%---LOSS:0.741---time:12.99
# Epoch:2---batch(29)训练集---ACC:81.25%---LOSS:0.682---time:18.22
# Epoch:2---batch(30)训练集---ACC:78.12%---LOSS:0.452---time:15.64
# Epoch:2---batch(31)训练集---ACC:78.12%---LOSS:0.589---time:26.16
# Epoch:2---batch(32)训练集---ACC:87.50%---LOSS:0.466---time:22.90
# Epoch:2---batch(33)训练集---ACC:62.50%---LOSS:0.947---time:34.35
# Epoch:2---batch(34)训练集---ACC:87.50%---LOSS:0.476---time:17.11
# Epoch:2---batch(35)训练集---ACC:75.00%---LOSS:0.587---time:16.02
# Epoch:2---batch(36)训练集---ACC:78.12%---LOSS:0.689---time:16.15
# Epoch:2---batch(37)训练集---ACC:68.75%---LOSS:0.757---time:7.86
# 第2轮测试集准确率：73.50%....测试集Loss:0.8052333508219037
# Epoch:3---batch(0)训练集---ACC:81.25%---LOSS:0.456---time:31.32
# Epoch:3---batch(1)训练集---ACC:90.62%---LOSS:0.437---time:29.73
# Epoch:3---batch(2)训练集---ACC:90.62%---LOSS:0.404---time:21.08
# Epoch:3---batch(3)训练集---ACC:78.12%---LOSS:0.426---time:17.94
# Epoch:3---batch(4)训练集---ACC:84.38%---LOSS:0.527---time:18.48
# Epoch:3---batch(5)训练集---ACC:75.00%---LOSS:0.692---time:16.98
# Epoch:3---batch(6)训练集---ACC:78.12%---LOSS:0.616---time:17.97
# Epoch:3---batch(7)训练集---ACC:78.12%---LOSS:0.539---time:17.62
# Epoch:3---batch(8)训练集---ACC:90.62%---LOSS:0.382---time:15.51
# Epoch:3---batch(9)训练集---ACC:87.50%---LOSS:0.370---time:15.41
# Epoch:3---batch(10)训练集---ACC:84.38%---LOSS:0.406---time:17.10
# Epoch:3---batch(11)训练集---ACC:78.12%---LOSS:0.587---time:19.94
# Epoch:3---batch(12)训练集---ACC:65.62%---LOSS:0.730---time:17.54
# Epoch:3---batch(13)训练集---ACC:68.75%---LOSS:0.783---time:16.39
# Epoch:3---batch(14)训练集---ACC:81.25%---LOSS:0.682---time:16.98
# Epoch:3---batch(15)训练集---ACC:81.25%---LOSS:0.600---time:16.73
# Epoch:3---batch(16)训练集---ACC:90.62%---LOSS:0.290---time:15.30
# Epoch:3---batch(17)训练集---ACC:84.38%---LOSS:0.435---time:14.56
# Epoch:3---batch(18)训练集---ACC:81.25%---LOSS:0.719---time:14.35
# Epoch:3---batch(19)训练集---ACC:87.50%---LOSS:0.357---time:27.59
# Epoch:3---batch(20)训练集---ACC:84.38%---LOSS:0.516---time:31.82
# Epoch:3---batch(21)训练集---ACC:84.38%---LOSS:0.454---time:25.10
# Epoch:3---batch(22)训练集---ACC:81.25%---LOSS:0.472---time:27.00
# Epoch:3---batch(23)训练集---ACC:75.00%---LOSS:1.007---time:29.92
# Epoch:3---batch(24)训练集---ACC:78.12%---LOSS:0.808---time:23.23
# Epoch:3---batch(25)训练集---ACC:84.38%---LOSS:0.519---time:15.20
# Epoch:3---batch(26)训练集---ACC:93.75%---LOSS:0.375---time:14.73
# Epoch:3---batch(27)训练集---ACC:87.50%---LOSS:0.482---time:15.29
# Epoch:3---batch(28)训练集---ACC:75.00%---LOSS:0.670---time:15.75
# Epoch:3---batch(29)训练集---ACC:75.00%---LOSS:0.637---time:15.47
# Epoch:3---batch(30)训练集---ACC:81.25%---LOSS:0.832---time:15.38
# Epoch:3---batch(31)训练集---ACC:71.88%---LOSS:0.756---time:13.59
# Epoch:3---batch(32)训练集---ACC:81.25%---LOSS:0.464---time:13.46
# Epoch:3---batch(33)训练集---ACC:65.62%---LOSS:0.974---time:17.84
# Epoch:3---batch(34)训练集---ACC:68.75%---LOSS:0.942---time:14.56
# Epoch:3---batch(35)训练集---ACC:78.12%---LOSS:0.672---time:15.91
# Epoch:3---batch(36)训练集---ACC:75.00%---LOSS:0.974---time:23.17
# Epoch:3---batch(37)训练集---ACC:87.50%---LOSS:0.432---time:14.29
# 第3轮测试集准确率：73.50%....测试集Loss:0.9073615159307208
# Epoch:4---batch(0)训练集---ACC:90.62%---LOSS:0.405---time:17.27
# Epoch:4---batch(1)训练集---ACC:71.88%---LOSS:0.630---time:27.74
# Epoch:4---batch(2)训练集---ACC:90.62%---LOSS:0.317---time:26.33
# Epoch:4---batch(3)训练集---ACC:81.25%---LOSS:0.467---time:21.52
# Epoch:4---batch(4)训练集---ACC:84.38%---LOSS:0.397---time:22.49
# Epoch:4---batch(5)训练集---ACC:93.75%---LOSS:0.280---time:16.30
# Epoch:4---batch(6)训练集---ACC:84.38%---LOSS:0.382---time:16.47
# Epoch:4---batch(7)训练集---ACC:75.00%---LOSS:1.167---time:21.29
# Epoch:4---batch(8)训练集---ACC:84.38%---LOSS:0.581---time:20.13
# Epoch:4---batch(9)训练集---ACC:78.12%---LOSS:0.535---time:16.84
# Epoch:4---batch(10)训练集---ACC:81.25%---LOSS:0.628---time:15.29
# Epoch:4---batch(11)训练集---ACC:68.75%---LOSS:0.940---time:15.14
# Epoch:4---batch(12)训练集---ACC:78.12%---LOSS:0.697---time:15.13
# Epoch:4---batch(13)训练集---ACC:87.50%---LOSS:0.421---time:15.37
# Epoch:4---batch(14)训练集---ACC:81.25%---LOSS:0.460---time:18.10
# Epoch:4---batch(15)训练集---ACC:81.25%---LOSS:0.451---time:16.98
# Epoch:4---batch(16)训练集---ACC:81.25%---LOSS:0.464---time:21.94
# Epoch:4---batch(17)训练集---ACC:59.38%---LOSS:0.944---time:17.35
# Epoch:4---batch(18)训练集---ACC:59.38%---LOSS:1.170---time:18.35
# Epoch:4---batch(19)训练集---ACC:78.12%---LOSS:0.619---time:16.36
# Epoch:4---batch(20)训练集---ACC:75.00%---LOSS:0.647---time:14.84
# Epoch:4---batch(21)训练集---ACC:71.88%---LOSS:0.618---time:18.12
# Epoch:4---batch(22)训练集---ACC:68.75%---LOSS:0.966---time:17.76
# Epoch:4---batch(23)训练集---ACC:81.25%---LOSS:0.449---time:22.43
# Epoch:4---batch(24)训练集---ACC:56.25%---LOSS:1.030---time:27.20
# Epoch:4---batch(25)训练集---ACC:68.75%---LOSS:0.944---time:28.10
# Epoch:4---batch(26)训练集---ACC:75.00%---LOSS:0.693---time:27.28
# Epoch:4---batch(27)训练集---ACC:78.12%---LOSS:0.600---time:24.79
# Epoch:4---batch(28)训练集---ACC:81.25%---LOSS:0.675---time:32.91
# Epoch:4---batch(29)训练集---ACC:71.88%---LOSS:1.025---time:23.59
# Epoch:4---batch(30)训练集---ACC:75.00%---LOSS:0.611---time:17.06
# Epoch:4---batch(31)训练集---ACC:78.12%---LOSS:0.924---time:16.84
# Epoch:4---batch(32)训练集---ACC:84.38%---LOSS:0.774---time:16.87
# Epoch:4---batch(33)训练集---ACC:78.12%---LOSS:0.682---time:17.84
# Epoch:4---batch(34)训练集---ACC:78.12%---LOSS:0.480---time:24.48
# Epoch:4---batch(35)训练集---ACC:78.12%---LOSS:0.672---time:19.62
# Epoch:4---batch(36)训练集---ACC:68.75%---LOSS:0.638---time:14.05
# Epoch:4---batch(37)训练集---ACC:75.00%---LOSS:1.006---time:9.73
# 第4轮测试集准确率：71.50%....测试集Loss:0.8980367694582257
# Epoch:5---batch(0)训练集---ACC:75.00%---LOSS:0.662---time:15.20
# Epoch:5---batch(1)训练集---ACC:87.50%---LOSS:0.434---time:13.97
# Epoch:5---batch(2)训练集---ACC:90.62%---LOSS:0.316---time:14.63
# Epoch:5---batch(3)训练集---ACC:62.50%---LOSS:1.172---time:14.76
# Epoch:5---batch(4)训练集---ACC:71.88%---LOSS:0.630---time:15.31
# Epoch:5---batch(5)训练集---ACC:65.62%---LOSS:0.869---time:15.01
# Epoch:5---batch(6)训练集---ACC:78.12%---LOSS:0.710---time:13.80
# Epoch:5---batch(7)训练集---ACC:75.00%---LOSS:0.722---time:14.68
# Epoch:5---batch(8)训练集---ACC:81.25%---LOSS:0.417---time:15.33
# Epoch:5---batch(9)训练集---ACC:75.00%---LOSS:0.725---time:15.33
# Epoch:5---batch(10)训练集---ACC:81.25%---LOSS:0.435---time:15.53
# Epoch:5---batch(11)训练集---ACC:71.88%---LOSS:0.616---time:15.34
# Epoch:5---batch(12)训练集---ACC:84.38%---LOSS:0.391---time:15.31
# Epoch:5---batch(13)训练集---ACC:90.62%---LOSS:0.367---time:15.66
# Epoch:5---batch(14)训练集---ACC:65.62%---LOSS:0.632---time:20.90
# Epoch:5---batch(15)训练集---ACC:87.50%---LOSS:0.438---time:17.07
# Epoch:5---batch(16)训练集---ACC:68.75%---LOSS:0.648---time:28.31
# Epoch:5---batch(17)训练集---ACC:81.25%---LOSS:0.481---time:28.11
# Epoch:5---batch(18)训练集---ACC:71.88%---LOSS:0.826---time:26.60
# Epoch:5---batch(19)训练集---ACC:71.88%---LOSS:0.621---time:23.46
# Epoch:5---batch(20)训练集---ACC:81.25%---LOSS:0.545---time:23.88
# Epoch:5---batch(21)训练集---ACC:84.38%---LOSS:0.358---time:22.86
# Epoch:5---batch(22)训练集---ACC:75.00%---LOSS:0.428---time:14.63
# Epoch:5---batch(23)训练集---ACC:78.12%---LOSS:0.791---time:14.75
# Epoch:5---batch(24)训练集---ACC:87.50%---LOSS:0.495---time:15.08
# Epoch:5---batch(25)训练集---ACC:84.38%---LOSS:0.385---time:15.16
# Epoch:5---batch(26)训练集---ACC:87.50%---LOSS:0.429---time:18.47
# Epoch:5---batch(27)训练集---ACC:84.38%---LOSS:0.774---time:26.79
# Epoch:5---batch(28)训练集---ACC:78.12%---LOSS:0.581---time:19.87
# Epoch:5---batch(29)训练集---ACC:78.12%---LOSS:0.506---time:12.98
# Epoch:5---batch(30)训练集---ACC:75.00%---LOSS:0.447---time:15.38
# Epoch:5---batch(31)训练集---ACC:87.50%---LOSS:0.497---time:18.27
# Epoch:5---batch(32)训练集---ACC:84.38%---LOSS:0.622---time:18.71
# Epoch:5---batch(33)训练集---ACC:78.12%---LOSS:0.677---time:19.06
# Epoch:5---batch(34)训练集---ACC:87.50%---LOSS:0.322---time:15.20
# Epoch:5---batch(35)训练集---ACC:75.00%---LOSS:0.531---time:15.79
# Epoch:5---batch(36)训练集---ACC:75.00%---LOSS:0.762---time:16.66
# Epoch:5---batch(37)训练集---ACC:87.50%---LOSS:0.533---time:12.31
# 第5轮测试集准确率：77.50%....测试集Loss:0.77842287506376
# Epoch:6---batch(0)训练集---ACC:84.38%---LOSS:0.523---time:17.09
# Epoch:6---batch(1)训练集---ACC:75.00%---LOSS:0.575---time:17.98
# Epoch:6---batch(2)训练集---ACC:93.75%---LOSS:0.336---time:18.13
# Epoch:6---batch(3)训练集---ACC:84.38%---LOSS:0.384---time:14.24
# Epoch:6---batch(4)训练集---ACC:78.12%---LOSS:0.691---time:16.15
# Epoch:6---batch(5)训练集---ACC:75.00%---LOSS:0.864---time:14.49
# Epoch:6---batch(6)训练集---ACC:75.00%---LOSS:0.525---time:14.13
# Epoch:6---batch(7)训练集---ACC:84.38%---LOSS:0.506---time:13.63
# Epoch:6---batch(8)训练集---ACC:71.88%---LOSS:0.572---time:15.76
# Epoch:6---batch(9)训练集---ACC:90.62%---LOSS:0.362---time:15.56
# Epoch:6---batch(10)训练集---ACC:78.12%---LOSS:0.585---time:16.39
# Epoch:6---batch(11)训练集---ACC:75.00%---LOSS:0.564---time:11.37
# Epoch:6---batch(12)训练集---ACC:84.38%---LOSS:0.414---time:14.86
# Epoch:6---batch(13)训练集---ACC:78.12%---LOSS:0.631---time:14.88
# Epoch:6---batch(14)训练集---ACC:87.50%---LOSS:0.449---time:14.00
# Epoch:6---batch(15)训练集---ACC:90.62%---LOSS:0.239---time:13.89
# Epoch:6---batch(16)训练集---ACC:84.38%---LOSS:0.702---time:13.92
# Epoch:6---batch(17)训练集---ACC:87.50%---LOSS:0.304---time:14.09
# Epoch:6---batch(18)训练集---ACC:87.50%---LOSS:0.350---time:14.14
# Epoch:6---batch(19)训练集---ACC:71.88%---LOSS:0.796---time:14.18
# Epoch:6---batch(20)训练集---ACC:87.50%---LOSS:0.361---time:13.99
# Epoch:6---batch(21)训练集---ACC:81.25%---LOSS:0.585---time:13.98
# Epoch:6---batch(22)训练集---ACC:81.25%---LOSS:0.618---time:13.84
# Epoch:6---batch(23)训练集---ACC:78.12%---LOSS:0.447---time:13.98
# Epoch:6---batch(24)训练集---ACC:84.38%---LOSS:0.487---time:13.84
# Epoch:6---batch(25)训练集---ACC:81.25%---LOSS:0.564---time:13.80
# Epoch:6---batch(26)训练集---ACC:78.12%---LOSS:0.723---time:14.15
# Epoch:6---batch(27)训练集---ACC:81.25%---LOSS:0.558---time:13.85
# Epoch:6---batch(28)训练集---ACC:71.88%---LOSS:0.818---time:13.95
# Epoch:6---batch(29)训练集---ACC:81.25%---LOSS:0.598---time:13.80
# Epoch:6---batch(30)训练集---ACC:84.38%---LOSS:0.471---time:14.03
# Epoch:6---batch(31)训练集---ACC:90.62%---LOSS:0.394---time:13.77
# Epoch:6---batch(32)训练集---ACC:71.88%---LOSS:0.745---time:13.92
# Epoch:6---batch(33)训练集---ACC:84.38%---LOSS:0.624---time:13.89
# Epoch:6---batch(34)训练集---ACC:84.38%---LOSS:0.416---time:14.01
# Epoch:6---batch(35)训练集---ACC:78.12%---LOSS:0.423---time:14.05
# Epoch:6---batch(36)训练集---ACC:71.88%---LOSS:0.627---time:13.83
# Epoch:6---batch(37)训练集---ACC:87.50%---LOSS:0.292---time:6.93
# 第6轮测试集准确率：73.00%....测试集Loss:0.7499955722263881
# Epoch:7---batch(0)训练集---ACC:87.50%---LOSS:0.380---time:14.21
# Epoch:7---batch(1)训练集---ACC:81.25%---LOSS:0.467---time:13.96
# Epoch:7---batch(2)训练集---ACC:90.62%---LOSS:0.314---time:13.77
# Epoch:7---batch(3)训练集---ACC:90.62%---LOSS:0.311---time:13.71
# Epoch:7---batch(4)训练集---ACC:90.62%---LOSS:0.357---time:14.04
# Epoch:7---batch(5)训练集---ACC:87.50%---LOSS:0.465---time:13.90
# Epoch:7---batch(6)训练集---ACC:78.12%---LOSS:0.632---time:13.82
# Epoch:7---batch(7)训练集---ACC:75.00%---LOSS:0.572---time:13.78
# Epoch:7---batch(8)训练集---ACC:81.25%---LOSS:0.499---time:14.05
# Epoch:7---batch(9)训练集---ACC:81.25%---LOSS:0.497---time:13.87
# Epoch:7---batch(10)训练集---ACC:84.38%---LOSS:0.467---time:13.79
# Epoch:7---batch(11)训练集---ACC:81.25%---LOSS:0.373---time:16.49
# Epoch:7---batch(12)训练集---ACC:78.12%---LOSS:0.687---time:19.57
# Epoch:7---batch(13)训练集---ACC:78.12%---LOSS:0.532---time:18.97
# Epoch:7---batch(14)训练集---ACC:84.38%---LOSS:0.478---time:18.77
# Epoch:7---batch(15)训练集---ACC:81.25%---LOSS:0.404---time:19.93
# Epoch:7---batch(16)训练集---ACC:84.38%---LOSS:0.428---time:18.66
# Epoch:7---batch(17)训练集---ACC:75.00%---LOSS:0.693---time:16.91
# Epoch:7---batch(18)训练集---ACC:90.62%---LOSS:0.357---time:18.49
# Epoch:7---batch(19)训练集---ACC:87.50%---LOSS:0.342---time:19.33
# Epoch:7---batch(20)训练集---ACC:87.50%---LOSS:0.424---time:17.78
# Epoch:7---batch(21)训练集---ACC:87.50%---LOSS:0.398---time:17.27
# Epoch:7---batch(22)训练集---ACC:78.12%---LOSS:0.529---time:16.35
# Epoch:7---batch(23)训练集---ACC:81.25%---LOSS:0.533---time:17.92
# Epoch:7---batch(24)训练集---ACC:90.62%---LOSS:0.347---time:16.10
# Epoch:7---batch(25)训练集---ACC:81.25%---LOSS:0.436---time:15.34
# Epoch:7---batch(26)训练集---ACC:87.50%---LOSS:0.489---time:14.35
# Epoch:7---batch(27)训练集---ACC:87.50%---LOSS:0.479---time:12.71
# Epoch:7---batch(28)训练集---ACC:90.62%---LOSS:0.408---time:14.65
# Epoch:7---batch(29)训练集---ACC:87.50%---LOSS:0.435---time:15.71
# Epoch:7---batch(30)训练集---ACC:75.00%---LOSS:0.764---time:19.14
# Epoch:7---batch(31)训练集---ACC:81.25%---LOSS:0.516---time:15.96
# Epoch:7---batch(32)训练集---ACC:75.00%---LOSS:0.732---time:15.04
# Epoch:7---batch(33)训练集---ACC:84.38%---LOSS:0.433---time:15.70
# Epoch:7---batch(34)训练集---ACC:93.75%---LOSS:0.233---time:15.50
# Epoch:7---batch(35)训练集---ACC:87.50%---LOSS:0.375---time:15.25
# Epoch:7---batch(36)训练集---ACC:78.12%---LOSS:0.784---time:15.53
# Epoch:7---batch(37)训练集---ACC:68.75%---LOSS:1.342---time:7.46
# 第7轮测试集准确率：71.50%....测试集Loss:1.070361669574465
# Epoch:8---batch(0)训练集---ACC:81.25%---LOSS:0.568---time:14.21
# Epoch:8---batch(1)训练集---ACC:84.38%---LOSS:0.416---time:13.22
# Epoch:8---batch(2)训练集---ACC:75.00%---LOSS:0.671---time:13.44
# Epoch:8---batch(3)训练集---ACC:93.75%---LOSS:0.402---time:13.12
# Epoch:8---batch(4)训练集---ACC:96.88%---LOSS:0.140---time:12.80
# Epoch:8---batch(5)训练集---ACC:87.50%---LOSS:0.304---time:13.38
# Epoch:8---batch(6)训练集---ACC:84.38%---LOSS:0.586---time:13.41
# Epoch:8---batch(7)训练集---ACC:93.75%---LOSS:0.325---time:12.69
# Epoch:8---batch(8)训练集---ACC:71.88%---LOSS:0.670---time:12.95
# Epoch:8---batch(9)训练集---ACC:75.00%---LOSS:0.531---time:13.53
# Epoch:8---batch(10)训练集---ACC:81.25%---LOSS:0.709---time:13.48
# Epoch:8---batch(11)训练集---ACC:84.38%---LOSS:0.393---time:12.82
# Epoch:8---batch(12)训练集---ACC:87.50%---LOSS:0.324---time:13.08
# Epoch:8---batch(13)训练集---ACC:87.50%---LOSS:0.335---time:13.33
# Epoch:8---batch(14)训练集---ACC:68.75%---LOSS:0.875---time:13.13
# Epoch:8---batch(15)训练集---ACC:84.38%---LOSS:0.509---time:12.92
# Epoch:8---batch(16)训练集---ACC:96.88%---LOSS:0.237---time:13.35
# Epoch:8---batch(17)训练集---ACC:75.00%---LOSS:0.514---time:13.34
# Epoch:8---batch(18)训练集---ACC:84.38%---LOSS:0.485---time:12.90
# Epoch:8---batch(19)训练集---ACC:90.62%---LOSS:0.405---time:13.12
# Epoch:8---batch(20)训练集---ACC:84.38%---LOSS:0.457---time:13.46
# Epoch:8---batch(21)训练集---ACC:81.25%---LOSS:0.442---time:13.08
# Epoch:8---batch(22)训练集---ACC:81.25%---LOSS:0.467---time:12.82
# Epoch:8---batch(23)训练集---ACC:90.62%---LOSS:0.280---time:13.23
# Epoch:8---batch(24)训练集---ACC:78.12%---LOSS:0.560---time:13.39
# Epoch:8---batch(25)训练集---ACC:87.50%---LOSS:0.482---time:13.36
# Epoch:8---batch(26)训练集---ACC:75.00%---LOSS:0.762---time:12.77
# Epoch:8---batch(27)训练集---ACC:84.38%---LOSS:0.392---time:13.25
# Epoch:8---batch(28)训练集---ACC:93.75%---LOSS:0.320---time:13.40
# Epoch:8---batch(29)训练集---ACC:81.25%---LOSS:0.520---time:13.11
# Epoch:8---batch(30)训练集---ACC:81.25%---LOSS:0.406---time:12.74
# Epoch:8---batch(31)训练集---ACC:78.12%---LOSS:0.465---time:13.31
# Epoch:8---batch(32)训练集---ACC:68.75%---LOSS:0.620---time:13.49
# Epoch:8---batch(33)训练集---ACC:75.00%---LOSS:0.464---time:12.78
# Epoch:8---batch(34)训练集---ACC:81.25%---LOSS:0.461---time:12.98
# Epoch:8---batch(35)训练集---ACC:75.00%---LOSS:0.891---time:13.50
# Epoch:8---batch(36)训练集---ACC:68.75%---LOSS:0.843---time:13.28
# Epoch:8---batch(37)训练集---ACC:93.75%---LOSS:0.213---time:6.46
# 第8轮测试集准确率：77.00%....测试集Loss:0.7269301073891776
# Epoch:9---batch(0)训练集---ACC:78.12%---LOSS:0.610---time:13.07
# Epoch:9---batch(1)训练集---ACC:87.50%---LOSS:0.533---time:12.72
# Epoch:9---batch(2)训练集---ACC:78.12%---LOSS:0.472---time:13.49
# Epoch:9---batch(3)训练集---ACC:65.62%---LOSS:0.656---time:13.31
# Epoch:9---batch(4)训练集---ACC:90.62%---LOSS:0.336---time:12.89
# Epoch:9---batch(5)训练集---ACC:93.75%---LOSS:0.163---time:12.88
# Epoch:9---batch(6)训练集---ACC:93.75%---LOSS:0.211---time:13.46
# Epoch:9---batch(7)训练集---ACC:87.50%---LOSS:0.333---time:13.27
# Epoch:9---batch(8)训练集---ACC:90.62%---LOSS:0.421---time:12.82
# Epoch:9---batch(9)训练集---ACC:81.25%---LOSS:0.564---time:13.10
# Epoch:9---batch(10)训练集---ACC:87.50%---LOSS:0.490---time:13.32
# Epoch:9---batch(11)训练集---ACC:78.12%---LOSS:0.474---time:13.22
# Epoch:9---batch(12)训练集---ACC:84.38%---LOSS:0.385---time:12.92
# Epoch:9---batch(13)训练集---ACC:75.00%---LOSS:0.702---time:13.19
# Epoch:9---batch(14)训练集---ACC:87.50%---LOSS:0.503---time:13.56
# Epoch:9---batch(15)训练集---ACC:84.38%---LOSS:0.413---time:13.08
# Epoch:9---batch(16)训练集---ACC:65.62%---LOSS:0.717---time:12.89
# Epoch:9---batch(17)训练集---ACC:81.25%---LOSS:0.506---time:13.06
# Epoch:9---batch(18)训练集---ACC:90.62%---LOSS:0.400---time:13.52
# Epoch:9---batch(19)训练集---ACC:81.25%---LOSS:0.723---time:12.93
# Epoch:9---batch(20)训练集---ACC:75.00%---LOSS:0.545---time:13.10
# Epoch:9---batch(21)训练集---ACC:90.62%---LOSS:0.350---time:13.66
# Epoch:9---batch(22)训练集---ACC:71.88%---LOSS:0.857---time:13.16
# Epoch:9---batch(23)训练集---ACC:84.38%---LOSS:0.426---time:12.75
# Epoch:9---batch(24)训练集---ACC:71.88%---LOSS:0.723---time:12.70
# Epoch:9---batch(25)训练集---ACC:81.25%---LOSS:0.514---time:12.54
# Epoch:9---batch(26)训练集---ACC:84.38%---LOSS:0.468---time:12.53
# Epoch:9---batch(27)训练集---ACC:93.75%---LOSS:0.258---time:12.83
# Epoch:9---batch(28)训练集---ACC:75.00%---LOSS:0.723---time:12.80
# Epoch:9---batch(29)训练集---ACC:81.25%---LOSS:0.825---time:12.67
# Epoch:9---batch(30)训练集---ACC:90.62%---LOSS:0.353---time:12.55
# Epoch:9---batch(31)训练集---ACC:90.62%---LOSS:0.292---time:12.87
# Epoch:9---batch(32)训练集---ACC:68.75%---LOSS:0.728---time:12.89
# Epoch:9---batch(33)训练集---ACC:87.50%---LOSS:0.350---time:12.96
# Epoch:9---batch(34)训练集---ACC:87.50%---LOSS:0.360---time:12.77
# Epoch:9---batch(35)训练集---ACC:68.75%---LOSS:0.692---time:12.88
# Epoch:9---batch(36)训练集---ACC:75.00%---LOSS:0.549---time:12.68
# Epoch:9---batch(37)训练集---ACC:75.00%---LOSS:0.634---time:6.39
# 第9轮测试集准确率：76.50%....测试集Loss:0.768579500062125
# Epoch:10---batch(0)训练集---ACC:87.50%---LOSS:0.447---time:12.62
# Epoch:10---batch(1)训练集---ACC:90.62%---LOSS:0.338---time:12.65
# Epoch:10---batch(2)训练集---ACC:84.38%---LOSS:0.546---time:12.38
# Epoch:10---batch(3)训练集---ACC:90.62%---LOSS:0.449---time:12.83
# Epoch:10---batch(4)训练集---ACC:96.88%---LOSS:0.175---time:12.55
# Epoch:10---batch(5)训练集---ACC:81.25%---LOSS:0.529---time:12.83
# Epoch:10---batch(6)训练集---ACC:78.12%---LOSS:0.438---time:12.79
# Epoch:10---batch(7)训练集---ACC:87.50%---LOSS:0.281---time:12.94
# Epoch:10---batch(8)训练集---ACC:84.38%---LOSS:0.434---time:12.75
# Epoch:10---batch(9)训练集---ACC:93.75%---LOSS:0.291---time:12.79
# Epoch:10---batch(10)训练集---ACC:78.12%---LOSS:0.540---time:12.79
# Epoch:10---batch(11)训练集---ACC:81.25%---LOSS:0.584---time:12.72
# Epoch:10---batch(12)训练集---ACC:84.38%---LOSS:0.488---time:12.70
# Epoch:10---batch(13)训练集---ACC:78.12%---LOSS:0.716---time:12.82
# Epoch:10---batch(14)训练集---ACC:90.62%---LOSS:0.251---time:12.80
# Epoch:10---batch(15)训练集---ACC:68.75%---LOSS:0.878---time:12.51
# Epoch:10---batch(16)训练集---ACC:87.50%---LOSS:0.378---time:12.98
# Epoch:10---batch(17)训练集---ACC:62.50%---LOSS:0.859---time:12.72
# Epoch:10---batch(18)训练集---ACC:87.50%---LOSS:0.359---time:12.78
# Epoch:10---batch(19)训练集---ACC:84.38%---LOSS:0.442---time:12.56
# Epoch:10---batch(20)训练集---ACC:71.88%---LOSS:0.732---time:12.80
# Epoch:10---batch(21)训练集---ACC:87.50%---LOSS:0.586---time:12.59
# Epoch:10---batch(22)训练集---ACC:81.25%---LOSS:0.518---time:12.68
# Epoch:10---batch(23)训练集---ACC:68.75%---LOSS:0.572---time:12.83
# Epoch:10---batch(24)训练集---ACC:90.62%---LOSS:0.265---time:12.64
# Epoch:10---batch(25)训练集---ACC:84.38%---LOSS:0.455---time:12.55
# Epoch:10---batch(26)训练集---ACC:81.25%---LOSS:0.480---time:12.70
# Epoch:10---batch(27)训练集---ACC:93.75%---LOSS:0.349---time:12.62
# Epoch:10---batch(28)训练集---ACC:87.50%---LOSS:0.424---time:12.54
# Epoch:10---batch(29)训练集---ACC:78.12%---LOSS:0.418---time:12.65
# Epoch:10---batch(30)训练集---ACC:81.25%---LOSS:0.523---time:12.60
# Epoch:10---batch(31)训练集---ACC:87.50%---LOSS:0.392---time:12.64
# Epoch:10---batch(32)训练集---ACC:84.38%---LOSS:0.326---time:12.49
# Epoch:10---batch(33)训练集---ACC:68.75%---LOSS:0.775---time:12.52
# Epoch:10---batch(34)训练集---ACC:87.50%---LOSS:0.331---time:12.58
# Epoch:10---batch(35)训练集---ACC:84.38%---LOSS:0.460---time:12.54
# Epoch:10---batch(36)训练集---ACC:90.62%---LOSS:0.303---time:12.33
# Epoch:10---batch(37)训练集---ACC:81.25%---LOSS:0.677---time:6.22
# 第10轮测试集准确率：75.50%....测试集Loss:0.7360805954251971
# Epoch:11---batch(0)训练集---ACC:84.38%---LOSS:0.295---time:12.62
# Epoch:11---batch(1)训练集---ACC:81.25%---LOSS:0.459---time:12.65
# Epoch:11---batch(2)训练集---ACC:84.38%---LOSS:0.619---time:12.56
# Epoch:11---batch(3)训练集---ACC:65.62%---LOSS:0.754---time:12.44
# Epoch:11---batch(4)训练集---ACC:84.38%---LOSS:0.529---time:12.35
# Epoch:11---batch(5)训练集---ACC:96.88%---LOSS:0.218---time:12.69
# Epoch:11---batch(6)训练集---ACC:90.62%---LOSS:0.445---time:12.55
# Epoch:11---batch(7)训练集---ACC:93.75%---LOSS:0.178---time:12.66
# Epoch:11---batch(8)训练集---ACC:84.38%---LOSS:0.405---time:12.57
# Epoch:11---batch(9)训练集---ACC:90.62%---LOSS:0.316---time:12.60
# Epoch:11---batch(10)训练集---ACC:81.25%---LOSS:0.457---time:12.55
# Epoch:11---batch(11)训练集---ACC:87.50%---LOSS:0.511---time:12.48
# Epoch:11---batch(12)训练集---ACC:78.12%---LOSS:0.629---time:12.50
# Epoch:11---batch(13)训练集---ACC:87.50%---LOSS:0.410---time:12.78
# Epoch:11---batch(14)训练集---ACC:93.75%---LOSS:0.344---time:12.81
# Epoch:11---batch(15)训练集---ACC:87.50%---LOSS:0.487---time:12.63
# Epoch:11---batch(16)训练集---ACC:75.00%---LOSS:0.614---time:12.72
# Epoch:11---batch(17)训练集---ACC:90.62%---LOSS:0.304---time:12.73
# Epoch:11---batch(18)训练集---ACC:93.75%---LOSS:0.346---time:12.63
# Epoch:11---batch(19)训练集---ACC:71.88%---LOSS:0.568---time:12.73
# Epoch:11---batch(20)训练集---ACC:90.62%---LOSS:0.378---time:12.49
# Epoch:11---batch(21)训练集---ACC:81.25%---LOSS:0.484---time:12.47
# Epoch:11---batch(22)训练集---ACC:81.25%---LOSS:0.424---time:12.62
# Epoch:11---batch(23)训练集---ACC:84.38%---LOSS:0.398---time:12.48
# Epoch:11---batch(24)训练集---ACC:84.38%---LOSS:0.348---time:12.65
# Epoch:11---batch(25)训练集---ACC:75.00%---LOSS:0.503---time:12.49
# Epoch:11---batch(26)训练集---ACC:81.25%---LOSS:0.686---time:12.53
# Epoch:11---batch(27)训练集---ACC:84.38%---LOSS:0.367---time:12.49
# Epoch:11---batch(28)训练集---ACC:90.62%---LOSS:0.361---time:12.66
# Epoch:11---batch(29)训练集---ACC:90.62%---LOSS:0.277---time:12.39
# Epoch:11---batch(30)训练集---ACC:84.38%---LOSS:0.356---time:13.82
# Epoch:11---batch(31)训练集---ACC:78.12%---LOSS:0.756---time:12.78
# Epoch:11---batch(32)训练集---ACC:81.25%---LOSS:0.555---time:12.60
# Epoch:11---batch(33)训练集---ACC:84.38%---LOSS:0.474---time:12.66
# Epoch:11---batch(34)训练集---ACC:87.50%---LOSS:0.416---time:12.68
# Epoch:11---batch(35)训练集---ACC:90.62%---LOSS:0.328---time:12.81
# Epoch:11---batch(36)训练集---ACC:84.38%---LOSS:0.387---time:12.59
# Epoch:11---batch(37)训练集---ACC:68.75%---LOSS:0.927---time:6.44
# 第11轮测试集准确率：77.50%....测试集Loss:0.7599054745265416
# Epoch:12---batch(0)训练集---ACC:87.50%---LOSS:0.426---time:12.47
# Epoch:12---batch(1)训练集---ACC:87.50%---LOSS:0.350---time:12.60
# Epoch:12---batch(2)训练集---ACC:81.25%---LOSS:0.546---time:12.74
# Epoch:12---batch(3)训练集---ACC:87.50%---LOSS:0.367---time:12.64
# Epoch:12---batch(4)训练集---ACC:84.38%---LOSS:0.491---time:12.56
# Epoch:12---batch(5)训练集---ACC:75.00%---LOSS:0.565---time:12.69
# Epoch:12---batch(6)训练集---ACC:93.75%---LOSS:0.315---time:12.57
# Epoch:12---batch(7)训练集---ACC:87.50%---LOSS:0.433---time:12.62
# Epoch:12---batch(8)训练集---ACC:90.62%---LOSS:0.405---time:12.45
# Epoch:12---batch(9)训练集---ACC:81.25%---LOSS:0.455---time:12.67
# Epoch:12---batch(10)训练集---ACC:78.12%---LOSS:0.503---time:12.75
# Epoch:12---batch(11)训练集---ACC:87.50%---LOSS:0.442---time:12.55
# Epoch:12---batch(12)训练集---ACC:75.00%---LOSS:0.427---time:12.69
# Epoch:12---batch(13)训练集---ACC:81.25%---LOSS:0.319---time:12.81
# Epoch:12---batch(14)训练集---ACC:96.88%---LOSS:0.178---time:12.60
# Epoch:12---batch(15)训练集---ACC:84.38%---LOSS:0.366---time:12.69
# Epoch:12---batch(16)训练集---ACC:87.50%---LOSS:0.353---time:12.45
# Epoch:12---batch(17)训练集---ACC:87.50%---LOSS:0.411---time:12.65
# Epoch:12---batch(18)训练集---ACC:90.62%---LOSS:0.263---time:12.60
# Epoch:12---batch(19)训练集---ACC:87.50%---LOSS:0.578---time:12.69
# Epoch:12---batch(20)训练集---ACC:84.38%---LOSS:0.342---time:12.52
# Epoch:12---batch(21)训练集---ACC:87.50%---LOSS:0.245---time:12.70
# Epoch:12---batch(22)训练集---ACC:87.50%---LOSS:0.316---time:12.52
# Epoch:12---batch(23)训练集---ACC:87.50%---LOSS:0.346---time:12.73
# Epoch:12---batch(24)训练集---ACC:84.38%---LOSS:0.366---time:12.52
# Epoch:12---batch(25)训练集---ACC:93.75%---LOSS:0.228---time:12.61
# Epoch:12---batch(26)训练集---ACC:84.38%---LOSS:0.303---time:12.75
# Epoch:12---batch(27)训练集---ACC:81.25%---LOSS:0.645---time:12.70
# Epoch:12---batch(28)训练集---ACC:84.38%---LOSS:0.404---time:12.54
# Epoch:12---batch(29)训练集---ACC:84.38%---LOSS:0.370---time:12.49
# Epoch:12---batch(30)训练集---ACC:87.50%---LOSS:0.459---time:12.80
# Epoch:12---batch(31)训练集---ACC:71.88%---LOSS:0.654---time:12.55
# Epoch:12---batch(32)训练集---ACC:84.38%---LOSS:0.336---time:12.60
# Epoch:12---batch(33)训练集---ACC:62.50%---LOSS:0.847---time:12.67
# Epoch:12---batch(34)训练集---ACC:84.38%---LOSS:0.588---time:12.65
# Epoch:12---batch(35)训练集---ACC:81.25%---LOSS:0.432---time:12.64
# Epoch:12---batch(36)训练集---ACC:81.25%---LOSS:0.579---time:12.73
# Epoch:12---batch(37)训练集---ACC:81.25%---LOSS:0.445---time:6.32
# 第12轮测试集准确率：75.50%....测试集Loss:0.8633766940661839
# Epoch:13---batch(0)训练集---ACC:84.38%---LOSS:0.455---time:12.89
# Epoch:13---batch(1)训练集---ACC:90.62%---LOSS:0.250---time:12.94
# Epoch:13---batch(2)训练集---ACC:93.75%---LOSS:0.245---time:12.93
# Epoch:13---batch(3)训练集---ACC:87.50%---LOSS:0.378---time:12.70
# Epoch:13---batch(4)训练集---ACC:68.75%---LOSS:0.885---time:12.40
# Epoch:13---batch(5)训练集---ACC:75.00%---LOSS:0.871---time:12.63
# Epoch:13---batch(6)训练集---ACC:81.25%---LOSS:0.488---time:12.55
# Epoch:13---batch(7)训练集---ACC:87.50%---LOSS:0.519---time:12.46
# Epoch:13---batch(8)训练集---ACC:84.38%---LOSS:0.405---time:12.44
# Epoch:13---batch(9)训练集---ACC:78.12%---LOSS:0.405---time:12.55
# Epoch:13---batch(10)训练集---ACC:75.00%---LOSS:0.668---time:12.71
# Epoch:13---batch(11)训练集---ACC:93.75%---LOSS:0.240---time:12.55
# Epoch:13---batch(12)训练集---ACC:93.75%---LOSS:0.223---time:12.62
# Epoch:13---batch(13)训练集---ACC:84.38%---LOSS:0.405---time:12.53
# Epoch:13---batch(14)训练集---ACC:71.88%---LOSS:0.660---time:12.49
# Epoch:13---batch(15)训练集---ACC:93.75%---LOSS:0.218---time:12.63
# Epoch:13---batch(16)训练集---ACC:87.50%---LOSS:0.263---time:12.66
# Epoch:13---batch(17)训练集---ACC:90.62%---LOSS:0.339---time:12.72
# Epoch:13---batch(18)训练集---ACC:81.25%---LOSS:0.539---time:12.70
# Epoch:13---batch(19)训练集---ACC:84.38%---LOSS:0.320---time:12.55
# Epoch:13---batch(20)训练集---ACC:87.50%---LOSS:0.283---time:12.49
# Epoch:13---batch(21)训练集---ACC:90.62%---LOSS:0.527---time:12.74
# Epoch:13---batch(22)训练集---ACC:84.38%---LOSS:0.320---time:12.58
# Epoch:13---batch(23)训练集---ACC:81.25%---LOSS:0.349---time:12.75
# Epoch:13---batch(24)训练集---ACC:81.25%---LOSS:0.417---time:12.58
# Epoch:13---batch(25)训练集---ACC:87.50%---LOSS:0.317---time:13.00
# Epoch:13---batch(26)训练集---ACC:78.12%---LOSS:0.426---time:12.33
# Epoch:13---batch(27)训练集---ACC:81.25%---LOSS:0.397---time:12.85
# Epoch:13---batch(28)训练集---ACC:93.75%---LOSS:0.302---time:12.56
# Epoch:13---batch(29)训练集---ACC:96.88%---LOSS:0.187---time:12.53
# Epoch:13---batch(30)训练集---ACC:81.25%---LOSS:0.654---time:12.83
# Epoch:13---batch(31)训练集---ACC:90.62%---LOSS:0.373---time:12.64
# Epoch:13---batch(32)训练集---ACC:78.12%---LOSS:0.512---time:12.58
# Epoch:13---batch(33)训练集---ACC:75.00%---LOSS:0.615---time:12.31
# Epoch:13---batch(34)训练集---ACC:96.88%---LOSS:0.173---time:12.63
# Epoch:13---batch(35)训练集---ACC:84.38%---LOSS:0.547---time:12.53
# Epoch:13---batch(36)训练集---ACC:84.38%---LOSS:0.354---time:12.41
# Epoch:13---batch(37)训练集---ACC:75.00%---LOSS:0.515---time:6.29
# 第13轮测试集准确率：79.50%....测试集Loss:0.833759782569749
# Epoch:14---batch(0)训练集---ACC:93.75%---LOSS:0.229---time:12.66
# Epoch:14---batch(1)训练集---ACC:84.38%---LOSS:0.708---time:12.50
# Epoch:14---batch(2)训练集---ACC:81.25%---LOSS:0.482---time:12.47
# Epoch:14---batch(3)训练集---ACC:87.50%---LOSS:0.211---time:12.56
# Epoch:14---batch(4)训练集---ACC:81.25%---LOSS:0.516---time:12.51
# Epoch:14---batch(5)训练集---ACC:78.12%---LOSS:0.573---time:12.69
# Epoch:14---batch(6)训练集---ACC:68.75%---LOSS:0.581---time:12.88
# Epoch:14---batch(7)训练集---ACC:90.62%---LOSS:0.280---time:12.77
# Epoch:14---batch(8)训练集---ACC:84.38%---LOSS:0.414---time:12.33
# Epoch:14---batch(9)训练集---ACC:84.38%---LOSS:0.545---time:12.49
# Epoch:14---batch(10)训练集---ACC:84.38%---LOSS:0.410---time:12.78
# Epoch:14---batch(11)训练集---ACC:81.25%---LOSS:0.587---time:12.45
# Epoch:14---batch(12)训练集---ACC:84.38%---LOSS:0.354---time:12.46
# Epoch:14---batch(13)训练集---ACC:84.38%---LOSS:0.406---time:12.58
# Epoch:14---batch(14)训练集---ACC:78.12%---LOSS:0.500---time:12.56
# Epoch:14---batch(15)训练集---ACC:93.75%---LOSS:0.369---time:12.59
# Epoch:14---batch(16)训练集---ACC:87.50%---LOSS:0.287---time:12.58
# Epoch:14---batch(17)训练集---ACC:93.75%---LOSS:0.330---time:12.63
# Epoch:14---batch(18)训练集---ACC:90.62%---LOSS:0.282---time:12.40
# Epoch:14---batch(19)训练集---ACC:90.62%---LOSS:0.319---time:12.56
# Epoch:14---batch(20)训练集---ACC:78.12%---LOSS:0.719---time:12.54
# Epoch:14---batch(21)训练集---ACC:96.88%---LOSS:0.352---time:12.53
# Epoch:14---batch(22)训练集---ACC:71.88%---LOSS:0.710---time:12.66
# Epoch:14---batch(23)训练集---ACC:81.25%---LOSS:0.485---time:12.70
# Epoch:14---batch(24)训练集---ACC:93.75%---LOSS:0.245---time:12.60
# Epoch:14---batch(25)训练集---ACC:78.12%---LOSS:0.424---time:12.46
# Epoch:14---batch(26)训练集---ACC:93.75%---LOSS:0.254---time:12.54
# Epoch:14---batch(27)训练集---ACC:81.25%---LOSS:0.492---time:12.56
# Epoch:14---batch(28)训练集---ACC:96.88%---LOSS:0.174---time:12.52
# Epoch:14---batch(29)训练集---ACC:87.50%---LOSS:0.518---time:12.68
# Epoch:14---batch(30)训练集---ACC:90.62%---LOSS:0.349---time:12.53
# Epoch:14---batch(31)训练集---ACC:75.00%---LOSS:0.497---time:12.73
# Epoch:14---batch(32)训练集---ACC:87.50%---LOSS:0.356---time:12.29
# Epoch:14---batch(33)训练集---ACC:68.75%---LOSS:0.711---time:12.58
# Epoch:14---batch(34)训练集---ACC:81.25%---LOSS:0.523---time:12.67
# Epoch:14---batch(35)训练集---ACC:84.38%---LOSS:0.395---time:12.64
# Epoch:14---batch(36)训练集---ACC:75.00%---LOSS:0.556---time:12.56
# Epoch:14---batch(37)训练集---ACC:81.25%---LOSS:0.463---time:6.18
# 第14轮测试集准确率：65.50%....测试集Loss:0.9195420401436942
# Epoch:15---batch(0)训练集---ACC:84.38%---LOSS:0.458---time:12.60
# Epoch:15---batch(1)训练集---ACC:78.12%---LOSS:0.653---time:12.79
# Epoch:15---batch(2)训练集---ACC:87.50%---LOSS:0.237---time:12.57
# Epoch:15---batch(3)训练集---ACC:93.75%---LOSS:0.201---time:12.56
# Epoch:15---batch(4)训练集---ACC:84.38%---LOSS:0.397---time:12.72
# Epoch:15---batch(5)训练集---ACC:81.25%---LOSS:0.789---time:12.56
# Epoch:15---batch(6)训练集---ACC:81.25%---LOSS:0.302---time:12.55
# Epoch:15---batch(7)训练集---ACC:78.12%---LOSS:0.911---time:12.59
# Epoch:15---batch(8)训练集---ACC:78.12%---LOSS:0.479---time:12.84
# Epoch:15---batch(9)训练集---ACC:84.38%---LOSS:0.482---time:12.71
# Epoch:15---batch(10)训练集---ACC:84.38%---LOSS:0.483---time:12.31
# Epoch:15---batch(11)训练集---ACC:87.50%---LOSS:0.331---time:12.72
# Epoch:15---batch(12)训练集---ACC:87.50%---LOSS:0.311---time:12.60
# Epoch:15---batch(13)训练集---ACC:78.12%---LOSS:0.498---time:12.74
# Epoch:15---batch(14)训练集---ACC:84.38%---LOSS:0.336---time:12.73
# Epoch:15---batch(15)训练集---ACC:75.00%---LOSS:0.489---time:12.62
# Epoch:15---batch(16)训练集---ACC:87.50%---LOSS:0.328---time:12.57
# Epoch:15---batch(17)训练集---ACC:84.38%---LOSS:0.464---time:12.74
# Epoch:15---batch(18)训练集---ACC:78.12%---LOSS:0.492---time:12.69
# Epoch:15---batch(19)训练集---ACC:90.62%---LOSS:0.389---time:12.74
# Epoch:15---batch(20)训练集---ACC:75.00%---LOSS:0.650---time:12.59
# Epoch:15---batch(21)训练集---ACC:81.25%---LOSS:0.406---time:12.71
# Epoch:15---batch(22)训练集---ACC:81.25%---LOSS:0.523---time:12.63
# Epoch:15---batch(23)训练集---ACC:84.38%---LOSS:0.425---time:12.74
# Epoch:15---batch(24)训练集---ACC:71.88%---LOSS:0.708---time:12.50
# Epoch:15---batch(25)训练集---ACC:75.00%---LOSS:0.471---time:12.41
# Epoch:15---batch(26)训练集---ACC:87.50%---LOSS:0.322---time:12.63
# Epoch:15---batch(27)训练集---ACC:78.12%---LOSS:0.560---time:12.72
# Epoch:15---batch(28)训练集---ACC:84.38%---LOSS:0.371---time:12.48
# Epoch:15---batch(29)训练集---ACC:84.38%---LOSS:0.484---time:12.62
# Epoch:15---batch(30)训练集---ACC:90.62%---LOSS:0.430---time:12.70
# Epoch:15---batch(31)训练集---ACC:78.12%---LOSS:0.618---time:12.67
# Epoch:15---batch(32)训练集---ACC:84.38%---LOSS:0.420---time:12.47
# Epoch:15---batch(33)训练集---ACC:87.50%---LOSS:0.249---time:12.40
# Epoch:15---batch(34)训练集---ACC:96.88%---LOSS:0.135---time:12.78
# Epoch:15---batch(35)训练集---ACC:90.62%---LOSS:0.444---time:12.45
# Epoch:15---batch(36)训练集---ACC:90.62%---LOSS:0.413---time:12.64
# Epoch:15---batch(37)训练集---ACC:62.50%---LOSS:0.775---time:6.26
# 第15轮测试集准确率：76.00%....测试集Loss:0.7858979531696865
# Epoch:16---batch(0)训练集---ACC:90.62%---LOSS:0.237---time:12.68
# Epoch:16---batch(1)训练集---ACC:59.38%---LOSS:1.011---time:12.52
# Epoch:16---batch(2)训练集---ACC:84.38%---LOSS:0.543---time:12.51
# Epoch:16---batch(3)训练集---ACC:93.75%---LOSS:0.230---time:12.33
# Epoch:16---batch(4)训练集---ACC:90.62%---LOSS:0.236---time:12.60
# Epoch:16---batch(5)训练集---ACC:71.88%---LOSS:0.564---time:12.45
# Epoch:16---batch(6)训练集---ACC:87.50%---LOSS:0.377---time:12.47
# Epoch:16---batch(7)训练集---ACC:81.25%---LOSS:0.574---time:12.84
# Epoch:16---batch(8)训练集---ACC:90.62%---LOSS:0.342---time:12.88
# Epoch:16---batch(9)训练集---ACC:78.12%---LOSS:0.574---time:12.70
# Epoch:16---batch(10)训练集---ACC:93.75%---LOSS:0.176---time:12.69
# Epoch:16---batch(11)训练集---ACC:84.38%---LOSS:0.368---time:12.66
# Epoch:16---batch(12)训练集---ACC:71.88%---LOSS:0.698---time:12.54
# Epoch:16---batch(13)训练集---ACC:87.50%---LOSS:0.349---time:12.36
# Epoch:16---batch(14)训练集---ACC:87.50%---LOSS:0.283---time:12.64
# Epoch:16---batch(15)训练集---ACC:81.25%---LOSS:0.398---time:12.66
# Epoch:16---batch(16)训练集---ACC:75.00%---LOSS:0.678---time:12.53
# Epoch:16---batch(17)训练集---ACC:81.25%---LOSS:0.794---time:12.58
# Epoch:16---batch(18)训练集---ACC:87.50%---LOSS:0.427---time:12.76
# Epoch:16---batch(19)训练集---ACC:93.75%---LOSS:0.296---time:12.41
# Epoch:16---batch(20)训练集---ACC:81.25%---LOSS:0.614---time:12.30
# Epoch:16---batch(21)训练集---ACC:84.38%---LOSS:0.382---time:12.71
# Epoch:16---batch(22)训练集---ACC:93.75%---LOSS:0.264---time:12.67
# Epoch:16---batch(23)训练集---ACC:90.62%---LOSS:0.329---time:12.47
# Epoch:16---batch(24)训练集---ACC:81.25%---LOSS:0.452---time:12.56
# Epoch:16---batch(25)训练集---ACC:75.00%---LOSS:0.648---time:12.59
# Epoch:16---batch(26)训练集---ACC:81.25%---LOSS:0.470---time:12.49
# Epoch:16---batch(27)训练集---ACC:90.62%---LOSS:0.407---time:12.54
# Epoch:16---batch(28)训练集---ACC:81.25%---LOSS:0.516---time:12.69
# Epoch:16---batch(29)训练集---ACC:84.38%---LOSS:0.272---time:12.49
# Epoch:16---batch(30)训练集---ACC:84.38%---LOSS:0.670---time:12.52
# Epoch:16---batch(31)训练集---ACC:78.12%---LOSS:0.541---time:12.69
# Epoch:16---batch(32)训练集---ACC:87.50%---LOSS:0.355---time:12.76
# Epoch:16---batch(33)训练集---ACC:87.50%---LOSS:0.437---time:12.56
# Epoch:16---batch(34)训练集---ACC:84.38%---LOSS:0.600---time:12.72
# Epoch:16---batch(35)训练集---ACC:90.62%---LOSS:0.195---time:12.47
# Epoch:16---batch(36)训练集---ACC:90.62%---LOSS:0.417---time:12.57
# Epoch:16---batch(37)训练集---ACC:87.50%---LOSS:0.398---time:6.31
# 第16轮测试集准确率：74.00%....测试集Loss:0.7754735095160348
# Epoch:17---batch(0)训练集---ACC:90.62%---LOSS:0.476---time:12.72
# Epoch:17---batch(1)训练集---ACC:84.38%---LOSS:0.483---time:12.78
# Epoch:17---batch(2)训练集---ACC:84.38%---LOSS:0.444---time:12.68
# Epoch:17---batch(3)训练集---ACC:84.38%---LOSS:0.396---time:12.50
# Epoch:17---batch(4)训练集---ACC:87.50%---LOSS:0.346---time:12.59
# Epoch:17---batch(5)训练集---ACC:84.38%---LOSS:0.524---time:12.47
# Epoch:17---batch(6)训练集---ACC:93.75%---LOSS:0.191---time:12.73
# Epoch:17---batch(7)训练集---ACC:81.25%---LOSS:0.518---time:12.59
# Epoch:17---batch(8)训练集---ACC:93.75%---LOSS:0.261---time:12.51
# Epoch:17---batch(9)训练集---ACC:93.75%---LOSS:0.220---time:12.43
# Epoch:17---batch(10)训练集---ACC:75.00%---LOSS:0.713---time:12.42
# Epoch:17---batch(11)训练集---ACC:71.88%---LOSS:0.589---time:12.57
# Epoch:17---batch(12)训练集---ACC:87.50%---LOSS:0.407---time:12.53
# Epoch:17---batch(13)训练集---ACC:90.62%---LOSS:0.227---time:12.67
# Epoch:17---batch(14)训练集---ACC:84.38%---LOSS:0.421---time:12.55
# Epoch:17---batch(15)训练集---ACC:96.88%---LOSS:0.170---time:12.45
# Epoch:17---batch(16)训练集---ACC:75.00%---LOSS:0.594---time:12.71
# Epoch:17---batch(17)训练集---ACC:87.50%---LOSS:0.282---time:12.67
# Epoch:17---batch(18)训练集---ACC:96.88%---LOSS:0.247---time:12.85
# Epoch:17---batch(19)训练集---ACC:78.12%---LOSS:0.500---time:12.42
# Epoch:17---batch(20)训练集---ACC:87.50%---LOSS:0.438---time:12.35
# Epoch:17---batch(21)训练集---ACC:93.75%---LOSS:0.293---time:12.78
# Epoch:17---batch(22)训练集---ACC:87.50%---LOSS:0.432---time:12.58
# Epoch:17---batch(23)训练集---ACC:78.12%---LOSS:0.699---time:12.80
# Epoch:17---batch(24)训练集---ACC:75.00%---LOSS:0.534---time:12.47
# Epoch:17---batch(25)训练集---ACC:81.25%---LOSS:0.466---time:12.60
# Epoch:17---batch(26)训练集---ACC:65.62%---LOSS:0.624---time:12.69
# Epoch:17---batch(27)训练集---ACC:87.50%---LOSS:0.475---time:12.65
# Epoch:17---batch(28)训练集---ACC:93.75%---LOSS:0.201---time:12.46
# Epoch:17---batch(29)训练集---ACC:71.88%---LOSS:0.720---time:12.52
# Epoch:17---batch(30)训练集---ACC:81.25%---LOSS:0.381---time:12.63
# Epoch:17---batch(31)训练集---ACC:62.50%---LOSS:0.870---time:12.58
# Epoch:17---batch(32)训练集---ACC:87.50%---LOSS:0.628---time:12.48
# Epoch:17---batch(33)训练集---ACC:84.38%---LOSS:0.411---time:12.81
# Epoch:17---batch(34)训练集---ACC:78.12%---LOSS:0.585---time:12.61
# Epoch:17---batch(35)训练集---ACC:90.62%---LOSS:0.233---time:12.53
# Epoch:17---batch(36)训练集---ACC:90.62%---LOSS:0.315---time:12.64
# Epoch:17---batch(37)训练集---ACC:75.00%---LOSS:1.295---time:6.42
# 第17轮测试集准确率：69.00%....测试集Loss:1.4474519491195679
# Epoch:18---batch(0)训练集---ACC:78.12%---LOSS:0.693---time:12.69
# Epoch:18---batch(1)训练集---ACC:78.12%---LOSS:0.942---time:12.64
# Epoch:18---batch(2)训练集---ACC:71.88%---LOSS:0.929---time:12.57
# Epoch:18---batch(3)训练集---ACC:87.50%---LOSS:0.496---time:12.36
# Epoch:18---batch(4)训练集---ACC:87.50%---LOSS:0.449---time:12.71
# Epoch:18---batch(5)训练集---ACC:84.38%---LOSS:0.395---time:12.63
# Epoch:18---batch(6)训练集---ACC:84.38%---LOSS:0.507---time:12.63
# Epoch:18---batch(7)训练集---ACC:78.12%---LOSS:0.619---time:12.70
# Epoch:18---batch(8)训练集---ACC:90.62%---LOSS:0.471---time:12.39
# Epoch:18---batch(9)训练集---ACC:84.38%---LOSS:0.618---time:12.57
# Epoch:18---batch(10)训练集---ACC:87.50%---LOSS:0.650---time:12.50
# Epoch:18---batch(11)训练集---ACC:71.88%---LOSS:0.581---time:12.43
# Epoch:18---batch(12)训练集---ACC:84.38%---LOSS:0.302---time:12.66
# Epoch:18---batch(13)训练集---ACC:90.62%---LOSS:0.284---time:12.69
# Epoch:18---batch(14)训练集---ACC:90.62%---LOSS:0.269---time:12.37
# Epoch:18---batch(15)训练集---ACC:81.25%---LOSS:0.574---time:12.66
# Epoch:18---batch(16)训练集---ACC:81.25%---LOSS:0.533---time:12.41
# Epoch:18---batch(17)训练集---ACC:84.38%---LOSS:0.469---time:12.62
# Epoch:18---batch(18)训练集---ACC:87.50%---LOSS:0.444---time:12.62
# Epoch:18---batch(19)训练集---ACC:96.88%---LOSS:0.260---time:12.64
# Epoch:18---batch(20)训练集---ACC:78.12%---LOSS:0.508---time:12.75
# Epoch:18---batch(21)训练集---ACC:100.00%---LOSS:0.157---time:12.45
# Epoch:18---batch(22)训练集---ACC:90.62%---LOSS:0.530---time:12.66
# Epoch:18---batch(23)训练集---ACC:96.88%---LOSS:0.260---time:12.76
# Epoch:18---batch(24)训练集---ACC:84.38%---LOSS:0.446---time:12.46
# Epoch:18---batch(25)训练集---ACC:87.50%---LOSS:0.577---time:12.54
# Epoch:18---batch(26)训练集---ACC:81.25%---LOSS:0.405---time:12.64
# Epoch:18---batch(27)训练集---ACC:81.25%---LOSS:0.512---time:12.61
# Epoch:18---batch(28)训练集---ACC:78.12%---LOSS:0.453---time:12.47
# Epoch:18---batch(29)训练集---ACC:90.62%---LOSS:0.282---time:12.56
# Epoch:18---batch(30)训练集---ACC:84.38%---LOSS:0.472---time:12.57
# Epoch:18---batch(31)训练集---ACC:81.25%---LOSS:0.384---time:12.67
# Epoch:18---batch(32)训练集---ACC:84.38%---LOSS:0.346---time:12.47
# Epoch:18---batch(33)训练集---ACC:93.75%---LOSS:0.263---time:12.81
# Epoch:18---batch(34)训练集---ACC:90.62%---LOSS:0.287---time:12.69
# Epoch:18---batch(35)训练集---ACC:90.62%---LOSS:0.318---time:12.57
# Epoch:18---batch(36)训练集---ACC:78.12%---LOSS:0.531---time:12.46
# Epoch:18---batch(37)训练集---ACC:93.75%---LOSS:0.177---time:6.32
# 第18轮测试集准确率：73.50%....测试集Loss:0.8220853550093514
# Epoch:19---batch(0)训练集---ACC:87.50%---LOSS:0.421---time:12.66
# Epoch:19---batch(1)训练集---ACC:93.75%---LOSS:0.242---time:12.73
# Epoch:19---batch(2)训练集---ACC:100.00%---LOSS:0.210---time:12.75
# Epoch:19---batch(3)训练集---ACC:84.38%---LOSS:0.316---time:12.52
# Epoch:19---batch(4)训练集---ACC:93.75%---LOSS:0.242---time:12.68
# Epoch:19---batch(5)训练集---ACC:78.12%---LOSS:0.665---time:12.54
# Epoch:19---batch(6)训练集---ACC:78.12%---LOSS:0.596---time:12.57
# Epoch:19---batch(7)训练集---ACC:81.25%---LOSS:0.399---time:12.44
# Epoch:19---batch(8)训练集---ACC:93.75%---LOSS:0.302---time:12.66
# Epoch:19---batch(9)训练集---ACC:87.50%---LOSS:0.282---time:12.46
# Epoch:19---batch(10)训练集---ACC:96.88%---LOSS:0.139---time:12.63
# Epoch:19---batch(11)训练集---ACC:90.62%---LOSS:0.425---time:12.78
# Epoch:19---batch(12)训练集---ACC:87.50%---LOSS:0.403---time:12.59
# Epoch:19---batch(13)训练集---ACC:87.50%---LOSS:0.388---time:12.58
# Epoch:19---batch(14)训练集---ACC:93.75%---LOSS:0.373---time:12.32
# Epoch:19---batch(15)训练集---ACC:93.75%---LOSS:0.251---time:12.74
# Epoch:19---batch(16)训练集---ACC:87.50%---LOSS:0.258---time:12.64
# Epoch:19---batch(17)训练集---ACC:84.38%---LOSS:0.557---time:12.72
# Epoch:19---batch(18)训练集---ACC:81.25%---LOSS:0.480---time:12.33
# Epoch:19---batch(19)训练集---ACC:87.50%---LOSS:0.677---time:12.60
# Epoch:19---batch(20)训练集---ACC:96.88%---LOSS:0.188---time:12.61
# Epoch:19---batch(21)训练集---ACC:84.38%---LOSS:0.292---time:12.69
# Epoch:19---batch(22)训练集---ACC:90.62%---LOSS:0.361---time:12.36
# Epoch:19---batch(23)训练集---ACC:87.50%---LOSS:0.293---time:12.62
# Epoch:19---batch(24)训练集---ACC:100.00%---LOSS:0.081---time:12.52
# Epoch:19---batch(25)训练集---ACC:87.50%---LOSS:0.375---time:12.53
# Epoch:19---batch(26)训练集---ACC:93.75%---LOSS:0.347---time:12.56
# Epoch:19---batch(27)训练集---ACC:90.62%---LOSS:0.278---time:12.71
# Epoch:19---batch(28)训练集---ACC:100.00%---LOSS:0.146---time:12.72
# Epoch:19---batch(29)训练集---ACC:90.62%---LOSS:0.260---time:12.47
# Epoch:19---batch(30)训练集---ACC:87.50%---LOSS:0.459---time:12.45
# Epoch:19---batch(31)训练集---ACC:90.62%---LOSS:0.244---time:12.51
# Epoch:19---batch(32)训练集---ACC:90.62%---LOSS:0.278---time:12.55
# Epoch:19---batch(33)训练集---ACC:87.50%---LOSS:0.357---time:12.70
# Epoch:19---batch(34)训练集---ACC:87.50%---LOSS:0.410---time:12.69
# Epoch:19---batch(35)训练集---ACC:78.12%---LOSS:0.670---time:12.66
# Epoch:19---batch(36)训练集---ACC:68.75%---LOSS:0.693---time:12.81
# Epoch:19---batch(37)训练集---ACC:75.00%---LOSS:0.410---time:6.33
# 第19轮测试集准确率：77.50%....测试集Loss:0.8272262683936528

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

# 经典与传统的对比
# 加载经典
# Classical_Train_data = pd.read_csv('/home/WUYING_986418966_1288354473/Desktop/QCNN/src/QCNN-FC/QTCNN-MNIST/640_train.csv')
# Classical_Val_data = pd.read_csv('/home/WUYING_986418966_1288354473/Desktop/QCNN/src/QCNN-FC/QTCNN-MNIST/2091_val.csv')

# Classical_Train_data_acc = Classical_Train_data[['Train_acc']]
# Classical_Train_data_loss = Classical_Train_data[['Train_loss']]

# Classical_Val_data_acc = Classical_Val_data[['Val_acc']]
# Classical_Val_data_loss = Classical_Val_data[['Val_loss']]
def result(acc,loss,plt1_title,plt2_title,title):     # 合并结果
    #绘图
    plt.xticks(np.arange(0,20,1))
    plt.plot(acc,label=plt1_title)
    plt.plot(loss,label=plt2_title)
    plt.title(title) 
    plt.xlabel('epoch')
    plt.ylabel('probability')
    plt.legend()   #显示标签
    plt.show()

# 加载qcnn
Qcnn_Train_data = pd.read_csv('E:\\Test\VsCode_Test\\Jupyter notebook\\Tensorcircuit\\result\\Fashion\\s=1\\943_train.csv')
Qcnn_Val_data = pd.read_csv('E:\\Test\\VsCode_Test\\Jupyter notebook\\Tensorcircuit\\result\\Fashion\\s=1\\2549_val.csv')

Qcnn_Train_data_acc = Qcnn_Train_data[['Train_acc']]
Qcnn_Train_data_loss = Qcnn_Train_data[['Train_loss']]

Qcnn_Val_data_acc = Qcnn_Val_data[['Val_acc']]
Qcnn_Val_data_loss = Qcnn_Val_data[['Val_loss']]

# 损失值比较
result(Qcnn_Train_data_loss,Qcnn_Val_data_loss,'Train_set','Val_set','Loss')
# 准确率比较
result(Qcnn_Train_data_acc,Qcnn_Val_data_acc,'Train_set','Val_set','ACC')
