# %%
# %%
import tensorcircuit as tc
# import pennylane as qml
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split,Subset
import random
import os
import time
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F
import numpy as np
import csv
import tensorflow as tf


data_path = 'E:\\Test\\VsCode_Test\\Jupyter notebook\\zemp\\xLw\\data'

val_num = 200
data_num =  1200           # 需要划分的数据集大小
epochs = 20                 # 迭代轮次数
batch_size = 32

K = tc.set_backend("tensorflow")
# 归一化处理
def trans(x):
    x = np.array(x)
    x = x/255.0
    # print(x.shape)    
    return torch.from_numpy(x).float()  # 将 NumPy 数组 x 转换为 PyTorch 张量

transform = transforms.Compose([
    transforms.Resize((14, 14)),                # 将图片缩小为 14x14
    transforms.Lambda(lambda x:trans(x))
])

# 加载MNIST数据集 28X28X1   10类别   
trainset = torchvision.datasets.MNIST(root=data_path, train=True,
                                        download=False, transform=transform)
testset = torchvision.datasets.MNIST(root=data_path, train=False,
                                        download=False, transform=transform)

# 随机抽取训练集 data_num 张图片作为子集
subset_indices = random.sample(range(len(trainset)), k=data_num)
train_subset = Subset(trainset, subset_indices)

# 随机抽取测试集 data_num 张图片作为子集
subset_val = random.sample(range(len(testset)), k=val_num)
val_subset = Subset(testset, subset_val)

# 加载测试集
trainloader = torch.utils.data.DataLoader(train_subset, batch_size=batch_size,  # type: ignore
                                          shuffle=True)
testloader = torch.utils.data.DataLoader(val_subset, batch_size=batch_size,    # type: ignore
                                         shuffle=False)

# %%
n = 4
nlayers = 1

# 我们定义量子函数，
# 注意这个函数是在 tensorflow 上运行的
def qpred(x, weights):
    c = tc.Circuit(n)
    for i in range(n):
        c.h(i)
        c.ry(i,theta=x[i]*weights[i])
    for i in range(n):
        c.crx(i,(i+1)%4,theta=weights[i+4])
    return [K.real(c.expectation([tc.gates.z(), [i]])) for i in range(n)]

# %%
qpred_vmap = K.vmap(qpred, vectorized_argnums=0)        # `qpred_vmap` 是一个具有向量化能力的 TensorFlow 函数
qpred_batch = tc.interfaces.torch_interface(qpred_vmap, jit=True) # 我们进一步将函数包装为 PyTorch 函数

# %%
class QuantumNetV2(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.q_weights = torch.nn.Parameter(torch.randn([n*2]))
        self.stride = 1
        self.padding_s = 2

    def forward(self, inputs):

        in_bs,in_ch,in_w,in_h = inputs.shape

        kernel_size = 2
        # 判断输入的步长S是多少再决定是否填充
        # padding_input_inside = self.padding_s - 1
        padding_size = kernel_size - 1                              # 边界填充数 14+13=27

        padding_temp = nn.functional.pad(inputs,(13,0,13,0),mode='constant',value=0)
        # print(padding_temp.shape) # 输出 27*27
        
        # 元素间填充
        for bs in range(in_bs):
            for ch in range(in_ch):
                for i in range(in_w):     # 14是输入图片大小
                    for j in range(in_h):
                        padding_temp[bs,ch,i*2,j*2] = inputs[bs,ch,i,j]   # 对原图像（14X14）进行内部空洞
        # print(padding_temp)
        # print(padding_temp.shape)       # torch.Size([32, 1, 27, 27])                                                                                                                                                                                                                            

        # 使用转置卷积进行上采样，作为转置卷积的输入
        padd_img = nn.functional.pad(padding_temp,(padding_size,padding_size,padding_size,padding_size),mode='constant',value=0)
        # print(padd_img.shape)   # torch.Size([32, 1, 29, 29])
        
        bs, ch , h , w = padd_img.size()                      #    h=29
        
        # 转置卷积后输出特征图的大小
        h_out = self.padding_s*(in_h-1)+kernel_size           #   2（14-1）+ 2 = 28
        w_out = self.padding_s*(in_w-1)+kernel_size           #   2（14-1）+ 2 = 28

        out = torch.zeros((bs,4, h_out, w_out))
        for b in range(bs):
                for j in range(0, h_out, self.stride):
                    for k in range(0, w_out, self.stride):
                        # print(f'padd_img[b, 0, j, k]={padd_img[b, 0, j, k].shape}')
                        t1 = padd_img[b, 0, j, k]        
                        t2 = padd_img[b, 0, j, k + 1]
                        t3 = padd_img[b, 0, j + 1, k]    
                        t4 = padd_img[b, 0, j + 1, k + 1]

                        temp = torch.Tensor([t1,t2,t3,t4]) # 
                        temp = temp.view(1,4)
    
                        q_results = qpred_batch(temp, self.q_weights)     
                        for c in range(4):
                            out[b, c,j // kernel_size, k // kernel_size] = q_results[c]
        return out

# %%
# 经典CNNmodel 可进行修改
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
            
        # Quantum layer 1
        self.conv1 = QuantumNetV2()
        self.relu1 = nn.ReLU()
        self.batch1 = nn.BatchNorm2d(4)  
        
        # Fully-Connected layer 2
        self.fc2 = nn.Linear(3136,10)
                
    def forward(self, x):

        # qconv layer 1
        out = self.conv1(x)                 
        out = self.relu1(out)   
        out = self.batch1(out)
        
        #Flatten拉平操作
        out = out.view(out.size(0),-1)      # print(f'-----拉平后的维度是--{out.shape}') #  torch.Size([64, 576])
        
        #FC 第二层
        out = self.fc2(out)
        return F.log_softmax(out,dim = 1)

# %%
model = CNNModel()
loss_fun = nn.CrossEntropyLoss()
opt = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
# 准确率计算
def accuracy(output,labels):
    prediction = torch.max(output.data,1)[1]
    rights = prediction.eq(labels.data.view_as(prediction)).sum()
    return rights,len(labels)

# 绘制训练结果
def draw_result(accs,losses,title):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14, 6))   # subplots创建1行 2列的子图
    
    ax1.plot(losses) 
    ax1.set_title(title+" Loss")
    ax1.set_xlabel("Steps")
    ax1.set_ylabel("Loss")
    
    ax2.plot(accs)
    ax2.set_title(title+" Accuracy")
    ax2.set_xlabel("Steps")
    ax2.set_ylabel("Accuracy")

# %%
def train(epochs,model,loss_fun,opt,train_loader,test_loader):
    train_accuracy = []             # 训练集准确率
    train_loss = []

    val_accuracy = []               # 验证集准确率
    val_loss = []
    for epoch in range(epochs):
                ### 训练模块
        train_total_accuracy = 0    # 训练集每epoch（18个batch的和）的准确率
        train_total_loss = 0
        for batch_idx,(data,labels) in enumerate(train_loader):
            t2 = time.time()
            data = data.view(data.shape[0],1, data.shape[1], data.shape[2])
            # print(data)
            model.train()					    # 1 模型训练       
            output = model(data)			    # 2 模型输出
            loss = loss_fun(output,labels)	    # 3 计算损失

            opt.zero_grad()					    # 4 梯度清零
            loss.backward() 				    # 5 开始反向传播
            opt.step()                          # 6 梯度更新
            
            # 计算准确率
            accuracy_count, total_count = accuracy(output,labels)
            accuracy_rate = accuracy_count / total_count  # 计算准确率（预测正确的样本数除以总样本数）

            train_total_accuracy += accuracy_count
            train_total_loss +=loss.item()

            batch_time = time.time()-t2
            print(f'Epoch:{epoch}---batch({batch_idx})训练集---ACC:{accuracy_rate:.2%}---LOSS:{loss.item():.3f}---time:{batch_time:.2f}')        
        
        train_total_loss /= batch_idx+1
        train_accuracy.append(train_total_accuracy/len(train_subset))   # 保存1轮的数据 len(train_accuracy)
        train_loss.append(train_total_loss)
### 验证模块
        total_acc = 0
        total_test_loss = 0
        model.eval()
        with torch.no_grad():# 进行评测的时候网络不更新梯度
            for step,(data,target) in enumerate(test_loader):
                data = data.view(data.shape[0],1, data.shape[1], data.shape[2])            # 调整维度一致
                outputs = model(data)
                losses = loss_fun(outputs,target)                               # 计算损失

                accuracy_count, total_count = accuracy(outputs,target)          # 计算准确率
                accuracy_rate = accuracy_count / total_count                    # 计算准确率（预测正确的样本数除以总样本数）

                total_acc += accuracy_count
                total_test_loss+=losses.item()

        total_test_loss /= step + 1
        val_accuracy.append((total_acc/len(val_subset)))
        val_loss.append(total_test_loss)
        print(f'第{epoch}轮测试集准确率：{total_acc/len(val_subset):.2%}....测试集Loss:{total_test_loss}')
    
    ### 画出训练结果图 ##############
    draw_result(train_accuracy,train_loss,"Train")
    draw_result(val_accuracy,val_loss,"Val")
    
    ####  训练的结果写入文件   ##############
    with open(str(random.randint(100,999))+"_train.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Train_loss','Train_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, train_loss[i], train_accuracy[i].numpy()])
    
    #### 测试的结果写入文件  ##############
    with open(str(random.randint(1000,9999))+"_val.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Val_loss','Val_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, val_loss[i], val_accuracy[i].numpy()])

    ### 保存训练的结果
    # Loss0 = torch.tensor(save_train_loss)
    # torch.save(Loss0,'E:\\Test\\VsCode_Test\\Python\\xlw\\test1\\lw2\\epoch_{}'.format(epochs))
    return model, train_accuracy,train_loss


model, train_accuracy,train_loss = train(epochs,model,loss_fun,opt,trainloader,testloader)
# Out:
# Epoch:0---batch(0)训练集---ACC:12.50%---LOSS:2.314---time:70.91
# Epoch:0---batch(1)训练集---ACC:28.12%---LOSS:6.875---time:52.70
# Epoch:0---batch(2)训练集---ACC:12.50%---LOSS:9.732---time:52.72
# Epoch:0---batch(3)训练集---ACC:31.25%---LOSS:4.627---time:52.49
# Epoch:0---batch(4)训练集---ACC:37.50%---LOSS:3.532---time:52.65
# Epoch:0---batch(5)训练集---ACC:25.00%---LOSS:4.077---time:53.21
# Epoch:0---batch(6)训练集---ACC:50.00%---LOSS:2.149---time:47.22
# Epoch:0---batch(7)训练集---ACC:43.75%---LOSS:2.148---time:46.02
# Epoch:0---batch(8)训练集---ACC:59.38%---LOSS:2.289---time:46.26
# Epoch:0---batch(9)训练集---ACC:59.38%---LOSS:2.345---time:46.24
# Epoch:0---batch(10)训练集---ACC:50.00%---LOSS:4.248---time:46.30
# Epoch:0---batch(11)训练集---ACC:62.50%---LOSS:4.615---time:46.23
# Epoch:0---batch(12)训练集---ACC:50.00%---LOSS:5.231---time:46.11
# Epoch:0---batch(13)训练集---ACC:62.50%---LOSS:1.755---time:46.14
# Epoch:0---batch(14)训练集---ACC:65.62%---LOSS:1.516---time:47.57
# Epoch:0---batch(15)训练集---ACC:62.50%---LOSS:1.434---time:46.44
# Epoch:0---batch(16)训练集---ACC:65.62%---LOSS:1.781---time:46.42
# Epoch:0---batch(17)训练集---ACC:71.88%---LOSS:1.116---time:46.08
# Epoch:0---batch(18)训练集---ACC:56.25%---LOSS:1.321---time:44.16
# Epoch:0---batch(19)训练集---ACC:62.50%---LOSS:1.028---time:44.10
# Epoch:0---batch(20)训练集---ACC:43.75%---LOSS:1.367---time:43.50
# Epoch:0---batch(21)训练集---ACC:71.88%---LOSS:0.845---time:44.03
# Epoch:0---batch(22)训练集---ACC:71.88%---LOSS:0.919---time:43.44
# Epoch:0---batch(23)训练集---ACC:65.62%---LOSS:0.900---time:43.60
# Epoch:0---batch(24)训练集---ACC:71.88%---LOSS:0.869---time:43.50
# Epoch:0---batch(25)训练集---ACC:56.25%---LOSS:1.040---time:47.13
# Epoch:0---batch(26)训练集---ACC:87.50%---LOSS:0.428---time:46.70
# Epoch:0---batch(27)训练集---ACC:81.25%---LOSS:0.641---time:44.69
# Epoch:0---batch(28)训练集---ACC:65.62%---LOSS:0.725---time:44.32
# Epoch:0---batch(29)训练集---ACC:68.75%---LOSS:1.022---time:44.30
# Epoch:0---batch(30)训练集---ACC:71.88%---LOSS:1.151---time:44.47
# Epoch:0---batch(31)训练集---ACC:81.25%---LOSS:0.743---time:44.74
# Epoch:0---batch(32)训练集---ACC:81.25%---LOSS:0.706---time:44.12
# Epoch:0---batch(33)训练集---ACC:84.38%---LOSS:0.375---time:43.95
# Epoch:0---batch(34)训练集---ACC:75.00%---LOSS:0.876---time:45.40
# Epoch:0---batch(35)训练集---ACC:68.75%---LOSS:1.019---time:44.27
# Epoch:0---batch(36)训练集---ACC:71.88%---LOSS:0.648---time:44.75
# Epoch:0---batch(37)训练集---ACC:81.25%---LOSS:0.524---time:21.81
# 第0轮测试集准确率：27.00%....测试集Loss:3.04476489339556
# Epoch:1---batch(0)训练集---ACC:78.12%---LOSS:0.606---time:46.38
# Epoch:1---batch(1)训练集---ACC:87.50%---LOSS:0.517---time:45.19
# Epoch:1---batch(2)训练集---ACC:81.25%---LOSS:0.535---time:44.12
# Epoch:1---batch(3)训练集---ACC:75.00%---LOSS:0.643---time:44.45
# Epoch:1---batch(4)训练集---ACC:71.88%---LOSS:0.651---time:43.88
# Epoch:1---batch(5)训练集---ACC:84.38%---LOSS:0.412---time:43.16
# Epoch:1---batch(6)训练集---ACC:90.62%---LOSS:0.294---time:43.31
# Epoch:1---batch(7)训练集---ACC:81.25%---LOSS:0.494---time:43.31
# Epoch:1---batch(8)训练集---ACC:84.38%---LOSS:0.706---time:43.19
# Epoch:1---batch(9)训练集---ACC:93.75%---LOSS:0.285---time:43.00
# Epoch:1---batch(10)训练集---ACC:90.62%---LOSS:0.377---time:43.39
# Epoch:1---batch(11)训练集---ACC:84.38%---LOSS:0.647---time:43.49
# Epoch:1---batch(12)训练集---ACC:81.25%---LOSS:0.597---time:43.13
# Epoch:1---batch(13)训练集---ACC:81.25%---LOSS:0.459---time:43.48
# Epoch:1---batch(14)训练集---ACC:100.00%---LOSS:0.062---time:43.76
# Epoch:1---batch(15)训练集---ACC:81.25%---LOSS:0.418---time:44.70
# Epoch:1---batch(16)训练集---ACC:87.50%---LOSS:0.385---time:46.05
# Epoch:1---batch(17)训练集---ACC:81.25%---LOSS:0.579---time:51.78
# Epoch:1---batch(18)训练集---ACC:84.38%---LOSS:0.512---time:53.00
# Epoch:1---batch(19)训练集---ACC:84.38%---LOSS:0.384---time:47.05
# Epoch:1---batch(20)训练集---ACC:87.50%---LOSS:0.326---time:40.85
# Epoch:1---batch(21)训练集---ACC:81.25%---LOSS:0.422---time:39.73
# Epoch:1---batch(22)训练集---ACC:87.50%---LOSS:0.381---time:39.02
# Epoch:1---batch(23)训练集---ACC:78.12%---LOSS:0.778---time:38.88
# Epoch:1---batch(24)训练集---ACC:87.50%---LOSS:0.715---time:38.86
# Epoch:1---batch(25)训练集---ACC:93.75%---LOSS:0.173---time:38.85
# Epoch:1---batch(26)训练集---ACC:96.88%---LOSS:0.149---time:39.06
# Epoch:1---batch(27)训练集---ACC:87.50%---LOSS:0.242---time:38.82
# Epoch:1---batch(28)训练集---ACC:90.62%---LOSS:0.321---time:38.91
# Epoch:1---batch(29)训练集---ACC:84.38%---LOSS:0.417---time:39.44
# Epoch:1---batch(30)训练集---ACC:87.50%---LOSS:0.424---time:39.07
# Epoch:1---batch(31)训练集---ACC:87.50%---LOSS:0.494---time:39.61
# Epoch:1---batch(32)训练集---ACC:84.38%---LOSS:0.374---time:39.58
# Epoch:1---batch(33)训练集---ACC:87.50%---LOSS:0.272---time:38.93
# Epoch:1---batch(34)训练集---ACC:90.62%---LOSS:0.310---time:39.06
# Epoch:1---batch(35)训练集---ACC:84.38%---LOSS:0.586---time:44.95
# Epoch:1---batch(36)训练集---ACC:93.75%---LOSS:0.151---time:46.51
# Epoch:1---batch(37)训练集---ACC:68.75%---LOSS:0.931---time:20.70
# 第1轮测试集准确率：86.00%....测试集Loss:0.45098560622760225
# Epoch:2---batch(0)训练集---ACC:96.88%---LOSS:0.130---time:50.64
# Epoch:2---batch(1)训练集---ACC:71.88%---LOSS:0.519---time:64.52
# Epoch:2---batch(2)训练集---ACC:84.38%---LOSS:0.477---time:57.30
# Epoch:2---batch(3)训练集---ACC:90.62%---LOSS:0.382---time:45.85
# Epoch:2---batch(4)训练集---ACC:87.50%---LOSS:0.341---time:45.85
# Epoch:2---batch(5)训练集---ACC:93.75%---LOSS:0.300---time:46.03
# Epoch:2---batch(6)训练集---ACC:90.62%---LOSS:0.313---time:46.51
# Epoch:2---batch(7)训练集---ACC:90.62%---LOSS:0.279---time:46.72
# Epoch:2---batch(8)训练集---ACC:90.62%---LOSS:0.376---time:46.78
# Epoch:2---batch(9)训练集---ACC:87.50%---LOSS:0.283---time:53.14
# Epoch:2---batch(10)训练集---ACC:84.38%---LOSS:0.417---time:55.74
# Epoch:2---batch(11)训练集---ACC:90.62%---LOSS:0.304---time:52.29
# Epoch:2---batch(12)训练集---ACC:96.88%---LOSS:0.091---time:51.46
# Epoch:2---batch(13)训练集---ACC:87.50%---LOSS:0.556---time:60.88
# Epoch:2---batch(14)训练集---ACC:87.50%---LOSS:0.282---time:54.13
# Epoch:2---batch(15)训练集---ACC:84.38%---LOSS:0.439---time:63.60
# Epoch:2---batch(16)训练集---ACC:90.62%---LOSS:0.267---time:51.30
# Epoch:2---batch(17)训练集---ACC:93.75%---LOSS:0.209---time:48.54
# Epoch:2---batch(18)训练集---ACC:93.75%---LOSS:0.318---time:45.03
# Epoch:2---batch(19)训练集---ACC:87.50%---LOSS:0.442---time:55.74
# Epoch:2---batch(20)训练集---ACC:90.62%---LOSS:0.238---time:52.24
# Epoch:2---batch(21)训练集---ACC:100.00%---LOSS:0.061---time:51.79
# Epoch:2---batch(22)训练集---ACC:93.75%---LOSS:0.127---time:51.31
# Epoch:2---batch(23)训练集---ACC:93.75%---LOSS:0.170---time:51.80
# Epoch:2---batch(24)训练集---ACC:90.62%---LOSS:0.171---time:52.25
# Epoch:2---batch(25)训练集---ACC:93.75%---LOSS:0.434---time:51.44
# Epoch:2---batch(26)训练集---ACC:84.38%---LOSS:0.375---time:52.61
# Epoch:2---batch(27)训练集---ACC:90.62%---LOSS:0.340---time:52.46
# Epoch:2---batch(28)训练集---ACC:87.50%---LOSS:0.181---time:52.14
# Epoch:2---batch(29)训练集---ACC:90.62%---LOSS:0.227---time:51.53
# Epoch:2---batch(30)训练集---ACC:93.75%---LOSS:0.251---time:48.48
# Epoch:2---batch(31)训练集---ACC:93.75%---LOSS:0.136---time:47.24
# Epoch:2---batch(32)训练集---ACC:93.75%---LOSS:0.221---time:42.51
# Epoch:2---batch(33)训练集---ACC:84.38%---LOSS:0.564---time:39.25
# Epoch:2---batch(34)训练集---ACC:93.75%---LOSS:0.191---time:39.21
# Epoch:2---batch(35)训练集---ACC:84.38%---LOSS:0.495---time:38.98
# Epoch:2---batch(36)训练集---ACC:87.50%---LOSS:0.373---time:53.16
# Epoch:2---batch(37)训练集---ACC:81.25%---LOSS:0.385---time:26.37
# 第2轮测试集准确率：89.00%....测试集Loss:0.32552824914455414
# Epoch:3---batch(0)训练集---ACC:87.50%---LOSS:0.192---time:51.55
# Epoch:3---batch(1)训练集---ACC:90.62%---LOSS:0.261---time:48.87
# Epoch:3---batch(2)训练集---ACC:90.62%---LOSS:0.220---time:49.78
# Epoch:3---batch(3)训练集---ACC:87.50%---LOSS:0.219---time:41.01
# Epoch:3---batch(4)训练集---ACC:93.75%---LOSS:0.150---time:39.79
# Epoch:3---batch(5)训练集---ACC:96.88%---LOSS:0.145---time:39.58
# Epoch:3---batch(6)训练集---ACC:96.88%---LOSS:0.145---time:39.69
# Epoch:3---batch(7)训练集---ACC:90.62%---LOSS:0.278---time:40.57
# Epoch:3---batch(8)训练集---ACC:93.75%---LOSS:0.176---time:43.18
# Epoch:3---batch(9)训练集---ACC:93.75%---LOSS:0.139---time:54.43
# Epoch:3---batch(10)训练集---ACC:96.88%---LOSS:0.149---time:57.50
# Epoch:3---batch(11)训练集---ACC:93.75%---LOSS:0.171---time:76.08
# Epoch:3---batch(12)训练集---ACC:87.50%---LOSS:0.299---time:66.37
# Epoch:3---batch(13)训练集---ACC:96.88%---LOSS:0.140---time:99.07
# Epoch:3---batch(14)训练集---ACC:96.88%---LOSS:0.147---time:119.46
# Epoch:3---batch(15)训练集---ACC:93.75%---LOSS:0.140---time:73.83
# Epoch:3---batch(16)训练集---ACC:87.50%---LOSS:0.463---time:63.05
# Epoch:3---batch(17)训练集---ACC:93.75%---LOSS:0.152---time:65.38
# Epoch:3---batch(18)训练集---ACC:93.75%---LOSS:0.135---time:61.94
# Epoch:3---batch(19)训练集---ACC:84.38%---LOSS:0.594---time:54.76
# Epoch:3---batch(20)训练集---ACC:90.62%---LOSS:0.244---time:62.34
# Epoch:3---batch(21)训练集---ACC:93.75%---LOSS:0.174---time:63.87
# Epoch:3---batch(22)训练集---ACC:96.88%---LOSS:0.236---time:63.69
# Epoch:3---batch(23)训练集---ACC:90.62%---LOSS:0.326---time:64.35
# Epoch:3---batch(24)训练集---ACC:90.62%---LOSS:0.309---time:63.10
# Epoch:3---batch(25)训练集---ACC:87.50%---LOSS:0.305---time:58.99
# Epoch:3---batch(26)训练集---ACC:90.62%---LOSS:0.331---time:52.60
# Epoch:3---batch(27)训练集---ACC:93.75%---LOSS:0.207---time:47.01
# Epoch:3---batch(28)训练集---ACC:90.62%---LOSS:0.208---time:48.88
# Epoch:3---batch(29)训练集---ACC:84.38%---LOSS:0.315---time:46.75
# Epoch:3---batch(30)训练集---ACC:87.50%---LOSS:0.326---time:61.44
# Epoch:3---batch(31)训练集---ACC:87.50%---LOSS:0.500---time:62.08
# Epoch:3---batch(32)训练集---ACC:87.50%---LOSS:0.286---time:58.38
# Epoch:3---batch(33)训练集---ACC:81.25%---LOSS:0.379---time:62.49
# Epoch:3---batch(34)训练集---ACC:93.75%---LOSS:0.376---time:63.48
# Epoch:3---batch(35)训练集---ACC:93.75%---LOSS:0.399---time:62.00
# Epoch:3---batch(36)训练集---ACC:87.50%---LOSS:0.449---time:61.59
# Epoch:3---batch(37)训练集---ACC:93.75%---LOSS:0.203---time:30.74
# 第3轮测试集准确率：89.50%....测试集Loss:0.3194591722318104
# Epoch:4---batch(0)训练集---ACC:93.75%---LOSS:0.230---time:63.68
# Epoch:4---batch(1)训练集---ACC:87.50%---LOSS:0.411---time:53.11
# Epoch:4---batch(2)训练集---ACC:93.75%---LOSS:0.149---time:58.06
# Epoch:4---batch(3)训练集---ACC:96.88%---LOSS:0.133---time:62.14
# Epoch:4---batch(4)训练集---ACC:93.75%---LOSS:0.376---time:58.78
# Epoch:4---batch(5)训练集---ACC:100.00%---LOSS:0.075---time:50.34
# Epoch:4---batch(6)训练集---ACC:93.75%---LOSS:0.342---time:47.01
# Epoch:4---batch(7)训练集---ACC:90.62%---LOSS:0.269---time:46.55
# Epoch:4---batch(8)训练集---ACC:93.75%---LOSS:0.171---time:58.31
# Epoch:4---batch(9)训练集---ACC:93.75%---LOSS:0.127---time:77.26
# Epoch:4---batch(10)训练集---ACC:90.62%---LOSS:0.253---time:85.97
# Epoch:4---batch(11)训练集---ACC:93.75%---LOSS:0.215---time:82.18
# Epoch:4---batch(12)训练集---ACC:96.88%---LOSS:0.155---time:78.17
# Epoch:4---batch(13)训练集---ACC:93.75%---LOSS:0.184---time:51.89
# Epoch:4---batch(14)训练集---ACC:96.88%---LOSS:0.161---time:51.92
# Epoch:4---batch(15)训练集---ACC:87.50%---LOSS:0.395---time:51.48
# Epoch:4---batch(16)训练集---ACC:96.88%---LOSS:0.132---time:51.47
# Epoch:4---batch(17)训练集---ACC:87.50%---LOSS:0.401---time:51.48
# Epoch:4---batch(18)训练集---ACC:87.50%---LOSS:0.352---time:51.56
# Epoch:4---batch(19)训练集---ACC:100.00%---LOSS:0.072---time:51.16
# Epoch:4---batch(20)训练集---ACC:100.00%---LOSS:0.088---time:51.56
# Epoch:4---batch(21)训练集---ACC:90.62%---LOSS:0.216---time:51.61
# Epoch:4---batch(22)训练集---ACC:84.38%---LOSS:0.367---time:52.04
# Epoch:4---batch(23)训练集---ACC:93.75%---LOSS:0.093---time:51.92
# Epoch:4---batch(24)训练集---ACC:96.88%---LOSS:0.121---time:51.97
# Epoch:4---batch(25)训练集---ACC:96.88%---LOSS:0.220---time:51.90
# Epoch:4---batch(26)训练集---ACC:78.12%---LOSS:0.370---time:51.56
# Epoch:4---batch(27)训练集---ACC:96.88%---LOSS:0.135---time:50.94
# Epoch:4---batch(28)训练集---ACC:100.00%---LOSS:0.077---time:51.11
# Epoch:4---batch(29)训练集---ACC:90.62%---LOSS:0.234---time:52.08
# Epoch:4---batch(30)训练集---ACC:93.75%---LOSS:0.153---time:47.36
# Epoch:4---batch(31)训练集---ACC:96.88%---LOSS:0.247---time:45.14
# Epoch:4---batch(32)训练集---ACC:93.75%---LOSS:0.164---time:44.92
# Epoch:4---batch(33)训练集---ACC:87.50%---LOSS:0.264---time:44.75
# Epoch:4---batch(34)训练集---ACC:90.62%---LOSS:0.291---time:44.41
# Epoch:4---batch(35)训练集---ACC:84.38%---LOSS:0.411---time:44.72
# Epoch:4---batch(36)训练集---ACC:90.62%---LOSS:0.225---time:44.51
# Epoch:4---batch(37)训练集---ACC:100.00%---LOSS:0.043---time:22.14
# 第4轮测试集准确率：89.50%....测试集Loss:0.3443607475076403
# Epoch:5---batch(0)训练集---ACC:90.62%---LOSS:0.321---time:44.39
# Epoch:5---batch(1)训练集---ACC:93.75%---LOSS:0.168---time:44.52
# Epoch:5---batch(2)训练集---ACC:100.00%---LOSS:0.055---time:44.82
# Epoch:5---batch(3)训练集---ACC:90.62%---LOSS:0.147---time:44.22
# Epoch:5---batch(4)训练集---ACC:90.62%---LOSS:0.226---time:44.45
# Epoch:5---batch(5)训练集---ACC:93.75%---LOSS:0.168---time:44.80
# Epoch:5---batch(6)训练集---ACC:93.75%---LOSS:0.233---time:44.35
# Epoch:5---batch(7)训练集---ACC:93.75%---LOSS:0.124---time:44.30
# Epoch:5---batch(8)训练集---ACC:96.88%---LOSS:0.094---time:69.88
# Epoch:5---batch(9)训练集---ACC:87.50%---LOSS:0.280---time:82.22
# Epoch:5---batch(10)训练集---ACC:90.62%---LOSS:0.235---time:80.61
# Epoch:5---batch(11)训练集---ACC:93.75%---LOSS:0.139---time:64.65
# Epoch:5---batch(12)训练集---ACC:90.62%---LOSS:0.248---time:62.40
# Epoch:5---batch(13)训练集---ACC:100.00%---LOSS:0.082---time:75.89
# Epoch:5---batch(14)训练集---ACC:100.00%---LOSS:0.068---time:68.99
# Epoch:5---batch(15)训练集---ACC:84.38%---LOSS:0.422---time:58.63
# Epoch:5---batch(16)训练集---ACC:87.50%---LOSS:0.406---time:67.23
# Epoch:5---batch(17)训练集---ACC:96.88%---LOSS:0.156---time:63.68
# Epoch:5---batch(18)训练集---ACC:100.00%---LOSS:0.106---time:57.34
# Epoch:5---batch(19)训练集---ACC:100.00%---LOSS:0.080---time:67.33
# Epoch:5---batch(20)训练集---ACC:84.38%---LOSS:0.442---time:57.88
# Epoch:5---batch(21)训练集---ACC:87.50%---LOSS:0.360---time:82.29
# Epoch:5---batch(22)训练集---ACC:96.88%---LOSS:0.177---time:76.03
# Epoch:5---batch(23)训练集---ACC:93.75%---LOSS:0.169---time:77.33
# Epoch:5---batch(24)训练集---ACC:96.88%---LOSS:0.092---time:75.72
# Epoch:5---batch(25)训练集---ACC:90.62%---LOSS:0.364---time:76.59
# Epoch:5---batch(26)训练集---ACC:90.62%---LOSS:0.450---time:69.32
# Epoch:5---batch(27)训练集---ACC:96.88%---LOSS:0.131---time:47.57
# Epoch:5---batch(28)训练集---ACC:100.00%---LOSS:0.118---time:46.10
# Epoch:5---batch(29)训练集---ACC:90.62%---LOSS:0.313---time:47.93
# Epoch:5---batch(30)训练集---ACC:100.00%---LOSS:0.100---time:46.47
# Epoch:5---batch(31)训练集---ACC:96.88%---LOSS:0.117---time:46.45
# Epoch:5---batch(32)训练集---ACC:87.50%---LOSS:0.247---time:47.63
# Epoch:5---batch(33)训练集---ACC:87.50%---LOSS:0.428---time:50.59
# Epoch:5---batch(34)训练集---ACC:100.00%---LOSS:0.053---time:48.36
# Epoch:5---batch(35)训练集---ACC:93.75%---LOSS:0.184---time:47.61
# Epoch:5---batch(36)训练集---ACC:96.88%---LOSS:0.184---time:47.47
# Epoch:5---batch(37)训练集---ACC:93.75%---LOSS:0.215---time:23.63
# 第5轮测试集准确率：89.00%....测试集Loss:0.3611277661153248
# Epoch:6---batch(0)训练集---ACC:96.88%---LOSS:0.167---time:65.39
# Epoch:6---batch(1)训练集---ACC:90.62%---LOSS:0.234---time:49.76
# Epoch:6---batch(2)训练集---ACC:93.75%---LOSS:0.153---time:52.75
# Epoch:6---batch(3)训练集---ACC:93.75%---LOSS:0.132---time:53.18
# Epoch:6---batch(4)训练集---ACC:90.62%---LOSS:0.240---time:49.78
# Epoch:6---batch(5)训练集---ACC:93.75%---LOSS:0.252---time:50.49
# Epoch:6---batch(6)训练集---ACC:90.62%---LOSS:0.156---time:49.40
# Epoch:6---batch(7)训练集---ACC:87.50%---LOSS:0.252---time:50.08
# Epoch:6---batch(8)训练集---ACC:96.88%---LOSS:0.115---time:51.24
# Epoch:6---batch(9)训练集---ACC:96.88%---LOSS:0.127---time:50.22
# Epoch:6---batch(10)训练集---ACC:84.38%---LOSS:0.526---time:50.01
# Epoch:6---batch(11)训练集---ACC:93.75%---LOSS:0.203---time:50.62
# Epoch:6---batch(12)训练集---ACC:87.50%---LOSS:0.386---time:50.25
# Epoch:6---batch(13)训练集---ACC:96.88%---LOSS:0.091---time:50.08
# Epoch:6---batch(14)训练集---ACC:90.62%---LOSS:0.182---time:50.62
# Epoch:6---batch(15)训练集---ACC:96.88%---LOSS:0.148---time:50.16
# Epoch:6---batch(16)训练集---ACC:96.88%---LOSS:0.163---time:50.04
# Epoch:6---batch(17)训练集---ACC:90.62%---LOSS:0.219---time:50.48
# Epoch:6---batch(18)训练集---ACC:93.75%---LOSS:0.294---time:50.28
# Epoch:6---batch(19)训练集---ACC:96.88%---LOSS:0.117---time:50.44
# Epoch:6---batch(20)训练集---ACC:87.50%---LOSS:0.377---time:50.57
# Epoch:6---batch(21)训练集---ACC:90.62%---LOSS:0.237---time:50.24
# Epoch:6---batch(22)训练集---ACC:90.62%---LOSS:0.170---time:50.29
# Epoch:6---batch(23)训练集---ACC:93.75%---LOSS:0.197---time:50.52
# Epoch:6---batch(24)训练集---ACC:90.62%---LOSS:0.314---time:50.47
# Epoch:6---batch(25)训练集---ACC:87.50%---LOSS:0.362---time:50.50
# Epoch:6---batch(26)训练集---ACC:87.50%---LOSS:0.327---time:68.22
# Epoch:6---batch(27)训练集---ACC:90.62%---LOSS:0.351---time:53.83
# Epoch:6---batch(28)训练集---ACC:84.38%---LOSS:0.554---time:53.66
# Epoch:6---batch(29)训练集---ACC:93.75%---LOSS:0.177---time:53.87
# Epoch:6---batch(30)训练集---ACC:93.75%---LOSS:0.191---time:53.71
# Epoch:6---batch(31)训练集---ACC:96.88%---LOSS:0.137---time:86.93
# Epoch:6---batch(32)训练集---ACC:93.75%---LOSS:0.199---time:102.41
# Epoch:6---batch(33)训练集---ACC:93.75%---LOSS:0.172---time:83.72
# Epoch:6---batch(34)训练集---ACC:96.88%---LOSS:0.153---time:65.33
# Epoch:6---batch(35)训练集---ACC:87.50%---LOSS:0.290---time:69.89
# Epoch:6---batch(36)训练集---ACC:93.75%---LOSS:0.259---time:77.00
# Epoch:6---batch(37)训练集---ACC:93.75%---LOSS:0.224---time:45.30
# 第6轮测试集准确率：88.50%....测试集Loss:0.3945801875420979
# Epoch:7---batch(0)训练集---ACC:96.88%---LOSS:0.106---time:128.96
# Epoch:7---batch(1)训练集---ACC:100.00%---LOSS:0.064---time:57.87
# Epoch:7---batch(2)训练集---ACC:96.88%---LOSS:0.172---time:48.29
# Epoch:7---batch(3)训练集---ACC:90.62%---LOSS:0.201---time:57.73
# Epoch:7---batch(4)训练集---ACC:87.50%---LOSS:0.271---time:76.96
# Epoch:7---batch(5)训练集---ACC:90.62%---LOSS:0.321---time:53.46
# Epoch:7---batch(6)训练集---ACC:100.00%---LOSS:0.048---time:67.14
# Epoch:7---batch(7)训练集---ACC:90.62%---LOSS:0.135---time:53.13
# Epoch:7---batch(8)训练集---ACC:87.50%---LOSS:0.275---time:52.06
# Epoch:7---batch(9)训练集---ACC:90.62%---LOSS:0.193---time:66.66
# Epoch:7---batch(10)训练集---ACC:87.50%---LOSS:0.344---time:82.50
# Epoch:7---batch(11)训练集---ACC:90.62%---LOSS:0.354---time:80.53
# Epoch:7---batch(12)训练集---ACC:87.50%---LOSS:0.423---time:81.99
# Epoch:7---batch(13)训练集---ACC:93.75%---LOSS:0.350---time:81.30
# Epoch:7---batch(14)训练集---ACC:96.88%---LOSS:0.092---time:81.24
# Epoch:7---batch(15)训练集---ACC:96.88%---LOSS:0.071---time:85.63
# Epoch:7---batch(16)训练集---ACC:96.88%---LOSS:0.103---time:80.35
# Epoch:7---batch(17)训练集---ACC:87.50%---LOSS:0.381---time:65.64
# Epoch:7---batch(18)训练集---ACC:93.75%---LOSS:0.144---time:63.75
# Epoch:7---batch(19)训练集---ACC:96.88%---LOSS:0.129---time:45.93
# Epoch:7---batch(20)训练集---ACC:96.88%---LOSS:0.203---time:62.68
# Epoch:7---batch(21)训练集---ACC:93.75%---LOSS:0.145---time:74.37
# Epoch:7---batch(22)训练集---ACC:100.00%---LOSS:0.068---time:50.86
# Epoch:7---batch(23)训练集---ACC:90.62%---LOSS:0.194---time:47.96
# Epoch:7---batch(24)训练集---ACC:93.75%---LOSS:0.170---time:47.98
# Epoch:7---batch(25)训练集---ACC:96.88%---LOSS:0.166---time:47.84
# Epoch:7---batch(26)训练集---ACC:100.00%---LOSS:0.100---time:48.61
# Epoch:7---batch(27)训练集---ACC:93.75%---LOSS:0.079---time:48.60
# Epoch:7---batch(28)训练集---ACC:100.00%---LOSS:0.088---time:47.79
# Epoch:7---batch(29)训练集---ACC:93.75%---LOSS:0.083---time:48.03
# Epoch:7---batch(30)训练集---ACC:84.38%---LOSS:0.424---time:48.07
# Epoch:7---batch(31)训练集---ACC:93.75%---LOSS:0.146---time:48.06
# Epoch:7---batch(32)训练集---ACC:93.75%---LOSS:0.203---time:47.71
# Epoch:7---batch(33)训练集---ACC:90.62%---LOSS:0.286---time:53.57
# Epoch:7---batch(34)训练集---ACC:87.50%---LOSS:0.246---time:49.93
# Epoch:7---batch(35)训练集---ACC:93.75%---LOSS:0.228---time:50.07
# Epoch:7---batch(36)训练集---ACC:90.62%---LOSS:0.223---time:49.34
# Epoch:7---batch(37)训练集---ACC:93.75%---LOSS:0.275---time:24.68
# 第7轮测试集准确率：89.50%....测试集Loss:0.39645145407744814
# Epoch:8---batch(0)训练集---ACC:96.88%---LOSS:0.089---time:49.53
# Epoch:8---batch(1)训练集---ACC:100.00%---LOSS:0.045---time:50.23
# Epoch:8---batch(2)训练集---ACC:96.88%---LOSS:0.121---time:49.84
# Epoch:8---batch(3)训练集---ACC:93.75%---LOSS:0.119---time:49.29
# Epoch:8---batch(4)训练集---ACC:93.75%---LOSS:0.204---time:49.67
# Epoch:8---batch(5)训练集---ACC:93.75%---LOSS:0.107---time:49.86
# Epoch:8---batch(6)训练集---ACC:100.00%---LOSS:0.019---time:49.44
# Epoch:8---batch(7)训练集---ACC:93.75%---LOSS:0.188---time:49.78
# Epoch:8---batch(8)训练集---ACC:96.88%---LOSS:0.074---time:46.07
# Epoch:8---batch(9)训练集---ACC:96.88%---LOSS:0.114---time:46.10
# Epoch:8---batch(10)训练集---ACC:87.50%---LOSS:0.234---time:45.73
# Epoch:8---batch(11)训练集---ACC:96.88%---LOSS:0.110---time:46.24
# Epoch:8---batch(12)训练集---ACC:93.75%---LOSS:0.229---time:45.90
# Epoch:8---batch(13)训练集---ACC:93.75%---LOSS:0.142---time:46.90
# Epoch:8---batch(14)训练集---ACC:93.75%---LOSS:0.328---time:45.92
# Epoch:8---batch(15)训练集---ACC:96.88%---LOSS:0.164---time:46.21
# Epoch:8---batch(16)训练集---ACC:96.88%---LOSS:0.091---time:45.90
# Epoch:8---batch(17)训练集---ACC:93.75%---LOSS:0.106---time:45.88
# Epoch:8---batch(18)训练集---ACC:100.00%---LOSS:0.019---time:45.91
# Epoch:8---batch(19)训练集---ACC:87.50%---LOSS:0.233---time:45.84
# Epoch:8---batch(20)训练集---ACC:87.50%---LOSS:0.282---time:46.39
# Epoch:8---batch(21)训练集---ACC:93.75%---LOSS:0.091---time:47.15
# Epoch:8---batch(22)训练集---ACC:96.88%---LOSS:0.166---time:46.36
# Epoch:8---batch(23)训练集---ACC:100.00%---LOSS:0.073---time:45.93
# Epoch:8---batch(24)训练集---ACC:100.00%---LOSS:0.062---time:46.19
# Epoch:8---batch(25)训练集---ACC:96.88%---LOSS:0.186---time:46.10
# Epoch:8---batch(26)训练集---ACC:84.38%---LOSS:0.377---time:46.16
# Epoch:8---batch(27)训练集---ACC:96.88%---LOSS:0.085---time:46.04
# Epoch:8---batch(28)训练集---ACC:93.75%---LOSS:0.178---time:46.05
# Epoch:8---batch(29)训练集---ACC:93.75%---LOSS:0.235---time:45.99
# Epoch:8---batch(30)训练集---ACC:96.88%---LOSS:0.067---time:45.81
# Epoch:8---batch(31)训练集---ACC:96.88%---LOSS:0.116---time:45.81
# Epoch:8---batch(32)训练集---ACC:96.88%---LOSS:0.109---time:46.17
# Epoch:8---batch(33)训练集---ACC:93.75%---LOSS:0.125---time:46.64
# Epoch:8---batch(34)训练集---ACC:93.75%---LOSS:0.189---time:46.12
# Epoch:8---batch(35)训练集---ACC:93.75%---LOSS:0.166---time:46.65
# Epoch:8---batch(36)训练集---ACC:100.00%---LOSS:0.073---time:45.95
# Epoch:8---batch(37)训练集---ACC:100.00%---LOSS:0.057---time:23.20
# 第8轮测试集准确率：90.50%....测试集Loss:0.33417621893542154
# Epoch:9---batch(0)训练集---ACC:100.00%---LOSS:0.047---time:49.59
# Epoch:9---batch(1)训练集---ACC:96.88%---LOSS:0.158---time:49.63
# Epoch:9---batch(2)训练集---ACC:90.62%---LOSS:0.175---time:49.85
# Epoch:9---batch(3)训练集---ACC:100.00%---LOSS:0.079---time:49.73
# Epoch:9---batch(4)训练集---ACC:93.75%---LOSS:0.134---time:49.32
# Epoch:9---batch(5)训练集---ACC:93.75%---LOSS:0.218---time:55.64
# Epoch:9---batch(6)训练集---ACC:90.62%---LOSS:0.137---time:41.30
# Epoch:9---batch(7)训练集---ACC:90.62%---LOSS:0.182---time:41.21
# Epoch:9---batch(8)训练集---ACC:96.88%---LOSS:0.116---time:40.47
# Epoch:9---batch(9)训练集---ACC:93.75%---LOSS:0.119---time:39.85
# Epoch:9---batch(10)训练集---ACC:96.88%---LOSS:0.123---time:40.01
# Epoch:9---batch(11)训练集---ACC:100.00%---LOSS:0.041---time:40.81
# Epoch:9---batch(12)训练集---ACC:96.88%---LOSS:0.070---time:40.25
# Epoch:9---batch(13)训练集---ACC:90.62%---LOSS:0.197---time:40.88
# Epoch:9---batch(14)训练集---ACC:100.00%---LOSS:0.049---time:40.81
# Epoch:9---batch(15)训练集---ACC:90.62%---LOSS:0.262---time:40.92
# Epoch:9---batch(16)训练集---ACC:90.62%---LOSS:0.183---time:40.41
# Epoch:9---batch(17)训练集---ACC:100.00%---LOSS:0.029---time:40.50
# Epoch:9---batch(18)训练集---ACC:96.88%---LOSS:0.075---time:42.59
# Epoch:9---batch(19)训练集---ACC:90.62%---LOSS:0.208---time:41.46
# Epoch:9---batch(20)训练集---ACC:93.75%---LOSS:0.158---time:41.73
# Epoch:9---batch(21)训练集---ACC:93.75%---LOSS:0.150---time:39.99
# Epoch:9---batch(22)训练集---ACC:100.00%---LOSS:0.043---time:39.84
# Epoch:9---batch(23)训练集---ACC:100.00%---LOSS:0.055---time:40.28
# Epoch:9---batch(24)训练集---ACC:90.62%---LOSS:0.230---time:39.98
# Epoch:9---batch(25)训练集---ACC:96.88%---LOSS:0.060---time:40.25
# Epoch:9---batch(26)训练集---ACC:87.50%---LOSS:0.251---time:40.65
# Epoch:9---batch(27)训练集---ACC:93.75%---LOSS:0.122---time:39.68
# Epoch:9---batch(28)训练集---ACC:96.88%---LOSS:0.088---time:47.58
# Epoch:9---batch(29)训练集---ACC:93.75%---LOSS:0.164---time:57.32
# Epoch:9---batch(30)训练集---ACC:90.62%---LOSS:0.180---time:55.65
# Epoch:9---batch(31)训练集---ACC:93.75%---LOSS:0.288---time:49.09
# Epoch:9---batch(32)训练集---ACC:96.88%---LOSS:0.060---time:43.21
# Epoch:9---batch(33)训练集---ACC:87.50%---LOSS:0.293---time:48.17
# Epoch:9---batch(34)训练集---ACC:100.00%---LOSS:0.049---time:83.65
# Epoch:9---batch(35)训练集---ACC:93.75%---LOSS:0.132---time:95.69
# Epoch:9---batch(36)训练集---ACC:100.00%---LOSS:0.027---time:67.06
# Epoch:9---batch(37)训练集---ACC:100.00%---LOSS:0.070---time:24.64
# 第9轮测试集准确率：88.50%....测试集Loss:0.4386536202260426
# Epoch:10---batch(0)训练集---ACC:100.00%---LOSS:0.029---time:62.50
# Epoch:10---batch(1)训练集---ACC:90.62%---LOSS:0.296---time:56.69
# Epoch:10---batch(2)训练集---ACC:96.88%---LOSS:0.072---time:62.26
# Epoch:10---batch(3)训练集---ACC:96.88%---LOSS:0.135---time:53.81
# Epoch:10---batch(4)训练集---ACC:100.00%---LOSS:0.057---time:51.25
# Epoch:10---batch(5)训练集---ACC:96.88%---LOSS:0.087---time:50.76
# Epoch:10---batch(6)训练集---ACC:100.00%---LOSS:0.027---time:50.67
# Epoch:10---batch(7)训练集---ACC:100.00%---LOSS:0.030---time:47.50
# Epoch:10---batch(8)训练集---ACC:96.88%---LOSS:0.065---time:47.41
# Epoch:10---batch(9)训练集---ACC:100.00%---LOSS:0.034---time:59.53
# Epoch:10---batch(10)训练集---ACC:100.00%---LOSS:0.037---time:51.33
# Epoch:10---batch(11)训练集---ACC:100.00%---LOSS:0.017---time:49.17
# Epoch:10---batch(12)训练集---ACC:93.75%---LOSS:0.118---time:49.09
# Epoch:10---batch(13)训练集---ACC:93.75%---LOSS:0.240---time:49.47
# Epoch:10---batch(14)训练集---ACC:93.75%---LOSS:0.124---time:49.59
# Epoch:10---batch(15)训练集---ACC:96.88%---LOSS:0.131---time:50.48
# Epoch:10---batch(16)训练集---ACC:96.88%---LOSS:0.098---time:49.48
# Epoch:10---batch(17)训练集---ACC:100.00%---LOSS:0.047---time:49.79
# Epoch:10---batch(18)训练集---ACC:100.00%---LOSS:0.051---time:48.98
# Epoch:10---batch(19)训练集---ACC:96.88%---LOSS:0.130---time:49.60
# Epoch:10---batch(20)训练集---ACC:90.62%---LOSS:0.181---time:48.86
# Epoch:10---batch(21)训练集---ACC:100.00%---LOSS:0.025---time:48.30
# Epoch:10---batch(22)训练集---ACC:96.88%---LOSS:0.128---time:48.24
# Epoch:10---batch(23)训练集---ACC:84.38%---LOSS:0.257---time:48.35
# Epoch:10---batch(24)训练集---ACC:96.88%---LOSS:0.118---time:48.45
# Epoch:10---batch(25)训练集---ACC:96.88%---LOSS:0.197---time:49.02
# Epoch:10---batch(26)训练集---ACC:100.00%---LOSS:0.004---time:48.40
# Epoch:10---batch(27)训练集---ACC:93.75%---LOSS:0.153---time:48.35
# Epoch:10---batch(28)训练集---ACC:93.75%---LOSS:0.283---time:46.75
# Epoch:10---batch(29)训练集---ACC:84.38%---LOSS:0.420---time:45.54
# Epoch:10---batch(30)训练集---ACC:93.75%---LOSS:0.134---time:45.71
# Epoch:10---batch(31)训练集---ACC:100.00%---LOSS:0.059---time:46.03
# Epoch:10---batch(32)训练集---ACC:93.75%---LOSS:0.209---time:46.21
# Epoch:10---batch(33)训练集---ACC:96.88%---LOSS:0.076---time:46.15
# Epoch:10---batch(34)训练集---ACC:87.50%---LOSS:0.329---time:45.92
# Epoch:10---batch(35)训练集---ACC:84.38%---LOSS:0.418---time:45.92
# Epoch:10---batch(36)训练集---ACC:93.75%---LOSS:0.297---time:46.06
# Epoch:10---batch(37)训练集---ACC:100.00%---LOSS:0.093---time:22.99
# 第10轮测试集准确率：88.50%....测试集Loss:0.40319752054555075
# Epoch:11---batch(0)训练集---ACC:96.88%---LOSS:0.109---time:47.37
# Epoch:11---batch(1)训练集---ACC:87.50%---LOSS:0.211---time:46.36
# Epoch:11---batch(2)训练集---ACC:93.75%---LOSS:0.147---time:46.03
# Epoch:11---batch(3)训练集---ACC:100.00%---LOSS:0.050---time:45.73
# Epoch:11---batch(4)训练集---ACC:100.00%---LOSS:0.043---time:46.08
# Epoch:11---batch(5)训练集---ACC:100.00%---LOSS:0.063---time:45.94
# Epoch:11---batch(6)训练集---ACC:100.00%---LOSS:0.039---time:45.71
# Epoch:11---batch(7)训练集---ACC:90.62%---LOSS:0.210---time:45.59
# Epoch:11---batch(8)训练集---ACC:87.50%---LOSS:0.233---time:45.79
# Epoch:11---batch(9)训练集---ACC:90.62%---LOSS:0.193---time:46.37
# Epoch:11---batch(10)训练集---ACC:100.00%---LOSS:0.091---time:45.81
# Epoch:11---batch(11)训练集---ACC:90.62%---LOSS:0.236---time:45.90
# Epoch:11---batch(12)训练集---ACC:100.00%---LOSS:0.031---time:46.18
# Epoch:11---batch(13)训练集---ACC:87.50%---LOSS:0.161---time:46.13
# Epoch:11---batch(14)训练集---ACC:84.38%---LOSS:0.513---time:45.73
# Epoch:11---batch(15)训练集---ACC:93.75%---LOSS:0.145---time:45.71
# Epoch:11---batch(16)训练集---ACC:87.50%---LOSS:0.296---time:45.74
# Epoch:11---batch(17)训练集---ACC:90.62%---LOSS:0.347---time:45.62
# Epoch:11---batch(18)训练集---ACC:87.50%---LOSS:0.579---time:45.75
# Epoch:11---batch(19)训练集---ACC:84.38%---LOSS:0.283---time:45.74
# Epoch:11---batch(20)训练集---ACC:96.88%---LOSS:0.093---time:46.26
# Epoch:11---batch(21)训练集---ACC:84.38%---LOSS:0.460---time:46.92
# Epoch:11---batch(22)训练集---ACC:81.25%---LOSS:0.488---time:46.12
# Epoch:11---batch(23)训练集---ACC:96.88%---LOSS:0.092---time:45.93
# Epoch:11---batch(24)训练集---ACC:87.50%---LOSS:0.275---time:46.23
# Epoch:11---batch(25)训练集---ACC:87.50%---LOSS:0.377---time:47.05
# Epoch:11---batch(26)训练集---ACC:93.75%---LOSS:0.228---time:45.62
# Epoch:11---batch(27)训练集---ACC:100.00%---LOSS:0.070---time:45.88
# Epoch:11---batch(28)训练集---ACC:81.25%---LOSS:0.438---time:46.18
# Epoch:11---batch(29)训练集---ACC:93.75%---LOSS:0.129---time:46.35
# Epoch:11---batch(30)训练集---ACC:93.75%---LOSS:0.219---time:47.52
# Epoch:11---batch(31)训练集---ACC:100.00%---LOSS:0.025---time:45.82
# Epoch:11---batch(32)训练集---ACC:93.75%---LOSS:0.138---time:45.34
# Epoch:11---batch(33)训练集---ACC:90.62%---LOSS:0.215---time:45.93
# Epoch:11---batch(34)训练集---ACC:96.88%---LOSS:0.150---time:46.25
# Epoch:11---batch(35)训练集---ACC:96.88%---LOSS:0.101---time:46.06
# Epoch:11---batch(36)训练集---ACC:96.88%---LOSS:0.116---time:45.78
# Epoch:11---batch(37)训练集---ACC:87.50%---LOSS:0.465---time:22.89
# 第11轮测试集准确率：88.00%....测试集Loss:0.5264945306948253
# Epoch:12---batch(0)训练集---ACC:100.00%---LOSS:0.018---time:45.42
# Epoch:12---batch(1)训练集---ACC:96.88%---LOSS:0.106---time:48.28
# Epoch:12---batch(2)训练集---ACC:100.00%---LOSS:0.047---time:53.29
# Epoch:12---batch(3)训练集---ACC:100.00%---LOSS:0.057---time:46.07
# Epoch:12---batch(4)训练集---ACC:96.88%---LOSS:0.109---time:44.33
# Epoch:12---batch(5)训练集---ACC:84.38%---LOSS:0.327---time:40.20
# Epoch:12---batch(6)训练集---ACC:90.62%---LOSS:0.300---time:42.61
# Epoch:12---batch(7)训练集---ACC:100.00%---LOSS:0.055---time:47.58
# Epoch:12---batch(8)训练集---ACC:96.88%---LOSS:0.081---time:44.08
# Epoch:12---batch(9)训练集---ACC:93.75%---LOSS:0.301---time:44.49
# Epoch:12---batch(10)训练集---ACC:100.00%---LOSS:0.012---time:44.76
# Epoch:12---batch(11)训练集---ACC:93.75%---LOSS:0.185---time:41.54
# Epoch:12---batch(12)训练集---ACC:96.88%---LOSS:0.112---time:39.77
# Epoch:12---batch(13)训练集---ACC:100.00%---LOSS:0.060---time:40.36
# Epoch:12---batch(14)训练集---ACC:96.88%---LOSS:0.127---time:43.11
# Epoch:12---batch(15)训练集---ACC:90.62%---LOSS:0.243---time:52.23
# Epoch:12---batch(16)训练集---ACC:90.62%---LOSS:0.278---time:64.57
# Epoch:12---batch(17)训练集---ACC:96.88%---LOSS:0.053---time:72.24
# Epoch:12---batch(18)训练集---ACC:93.75%---LOSS:0.272---time:67.00
# Epoch:12---batch(19)训练集---ACC:96.88%---LOSS:0.073---time:65.90
# Epoch:12---batch(20)训练集---ACC:93.75%---LOSS:0.089---time:53.17
# Epoch:12---batch(21)训练集---ACC:100.00%---LOSS:0.033---time:47.62
# Epoch:12---batch(22)训练集---ACC:90.62%---LOSS:0.121---time:48.44
# Epoch:12---batch(23)训练集---ACC:93.75%---LOSS:0.105---time:53.81
# Epoch:12---batch(24)训练集---ACC:100.00%---LOSS:0.069---time:65.59
# Epoch:12---batch(25)训练集---ACC:96.88%---LOSS:0.042---time:54.43
# Epoch:12---batch(26)训练集---ACC:96.88%---LOSS:0.070---time:81.65
# Epoch:12---batch(27)训练集---ACC:84.38%---LOSS:0.395---time:86.33
# Epoch:12---batch(28)训练集---ACC:96.88%---LOSS:0.070---time:75.99
# Epoch:12---batch(29)训练集---ACC:93.75%---LOSS:0.220---time:83.01
# Epoch:12---batch(30)训练集---ACC:90.62%---LOSS:0.457---time:77.84
# Epoch:12---batch(31)训练集---ACC:100.00%---LOSS:0.087---time:88.84
# Epoch:12---batch(32)训练集---ACC:87.50%---LOSS:0.169---time:79.04
# Epoch:12---batch(33)训练集---ACC:90.62%---LOSS:0.216---time:106.13
# Epoch:12---batch(34)训练集---ACC:96.88%---LOSS:0.068---time:116.61
# Epoch:12---batch(35)训练集---ACC:100.00%---LOSS:0.053---time:82.08
# Epoch:12---batch(36)训练集---ACC:96.88%---LOSS:0.179---time:67.44
# Epoch:12---batch(37)训练集---ACC:87.50%---LOSS:0.176---time:33.44
# 第12轮测试集准确率：88.00%....测试集Loss:0.43328216671943665
# Epoch:13---batch(0)训练集---ACC:96.88%---LOSS:0.123---time:68.99
# Epoch:13---batch(1)训练集---ACC:93.75%---LOSS:0.174---time:71.11
# Epoch:13---batch(2)训练集---ACC:96.88%---LOSS:0.082---time:74.68
# Epoch:13---batch(3)训练集---ACC:100.00%---LOSS:0.011---time:63.86
# Epoch:13---batch(4)训练集---ACC:100.00%---LOSS:0.027---time:53.14
# Epoch:13---batch(5)训练集---ACC:84.38%---LOSS:0.230---time:51.01
# Epoch:13---batch(6)训练集---ACC:100.00%---LOSS:0.079---time:57.56
# Epoch:13---batch(7)训练集---ACC:93.75%---LOSS:0.118---time:49.97
# Epoch:13---batch(8)训练集---ACC:96.88%---LOSS:0.077---time:52.21
# Epoch:13---batch(9)训练集---ACC:100.00%---LOSS:0.062---time:54.23
# Epoch:13---batch(10)训练集---ACC:100.00%---LOSS:0.034---time:89.00
# Epoch:13---batch(11)训练集---ACC:93.75%---LOSS:0.162---time:99.88
# Epoch:13---batch(12)训练集---ACC:100.00%---LOSS:0.031---time:71.56
# Epoch:13---batch(13)训练集---ACC:100.00%---LOSS:0.037---time:62.95
# Epoch:13---batch(14)训练集---ACC:100.00%---LOSS:0.022---time:68.81
# Epoch:13---batch(15)训练集---ACC:100.00%---LOSS:0.013---time:77.69
# Epoch:13---batch(16)训练集---ACC:93.75%---LOSS:0.093---time:62.92
# Epoch:13---batch(17)训练集---ACC:96.88%---LOSS:0.145---time:50.52
# Epoch:13---batch(18)训练集---ACC:90.62%---LOSS:0.295---time:50.24
# Epoch:13---batch(19)训练集---ACC:93.75%---LOSS:0.149---time:50.08
# Epoch:13---batch(20)训练集---ACC:87.50%---LOSS:0.205---time:74.83
# Epoch:13---batch(21)训练集---ACC:100.00%---LOSS:0.013---time:101.31
# Epoch:13---batch(22)训练集---ACC:90.62%---LOSS:0.248---time:57.61
# Epoch:13---batch(23)训练集---ACC:100.00%---LOSS:0.007---time:71.34
# Epoch:13---batch(24)训练集---ACC:100.00%---LOSS:0.012---time:59.13
# Epoch:13---batch(25)训练集---ACC:93.75%---LOSS:0.159---time:90.92
# Epoch:13---batch(26)训练集---ACC:93.75%---LOSS:0.128---time:131.30
# Epoch:13---batch(27)训练集---ACC:93.75%---LOSS:0.201---time:128.94
# Epoch:13---batch(28)训练集---ACC:100.00%---LOSS:0.016---time:79.96
# Epoch:13---batch(29)训练集---ACC:96.88%---LOSS:0.147---time:97.96
# Epoch:13---batch(30)训练集---ACC:100.00%---LOSS:0.029---time:66.03
# Epoch:13---batch(31)训练集---ACC:93.75%---LOSS:0.162---time:53.57
# Epoch:13---batch(32)训练集---ACC:93.75%---LOSS:0.097---time:54.16
# Epoch:13---batch(33)训练集---ACC:100.00%---LOSS:0.030---time:55.04
# Epoch:13---batch(34)训练集---ACC:100.00%---LOSS:0.019---time:59.65
# Epoch:13---batch(35)训练集---ACC:96.88%---LOSS:0.088---time:54.41
# Epoch:13---batch(36)训练集---ACC:100.00%---LOSS:0.020---time:62.63
# Epoch:13---batch(37)训练集---ACC:81.25%---LOSS:0.314---time:34.53
# 第13轮测试集准确率：90.00%....测试集Loss:0.4185601494141987
# Epoch:14---batch(0)训练集---ACC:100.00%---LOSS:0.028---time:39.25
# Epoch:14---batch(1)训练集---ACC:93.75%---LOSS:0.178---time:39.69
# Epoch:14---batch(2)训练集---ACC:90.62%---LOSS:0.202---time:39.14
# Epoch:14---batch(3)训练集---ACC:100.00%---LOSS:0.041---time:39.31
# Epoch:14---batch(4)训练集---ACC:100.00%---LOSS:0.043---time:39.27
# Epoch:14---batch(5)训练集---ACC:100.00%---LOSS:0.017---time:39.34
# Epoch:14---batch(6)训练集---ACC:96.88%---LOSS:0.046---time:39.25
# Epoch:14---batch(7)训练集---ACC:96.88%---LOSS:0.058---time:39.48
# Epoch:14---batch(8)训练集---ACC:100.00%---LOSS:0.022---time:39.24
# Epoch:14---batch(9)训练集---ACC:96.88%---LOSS:0.056---time:39.25
# Epoch:14---batch(10)训练集---ACC:96.88%---LOSS:0.125---time:39.24
# Epoch:14---batch(11)训练集---ACC:100.00%---LOSS:0.036---time:39.06
# Epoch:14---batch(12)训练集---ACC:93.75%---LOSS:0.081---time:39.20
# Epoch:14---batch(13)训练集---ACC:93.75%---LOSS:0.132---time:39.51
# Epoch:14---batch(14)训练集---ACC:93.75%---LOSS:0.134---time:39.03
# Epoch:14---batch(15)训练集---ACC:96.88%---LOSS:0.070---time:39.17
# Epoch:14---batch(16)训练集---ACC:96.88%---LOSS:0.043---time:39.15
# Epoch:14---batch(17)训练集---ACC:100.00%---LOSS:0.062---time:39.16
# Epoch:14---batch(18)训练集---ACC:90.62%---LOSS:0.198---time:39.03
# Epoch:14---batch(19)训练集---ACC:96.88%---LOSS:0.101---time:38.98
# Epoch:14---batch(20)训练集---ACC:93.75%---LOSS:0.095---time:38.95
# Epoch:14---batch(21)训练集---ACC:96.88%---LOSS:0.117---time:39.10
# Epoch:14---batch(22)训练集---ACC:90.62%---LOSS:0.264---time:38.97
# Epoch:14---batch(23)训练集---ACC:96.88%---LOSS:0.119---time:39.16
# Epoch:14---batch(24)训练集---ACC:100.00%---LOSS:0.068---time:39.02
# Epoch:14---batch(25)训练集---ACC:100.00%---LOSS:0.050---time:39.07
# Epoch:14---batch(26)训练集---ACC:93.75%---LOSS:0.108---time:39.08
# Epoch:14---batch(27)训练集---ACC:96.88%---LOSS:0.114---time:39.08
# Epoch:14---batch(28)训练集---ACC:90.62%---LOSS:0.146---time:39.13
# Epoch:14---batch(29)训练集---ACC:87.50%---LOSS:0.303---time:39.02
# Epoch:14---batch(30)训练集---ACC:100.00%---LOSS:0.024---time:39.21
# Epoch:14---batch(31)训练集---ACC:100.00%---LOSS:0.075---time:38.96
# Epoch:14---batch(32)训练集---ACC:100.00%---LOSS:0.036---time:39.14
# Epoch:14---batch(33)训练集---ACC:100.00%---LOSS:0.013---time:38.93
# Epoch:14---batch(34)训练集---ACC:90.62%---LOSS:0.118---time:38.79
# Epoch:14---batch(35)训练集---ACC:96.88%---LOSS:0.061---time:39.02
# Epoch:14---batch(36)训练集---ACC:90.62%---LOSS:0.317---time:38.97
# Epoch:14---batch(37)训练集---ACC:93.75%---LOSS:0.109---time:19.47
# 第14轮测试集准确率：88.00%....测试集Loss:0.46852519256728037
# Epoch:15---batch(0)训练集---ACC:100.00%---LOSS:0.028---time:39.08
# Epoch:15---batch(1)训练集---ACC:100.00%---LOSS:0.011---time:39.11
# Epoch:15---batch(2)训练集---ACC:93.75%---LOSS:0.207---time:39.60
# Epoch:15---batch(3)训练集---ACC:96.88%---LOSS:0.092---time:39.06
# Epoch:15---batch(4)训练集---ACC:93.75%---LOSS:0.121---time:39.69
# Epoch:15---batch(5)训练集---ACC:96.88%---LOSS:0.046---time:39.03
# Epoch:15---batch(6)训练集---ACC:90.62%---LOSS:0.274---time:39.43
# Epoch:15---batch(7)训练集---ACC:100.00%---LOSS:0.013---time:39.19
# Epoch:15---batch(8)训练集---ACC:93.75%---LOSS:0.168---time:39.11
# Epoch:15---batch(9)训练集---ACC:96.88%---LOSS:0.065---time:38.93
# Epoch:15---batch(10)训练集---ACC:96.88%---LOSS:0.096---time:38.93
# Epoch:15---batch(11)训练集---ACC:96.88%---LOSS:0.081---time:39.01
# Epoch:15---batch(12)训练集---ACC:100.00%---LOSS:0.008---time:38.83
# Epoch:15---batch(13)训练集---ACC:96.88%---LOSS:0.114---time:38.97
# Epoch:15---batch(14)训练集---ACC:96.88%---LOSS:0.102---time:38.81
# Epoch:15---batch(15)训练集---ACC:87.50%---LOSS:0.371---time:39.16
# Epoch:15---batch(16)训练集---ACC:96.88%---LOSS:0.209---time:38.91
# Epoch:15---batch(17)训练集---ACC:100.00%---LOSS:0.055---time:38.92
# Epoch:15---batch(18)训练集---ACC:100.00%---LOSS:0.008---time:40.45
# Epoch:15---batch(19)训练集---ACC:100.00%---LOSS:0.014---time:38.93
# Epoch:15---batch(20)训练集---ACC:90.62%---LOSS:0.164---time:38.97
# Epoch:15---batch(21)训练集---ACC:90.62%---LOSS:0.255---time:39.56
# Epoch:15---batch(22)训练集---ACC:96.88%---LOSS:0.118---time:39.35
# Epoch:15---batch(23)训练集---ACC:93.75%---LOSS:0.130---time:39.14
# Epoch:15---batch(24)训练集---ACC:90.62%---LOSS:0.221---time:38.96
# Epoch:15---batch(25)训练集---ACC:93.75%---LOSS:0.106---time:39.07
# Epoch:15---batch(26)训练集---ACC:100.00%---LOSS:0.013---time:39.11
# Epoch:15---batch(27)训练集---ACC:100.00%---LOSS:0.008---time:38.97
# Epoch:15---batch(28)训练集---ACC:96.88%---LOSS:0.088---time:39.09
# Epoch:15---batch(29)训练集---ACC:100.00%---LOSS:0.049---time:39.19
# Epoch:15---batch(30)训练集---ACC:96.88%---LOSS:0.065---time:39.20
# Epoch:15---batch(31)训练集---ACC:90.62%---LOSS:0.234---time:39.42
# Epoch:15---batch(32)训练集---ACC:100.00%---LOSS:0.036---time:38.79
# Epoch:15---batch(33)训练集---ACC:100.00%---LOSS:0.020---time:39.57
# Epoch:15---batch(34)训练集---ACC:96.88%---LOSS:0.092---time:38.83
# Epoch:15---batch(35)训练集---ACC:96.88%---LOSS:0.093---time:38.97
# Epoch:15---batch(36)训练集---ACC:96.88%---LOSS:0.064---time:39.63
# Epoch:15---batch(37)训练集---ACC:100.00%---LOSS:0.041---time:19.74
# 第15轮测试集准确率：88.50%....测试集Loss:0.5052835047245026
# Epoch:16---batch(0)训练集---ACC:96.88%---LOSS:0.088---time:39.03
# Epoch:16---batch(1)训练集---ACC:100.00%---LOSS:0.066---time:40.34
# Epoch:16---batch(2)训练集---ACC:100.00%---LOSS:0.017---time:39.80
# Epoch:16---batch(3)训练集---ACC:96.88%---LOSS:0.045---time:39.21
# Epoch:16---batch(4)训练集---ACC:100.00%---LOSS:0.032---time:39.39
# Epoch:16---batch(5)训练集---ACC:96.88%---LOSS:0.083---time:39.44
# Epoch:16---batch(6)训练集---ACC:100.00%---LOSS:0.060---time:38.94
# Epoch:16---batch(7)训练集---ACC:96.88%---LOSS:0.051---time:38.96
# Epoch:16---batch(8)训练集---ACC:96.88%---LOSS:0.069---time:38.97
# Epoch:16---batch(9)训练集---ACC:96.88%---LOSS:0.053---time:38.94
# Epoch:16---batch(10)训练集---ACC:93.75%---LOSS:0.119---time:39.15
# Epoch:16---batch(11)训练集---ACC:100.00%---LOSS:0.010---time:38.98
# Epoch:16---batch(12)训练集---ACC:100.00%---LOSS:0.025---time:38.92
# Epoch:16---batch(13)训练集---ACC:96.88%---LOSS:0.069---time:38.92
# Epoch:16---batch(14)训练集---ACC:90.62%---LOSS:0.101---time:38.92
# Epoch:16---batch(15)训练集---ACC:96.88%---LOSS:0.061---time:38.87
# Epoch:16---batch(16)训练集---ACC:96.88%---LOSS:0.057---time:38.97
# Epoch:16---batch(17)训练集---ACC:93.75%---LOSS:0.125---time:38.77
# Epoch:16---batch(18)训练集---ACC:93.75%---LOSS:0.144---time:38.92
# Epoch:16---batch(19)训练集---ACC:93.75%---LOSS:0.148---time:38.95
# Epoch:16---batch(20)训练集---ACC:96.88%---LOSS:0.030---time:39.03
# Epoch:16---batch(21)训练集---ACC:96.88%---LOSS:0.079---time:38.90
# Epoch:16---batch(22)训练集---ACC:100.00%---LOSS:0.036---time:39.22
# Epoch:16---batch(23)训练集---ACC:96.88%---LOSS:0.059---time:38.95
# Epoch:16---batch(24)训练集---ACC:93.75%---LOSS:0.240---time:38.96
# Epoch:16---batch(25)训练集---ACC:100.00%---LOSS:0.017---time:39.14
# Epoch:16---batch(26)训练集---ACC:100.00%---LOSS:0.032---time:39.02
# Epoch:16---batch(27)训练集---ACC:96.88%---LOSS:0.081---time:39.02
# Epoch:16---batch(28)训练集---ACC:96.88%---LOSS:0.073---time:39.11
# Epoch:16---batch(29)训练集---ACC:93.75%---LOSS:0.110---time:39.09
# Epoch:16---batch(30)训练集---ACC:96.88%---LOSS:0.177---time:38.87
# Epoch:16---batch(31)训练集---ACC:96.88%---LOSS:0.060---time:39.11
# Epoch:16---batch(32)训练集---ACC:100.00%---LOSS:0.039---time:38.90
# Epoch:16---batch(33)训练集---ACC:90.62%---LOSS:0.266---time:39.20
# Epoch:16---batch(34)训练集---ACC:93.75%---LOSS:0.126---time:38.93
# Epoch:16---batch(35)训练集---ACC:96.88%---LOSS:0.058---time:38.89
# Epoch:16---batch(36)训练集---ACC:96.88%---LOSS:0.077---time:38.93
# Epoch:16---batch(37)训练集---ACC:93.75%---LOSS:0.185---time:19.41
# 第16轮测试集准确率：90.00%....测试集Loss:0.475529534476144
# Epoch:17---batch(0)训练集---ACC:96.88%---LOSS:0.066---time:38.86
# Epoch:17---batch(1)训练集---ACC:100.00%---LOSS:0.044---time:38.94
# Epoch:17---batch(2)训练集---ACC:100.00%---LOSS:0.026---time:38.98
# Epoch:17---batch(3)训练集---ACC:90.62%---LOSS:0.225---time:38.98
# Epoch:17---batch(4)训练集---ACC:96.88%---LOSS:0.123---time:38.91
# Epoch:17---batch(5)训练集---ACC:100.00%---LOSS:0.039---time:39.03
# Epoch:17---batch(6)训练集---ACC:93.75%---LOSS:0.102---time:38.94
# Epoch:17---batch(7)训练集---ACC:100.00%---LOSS:0.027---time:39.11
# Epoch:17---batch(8)训练集---ACC:100.00%---LOSS:0.017---time:38.95
# Epoch:17---batch(9)训练集---ACC:100.00%---LOSS:0.035---time:39.00
# Epoch:17---batch(10)训练集---ACC:96.88%---LOSS:0.089---time:39.15
# Epoch:17---batch(11)训练集---ACC:100.00%---LOSS:0.023---time:39.03
# Epoch:17---batch(12)训练集---ACC:96.88%---LOSS:0.060---time:39.20
# Epoch:17---batch(13)训练集---ACC:100.00%---LOSS:0.094---time:39.04
# Epoch:17---batch(14)训练集---ACC:100.00%---LOSS:0.039---time:39.44
# Epoch:17---batch(15)训练集---ACC:96.88%---LOSS:0.085---time:39.81
# Epoch:17---batch(16)训练集---ACC:100.00%---LOSS:0.020---time:39.46
# Epoch:17---batch(17)训练集---ACC:100.00%---LOSS:0.013---time:39.07
# Epoch:17---batch(18)训练集---ACC:96.88%---LOSS:0.111---time:39.02
# Epoch:17---batch(19)训练集---ACC:93.75%---LOSS:0.096---time:38.75
# Epoch:17---batch(20)训练集---ACC:96.88%---LOSS:0.037---time:39.15
# Epoch:17---batch(21)训练集---ACC:96.88%---LOSS:0.045---time:39.08
# Epoch:17---batch(22)训练集---ACC:96.88%---LOSS:0.032---time:39.04
# Epoch:17---batch(23)训练集---ACC:93.75%---LOSS:0.214---time:39.04
# Epoch:17---batch(24)训练集---ACC:96.88%---LOSS:0.079---time:38.95
# Epoch:17---batch(25)训练集---ACC:100.00%---LOSS:0.057---time:39.13
# Epoch:17---batch(26)训练集---ACC:96.88%---LOSS:0.064---time:39.13
# Epoch:17---batch(27)训练集---ACC:96.88%---LOSS:0.179---time:39.04
# Epoch:17---batch(28)训练集---ACC:96.88%---LOSS:0.083---time:39.03
# Epoch:17---batch(29)训练集---ACC:100.00%---LOSS:0.035---time:39.18
# Epoch:17---batch(30)训练集---ACC:93.75%---LOSS:0.116---time:38.81
# Epoch:17---batch(31)训练集---ACC:96.88%---LOSS:0.100---time:39.20
# Epoch:17---batch(32)训练集---ACC:93.75%---LOSS:0.123---time:39.13
# Epoch:17---batch(33)训练集---ACC:100.00%---LOSS:0.026---time:38.84
# Epoch:17---batch(34)训练集---ACC:96.88%---LOSS:0.087---time:39.02
# Epoch:17---batch(35)训练集---ACC:100.00%---LOSS:0.032---time:39.25
# Epoch:17---batch(36)训练集---ACC:96.88%---LOSS:0.118---time:38.92
# Epoch:17---batch(37)训练集---ACC:93.75%---LOSS:0.078---time:19.56
# 第17轮测试集准确率：91.00%....测试集Loss:0.47282218507358004
# Epoch:18---batch(0)训练集---ACC:100.00%---LOSS:0.045---time:39.11
# Epoch:18---batch(1)训练集---ACC:96.88%---LOSS:0.054---time:38.95
# Epoch:18---batch(2)训练集---ACC:100.00%---LOSS:0.010---time:39.01
# Epoch:18---batch(3)训练集---ACC:96.88%---LOSS:0.106---time:39.05
# Epoch:18---batch(4)训练集---ACC:100.00%---LOSS:0.040---time:39.28
# Epoch:18---batch(5)训练集---ACC:100.00%---LOSS:0.011---time:38.87
# Epoch:18---batch(6)训练集---ACC:93.75%---LOSS:0.060---time:38.82
# Epoch:18---batch(7)训练集---ACC:100.00%---LOSS:0.026---time:39.04
# Epoch:18---batch(8)训练集---ACC:96.88%---LOSS:0.128---time:38.75
# Epoch:18---batch(9)训练集---ACC:96.88%---LOSS:0.082---time:39.26
# Epoch:18---batch(10)训练集---ACC:96.88%---LOSS:0.086---time:39.14
# Epoch:18---batch(11)训练集---ACC:96.88%---LOSS:0.137---time:39.12
# Epoch:18---batch(12)训练集---ACC:100.00%---LOSS:0.003---time:39.66
# Epoch:18---batch(13)训练集---ACC:96.88%---LOSS:0.067---time:39.61
# Epoch:18---batch(14)训练集---ACC:100.00%---LOSS:0.049---time:39.62
# Epoch:18---batch(15)训练集---ACC:100.00%---LOSS:0.013---time:39.77
# Epoch:18---batch(16)训练集---ACC:100.00%---LOSS:0.033---time:39.80
# Epoch:18---batch(17)训练集---ACC:96.88%---LOSS:0.032---time:38.93
# Epoch:18---batch(18)训练集---ACC:96.88%---LOSS:0.114---time:39.18
# Epoch:18---batch(19)训练集---ACC:100.00%---LOSS:0.026---time:39.18
# Epoch:18---batch(20)训练集---ACC:96.88%---LOSS:0.140---time:38.87
# Epoch:18---batch(21)训练集---ACC:100.00%---LOSS:0.015---time:39.08
# Epoch:18---batch(22)训练集---ACC:96.88%---LOSS:0.055---time:39.94
# Epoch:18---batch(23)训练集---ACC:100.00%---LOSS:0.004---time:39.79
# Epoch:18---batch(24)训练集---ACC:100.00%---LOSS:0.033---time:39.62
# Epoch:18---batch(25)训练集---ACC:100.00%---LOSS:0.028---time:39.63
# Epoch:18---batch(26)训练集---ACC:93.75%---LOSS:0.151---time:39.56
# Epoch:18---batch(27)训练集---ACC:100.00%---LOSS:0.015---time:40.07
# Epoch:18---batch(28)训练集---ACC:96.88%---LOSS:0.067---time:39.65
# Epoch:18---batch(29)训练集---ACC:100.00%---LOSS:0.039---time:39.09
# Epoch:18---batch(30)训练集---ACC:96.88%---LOSS:0.070---time:39.79
# Epoch:18---batch(31)训练集---ACC:96.88%---LOSS:0.097---time:39.23
# Epoch:18---batch(32)训练集---ACC:100.00%---LOSS:0.044---time:39.80
# Epoch:18---batch(33)训练集---ACC:96.88%---LOSS:0.093---time:39.33
# Epoch:18---batch(34)训练集---ACC:93.75%---LOSS:0.109---time:39.61
# Epoch:18---batch(35)训练集---ACC:100.00%---LOSS:0.025---time:39.78
# Epoch:18---batch(36)训练集---ACC:100.00%---LOSS:0.020---time:39.55
# Epoch:18---batch(37)训练集---ACC:100.00%---LOSS:0.021---time:19.80
# 第18轮测试集准确率：88.00%....测试集Loss:0.44853976581777844
# Epoch:19---batch(0)训练集---ACC:96.88%---LOSS:0.076---time:38.83
# Epoch:19---batch(1)训练集---ACC:100.00%---LOSS:0.035---time:39.14
# Epoch:19---batch(2)训练集---ACC:96.88%---LOSS:0.076---time:39.03
# Epoch:19---batch(3)训练集---ACC:100.00%---LOSS:0.012---time:39.01
# Epoch:19---batch(4)训练集---ACC:96.88%---LOSS:0.051---time:39.10
# Epoch:19---batch(5)训练集---ACC:100.00%---LOSS:0.022---time:39.51
# Epoch:19---batch(6)训练集---ACC:100.00%---LOSS:0.029---time:39.13
# Epoch:19---batch(7)训练集---ACC:96.88%---LOSS:0.089---time:39.66
# Epoch:19---batch(8)训练集---ACC:100.00%---LOSS:0.018---time:39.26
# Epoch:19---batch(9)训练集---ACC:96.88%---LOSS:0.077---time:39.19
# Epoch:19---batch(10)训练集---ACC:96.88%---LOSS:0.106---time:38.95
# Epoch:19---batch(11)训练集---ACC:100.00%---LOSS:0.041---time:38.99
# Epoch:19---batch(12)训练集---ACC:100.00%---LOSS:0.016---time:39.60
# Epoch:19---batch(13)训练集---ACC:96.88%---LOSS:0.067---time:39.34
# Epoch:19---batch(14)训练集---ACC:100.00%---LOSS:0.032---time:38.94
# Epoch:19---batch(15)训练集---ACC:100.00%---LOSS:0.020---time:39.59
# Epoch:19---batch(16)训练集---ACC:96.88%---LOSS:0.035---time:39.71
# Epoch:19---batch(17)训练集---ACC:90.62%---LOSS:0.104---time:39.28
# Epoch:19---batch(18)训练集---ACC:100.00%---LOSS:0.048---time:39.42
# Epoch:19---batch(19)训练集---ACC:96.88%---LOSS:0.054---time:39.09
# Epoch:19---batch(20)训练集---ACC:100.00%---LOSS:0.025---time:39.09
# Epoch:19---batch(21)训练集---ACC:100.00%---LOSS:0.008---time:38.96
# Epoch:19---batch(22)训练集---ACC:96.88%---LOSS:0.057---time:39.11
# Epoch:19---batch(23)训练集---ACC:100.00%---LOSS:0.055---time:39.13
# Epoch:19---batch(24)训练集---ACC:93.75%---LOSS:0.108---time:39.13
# Epoch:19---batch(25)训练集---ACC:96.88%---LOSS:0.110---time:38.93
# Epoch:19---batch(26)训练集---ACC:100.00%---LOSS:0.005---time:38.96
# Epoch:19---batch(27)训练集---ACC:100.00%---LOSS:0.032---time:39.15
# Epoch:19---batch(28)训练集---ACC:96.88%---LOSS:0.055---time:38.98
# Epoch:19---batch(29)训练集---ACC:100.00%---LOSS:0.013---time:39.55
# Epoch:19---batch(30)训练集---ACC:100.00%---LOSS:0.067---time:39.04
# Epoch:19---batch(31)训练集---ACC:100.00%---LOSS:0.054---time:39.05
# Epoch:19---batch(32)训练集---ACC:96.88%---LOSS:0.072---time:39.08
# Epoch:19---batch(33)训练集---ACC:93.75%---LOSS:0.200---time:39.30
# Epoch:19---batch(34)训练集---ACC:96.88%---LOSS:0.055---time:39.09
# Epoch:19---batch(35)训练集---ACC:100.00%---LOSS:0.051---time:38.85
# Epoch:19---batch(36)训练集---ACC:100.00%---LOSS:0.027---time:39.20
# Epoch:19---batch(37)训练集---ACC:100.00%---LOSS:0.020---time:19.48
# 第19轮测试集准确率：88.00%....测试集Loss:0.4764397655214582
