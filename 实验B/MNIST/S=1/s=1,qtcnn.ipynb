# %%
# %%
import tensorcircuit as tc
import pennylane as qml
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split,Subset
import random
import os
import time
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F
import numpy as np
import csv
import tensorflow as tf


data_path = 'E:\\Test\\VsCode_Test\\Jupyter notebook\\zemp\\xLw\\data'

val_num = 200
data_num =  1200           # 需要划分的数据集大小
epochs = 20                 # 迭代轮次数
batch_size = 32

K = tc.set_backend("tensorflow")
# 归一化处理
def trans(x):
    x = np.array(x)
    x = x/255.0
    # print(x.shape)    
    return torch.from_numpy(x).float()  # 将 NumPy 数组 x 转换为 PyTorch 张量

transform = transforms.Compose([
    transforms.Resize((14, 14)),                # 将图片缩小为 14x14
    transforms.Lambda(lambda x:trans(x))
])

# 加载MNIST数据集 28X28X1   10类别   
trainset = torchvision.datasets.MNIST(root=data_path, train=True,
                                        download=False, transform=transform)
testset = torchvision.datasets.MNIST(root=data_path, train=False,
                                        download=False, transform=transform)

# 随机抽取训练集 data_num 张图片作为子集
subset_indices = random.sample(range(len(trainset)), k=data_num)
train_subset = Subset(trainset, subset_indices)

# 随机抽取测试集 data_num 张图片作为子集
subset_val = random.sample(range(len(testset)), k=val_num)
val_subset = Subset(testset, subset_val)

# 加载测试集
trainloader = torch.utils.data.DataLoader(train_subset, batch_size=batch_size,  # type: ignore
                                          shuffle=True)
testloader = torch.utils.data.DataLoader(val_subset, batch_size=batch_size,    # type: ignore
                                         shuffle=False)

# %%
n = 4
nlayers = 1


# 我们定义量子函数，
# 注意这个函数是在 tensorflow 上运行的
def qpred(x, weights):
    c = tc.Circuit(n)
    for i in range(n):
        c.h(i)
        c.ry(i,theta=x[i]*weights[i])
    for i in range(n):
        c.crx(i,(i+1)%4,theta=weights[i+4])
    return [K.real(c.expectation([tc.gates.z(), [i]])) for i in range(n)]

# %%
qpred_vmap = K.vmap(qpred, vectorized_argnums=0)        # `qpred_vmap` 是一个具有向量化能力的 TensorFlow 函数
qpred_batch = tc.interfaces.torch_interface(qpred_vmap, jit=True) # 我们进一步将函数包装为 PyTorch 函数

# %%
class QuantumNetV2(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.q_weights = torch.nn.Parameter(torch.randn([n*2]))
        self.stride = 1

    def forward(self, inputs):
        kernel_size = 2
        
        # 使用转置卷积进行上采样
        padding_size = kernel_size - 1                  # 1 先进行填充
        padd_img = nn.functional.pad(inputs,(padding_size,padding_size,padding_size,padding_size),mode='constant',value=0)
        # padding_img.size()=16
        bs, ch , h , w = padd_img.size()                #    h=16

        h_out = self.stride*(h-1)+kernel_size           #   （14-1）+ 2 = 15
        w_out = self.stride*(w-1)+kernel_size           #   （14-1）+ 2 = 15
        out = torch.zeros((bs,4, h_out, w_out))
        for b in range(bs):
                for j in range(0, h_out-padding_size-1, self.stride):
                    for k in range(0, w_out-padding_size-1, self.stride):
                        # print(f'padd_img[b, 0, j, k]={padd_img[b, 0, j, k].shape}')
                        t1 = padd_img[b, 0, j, k]        
                        t2 = padd_img[b, 0, j, k + 1]
                        t3 = padd_img[b, 0, j + 1, k]    
                        t4 = padd_img[b, 0, j + 1, k + 1]

                        temp = torch.Tensor([t1,t2,t3,t4]) # 
                        temp = temp.view(1,4)

                        # temp = torch.unsqueeze(temp, 0)      
                        q_results = qpred_batch(temp, self.q_weights)     
                        for c in range(4):
                            out[b, c,j // kernel_size, k // kernel_size] = q_results[c]
        return out

# 经典CNNmodel 可进行修改
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
            
        # Quantum layer 1
        self.conv1 = QuantumNetV2()
        self.relu1 = nn.ReLU()
        self.batch1 = nn.BatchNorm2d(4)  # 4
                
        # Fully-Connected layer 2
        self.fc2 = nn.Linear(1156,10)
                
    def forward(self, x):

        # qconv layer 1
        out = self.conv1(x)                 
        out = self.relu1(out)   
        out = self.batch1(out)
        
        #Flatten拉平操作
        out = out.view(out.size(0),-1)      # print(f'-----拉平后的维度是--{out.shape}') #  torch.Size([64, 576])
        
        #FC 第二层
        out = self.fc2(out)
        return F.log_softmax(out,dim = 1)

# %%
model = CNNModel()
loss_fun = nn.CrossEntropyLoss()
opt = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
# 准确率计算
def accuracy(output,labels):
    prediction = torch.max(output.data,1)[1]
    rights = prediction.eq(labels.data.view_as(prediction)).sum()
    return rights,len(labels)

# 绘制训练结果
def draw_result(accs,losses,title):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14, 6))   # subplots创建1行 2列的子图
    
    ax1.plot(losses) 
    ax1.set_title(title+" Loss")
    ax1.set_xlabel("Steps")
    ax1.set_ylabel("Loss")
    
    ax2.plot(accs)
    ax2.set_title(title+" Accuracy")
    ax2.set_xlabel("Steps")
    ax2.set_ylabel("Accuracy")

# %%
def train(epochs,model,loss_fun,opt,train_loader,test_loader):
    train_accuracy = []             # 训练集准确率
    train_loss = []

    val_accuracy = []               # 验证集准确率
    val_loss = []
    for epoch in range(epochs):
                ### 训练模块
        train_total_accuracy = 0    # 训练集每epoch（18个batch的和）的准确率
        train_total_loss = 0
        for batch_idx,(data,labels) in enumerate(train_loader):
            t2 = time.time()
            data = data.view(data.shape[0],1, data.shape[1], data.shape[2])
            
            model.train()					    # 1 模型训练       
            output = model(data)			    # 2 模型输出
            # print(f'output.shape is {output.shape}')    # output.shape is torch.Size([64, 4, 17, 17])
            # print(f'labels.shape is {labels.shape}')    # labels.shape is torch.Size([64])
            loss = loss_fun(output,labels)	    # 3 计算损失

            opt.zero_grad()					    # 4 梯度清零
            loss.backward() 				    # 5 开始反向传播
            opt.step()                          # 6 梯度更新
            
            # 计算准确率
            accuracy_count, total_count = accuracy(output,labels)
            accuracy_rate = accuracy_count / total_count  # 计算准确率（预测正确的样本数除以总样本数）

            train_total_accuracy += accuracy_count
            train_total_loss +=loss.item()

            batch_time = time.time()-t2
            print(f'Epoch:{epoch}---batch({batch_idx})训练集---ACC:{accuracy_rate:.2%}---LOSS:{loss.item():.3f}---time:{batch_time:.2f}')        
        
        train_total_loss /= batch_idx+1
        train_accuracy.append(train_total_accuracy/len(train_subset))   # 保存1轮的数据 len(train_accuracy)
        train_loss.append(train_total_loss)
### 验证模块
        total_acc = 0
        total_test_loss = 0
        model.eval()
        with torch.no_grad():# 进行评测的时候网络不更新梯度
            for step,(data,target) in enumerate(test_loader):
                data = data.view(data.shape[0],1, data.shape[1], data.shape[2])            # 调整维度一致
                outputs = model(data)
                losses = loss_fun(outputs,target)                               # 计算损失

                accuracy_count, total_count = accuracy(outputs,target)          # 计算准确率
                accuracy_rate = accuracy_count / total_count                    # 计算准确率（预测正确的样本数除以总样本数）

                total_acc += accuracy_count
                total_test_loss+=losses.item()

        total_test_loss /= step + 1
        val_accuracy.append((total_acc/len(val_subset)))
        val_loss.append(total_test_loss)
        print(f'第{epoch}轮测试集准确率：{total_acc/len(val_subset):.2%}....测试集Loss:{total_test_loss}')
    
    ### 画出训练结果图 ##############
    draw_result(train_accuracy,train_loss,"Train")
    draw_result(val_accuracy,val_loss,"Val")
    
    ####  训练的结果写入文件   ##############
    with open(str(random.randint(100,999))+"_train.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Train_loss','Train_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, train_loss[i], train_accuracy[i].numpy()])
    
    #### 测试的结果写入文件  ##############
    with open(str(random.randint(1000,9999))+"_val.csv",mode='w',newline='') as file:         # newline='' 指定行与行之间的分隔符，每一行都将以换行符（'\n'）作为分隔符
        wirter = csv.writer(file)                               # 以视图模式打开csv文件
        wirter.writerow(['Epoch','Val_loss','Val_acc'])     # 将一行数据写入csv文件中，这里写入标题行
        for i in range(epochs):                                 # 写入数据行
            wirter.writerow([i, val_loss[i], val_accuracy[i].numpy()])

    ### 保存训练的结果
    # Loss0 = torch.tensor(save_train_loss)
    # torch.save(Loss0,'E:\\Test\\VsCode_Test\\Python\\xlw\\test1\\lw2\\epoch_{}'.format(epochs))
    return model, train_accuracy,train_loss

model, train_accuracy,train_loss = train(epochs,model,loss_fun,opt,trainloader,testloader)
# Out:
# Epoch:0---batch(0)训练集---ACC:18.75%---LOSS:2.464---time:18.99
# Epoch:0---batch(1)训练集---ACC:12.50%---LOSS:2.781---time:15.38
# Epoch:0---batch(2)训练集---ACC:18.75%---LOSS:2.749---time:17.33
# Epoch:0---batch(3)训练集---ACC:34.38%---LOSS:2.295---time:16.24
# Epoch:0---batch(4)训练集---ACC:12.50%---LOSS:2.314---time:23.28
# Epoch:0---batch(5)训练集---ACC:31.25%---LOSS:1.707---time:20.64
# Epoch:0---batch(6)训练集---ACC:56.25%---LOSS:1.445---time:20.54
# Epoch:0---batch(7)训练集---ACC:56.25%---LOSS:1.384---time:16.73
# Epoch:0---batch(8)训练集---ACC:46.88%---LOSS:1.496---time:16.58
# Epoch:0---batch(9)训练集---ACC:56.25%---LOSS:1.418---time:16.45
# Epoch:0---batch(10)训练集---ACC:62.50%---LOSS:1.170---time:16.66
# Epoch:0---batch(11)训练集---ACC:78.12%---LOSS:1.166---time:16.52
# Epoch:0---batch(12)训练集---ACC:65.62%---LOSS:1.258---time:16.26
# Epoch:0---batch(13)训练集---ACC:62.50%---LOSS:1.218---time:16.72
# Epoch:0---batch(14)训练集---ACC:56.25%---LOSS:1.173---time:20.22
# Epoch:0---batch(15)训练集---ACC:75.00%---LOSS:1.020---time:19.14
# Epoch:0---batch(16)训练集---ACC:53.12%---LOSS:1.345---time:18.47
# Epoch:0---batch(17)训练集---ACC:68.75%---LOSS:1.013---time:16.33
# Epoch:0---batch(18)训练集---ACC:68.75%---LOSS:0.874---time:16.96
# Epoch:0---batch(19)训练集---ACC:71.88%---LOSS:1.238---time:17.68
# Epoch:0---batch(20)训练集---ACC:59.38%---LOSS:1.114---time:14.82
# Epoch:0---batch(21)训练集---ACC:75.00%---LOSS:0.639---time:16.12
# Epoch:0---batch(22)训练集---ACC:71.88%---LOSS:0.840---time:13.85
# Epoch:0---batch(23)训练集---ACC:62.50%---LOSS:0.910---time:13.43
# Epoch:0---batch(24)训练集---ACC:68.75%---LOSS:0.797---time:13.91
# Epoch:0---batch(25)训练集---ACC:68.75%---LOSS:1.036---time:16.54
# Epoch:0---batch(26)训练集---ACC:84.38%---LOSS:0.789---time:14.28
# Epoch:0---batch(27)训练集---ACC:75.00%---LOSS:0.751---time:14.89
# Epoch:0---batch(28)训练集---ACC:71.88%---LOSS:1.040---time:16.47
# Epoch:0---batch(29)训练集---ACC:75.00%---LOSS:0.848---time:16.39
# Epoch:0---batch(30)训练集---ACC:65.62%---LOSS:0.948---time:15.14
# Epoch:0---batch(31)训练集---ACC:65.62%---LOSS:0.862---time:15.35
# Epoch:0---batch(32)训练集---ACC:81.25%---LOSS:0.686---time:12.84
# Epoch:0---batch(33)训练集---ACC:90.62%---LOSS:0.360---time:14.63
# Epoch:0---batch(34)训练集---ACC:84.38%---LOSS:0.635---time:15.54
# Epoch:0---batch(35)训练集---ACC:78.12%---LOSS:0.669---time:15.70
# Epoch:0---batch(36)训练集---ACC:84.38%---LOSS:0.420---time:12.91
# Epoch:0---batch(37)训练集---ACC:75.00%---LOSS:0.727---time:6.38
# 第0轮测试集准确率：50.50%....测试集Loss:1.5813059295926775
# Epoch:1---batch(0)训练集---ACC:78.12%---LOSS:0.533---time:13.86
# Epoch:1---batch(1)训练集---ACC:71.88%---LOSS:0.877---time:13.08
# Epoch:1---batch(2)训练集---ACC:90.62%---LOSS:0.465---time:12.24
# Epoch:1---batch(3)训练集---ACC:62.50%---LOSS:0.819---time:12.97
# Epoch:1---batch(4)训练集---ACC:75.00%---LOSS:0.867---time:11.38
# Epoch:1---batch(5)训练集---ACC:78.12%---LOSS:0.808---time:11.23
# Epoch:1---batch(6)训练集---ACC:84.38%---LOSS:0.464---time:11.20
# Epoch:1---batch(7)训练集---ACC:81.25%---LOSS:0.847---time:11.87
# Epoch:1---batch(8)训练集---ACC:78.12%---LOSS:0.461---time:11.63
# Epoch:1---batch(9)训练集---ACC:84.38%---LOSS:0.541---time:11.86
# Epoch:1---batch(10)训练集---ACC:75.00%---LOSS:0.761---time:11.71
# Epoch:1---batch(11)训练集---ACC:78.12%---LOSS:0.517---time:11.78
# Epoch:1---batch(12)训练集---ACC:78.12%---LOSS:0.604---time:11.90
# Epoch:1---batch(13)训练集---ACC:81.25%---LOSS:0.653---time:11.81
# Epoch:1---batch(14)训练集---ACC:87.50%---LOSS:0.373---time:10.99
# Epoch:1---batch(15)训练集---ACC:87.50%---LOSS:0.375---time:11.23
# Epoch:1---batch(16)训练集---ACC:84.38%---LOSS:0.553---time:11.80
# Epoch:1---batch(17)训练集---ACC:84.38%---LOSS:0.544---time:11.95
# Epoch:1---batch(18)训练集---ACC:90.62%---LOSS:0.340---time:12.43
# Epoch:1---batch(19)训练集---ACC:93.75%---LOSS:0.421---time:11.66
# Epoch:1---batch(20)训练集---ACC:84.38%---LOSS:0.680---time:11.67
# Epoch:1---batch(21)训练集---ACC:84.38%---LOSS:0.487---time:11.57
# Epoch:1---batch(22)训练集---ACC:75.00%---LOSS:0.665---time:11.23
# Epoch:1---batch(23)训练集---ACC:75.00%---LOSS:0.520---time:11.28
# Epoch:1---batch(24)训练集---ACC:81.25%---LOSS:0.528---time:11.53
# Epoch:1---batch(25)训练集---ACC:87.50%---LOSS:0.377---time:12.39
# Epoch:1---batch(26)训练集---ACC:84.38%---LOSS:0.406---time:12.17
# Epoch:1---batch(27)训练集---ACC:87.50%---LOSS:0.311---time:13.98
# Epoch:1---batch(28)训练集---ACC:90.62%---LOSS:0.476---time:13.04
# Epoch:1---batch(29)训练集---ACC:84.38%---LOSS:0.390---time:11.36
# Epoch:1---batch(30)训练集---ACC:81.25%---LOSS:0.538---time:11.98
# Epoch:1---batch(31)训练集---ACC:87.50%---LOSS:0.411---time:12.79
# Epoch:1---batch(32)训练集---ACC:81.25%---LOSS:0.608---time:12.19
# Epoch:1---batch(33)训练集---ACC:81.25%---LOSS:0.577---time:12.46
# Epoch:1---batch(34)训练集---ACC:84.38%---LOSS:0.325---time:13.88
# Epoch:1---batch(35)训练集---ACC:93.75%---LOSS:0.286---time:12.83
# Epoch:1---batch(36)训练集---ACC:81.25%---LOSS:0.531---time:12.50
# Epoch:1---batch(37)训练集---ACC:68.75%---LOSS:1.046---time:6.01
# 第1轮测试集准确率：82.50%....测试集Loss:0.5731493788106101
# Epoch:2---batch(0)训练集---ACC:96.88%---LOSS:0.260---time:11.84
# Epoch:2---batch(1)训练集---ACC:84.38%---LOSS:0.440---time:11.07
# Epoch:2---batch(2)训练集---ACC:87.50%---LOSS:0.441---time:12.00
# Epoch:2---batch(3)训练集---ACC:96.88%---LOSS:0.254---time:11.51
# Epoch:2---batch(4)训练集---ACC:81.25%---LOSS:0.402---time:12.59
# Epoch:2---batch(5)训练集---ACC:78.12%---LOSS:0.846---time:11.83
# Epoch:2---batch(6)训练集---ACC:87.50%---LOSS:0.491---time:12.32
# Epoch:2---batch(7)训练集---ACC:84.38%---LOSS:0.597---time:12.00
# Epoch:2---batch(8)训练集---ACC:81.25%---LOSS:0.584---time:12.84
# Epoch:2---batch(9)训练集---ACC:90.62%---LOSS:0.253---time:14.65
# Epoch:2---batch(10)训练集---ACC:87.50%---LOSS:0.388---time:13.62
# Epoch:2---batch(11)训练集---ACC:84.38%---LOSS:0.396---time:12.50
# Epoch:2---batch(12)训练集---ACC:84.38%---LOSS:0.354---time:13.46
# Epoch:2---batch(13)训练集---ACC:87.50%---LOSS:0.550---time:12.67
# Epoch:2---batch(14)训练集---ACC:90.62%---LOSS:0.402---time:12.04
# Epoch:2---batch(15)训练集---ACC:84.38%---LOSS:0.452---time:12.36
# Epoch:2---batch(16)训练集---ACC:90.62%---LOSS:0.424---time:12.47
# Epoch:2---batch(17)训练集---ACC:87.50%---LOSS:0.431---time:12.40
# Epoch:2---batch(18)训练集---ACC:78.12%---LOSS:0.707---time:12.15
# Epoch:2---batch(19)训练集---ACC:87.50%---LOSS:0.529---time:11.64
# Epoch:2---batch(20)训练集---ACC:84.38%---LOSS:0.468---time:12.07
# Epoch:2---batch(21)训练集---ACC:90.62%---LOSS:0.338---time:14.07
# Epoch:2---batch(22)训练集---ACC:84.38%---LOSS:0.343---time:13.32
# Epoch:2---batch(23)训练集---ACC:93.75%---LOSS:0.331---time:13.24
# Epoch:2---batch(24)训练集---ACC:87.50%---LOSS:0.482---time:13.55
# Epoch:2---batch(25)训练集---ACC:90.62%---LOSS:0.304---time:13.05
# Epoch:2---batch(26)训练集---ACC:75.00%---LOSS:0.854---time:12.27
# Epoch:2---batch(27)训练集---ACC:84.38%---LOSS:0.488---time:11.98
# Epoch:2---batch(28)训练集---ACC:87.50%---LOSS:0.345---time:11.94
# Epoch:2---batch(29)训练集---ACC:84.38%---LOSS:0.393---time:12.14
# Epoch:2---batch(30)训练集---ACC:78.12%---LOSS:0.632---time:13.30
# Epoch:2---batch(31)训练集---ACC:93.75%---LOSS:0.211---time:13.18
# Epoch:2---batch(32)训练集---ACC:87.50%---LOSS:0.504---time:13.39
# Epoch:2---batch(33)训练集---ACC:87.50%---LOSS:0.415---time:12.89
# Epoch:2---batch(34)训练集---ACC:96.88%---LOSS:0.362---time:12.74
# Epoch:2---batch(35)训练集---ACC:84.38%---LOSS:0.415---time:13.03
# Epoch:2---batch(36)训练集---ACC:87.50%---LOSS:0.410---time:12.31
# Epoch:2---batch(37)训练集---ACC:93.75%---LOSS:0.280---time:5.90
# 第2轮测试集准确率：83.00%....测试集Loss:0.5565686311040606
# Epoch:3---batch(0)训练集---ACC:96.88%---LOSS:0.217---time:12.02
# Epoch:3---batch(1)训练集---ACC:84.38%---LOSS:0.851---time:11.58
# Epoch:3---batch(2)训练集---ACC:90.62%---LOSS:0.311---time:11.77
# Epoch:3---batch(3)训练集---ACC:96.88%---LOSS:0.253---time:11.51
# Epoch:3---batch(4)训练集---ACC:84.38%---LOSS:0.597---time:11.82
# Epoch:3---batch(5)训练集---ACC:96.88%---LOSS:0.104---time:11.81
# Epoch:3---batch(6)训练集---ACC:84.38%---LOSS:0.611---time:11.45
# Epoch:3---batch(7)训练集---ACC:93.75%---LOSS:0.269---time:11.99
# Epoch:3---batch(8)训练集---ACC:93.75%---LOSS:0.193---time:11.52
# Epoch:3---batch(9)训练集---ACC:81.25%---LOSS:0.711---time:11.62
# Epoch:3---batch(10)训练集---ACC:93.75%---LOSS:0.180---time:11.21
# Epoch:3---batch(11)训练集---ACC:87.50%---LOSS:0.303---time:11.79
# Epoch:3---batch(12)训练集---ACC:84.38%---LOSS:0.508---time:11.68
# Epoch:3---batch(13)训练集---ACC:96.88%---LOSS:0.127---time:11.20
# Epoch:3---batch(14)训练集---ACC:93.75%---LOSS:0.166---time:11.01
# Epoch:3---batch(15)训练集---ACC:87.50%---LOSS:0.283---time:11.49
# Epoch:3---batch(16)训练集---ACC:87.50%---LOSS:0.359---time:11.62
# Epoch:3---batch(17)训练集---ACC:84.38%---LOSS:0.473---time:14.17
# Epoch:3---batch(18)训练集---ACC:84.38%---LOSS:0.793---time:12.33
# Epoch:3---batch(19)训练集---ACC:84.38%---LOSS:0.479---time:13.14
# Epoch:3---batch(20)训练集---ACC:96.88%---LOSS:0.168---time:11.63
# Epoch:3---batch(21)训练集---ACC:71.88%---LOSS:0.670---time:11.04
# Epoch:3---batch(22)训练集---ACC:87.50%---LOSS:0.321---time:10.98
# Epoch:3---batch(23)训练集---ACC:93.75%---LOSS:0.283---time:12.39
# Epoch:3---batch(24)训练集---ACC:87.50%---LOSS:0.270---time:11.79
# Epoch:3---batch(25)训练集---ACC:87.50%---LOSS:0.292---time:11.70
# Epoch:3---batch(26)训练集---ACC:96.88%---LOSS:0.170---time:13.17
# Epoch:3---batch(27)训练集---ACC:90.62%---LOSS:0.264---time:12.02
# Epoch:3---batch(28)训练集---ACC:81.25%---LOSS:0.549---time:12.08
# Epoch:3---batch(29)训练集---ACC:84.38%---LOSS:0.346---time:11.90
# Epoch:3---batch(30)训练集---ACC:81.25%---LOSS:0.526---time:12.00
# Epoch:3---batch(31)训练集---ACC:84.38%---LOSS:0.425---time:11.89
# Epoch:3---batch(32)训练集---ACC:87.50%---LOSS:0.312---time:11.74
# Epoch:3---batch(33)训练集---ACC:90.62%---LOSS:0.431---time:11.74
# Epoch:3---batch(34)训练集---ACC:93.75%---LOSS:0.204---time:11.42
# Epoch:3---batch(35)训练集---ACC:84.38%---LOSS:0.402---time:11.29
# Epoch:3---batch(36)训练集---ACC:87.50%---LOSS:0.545---time:11.76
# Epoch:3---batch(37)训练集---ACC:93.75%---LOSS:0.243---time:5.67
# 第3轮测试集准确率：83.00%....测试集Loss:0.503757676907948
# Epoch:4---batch(0)训练集---ACC:96.88%---LOSS:0.170---time:12.04
# Epoch:4---batch(1)训练集---ACC:87.50%---LOSS:0.271---time:12.84
# Epoch:4---batch(2)训练集---ACC:93.75%---LOSS:0.162---time:14.67
# Epoch:4---batch(3)训练集---ACC:84.38%---LOSS:0.318---time:12.01
# Epoch:4---batch(4)训练集---ACC:93.75%---LOSS:0.229---time:12.16
# Epoch:4---batch(5)训练集---ACC:93.75%---LOSS:0.240---time:11.86
# Epoch:4---batch(6)训练集---ACC:90.62%---LOSS:0.230---time:12.13
# Epoch:4---batch(7)训练集---ACC:84.38%---LOSS:0.344---time:12.53
# Epoch:4---batch(8)训练集---ACC:90.62%---LOSS:0.191---time:12.27
# Epoch:4---batch(9)训练集---ACC:87.50%---LOSS:0.497---time:13.08
# Epoch:4---batch(10)训练集---ACC:84.38%---LOSS:0.421---time:11.84
# Epoch:4---batch(11)训练集---ACC:84.38%---LOSS:0.573---time:12.23
# Epoch:4---batch(12)训练集---ACC:90.62%---LOSS:0.229---time:11.83
# Epoch:4---batch(13)训练集---ACC:90.62%---LOSS:0.382---time:11.42
# Epoch:4---batch(14)训练集---ACC:84.38%---LOSS:0.330---time:11.64
# Epoch:4---batch(15)训练集---ACC:75.00%---LOSS:0.541---time:12.34
# Epoch:4---batch(16)训练集---ACC:90.62%---LOSS:0.470---time:11.62
# Epoch:4---batch(17)训练集---ACC:90.62%---LOSS:0.236---time:11.95
# Epoch:4---batch(18)训练集---ACC:84.38%---LOSS:0.491---time:11.10
# Epoch:4---batch(19)训练集---ACC:90.62%---LOSS:0.247---time:10.99
# Epoch:4---batch(20)训练集---ACC:84.38%---LOSS:0.432---time:11.18
# Epoch:4---batch(21)训练集---ACC:75.00%---LOSS:0.534---time:10.96
# Epoch:4---batch(22)训练集---ACC:90.62%---LOSS:0.341---time:10.66
# Epoch:4---batch(23)训练集---ACC:78.12%---LOSS:0.498---time:11.05
# Epoch:4---batch(24)训练集---ACC:96.88%---LOSS:0.216---time:11.27
# Epoch:4---batch(25)训练集---ACC:87.50%---LOSS:0.259---time:13.33
# Epoch:4---batch(26)训练集---ACC:93.75%---LOSS:0.199---time:12.48
# Epoch:4---batch(27)训练集---ACC:81.25%---LOSS:0.400---time:12.37
# Epoch:4---batch(28)训练集---ACC:78.12%---LOSS:0.607---time:11.95
# Epoch:4---batch(29)训练集---ACC:84.38%---LOSS:0.322---time:11.97
# Epoch:4---batch(30)训练集---ACC:93.75%---LOSS:0.145---time:11.74
# Epoch:4---batch(31)训练集---ACC:90.62%---LOSS:0.235---time:12.00
# Epoch:4---batch(32)训练集---ACC:87.50%---LOSS:0.559---time:12.81
# Epoch:4---batch(33)训练集---ACC:84.38%---LOSS:0.746---time:11.23
# Epoch:4---batch(34)训练集---ACC:90.62%---LOSS:0.371---time:11.28
# Epoch:4---batch(35)训练集---ACC:81.25%---LOSS:0.892---time:11.37
# Epoch:4---batch(36)训练集---ACC:87.50%---LOSS:0.329---time:11.63
# Epoch:4---batch(37)训练集---ACC:87.50%---LOSS:0.439---time:5.92
# 第4轮测试集准确率：85.00%....测试集Loss:0.5116850563458034
# Epoch:5---batch(0)训练集---ACC:75.00%---LOSS:0.815---time:10.85
# Epoch:5---batch(1)训练集---ACC:96.88%---LOSS:0.124---time:12.19
# Epoch:5---batch(2)训练集---ACC:100.00%---LOSS:0.154---time:12.39
# Epoch:5---batch(3)训练集---ACC:84.38%---LOSS:0.527---time:11.25
# Epoch:5---batch(4)训练集---ACC:93.75%---LOSS:0.157---time:10.88
# Epoch:5---batch(5)训练集---ACC:90.62%---LOSS:0.420---time:12.96
# Epoch:5---batch(6)训练集---ACC:90.62%---LOSS:0.236---time:12.12
# Epoch:5---batch(7)训练集---ACC:90.62%---LOSS:0.447---time:11.51
# Epoch:5---batch(8)训练集---ACC:84.38%---LOSS:0.586---time:11.93
# Epoch:5---batch(9)训练集---ACC:84.38%---LOSS:0.657---time:12.10
# Epoch:5---batch(10)训练集---ACC:96.88%---LOSS:0.145---time:11.86
# Epoch:5---batch(11)训练集---ACC:93.75%---LOSS:0.226---time:11.30
# Epoch:5---batch(12)训练集---ACC:90.62%---LOSS:0.269---time:11.19
# Epoch:5---batch(13)训练集---ACC:96.88%---LOSS:0.163---time:11.42
# Epoch:5---batch(14)训练集---ACC:87.50%---LOSS:0.271---time:11.21
# Epoch:5---batch(15)训练集---ACC:84.38%---LOSS:0.319---time:11.14
# Epoch:5---batch(16)训练集---ACC:78.12%---LOSS:0.603---time:12.29
# Epoch:5---batch(17)训练集---ACC:87.50%---LOSS:0.279---time:13.58
# Epoch:5---batch(18)训练集---ACC:87.50%---LOSS:0.431---time:12.85
# Epoch:5---batch(19)训练集---ACC:96.88%---LOSS:0.123---time:13.21
# Epoch:5---batch(20)训练集---ACC:87.50%---LOSS:0.490---time:13.98
# Epoch:5---batch(21)训练集---ACC:100.00%---LOSS:0.159---time:13.09
# Epoch:5---batch(22)训练集---ACC:93.75%---LOSS:0.211---time:12.80
# Epoch:5---batch(23)训练集---ACC:78.12%---LOSS:0.424---time:12.56
# Epoch:5---batch(24)训练集---ACC:96.88%---LOSS:0.339---time:11.95
# Epoch:5---batch(25)训练集---ACC:84.38%---LOSS:0.336---time:12.60
# Epoch:5---batch(26)训练集---ACC:81.25%---LOSS:0.532---time:13.13
# Epoch:5---batch(27)训练集---ACC:93.75%---LOSS:0.196---time:12.15
# Epoch:5---batch(28)训练集---ACC:87.50%---LOSS:0.315---time:12.93
# Epoch:5---batch(29)训练集---ACC:90.62%---LOSS:0.378---time:11.95
# Epoch:5---batch(30)训练集---ACC:93.75%---LOSS:0.204---time:11.43
# Epoch:5---batch(31)训练集---ACC:81.25%---LOSS:0.523---time:11.48
# Epoch:5---batch(32)训练集---ACC:87.50%---LOSS:0.360---time:12.71
# Epoch:5---batch(33)训练集---ACC:90.62%---LOSS:0.292---time:12.24
# Epoch:5---batch(34)训练集---ACC:84.38%---LOSS:0.409---time:11.74
# Epoch:5---batch(35)训练集---ACC:87.50%---LOSS:0.375---time:12.51
# Epoch:5---batch(36)训练集---ACC:93.75%---LOSS:0.233---time:11.98
# Epoch:5---batch(37)训练集---ACC:87.50%---LOSS:0.562---time:6.03
# 第5轮测试集准确率：83.00%....测试集Loss:0.5499992668628693
# Epoch:6---batch(0)训练集---ACC:90.62%---LOSS:0.336---time:12.03
# Epoch:6---batch(1)训练集---ACC:87.50%---LOSS:0.276---time:14.07
# Epoch:6---batch(2)训练集---ACC:90.62%---LOSS:0.357---time:12.73
# Epoch:6---batch(3)训练集---ACC:93.75%---LOSS:0.189---time:12.80
# Epoch:6---batch(4)训练集---ACC:84.38%---LOSS:0.371---time:12.63
# Epoch:6---batch(5)训练集---ACC:87.50%---LOSS:0.566---time:10.98
# Epoch:6---batch(6)训练集---ACC:100.00%---LOSS:0.120---time:11.02
# Epoch:6---batch(7)训练集---ACC:93.75%---LOSS:0.236---time:11.06
# Epoch:6---batch(8)训练集---ACC:87.50%---LOSS:0.406---time:11.01
# Epoch:6---batch(9)训练集---ACC:93.75%---LOSS:0.279---time:10.90
# Epoch:6---batch(10)训练集---ACC:93.75%---LOSS:0.368---time:11.15
# Epoch:6---batch(11)训练集---ACC:90.62%---LOSS:0.295---time:11.06
# Epoch:6---batch(12)训练集---ACC:93.75%---LOSS:0.191---time:11.08
# Epoch:6---batch(13)训练集---ACC:93.75%---LOSS:0.168---time:10.97
# Epoch:6---batch(14)训练集---ACC:90.62%---LOSS:0.209---time:10.94
# Epoch:6---batch(15)训练集---ACC:93.75%---LOSS:0.186---time:11.06
# Epoch:6---batch(16)训练集---ACC:93.75%---LOSS:0.203---time:10.92
# Epoch:6---batch(17)训练集---ACC:87.50%---LOSS:0.300---time:13.69
# Epoch:6---batch(18)训练集---ACC:90.62%---LOSS:0.183---time:12.62
# Epoch:6---batch(19)训练集---ACC:90.62%---LOSS:0.222---time:13.75
# Epoch:6---batch(20)训练集---ACC:87.50%---LOSS:0.320---time:12.38
# Epoch:6---batch(21)训练集---ACC:87.50%---LOSS:0.558---time:13.06
# Epoch:6---batch(22)训练集---ACC:87.50%---LOSS:0.427---time:12.48
# Epoch:6---batch(23)训练集---ACC:93.75%---LOSS:0.188---time:13.19
# Epoch:6---batch(24)训练集---ACC:93.75%---LOSS:0.461---time:13.15
# Epoch:6---batch(25)训练集---ACC:84.38%---LOSS:0.342---time:14.73
# Epoch:6---batch(26)训练集---ACC:100.00%---LOSS:0.140---time:16.56
# Epoch:6---batch(27)训练集---ACC:96.88%---LOSS:0.138---time:16.01
# Epoch:6---batch(28)训练集---ACC:71.88%---LOSS:0.779---time:16.06
# Epoch:6---batch(29)训练集---ACC:90.62%---LOSS:0.376---time:15.84
# Epoch:6---batch(30)训练集---ACC:96.88%---LOSS:0.211---time:15.01
# Epoch:6---batch(31)训练集---ACC:100.00%---LOSS:0.149---time:12.54
# Epoch:6---batch(32)训练集---ACC:87.50%---LOSS:0.362---time:14.39
# Epoch:6---batch(33)训练集---ACC:90.62%---LOSS:0.371---time:14.68
# Epoch:6---batch(34)训练集---ACC:90.62%---LOSS:0.302---time:11.74
# Epoch:6---batch(35)训练集---ACC:96.88%---LOSS:0.190---time:12.72
# Epoch:6---batch(36)训练集---ACC:84.38%---LOSS:0.532---time:12.53
# Epoch:6---batch(37)训练集---ACC:93.75%---LOSS:0.255---time:6.25
# 第6轮测试集准确率：87.00%....测试集Loss:0.5200943861688886
# Epoch:7---batch(0)训练集---ACC:87.50%---LOSS:0.473---time:14.46
# Epoch:7---batch(1)训练集---ACC:84.38%---LOSS:0.306---time:14.45
# Epoch:7---batch(2)训练集---ACC:81.25%---LOSS:0.297---time:13.98
# Epoch:7---batch(3)训练集---ACC:96.88%---LOSS:0.219---time:13.30
# Epoch:7---batch(4)训练集---ACC:90.62%---LOSS:0.191---time:13.40
# Epoch:7---batch(5)训练集---ACC:90.62%---LOSS:0.253---time:13.93
# Epoch:7---batch(6)训练集---ACC:93.75%---LOSS:0.235---time:13.48
# Epoch:7---batch(7)训练集---ACC:87.50%---LOSS:0.280---time:13.36
# Epoch:7---batch(8)训练集---ACC:93.75%---LOSS:0.189---time:13.30
# Epoch:7---batch(9)训练集---ACC:93.75%---LOSS:0.202---time:13.29
# Epoch:7---batch(10)训练集---ACC:84.38%---LOSS:0.534---time:13.37
# Epoch:7---batch(11)训练集---ACC:90.62%---LOSS:0.270---time:13.32
# Epoch:7---batch(12)训练集---ACC:93.75%---LOSS:0.211---time:14.43
# Epoch:7---batch(13)训练集---ACC:93.75%---LOSS:0.182---time:15.47
# Epoch:7---batch(14)训练集---ACC:96.88%---LOSS:0.172---time:15.71
# Epoch:7---batch(15)训练集---ACC:93.75%---LOSS:0.257---time:15.06
# Epoch:7---batch(16)训练集---ACC:96.88%---LOSS:0.182---time:13.81
# Epoch:7---batch(17)训练集---ACC:87.50%---LOSS:0.334---time:13.56
# Epoch:7---batch(18)训练集---ACC:90.62%---LOSS:0.207---time:13.68
# Epoch:7---batch(19)训练集---ACC:84.38%---LOSS:0.534---time:14.31
# Epoch:7---batch(20)训练集---ACC:93.75%---LOSS:0.195---time:14.18
# Epoch:7---batch(21)训练集---ACC:93.75%---LOSS:0.258---time:12.28
# Epoch:7---batch(22)训练集---ACC:90.62%---LOSS:0.254---time:12.23
# Epoch:7---batch(23)训练集---ACC:93.75%---LOSS:0.199---time:14.49
# Epoch:7---batch(24)训练集---ACC:87.50%---LOSS:0.388---time:12.71
# Epoch:7---batch(25)训练集---ACC:93.75%---LOSS:0.320---time:13.54
# Epoch:7---batch(26)训练集---ACC:93.75%---LOSS:0.165---time:12.93
# Epoch:7---batch(27)训练集---ACC:75.00%---LOSS:0.996---time:13.32
# Epoch:7---batch(28)训练集---ACC:87.50%---LOSS:0.531---time:12.02
# Epoch:7---batch(29)训练集---ACC:100.00%---LOSS:0.158---time:12.21
# Epoch:7---batch(30)训练集---ACC:87.50%---LOSS:0.405---time:12.41
# Epoch:7---batch(31)训练集---ACC:90.62%---LOSS:0.262---time:16.16
# Epoch:7---batch(32)训练集---ACC:96.88%---LOSS:0.162---time:15.89
# Epoch:7---batch(33)训练集---ACC:90.62%---LOSS:0.245---time:12.79
# Epoch:7---batch(34)训练集---ACC:87.50%---LOSS:0.318---time:13.28
# Epoch:7---batch(35)训练集---ACC:90.62%---LOSS:0.201---time:13.79
# Epoch:7---batch(36)训练集---ACC:96.88%---LOSS:0.230---time:14.23
# Epoch:7---batch(37)训练集---ACC:81.25%---LOSS:0.572---time:6.51
# 第7轮测试集准确率：86.00%....测试集Loss:0.6044489400727409
# Epoch:8---batch(0)训练集---ACC:90.62%---LOSS:0.176---time:11.56
# Epoch:8---batch(1)训练集---ACC:96.88%---LOSS:0.193---time:11.17
# Epoch:8---batch(2)训练集---ACC:96.88%---LOSS:0.166---time:11.23
# Epoch:8---batch(3)训练集---ACC:87.50%---LOSS:0.477---time:11.17
# Epoch:8---batch(4)训练集---ACC:87.50%---LOSS:0.260---time:11.94
# Epoch:8---batch(5)训练集---ACC:87.50%---LOSS:0.410---time:12.35
# Epoch:8---batch(6)训练集---ACC:87.50%---LOSS:0.331---time:13.52
# Epoch:8---batch(7)训练集---ACC:90.62%---LOSS:0.244---time:13.96
# Epoch:8---batch(8)训练集---ACC:93.75%---LOSS:0.142---time:15.10
# Epoch:8---batch(9)训练集---ACC:84.38%---LOSS:0.435---time:14.68
# Epoch:8---batch(10)训练集---ACC:87.50%---LOSS:0.326---time:14.78
# Epoch:8---batch(11)训练集---ACC:90.62%---LOSS:0.240---time:14.52
# Epoch:8---batch(12)训练集---ACC:93.75%---LOSS:0.182---time:15.70
# Epoch:8---batch(13)训练集---ACC:87.50%---LOSS:0.416---time:15.24
# Epoch:8---batch(14)训练集---ACC:93.75%---LOSS:0.312---time:15.31
# Epoch:8---batch(15)训练集---ACC:87.50%---LOSS:0.306---time:15.65
# Epoch:8---batch(16)训练集---ACC:93.75%---LOSS:0.256---time:14.51
# Epoch:8---batch(17)训练集---ACC:100.00%---LOSS:0.114---time:13.83
# Epoch:8---batch(18)训练集---ACC:93.75%---LOSS:0.156---time:14.09
# Epoch:8---batch(19)训练集---ACC:87.50%---LOSS:0.309---time:13.81
# Epoch:8---batch(20)训练集---ACC:90.62%---LOSS:0.258---time:13.76
# Epoch:8---batch(21)训练集---ACC:96.88%---LOSS:0.137---time:14.82
# Epoch:8---batch(22)训练集---ACC:93.75%---LOSS:0.389---time:13.85
# Epoch:8---batch(23)训练集---ACC:100.00%---LOSS:0.145---time:13.84
# Epoch:8---batch(24)训练集---ACC:96.88%---LOSS:0.151---time:13.36
# Epoch:8---batch(25)训练集---ACC:90.62%---LOSS:0.201---time:13.94
# Epoch:8---batch(26)训练集---ACC:90.62%---LOSS:0.336---time:13.94
# Epoch:8---batch(27)训练集---ACC:93.75%---LOSS:0.226---time:13.46
# Epoch:8---batch(28)训练集---ACC:81.25%---LOSS:0.515---time:13.41
# Epoch:8---batch(29)训练集---ACC:90.62%---LOSS:0.183---time:13.38
# Epoch:8---batch(30)训练集---ACC:78.12%---LOSS:0.706---time:14.88
# Epoch:8---batch(31)训练集---ACC:93.75%---LOSS:0.223---time:13.90
# Epoch:8---batch(32)训练集---ACC:84.38%---LOSS:0.450---time:15.88
# Epoch:8---batch(33)训练集---ACC:81.25%---LOSS:0.548---time:14.23
# Epoch:8---batch(34)训练集---ACC:96.88%---LOSS:0.102---time:13.43
# Epoch:8---batch(35)训练集---ACC:90.62%---LOSS:0.457---time:15.15
# Epoch:8---batch(36)训练集---ACC:87.50%---LOSS:0.372---time:14.02
# Epoch:8---batch(37)训练集---ACC:81.25%---LOSS:0.434---time:6.55
# 第8轮测试集准确率：83.50%....测试集Loss:0.7036071845463344
# Epoch:9---batch(0)训练集---ACC:90.62%---LOSS:0.357---time:13.93
# Epoch:9---batch(1)训练集---ACC:90.62%---LOSS:0.274---time:13.57
# Epoch:9---batch(2)训练集---ACC:96.88%---LOSS:0.195---time:13.95
# Epoch:9---batch(3)训练集---ACC:90.62%---LOSS:0.229---time:13.52
# Epoch:9---batch(4)训练集---ACC:96.88%---LOSS:0.235---time:14.12
# Epoch:9---batch(5)训练集---ACC:93.75%---LOSS:0.403---time:14.35
# Epoch:9---batch(6)训练集---ACC:93.75%---LOSS:0.150---time:15.19
# Epoch:9---batch(7)训练集---ACC:87.50%---LOSS:0.223---time:12.80
# Epoch:9---batch(8)训练集---ACC:96.88%---LOSS:0.088---time:12.16
# Epoch:9---batch(9)训练集---ACC:93.75%---LOSS:0.184---time:12.50
# Epoch:9---batch(10)训练集---ACC:93.75%---LOSS:0.235---time:13.29
# Epoch:9---batch(11)训练集---ACC:93.75%---LOSS:0.232---time:18.61
# Epoch:9---batch(12)训练集---ACC:93.75%---LOSS:0.156---time:12.27
# Epoch:9---batch(13)训练集---ACC:93.75%---LOSS:0.254---time:11.42
# Epoch:9---batch(14)训练集---ACC:93.75%---LOSS:0.209---time:11.99
# Epoch:9---batch(15)训练集---ACC:87.50%---LOSS:0.333---time:12.47
# Epoch:9---batch(16)训练集---ACC:93.75%---LOSS:0.215---time:12.22
# Epoch:9---batch(17)训练集---ACC:90.62%---LOSS:0.363---time:12.04
# Epoch:9---batch(18)训练集---ACC:93.75%---LOSS:0.191---time:12.03
# Epoch:9---batch(19)训练集---ACC:90.62%---LOSS:0.215---time:12.12
# Epoch:9---batch(20)训练集---ACC:90.62%---LOSS:0.315---time:11.72
# Epoch:9---batch(21)训练集---ACC:78.12%---LOSS:0.625---time:11.89
# Epoch:9---batch(22)训练集---ACC:100.00%---LOSS:0.055---time:11.92
# Epoch:9---batch(23)训练集---ACC:90.62%---LOSS:0.384---time:14.61
# Epoch:9---batch(24)训练集---ACC:90.62%---LOSS:0.229---time:15.08
# Epoch:9---batch(25)训练集---ACC:87.50%---LOSS:0.536---time:15.20
# Epoch:9---batch(26)训练集---ACC:90.62%---LOSS:0.360---time:14.90
# Epoch:9---batch(27)训练集---ACC:81.25%---LOSS:0.569---time:14.33
# Epoch:9---batch(28)训练集---ACC:96.88%---LOSS:0.135---time:14.71
# Epoch:9---batch(29)训练集---ACC:87.50%---LOSS:0.290---time:14.55
# Epoch:9---batch(30)训练集---ACC:90.62%---LOSS:0.311---time:14.57
# Epoch:9---batch(31)训练集---ACC:84.38%---LOSS:0.379---time:14.66
# Epoch:9---batch(32)训练集---ACC:84.38%---LOSS:0.550---time:14.71
# Epoch:9---batch(33)训练集---ACC:96.88%---LOSS:0.083---time:14.61
# Epoch:9---batch(34)训练集---ACC:87.50%---LOSS:0.317---time:14.47
# Epoch:9---batch(35)训练集---ACC:96.88%---LOSS:0.164---time:15.50
# Epoch:9---batch(36)训练集---ACC:96.88%---LOSS:0.095---time:13.91
# Epoch:9---batch(37)训练集---ACC:87.50%---LOSS:0.278---time:7.00
# 第9轮测试集准确率：84.50%....测试集Loss:0.6035179538386208
# Epoch:10---batch(0)训练集---ACC:78.12%---LOSS:0.731---time:13.92
# Epoch:10---batch(1)训练集---ACC:93.75%---LOSS:0.144---time:14.28
# Epoch:10---batch(2)训练集---ACC:90.62%---LOSS:0.133---time:14.58
# Epoch:10---batch(3)训练集---ACC:96.88%---LOSS:0.120---time:14.18
# Epoch:10---batch(4)训练集---ACC:87.50%---LOSS:0.310---time:14.50
# Epoch:10---batch(5)训练集---ACC:93.75%---LOSS:0.150---time:15.04
# Epoch:10---batch(6)训练集---ACC:87.50%---LOSS:0.276---time:15.04
# Epoch:10---batch(7)训练集---ACC:100.00%---LOSS:0.058---time:15.54
# Epoch:10---batch(8)训练集---ACC:90.62%---LOSS:0.216---time:15.68
# Epoch:10---batch(9)训练集---ACC:93.75%---LOSS:0.168---time:14.29
# Epoch:10---batch(10)训练集---ACC:90.62%---LOSS:0.353---time:14.38
# Epoch:10---batch(11)训练集---ACC:90.62%---LOSS:0.293---time:14.96
# Epoch:10---batch(12)训练集---ACC:81.25%---LOSS:0.446---time:14.61
# Epoch:10---batch(13)训练集---ACC:90.62%---LOSS:0.260---time:14.68
# Epoch:10---batch(14)训练集---ACC:93.75%---LOSS:0.188---time:15.41
# Epoch:10---batch(15)训练集---ACC:100.00%---LOSS:0.092---time:14.34
# Epoch:10---batch(16)训练集---ACC:90.62%---LOSS:0.222---time:14.90
# Epoch:10---batch(17)训练集---ACC:93.75%---LOSS:0.146---time:15.09
# Epoch:10---batch(18)训练集---ACC:96.88%---LOSS:0.153---time:14.92
# Epoch:10---batch(19)训练集---ACC:96.88%---LOSS:0.143---time:16.24
# Epoch:10---batch(20)训练集---ACC:96.88%---LOSS:0.127---time:15.14
# Epoch:10---batch(21)训练集---ACC:96.88%---LOSS:0.140---time:15.53
# Epoch:10---batch(22)训练集---ACC:93.75%---LOSS:0.313---time:15.07
# Epoch:10---batch(23)训练集---ACC:84.38%---LOSS:0.506---time:12.59
# Epoch:10---batch(24)训练集---ACC:90.62%---LOSS:0.241---time:11.80
# Epoch:10---batch(25)训练集---ACC:93.75%---LOSS:0.229---time:11.49
# Epoch:10---batch(26)训练集---ACC:90.62%---LOSS:0.309---time:11.53
# Epoch:10---batch(27)训练集---ACC:84.38%---LOSS:0.422---time:11.49
# Epoch:10---batch(28)训练集---ACC:93.75%---LOSS:0.154---time:11.45
# Epoch:10---batch(29)训练集---ACC:84.38%---LOSS:0.436---time:11.52
# Epoch:10---batch(30)训练集---ACC:84.38%---LOSS:0.289---time:11.54
# Epoch:10---batch(31)训练集---ACC:84.38%---LOSS:0.324---time:11.55
# Epoch:10---batch(32)训练集---ACC:81.25%---LOSS:0.550---time:11.47
# Epoch:10---batch(33)训练集---ACC:90.62%---LOSS:0.342---time:11.54
# Epoch:10---batch(34)训练集---ACC:90.62%---LOSS:0.338---time:11.54
# Epoch:10---batch(35)训练集---ACC:87.50%---LOSS:0.297---time:11.48
# Epoch:10---batch(36)训练集---ACC:87.50%---LOSS:0.226---time:11.47
# Epoch:10---batch(37)训练集---ACC:81.25%---LOSS:0.619---time:5.73
# 第10轮测试集准确率：87.50%....测试集Loss:0.6068405338696071
# Epoch:11---batch(0)训练集---ACC:93.75%---LOSS:0.196---time:11.60
# Epoch:11---batch(1)训练集---ACC:90.62%---LOSS:0.230---time:11.52
# Epoch:11---batch(2)训练集---ACC:90.62%---LOSS:0.347---time:11.77
# Epoch:11---batch(3)训练集---ACC:96.88%---LOSS:0.124---time:11.49
# Epoch:11---batch(4)训练集---ACC:78.12%---LOSS:0.455---time:11.46
# Epoch:11---batch(5)训练集---ACC:90.62%---LOSS:0.248---time:11.51
# Epoch:11---batch(6)训练集---ACC:93.75%---LOSS:0.341---time:11.55
# Epoch:11---batch(7)训练集---ACC:96.88%---LOSS:0.165---time:11.45
# Epoch:11---batch(8)训练集---ACC:96.88%---LOSS:0.100---time:11.54
# Epoch:11---batch(9)训练集---ACC:96.88%---LOSS:0.096---time:11.50
# Epoch:11---batch(10)训练集---ACC:96.88%---LOSS:0.094---time:11.51
# Epoch:11---batch(11)训练集---ACC:93.75%---LOSS:0.257---time:11.61
# Epoch:11---batch(12)训练集---ACC:93.75%---LOSS:0.246---time:11.48
# Epoch:11---batch(13)训练集---ACC:87.50%---LOSS:0.402---time:11.50
# Epoch:11---batch(14)训练集---ACC:90.62%---LOSS:0.201---time:11.48
# Epoch:11---batch(15)训练集---ACC:87.50%---LOSS:0.554---time:11.48
# Epoch:11---batch(16)训练集---ACC:96.88%---LOSS:0.160---time:11.49
# Epoch:11---batch(17)训练集---ACC:100.00%---LOSS:0.083---time:11.51
# Epoch:11---batch(18)训练集---ACC:93.75%---LOSS:0.260---time:11.47
# Epoch:11---batch(19)训练集---ACC:93.75%---LOSS:0.473---time:11.59
# Epoch:11---batch(20)训练集---ACC:90.62%---LOSS:0.261---time:11.59
# Epoch:11---batch(21)训练集---ACC:90.62%---LOSS:0.407---time:11.49
# Epoch:11---batch(22)训练集---ACC:87.50%---LOSS:0.220---time:11.48
# Epoch:11---batch(23)训练集---ACC:87.50%---LOSS:0.326---time:11.46
# Epoch:11---batch(24)训练集---ACC:90.62%---LOSS:0.503---time:11.46
# Epoch:11---batch(25)训练集---ACC:96.88%---LOSS:0.121---time:11.48
# Epoch:11---batch(26)训练集---ACC:96.88%---LOSS:0.200---time:11.60
# Epoch:11---batch(27)训练集---ACC:93.75%---LOSS:0.207---time:11.52
# Epoch:11---batch(28)训练集---ACC:93.75%---LOSS:0.264---time:11.48
# Epoch:11---batch(29)训练集---ACC:90.62%---LOSS:0.231---time:11.49
# Epoch:11---batch(30)训练集---ACC:90.62%---LOSS:0.243---time:13.24
# Epoch:11---batch(31)训练集---ACC:96.88%---LOSS:0.146---time:14.48
# Epoch:11---batch(32)训练集---ACC:90.62%---LOSS:0.243---time:11.94
# Epoch:11---batch(33)训练集---ACC:90.62%---LOSS:0.241---time:11.49
# Epoch:11---batch(34)训练集---ACC:93.75%---LOSS:0.194---time:11.51
# Epoch:11---batch(35)训练集---ACC:90.62%---LOSS:0.176---time:11.49
# Epoch:11---batch(36)训练集---ACC:90.62%---LOSS:0.205---time:11.48
# Epoch:11---batch(37)训练集---ACC:100.00%---LOSS:0.162---time:5.73
# 第11轮测试集准确率：84.00%....测试集Loss:0.6410342561347144
# Epoch:12---batch(0)训练集---ACC:90.62%---LOSS:0.221---time:11.47
# Epoch:12---batch(1)训练集---ACC:93.75%---LOSS:0.115---time:11.50
# Epoch:12---batch(2)训练集---ACC:90.62%---LOSS:0.220---time:11.49
# Epoch:12---batch(3)训练集---ACC:93.75%---LOSS:0.123---time:11.45
# Epoch:12---batch(4)训练集---ACC:93.75%---LOSS:0.333---time:11.57
# Epoch:12---batch(5)训练集---ACC:87.50%---LOSS:0.366---time:11.47
# Epoch:12---batch(6)训练集---ACC:96.88%---LOSS:0.130---time:11.55
# Epoch:12---batch(7)训练集---ACC:90.62%---LOSS:0.205---time:11.46
# Epoch:12---batch(8)训练集---ACC:96.88%---LOSS:0.176---time:11.64
# Epoch:12---batch(9)训练集---ACC:96.88%---LOSS:0.087---time:11.53
# Epoch:12---batch(10)训练集---ACC:93.75%---LOSS:0.169---time:11.50
# Epoch:12---batch(11)训练集---ACC:87.50%---LOSS:0.324---time:11.59
# Epoch:12---batch(12)训练集---ACC:90.62%---LOSS:0.354---time:11.47
# Epoch:12---batch(13)训练集---ACC:90.62%---LOSS:0.342---time:11.48
# Epoch:12---batch(14)训练集---ACC:93.75%---LOSS:0.176---time:11.69
# Epoch:12---batch(15)训练集---ACC:93.75%---LOSS:0.149---time:18.71
# Epoch:12---batch(16)训练集---ACC:90.62%---LOSS:0.286---time:27.44
# Epoch:12---batch(17)训练集---ACC:81.25%---LOSS:0.496---time:26.95
# Epoch:12---batch(18)训练集---ACC:96.88%---LOSS:0.180---time:27.69
# Epoch:12---batch(19)训练集---ACC:93.75%---LOSS:0.164---time:27.49
# Epoch:12---batch(20)训练集---ACC:93.75%---LOSS:0.147---time:27.45
# Epoch:12---batch(21)训练集---ACC:90.62%---LOSS:0.361---time:27.70
# Epoch:12---batch(22)训练集---ACC:93.75%---LOSS:0.137---time:27.63
# Epoch:12---batch(23)训练集---ACC:90.62%---LOSS:0.217---time:28.56
# Epoch:12---batch(24)训练集---ACC:96.88%---LOSS:0.134---time:26.02
# Epoch:12---batch(25)训练集---ACC:90.62%---LOSS:0.205---time:27.38
# Epoch:12---batch(26)训练集---ACC:93.75%---LOSS:0.143---time:27.49
# Epoch:12---batch(27)训练集---ACC:100.00%---LOSS:0.103---time:27.83
# Epoch:12---batch(28)训练集---ACC:90.62%---LOSS:0.239---time:27.67
# Epoch:12---batch(29)训练集---ACC:90.62%---LOSS:0.407---time:27.50
# Epoch:12---batch(30)训练集---ACC:96.88%---LOSS:0.193---time:27.54
# Epoch:12---batch(31)训练集---ACC:96.88%---LOSS:0.143---time:27.42
# Epoch:12---batch(32)训练集---ACC:93.75%---LOSS:0.385---time:27.70
# Epoch:12---batch(33)训练集---ACC:93.75%---LOSS:0.292---time:27.68
# Epoch:12---batch(34)训练集---ACC:87.50%---LOSS:0.282---time:28.89
# Epoch:12---batch(35)训练集---ACC:96.88%---LOSS:0.059---time:27.96
# Epoch:12---batch(36)训练集---ACC:93.75%---LOSS:0.295---time:28.05
# Epoch:12---batch(37)训练集---ACC:93.75%---LOSS:0.605---time:13.92
# 第12轮测试集准确率：83.00%....测试集Loss:0.7602769093854087
# Epoch:13---batch(0)训练集---ACC:100.00%---LOSS:0.084---time:27.80
# Epoch:13---batch(1)训练集---ACC:90.62%---LOSS:0.310---time:28.66
# Epoch:13---batch(2)训练集---ACC:93.75%---LOSS:0.358---time:28.12
# Epoch:13---batch(3)训练集---ACC:84.38%---LOSS:0.708---time:27.39
# Epoch:13---batch(4)训练集---ACC:100.00%---LOSS:0.100---time:27.76
# Epoch:13---batch(5)训练集---ACC:90.62%---LOSS:0.248---time:28.02
# Epoch:13---batch(6)训练集---ACC:93.75%---LOSS:0.373---time:27.45
# Epoch:13---batch(7)训练集---ACC:93.75%---LOSS:0.235---time:28.02
# Epoch:13---batch(8)训练集---ACC:90.62%---LOSS:0.205---time:27.11
# Epoch:13---batch(9)训练集---ACC:96.88%---LOSS:0.128---time:28.35
# Epoch:13---batch(10)训练集---ACC:93.75%---LOSS:0.209---time:28.01
# Epoch:13---batch(11)训练集---ACC:93.75%---LOSS:0.172---time:27.77
# Epoch:13---batch(12)训练集---ACC:96.88%---LOSS:0.140---time:28.22
# Epoch:13---batch(13)训练集---ACC:96.88%---LOSS:0.141---time:27.14
# Epoch:13---batch(14)训练集---ACC:96.88%---LOSS:0.077---time:28.25
# Epoch:13---batch(15)训练集---ACC:84.38%---LOSS:0.611---time:29.14
# Epoch:13---batch(16)训练集---ACC:96.88%---LOSS:0.124---time:28.78
# Epoch:13---batch(17)训练集---ACC:90.62%---LOSS:0.296---time:29.13
# Epoch:13---batch(18)训练集---ACC:81.25%---LOSS:0.523---time:29.18
# Epoch:13---batch(19)训练集---ACC:90.62%---LOSS:0.283---time:29.11
# Epoch:13---batch(20)训练集---ACC:96.88%---LOSS:0.145---time:28.86
# Epoch:13---batch(21)训练集---ACC:87.50%---LOSS:0.425---time:28.96
# Epoch:13---batch(22)训练集---ACC:87.50%---LOSS:0.451---time:30.21
# Epoch:13---batch(23)训练集---ACC:96.88%---LOSS:0.141---time:29.01
# Epoch:13---batch(24)训练集---ACC:93.75%---LOSS:0.156---time:29.17
# Epoch:13---batch(25)训练集---ACC:96.88%---LOSS:0.100---time:28.92
# Epoch:13---batch(26)训练集---ACC:84.38%---LOSS:0.459---time:29.15
# Epoch:13---batch(27)训练集---ACC:90.62%---LOSS:0.226---time:28.88
# Epoch:13---batch(28)训练集---ACC:90.62%---LOSS:0.285---time:28.21
# Epoch:13---batch(29)训练集---ACC:87.50%---LOSS:0.390---time:29.01
# Epoch:13---batch(30)训练集---ACC:90.62%---LOSS:0.398---time:30.27
# Epoch:13---batch(31)训练集---ACC:90.62%---LOSS:0.193---time:28.79
# Epoch:13---batch(32)训练集---ACC:90.62%---LOSS:0.256---time:29.96
# Epoch:13---batch(33)训练集---ACC:87.50%---LOSS:0.239---time:29.08
# Epoch:13---batch(34)训练集---ACC:87.50%---LOSS:0.257---time:29.14
# Epoch:13---batch(35)训练集---ACC:90.62%---LOSS:0.156---time:28.92
# Epoch:13---batch(36)训练集---ACC:100.00%---LOSS:0.037---time:28.97
# Epoch:13---batch(37)训练集---ACC:87.50%---LOSS:0.163---time:14.45
# 第13轮测试集准确率：84.50%....测试集Loss:0.7511404071535382
# Epoch:14---batch(0)训练集---ACC:90.62%---LOSS:0.182---time:28.87
# Epoch:14---batch(1)训练集---ACC:96.88%---LOSS:0.153---time:27.72
# Epoch:14---batch(2)训练集---ACC:90.62%---LOSS:0.232---time:28.74
# Epoch:14---batch(3)训练集---ACC:100.00%---LOSS:0.059---time:29.22
# Epoch:14---batch(4)训练集---ACC:90.62%---LOSS:0.322---time:29.46
# Epoch:14---batch(5)训练集---ACC:96.88%---LOSS:0.117---time:29.05
# Epoch:14---batch(6)训练集---ACC:90.62%---LOSS:0.254---time:29.17
# Epoch:14---batch(7)训练集---ACC:96.88%---LOSS:0.090---time:28.85
# Epoch:14---batch(8)训练集---ACC:87.50%---LOSS:0.393---time:29.06
# Epoch:14---batch(9)训练集---ACC:90.62%---LOSS:0.221---time:29.91
# Epoch:14---batch(10)训练集---ACC:90.62%---LOSS:0.247---time:28.99
# Epoch:14---batch(11)训练集---ACC:96.88%---LOSS:0.271---time:28.99
# Epoch:14---batch(12)训练集---ACC:96.88%---LOSS:0.178---time:29.18
# Epoch:14---batch(13)训练集---ACC:96.88%---LOSS:0.157---time:28.61
# Epoch:14---batch(14)训练集---ACC:87.50%---LOSS:0.364---time:29.09
# Epoch:14---batch(15)训练集---ACC:87.50%---LOSS:0.282---time:28.77
# Epoch:14---batch(16)训练集---ACC:96.88%---LOSS:0.118---time:29.10
# Epoch:14---batch(17)训练集---ACC:90.62%---LOSS:0.189---time:29.03
# Epoch:14---batch(18)训练集---ACC:90.62%---LOSS:0.624---time:29.40
# Epoch:14---batch(19)训练集---ACC:87.50%---LOSS:0.335---time:29.08
# Epoch:14---batch(20)训练集---ACC:93.75%---LOSS:0.280---time:29.86
# Epoch:14---batch(21)训练集---ACC:90.62%---LOSS:0.228---time:29.21
# Epoch:14---batch(22)训练集---ACC:87.50%---LOSS:0.485---time:28.70
# Epoch:14---batch(23)训练集---ACC:90.62%---LOSS:0.327---time:29.20
# Epoch:14---batch(24)训练集---ACC:87.50%---LOSS:0.355---time:29.07
# Epoch:14---batch(25)训练集---ACC:90.62%---LOSS:0.148---time:28.76
# Epoch:14---batch(26)训练集---ACC:96.88%---LOSS:0.145---time:29.08
# Epoch:14---batch(27)训练集---ACC:96.88%---LOSS:0.158---time:28.29
# Epoch:14---batch(28)训练集---ACC:90.62%---LOSS:0.396---time:28.78
# Epoch:14---batch(29)训练集---ACC:96.88%---LOSS:0.180---time:29.10
# Epoch:14---batch(30)训练集---ACC:90.62%---LOSS:0.211---time:30.17
# Epoch:14---batch(31)训练集---ACC:90.62%---LOSS:0.313---time:29.03
# Epoch:14---batch(32)训练集---ACC:87.50%---LOSS:0.439---time:27.97
# Epoch:14---batch(33)训练集---ACC:87.50%---LOSS:0.393---time:29.28
# Epoch:14---batch(34)训练集---ACC:96.88%---LOSS:0.137---time:28.99
# Epoch:14---batch(35)训练集---ACC:87.50%---LOSS:0.288---time:28.89
# Epoch:14---batch(36)训练集---ACC:100.00%---LOSS:0.064---time:28.78
# Epoch:14---batch(37)训练集---ACC:81.25%---LOSS:0.896---time:14.11
# 第14轮测试集准确率：83.00%....测试集Loss:0.7119326442480087
# Epoch:15---batch(0)训练集---ACC:90.62%---LOSS:0.229---time:28.79
# Epoch:15---batch(1)训练集---ACC:78.12%---LOSS:0.559---time:29.10
# Epoch:15---batch(2)训练集---ACC:87.50%---LOSS:0.181---time:29.20
# Epoch:15---batch(3)训练集---ACC:96.88%---LOSS:0.175---time:29.25
# Epoch:15---batch(4)训练集---ACC:81.25%---LOSS:0.460---time:28.68
# Epoch:15---batch(5)训练集---ACC:87.50%---LOSS:0.372---time:29.17
# Epoch:15---batch(6)训练集---ACC:96.88%---LOSS:0.226---time:28.89
# Epoch:15---batch(7)训练集---ACC:90.62%---LOSS:0.260---time:31.14
# Epoch:15---batch(8)训练集---ACC:90.62%---LOSS:0.271---time:27.87
# Epoch:15---batch(9)训练集---ACC:90.62%---LOSS:0.439---time:28.94
# Epoch:15---batch(10)训练集---ACC:93.75%---LOSS:0.154---time:32.57
# Epoch:15---batch(11)训练集---ACC:90.62%---LOSS:0.237---time:30.09
# Epoch:15---batch(12)训练集---ACC:84.38%---LOSS:0.367---time:29.03
# Epoch:15---batch(13)训练集---ACC:96.88%---LOSS:0.114---time:21.27
# Epoch:15---batch(14)训练集---ACC:84.38%---LOSS:0.353---time:11.81
# Epoch:15---batch(15)训练集---ACC:90.62%---LOSS:0.246---time:12.58
# Epoch:15---batch(16)训练集---ACC:84.38%---LOSS:0.468---time:15.60
# Epoch:15---batch(17)训练集---ACC:90.62%---LOSS:0.242---time:15.60
# Epoch:15---batch(18)训练集---ACC:90.62%---LOSS:0.192---time:16.18
# Epoch:15---batch(19)训练集---ACC:93.75%---LOSS:0.285---time:14.99
# Epoch:15---batch(20)训练集---ACC:96.88%---LOSS:0.335---time:14.97
# Epoch:15---batch(21)训练集---ACC:93.75%---LOSS:0.140---time:14.91
# Epoch:15---batch(22)训练集---ACC:93.75%---LOSS:0.156---time:15.11
# Epoch:15---batch(23)训练集---ACC:100.00%---LOSS:0.055---time:13.12
# Epoch:15---batch(24)训练集---ACC:84.38%---LOSS:0.262---time:12.12
# Epoch:15---batch(25)训练集---ACC:100.00%---LOSS:0.037---time:13.47
# Epoch:15---batch(26)训练集---ACC:87.50%---LOSS:0.256---time:12.84
# Epoch:15---batch(27)训练集---ACC:87.50%---LOSS:0.278---time:13.09
# Epoch:15---batch(28)训练集---ACC:96.88%---LOSS:0.174---time:13.15
# Epoch:15---batch(29)训练集---ACC:100.00%---LOSS:0.109---time:13.68
# Epoch:15---batch(30)训练集---ACC:90.62%---LOSS:0.225---time:13.79
# Epoch:15---batch(31)训练集---ACC:81.25%---LOSS:0.467---time:13.94
# Epoch:15---batch(32)训练集---ACC:81.25%---LOSS:0.461---time:13.50
# Epoch:15---batch(33)训练集---ACC:93.75%---LOSS:0.139---time:13.95
# Epoch:15---batch(34)训练集---ACC:96.88%---LOSS:0.116---time:13.25
# Epoch:15---batch(35)训练集---ACC:84.38%---LOSS:0.678---time:12.81
# Epoch:15---batch(36)训练集---ACC:96.88%---LOSS:0.084---time:14.75
# Epoch:15---batch(37)训练集---ACC:93.75%---LOSS:0.197---time:7.09
# 第15轮测试集准确率：86.00%....测试集Loss:0.6547969664846148
# Epoch:16---batch(0)训练集---ACC:87.50%---LOSS:0.249---time:13.54
# Epoch:16---batch(1)训练集---ACC:96.88%---LOSS:0.151---time:13.95
# Epoch:16---batch(2)训练集---ACC:93.75%---LOSS:0.154---time:13.22
# Epoch:16---batch(3)训练集---ACC:96.88%---LOSS:0.131---time:13.93
# Epoch:16---batch(4)训练集---ACC:100.00%---LOSS:0.087---time:13.44
# Epoch:16---batch(5)训练集---ACC:96.88%---LOSS:0.089---time:13.96
# Epoch:16---batch(6)训练集---ACC:96.88%---LOSS:0.219---time:16.22
# Epoch:16---batch(7)训练集---ACC:87.50%---LOSS:0.435---time:15.86
# Epoch:16---batch(8)训练集---ACC:87.50%---LOSS:0.364---time:14.23
# Epoch:16---batch(9)训练集---ACC:87.50%---LOSS:0.319---time:13.69
# Epoch:16---batch(10)训练集---ACC:96.88%---LOSS:0.128---time:14.24
# Epoch:16---batch(11)训练集---ACC:87.50%---LOSS:0.270---time:13.32
# Epoch:16---batch(12)训练集---ACC:90.62%---LOSS:0.340---time:12.89
# Epoch:16---batch(13)训练集---ACC:93.75%---LOSS:0.120---time:13.33
# Epoch:16---batch(14)训练集---ACC:87.50%---LOSS:0.210---time:16.67
# Epoch:16---batch(15)训练集---ACC:93.75%---LOSS:0.150---time:17.45
# Epoch:16---batch(16)训练集---ACC:90.62%---LOSS:0.248---time:14.13
# Epoch:16---batch(17)训练集---ACC:96.88%---LOSS:0.131---time:11.93
# Epoch:16---batch(18)训练集---ACC:90.62%---LOSS:0.260---time:12.46
# Epoch:16---batch(19)训练集---ACC:81.25%---LOSS:0.509---time:13.33
# Epoch:16---batch(20)训练集---ACC:87.50%---LOSS:0.235---time:14.80
# Epoch:16---batch(21)训练集---ACC:87.50%---LOSS:0.274---time:13.88
# Epoch:16---batch(22)训练集---ACC:87.50%---LOSS:0.223---time:11.76
# Epoch:16---batch(23)训练集---ACC:96.88%---LOSS:0.114---time:11.99
# Epoch:16---batch(24)训练集---ACC:93.75%---LOSS:0.140---time:15.98
# Epoch:16---batch(25)训练集---ACC:90.62%---LOSS:0.294---time:13.96
# Epoch:16---batch(26)训练集---ACC:87.50%---LOSS:0.297---time:14.14
# Epoch:16---batch(27)训练集---ACC:68.75%---LOSS:0.717---time:13.82
# Epoch:16---batch(28)训练集---ACC:87.50%---LOSS:0.411---time:11.76
# Epoch:16---batch(29)训练集---ACC:93.75%---LOSS:0.408---time:12.55
# Epoch:16---batch(30)训练集---ACC:90.62%---LOSS:0.201---time:12.33
# Epoch:16---batch(31)训练集---ACC:93.75%---LOSS:0.144---time:11.55
# Epoch:16---batch(32)训练集---ACC:90.62%---LOSS:0.251---time:11.49
# Epoch:16---batch(33)训练集---ACC:93.75%---LOSS:0.264---time:11.65
# Epoch:16---batch(34)训练集---ACC:96.88%---LOSS:0.220---time:12.06
# Epoch:16---batch(35)训练集---ACC:87.50%---LOSS:0.333---time:12.51
# Epoch:16---batch(36)训练集---ACC:93.75%---LOSS:0.185---time:11.83
# Epoch:16---batch(37)训练集---ACC:100.00%---LOSS:0.050---time:6.15
# 第16轮测试集准确率：83.00%....测试集Loss:0.6922369365181241
# Epoch:17---batch(0)训练集---ACC:96.88%---LOSS:0.188---time:13.41
# Epoch:17---batch(1)训练集---ACC:93.75%---LOSS:0.277---time:12.80
# Epoch:17---batch(2)训练集---ACC:81.25%---LOSS:0.467---time:13.36
# Epoch:17---batch(3)训练集---ACC:90.62%---LOSS:0.516---time:11.75
# Epoch:17---batch(4)训练集---ACC:93.75%---LOSS:0.151---time:11.64
# Epoch:17---batch(5)训练集---ACC:87.50%---LOSS:0.246---time:11.70
# Epoch:17---batch(6)训练集---ACC:90.62%---LOSS:0.220---time:11.77
# Epoch:17---batch(7)训练集---ACC:96.88%---LOSS:0.146---time:12.68
# Epoch:17---batch(8)训练集---ACC:87.50%---LOSS:0.324---time:12.85
# Epoch:17---batch(9)训练集---ACC:87.50%---LOSS:0.255---time:14.28
# Epoch:17---batch(10)训练集---ACC:96.88%---LOSS:0.106---time:13.90
# Epoch:17---batch(11)训练集---ACC:96.88%---LOSS:0.183---time:13.47
# Epoch:17---batch(12)训练集---ACC:90.62%---LOSS:0.334---time:12.97
# Epoch:17---batch(13)训练集---ACC:93.75%---LOSS:0.239---time:11.63
# Epoch:17---batch(14)训练集---ACC:81.25%---LOSS:0.622---time:12.08
# Epoch:17---batch(15)训练集---ACC:96.88%---LOSS:0.203---time:12.02
# Epoch:17---batch(16)训练集---ACC:100.00%---LOSS:0.076---time:11.72
# Epoch:17---batch(17)训练集---ACC:90.62%---LOSS:0.467---time:11.75
# Epoch:17---batch(18)训练集---ACC:84.38%---LOSS:0.205---time:11.45
# Epoch:17---batch(19)训练集---ACC:93.75%---LOSS:0.159---time:13.54
# Epoch:17---batch(20)训练集---ACC:87.50%---LOSS:0.371---time:13.56
# Epoch:17---batch(21)训练集---ACC:87.50%---LOSS:0.297---time:12.87
# Epoch:17---batch(22)训练集---ACC:90.62%---LOSS:0.195---time:12.72
# Epoch:17---batch(23)训练集---ACC:93.75%---LOSS:0.152---time:13.14
# Epoch:17---batch(24)训练集---ACC:96.88%---LOSS:0.069---time:13.18
# Epoch:17---batch(25)训练集---ACC:100.00%---LOSS:0.036---time:13.08
# Epoch:17---batch(26)训练集---ACC:96.88%---LOSS:0.160---time:13.15
# Epoch:17---batch(27)训练集---ACC:90.62%---LOSS:0.404---time:14.12
# Epoch:17---batch(28)训练集---ACC:93.75%---LOSS:0.208---time:15.21
# Epoch:17---batch(29)训练集---ACC:84.38%---LOSS:0.428---time:15.96
# Epoch:17---batch(30)训练集---ACC:93.75%---LOSS:0.217---time:14.46
# Epoch:17---batch(31)训练集---ACC:90.62%---LOSS:0.243---time:13.54
# Epoch:17---batch(32)训练集---ACC:84.38%---LOSS:0.601---time:13.83
# Epoch:17---batch(33)训练集---ACC:93.75%---LOSS:0.176---time:14.63
# Epoch:17---batch(34)训练集---ACC:93.75%---LOSS:0.161---time:13.63
# Epoch:17---batch(35)训练集---ACC:93.75%---LOSS:0.179---time:12.63
# Epoch:17---batch(36)训练集---ACC:93.75%---LOSS:0.120---time:12.99
# Epoch:17---batch(37)训练集---ACC:93.75%---LOSS:0.274---time:6.87
# 第17轮测试集准确率：83.50%....测试集Loss:0.7092981721673693
# Epoch:18---batch(0)训练集---ACC:78.12%---LOSS:0.735---time:13.72
# Epoch:18---batch(1)训练集---ACC:96.88%---LOSS:0.166---time:13.59
# Epoch:18---batch(2)训练集---ACC:96.88%---LOSS:0.122---time:13.59
# Epoch:18---batch(3)训练集---ACC:90.62%---LOSS:0.273---time:13.64
# Epoch:18---batch(4)训练集---ACC:96.88%---LOSS:0.145---time:14.26
# Epoch:18---batch(5)训练集---ACC:90.62%---LOSS:0.264---time:14.66
# Epoch:18---batch(6)训练集---ACC:87.50%---LOSS:0.280---time:11.72
# Epoch:18---batch(7)训练集---ACC:96.88%---LOSS:0.139---time:11.03
# Epoch:18---batch(8)训练集---ACC:84.38%---LOSS:0.418---time:11.11
# Epoch:18---batch(9)训练集---ACC:93.75%---LOSS:0.322---time:12.10
# Epoch:18---batch(10)训练集---ACC:93.75%---LOSS:0.280---time:12.97
# Epoch:18---batch(11)训练集---ACC:90.62%---LOSS:0.258---time:11.83
# Epoch:18---batch(12)训练集---ACC:93.75%---LOSS:0.125---time:11.59
# Epoch:18---batch(13)训练集---ACC:87.50%---LOSS:0.359---time:11.86
# Epoch:18---batch(14)训练集---ACC:96.88%---LOSS:0.116---time:12.44
# Epoch:18---batch(15)训练集---ACC:87.50%---LOSS:0.203---time:12.76
# Epoch:18---batch(16)训练集---ACC:90.62%---LOSS:0.363---time:13.73
# Epoch:18---batch(17)训练集---ACC:90.62%---LOSS:0.466---time:13.16
# Epoch:18---batch(18)训练集---ACC:87.50%---LOSS:0.292---time:11.80
# Epoch:18---batch(19)训练集---ACC:93.75%---LOSS:0.332---time:12.13
# Epoch:18---batch(20)训练集---ACC:90.62%---LOSS:0.362---time:12.02
# Epoch:18---batch(21)训练集---ACC:90.62%---LOSS:0.266---time:12.01
# Epoch:18---batch(22)训练集---ACC:87.50%---LOSS:0.280---time:11.90
# Epoch:18---batch(23)训练集---ACC:96.88%---LOSS:0.147---time:11.88
# Epoch:18---batch(24)训练集---ACC:90.62%---LOSS:0.168---time:12.16
# Epoch:18---batch(25)训练集---ACC:100.00%---LOSS:0.091---time:11.79
# Epoch:18---batch(26)训练集---ACC:96.88%---LOSS:0.244---time:12.81
# Epoch:18---batch(27)训练集---ACC:84.38%---LOSS:0.497---time:12.83
# Epoch:18---batch(28)训练集---ACC:90.62%---LOSS:0.357---time:12.03
# Epoch:18---batch(29)训练集---ACC:93.75%---LOSS:0.182---time:13.45
# Epoch:18---batch(30)训练集---ACC:90.62%---LOSS:0.357---time:12.80
# Epoch:18---batch(31)训练集---ACC:87.50%---LOSS:0.386---time:11.93
# Epoch:18---batch(32)训练集---ACC:84.38%---LOSS:0.234---time:12.40
# Epoch:18---batch(33)训练集---ACC:93.75%---LOSS:0.216---time:12.03
# Epoch:18---batch(34)训练集---ACC:90.62%---LOSS:0.226---time:12.30
# Epoch:18---batch(35)训练集---ACC:93.75%---LOSS:0.072---time:13.09
# Epoch:18---batch(36)训练集---ACC:84.38%---LOSS:0.502---time:11.86
# Epoch:18---batch(37)训练集---ACC:100.00%---LOSS:0.033---time:5.99
# 第18轮测试集准确率：83.50%....测试集Loss:0.7616532913276127
# Epoch:19---batch(0)训练集---ACC:87.50%---LOSS:0.250---time:21.09
# Epoch:19---batch(1)训练集---ACC:93.75%---LOSS:0.256---time:15.27
# Epoch:19---batch(2)训练集---ACC:93.75%---LOSS:0.098---time:15.98
# Epoch:19---batch(3)训练集---ACC:93.75%---LOSS:0.273---time:17.38
# Epoch:19---batch(4)训练集---ACC:84.38%---LOSS:0.360---time:21.70
# Epoch:19---batch(5)训练集---ACC:93.75%---LOSS:0.186---time:30.29
# Epoch:19---batch(6)训练集---ACC:96.88%---LOSS:0.115---time:26.81
# Epoch:19---batch(7)训练集---ACC:93.75%---LOSS:0.221---time:23.09
# Epoch:19---batch(8)训练集---ACC:96.88%---LOSS:0.136---time:14.75
# Epoch:19---batch(9)训练集---ACC:87.50%---LOSS:0.214---time:14.29
# Epoch:19---batch(10)训练集---ACC:93.75%---LOSS:0.212---time:14.62
# Epoch:19---batch(11)训练集---ACC:90.62%---LOSS:0.208---time:18.21
# Epoch:19---batch(12)训练集---ACC:90.62%---LOSS:0.318---time:19.21
# Epoch:19---batch(13)训练集---ACC:96.88%---LOSS:0.199---time:18.08
# Epoch:19---batch(14)训练集---ACC:87.50%---LOSS:0.309---time:19.95
# Epoch:19---batch(15)训练集---ACC:93.75%---LOSS:0.161---time:21.60
# Epoch:19---batch(16)训练集---ACC:96.88%---LOSS:0.210---time:15.51
# Epoch:19---batch(17)训练集---ACC:84.38%---LOSS:0.303---time:15.91
# Epoch:19---batch(18)训练集---ACC:87.50%---LOSS:0.470---time:14.92
# Epoch:19---batch(19)训练集---ACC:96.88%---LOSS:0.151---time:14.92
# Epoch:19---batch(20)训练集---ACC:96.88%---LOSS:0.119---time:14.73
# Epoch:19---batch(21)训练集---ACC:96.88%---LOSS:0.172---time:15.82
# Epoch:19---batch(22)训练集---ACC:87.50%---LOSS:0.418---time:13.81
# Epoch:19---batch(23)训练集---ACC:90.62%---LOSS:0.220---time:12.90
# Epoch:19---batch(24)训练集---ACC:93.75%---LOSS:0.114---time:13.12
# Epoch:19---batch(25)训练集---ACC:90.62%---LOSS:0.345---time:14.01
# Epoch:19---batch(26)训练集---ACC:93.75%---LOSS:0.226---time:12.96
# Epoch:19---batch(27)训练集---ACC:100.00%---LOSS:0.104---time:13.69
# Epoch:19---batch(28)训练集---ACC:96.88%---LOSS:0.088---time:15.29
# Epoch:19---batch(29)训练集---ACC:90.62%---LOSS:0.351---time:16.19
# Epoch:19---batch(30)训练集---ACC:100.00%---LOSS:0.060---time:16.15
# Epoch:19---batch(31)训练集---ACC:87.50%---LOSS:0.263---time:14.38
# Epoch:19---batch(32)训练集---ACC:93.75%---LOSS:0.145---time:15.10
# Epoch:19---batch(33)训练集---ACC:93.75%---LOSS:0.149---time:12.32
# Epoch:19---batch(34)训练集---ACC:90.62%---LOSS:0.298---time:12.16
# Epoch:19---batch(35)训练集---ACC:93.75%---LOSS:0.170---time:12.53
# Epoch:19---batch(36)训练集---ACC:90.62%---LOSS:0.217---time:12.19
# Epoch:19---batch(37)训练集---ACC:75.00%---LOSS:0.372---time:6.14
# 第19轮测试集准确率：80.00%....测试集Loss:0.8456187333379473

# %% [markdown]
# 3小时跑完
